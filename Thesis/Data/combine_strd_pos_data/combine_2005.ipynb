# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
csv_list=[]
for i in range(2005,2006):
    filename="../PlayerData/"+str(i)+"/posession"
    filename2=[]
    for elem in os.listdir(filename):
        filename2.append(filename+'/'+elem)
    csv_list.append(os.listdir(filename))
    print os.listdir(filename)
# Out:
# ['abdelju01_pos_.csv', 'aiellan01_pos_.csv', 'anikevi01_pos_.csv', 'aquinlu01_pos_.csv', 'aubinma01_pos_.csv', 'baileja01_pos_.csv', 'baileky01_pos_.csv', 'baldwgo01_pos_.csv', 'barnejo01_pos_.csv', 'bartama01_pos_.csv', 'bartuos01_pos_.csv', 'bassco01_pos_.csv', 'bearsza01_pos_.csv', 'beauljo01_pos_.csv', 'beechke01_pos_.csv', 'bellegr01_pos_.csv', 'bergfni01_pos_.csv', 'berryal01_pos_.csv', 'bertrda01_pos_.csv', 'bishobe01_pos_.csv', 'blancni01_pos_.csv', 'bliznma01_pos_.csv', 'blundmi01_pos_.csv', 'bollja01_pos_.csv', 'boltbo01_pos_.csv', 'bourdlu01_pos_.csv', 'bourral01_pos_.csv', 'bradfbr01_pos_.csv', 'brophev01_pos_.csv', 'brosnpa01_pos_.csv', 'brulegi01_pos_.csv', 'buravvy01_pos_.csv', 'butchma01_pos_.csv', 'butlech01_pos_.csv', 'charljo01_pos_.csv', 'chornta01_pos_.csv', 'clackma01_pos_.csv', 'clichma01_pos_.csv', 'cluneri01_pos_.csv', 'coglian01_pos_.csv', 'colbewi01_pos_.csv', 'collida01_pos_.csv', 'crosbsi01_pos_.csv', 'crowdti01_pos_.csv', 'cumisky01_pos_.csv', 'dagosma01
# ...

# %%
listcsv=csv_list[0]

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"=pd.read_csv(../PlayerData/2005/posession/"+elem+",index_col=0)"
# Out:
# df_abdelju01_pos=pd.read_csv(../PlayerData/2005/posession/abdelju01_pos_.csv,index_col=0)
# df_aiellan01_pos=pd.read_csv(../PlayerData/2005/posession/aiellan01_pos_.csv,index_col=0)
# df_anikevi01_pos=pd.read_csv(../PlayerData/2005/posession/anikevi01_pos_.csv,index_col=0)
# df_aquinlu01_pos=pd.read_csv(../PlayerData/2005/posession/aquinlu01_pos_.csv,index_col=0)
# df_aubinma01_pos=pd.read_csv(../PlayerData/2005/posession/aubinma01_pos_.csv,index_col=0)
# df_baileja01_pos=pd.read_csv(../PlayerData/2005/posession/baileja01_pos_.csv,index_col=0)
# df_baileky01_pos=pd.read_csv(../PlayerData/2005/posession/baileky01_pos_.csv,index_col=0)
# df_baldwgo01_pos=pd.read_csv(../PlayerData/2005/posession/baldwgo01_pos_.csv,index_col=0)
# df_barnejo01_pos=pd.read_csv(../PlayerData/2005/posession/barnejo01_pos_.csv,index_col=0)
# df_bartama01_pos=pd.read_csv(../PlayerData/2005/posession/bartama01_pos_.csv,index_col=0)
# ...

# %%
df_abdelju01_pos=pd.read_csv('../PlayerData/2005/posession/abdelju01_pos_.csv',index_col=0)
df_aiellan01_pos=pd.read_csv('../PlayerData/2005/posession/aiellan01_pos_.csv',index_col=0)
df_anikevi01_pos=pd.read_csv('../PlayerData/2005/posession/anikevi01_pos_.csv',index_col=0)
df_aquinlu01_pos=pd.read_csv('../PlayerData/2005/posession/aquinlu01_pos_.csv',index_col=0)
df_aubinma01_pos=pd.read_csv('../PlayerData/2005/posession/aubinma01_pos_.csv',index_col=0)
df_baileja01_pos=pd.read_csv('../PlayerData/2005/posession/baileja01_pos_.csv',index_col=0)
df_baileky01_pos=pd.read_csv('../PlayerData/2005/posession/baileky01_pos_.csv',index_col=0)
df_baldwgo01_pos=pd.read_csv('../PlayerData/2005/posession/baldwgo01_pos_.csv',index_col=0)
df_barnejo01_pos=pd.read_csv('../PlayerData/2005/posession/barnejo01_pos_.csv',index_col=0)
df_bartama01_pos=pd.read_csv('../PlayerData/2005/posession/bartama01_pos_.csv',index_col=0)
df_bartuos01_pos=pd.read_csv('../PlayerData/2005/posession/bartuos01_pos_.csv',index_col=0)
df_bassco01_pos=pd.read_csv('../PlayerData/2005/posession/bassco01_pos_.csv',index_col=0)
df_bearsza01_pos=pd.read_csv('../PlayerData/2005/posession/bearsza01_pos_.csv',index_col=0)
df_beauljo01_pos=pd.read_csv('../PlayerData/2005/posession/beauljo01_pos_.csv',index_col=0)
df_beechke01_pos=pd.read_csv('../PlayerData/2005/posession/beechke01_pos_.csv',index_col=0)
df_bellegr01_pos=pd.read_csv('../PlayerData/2005/posession/bellegr01_pos_.csv',index_col=0)
df_bergfni01_pos=pd.read_csv('../PlayerData/2005/posession/bergfni01_pos_.csv',index_col=0)
df_berryal01_pos=pd.read_csv('../PlayerData/2005/posession/berryal01_pos_.csv',index_col=0)
df_bertrda01_pos=pd.read_csv('../PlayerData/2005/posession/bertrda01_pos_.csv',index_col=0)
df_bishobe01_pos=pd.read_csv('../PlayerData/2005/posession/bishobe01_pos_.csv',index_col=0)
df_blancni01_pos=pd.read_csv('../PlayerData/2005/posession/blancni01_pos_.csv',index_col=0)
df_bliznma01_pos=pd.read_csv('../PlayerData/2005/posession/bliznma01_pos_.csv',index_col=0)
df_blundmi01_pos=pd.read_csv('../PlayerData/2005/posession/blundmi01_pos_.csv',index_col=0)
df_bollja01_pos=pd.read_csv('../PlayerData/2005/posession/bollja01_pos_.csv',index_col=0)
df_boltbo01_pos=pd.read_csv('../PlayerData/2005/posession/boltbo01_pos_.csv',index_col=0)
df_bourdlu01_pos=pd.read_csv('../PlayerData/2005/posession/bourdlu01_pos_.csv',index_col=0)
df_bourral01_pos=pd.read_csv('../PlayerData/2005/posession/bourral01_pos_.csv',index_col=0)
df_bradfbr01_pos=pd.read_csv('../PlayerData/2005/posession/bradfbr01_pos_.csv',index_col=0)
df_brophev01_pos=pd.read_csv('../PlayerData/2005/posession/brophev01_pos_.csv',index_col=0)
df_brosnpa01_pos=pd.read_csv('../PlayerData/2005/posession/brosnpa01_pos_.csv',index_col=0)
df_brulegi01_pos=pd.read_csv('../PlayerData/2005/posession/brulegi01_pos_.csv',index_col=0)
df_buravvy01_pos=pd.read_csv('../PlayerData/2005/posession/buravvy01_pos_.csv',index_col=0)
df_butchma01_pos=pd.read_csv('../PlayerData/2005/posession/butchma01_pos_.csv',index_col=0)
df_butlech01_pos=pd.read_csv('../PlayerData/2005/posession/butlech01_pos_.csv',index_col=0)
df_charljo01_pos=pd.read_csv('../PlayerData/2005/posession/charljo01_pos_.csv',index_col=0)
df_chornta01_pos=pd.read_csv('../PlayerData/2005/posession/chornta01_pos_.csv',index_col=0)
df_clackma01_pos=pd.read_csv('../PlayerData/2005/posession/clackma01_pos_.csv',index_col=0)
df_clichma01_pos=pd.read_csv('../PlayerData/2005/posession/clichma01_pos_.csv',index_col=0)
df_cluneri01_pos=pd.read_csv('../PlayerData/2005/posession/cluneri01_pos_.csv',index_col=0)
df_coglian01_pos=pd.read_csv('../PlayerData/2005/posession/coglian01_pos_.csv',index_col=0)
df_colbewi01_pos=pd.read_csv('../PlayerData/2005/posession/colbewi01_pos_.csv',index_col=0)
df_collida01_pos=pd.read_csv('../PlayerData/2005/posession/collida01_pos_.csv',index_col=0)
df_crosbsi01_pos=pd.read_csv('../PlayerData/2005/posession/crosbsi01_pos_.csv',index_col=0)
df_crowdti01_pos=pd.read_csv('../PlayerData/2005/posession/crowdti01_pos_.csv',index_col=0)
df_cumisky01_pos=pd.read_csv('../PlayerData/2005/posession/cumisky01_pos_.csv',index_col=0)
df_dagosma01_pos=pd.read_csv('../PlayerData/2005/posession/dagosma01_pos_.csv',index_col=0)
df_dahlbjo01_pos=pd.read_csv('../PlayerData/2005/posession/dahlbjo01_pos_.csv',index_col=0)
df_dakerta01_pos=pd.read_csv('../PlayerData/2005/posession/dakerta01_pos_.csv',index_col=0)
df_davisna01_pos=pd.read_csv('../PlayerData/2005/posession/davisna01_pos_.csv',index_col=0)
df_davispa01_pos=pd.read_csv('../PlayerData/2005/posession/davispa01_pos_.csv',index_col=0)
df_deero01_pos=pd.read_csv('../PlayerData/2005/posession/deero01_pos_.csv',index_col=0)
df_denniad01_pos=pd.read_csv('../PlayerData/2005/posession/denniad01_pos_.csv',index_col=0)
df_dennych01_pos=pd.read_csv('../PlayerData/2005/posession/dennych01_pos_.csv',index_col=0)
df_derlyro01_pos=pd.read_csv('../PlayerData/2005/posession/derlyro01_pos_.csv',index_col=0)
df_dovgavi01_pos=pd.read_csv('../PlayerData/2005/posession/dovgavi01_pos_.csv',index_col=0)
df_downist01_pos=pd.read_csv('../PlayerData/2005/posession/downist01_pos_.csv',index_col=0)
df_drazeni01_pos=pd.read_csv('../PlayerData/2005/posession/drazeni01_pos_.csv',index_col=0)
df_ducheje01_pos=pd.read_csv('../PlayerData/2005/posession/ducheje01_pos_.csv',index_col=0)
df_duffyma01_pos=pd.read_csv('../PlayerData/2005/posession/duffyma01_pos_.csv',index_col=0)
df_duponbr01_pos=pd.read_csv('../PlayerData/2005/posession/duponbr01_pos_.csv',index_col=0)
df_duranch01_pos=pd.read_csv('../PlayerData/2005/posession/duranch01_pos_.csv',index_col=0)
df_emmerri01_pos=pd.read_csv('../PlayerData/2005/posession/emmerri01_pos_.csv',index_col=0)
df_fallojo01_pos=pd.read_csv('../PlayerData/2005/posession/fallojo01_pos_.csv',index_col=0)
#df_fastt.01_pos=pd.read_csv('../PlayerData/2005/posession/fastt.01_pos_.csv',index_col=0)
df_faynema01_pos=pd.read_csv('../PlayerData/2005/posession/faynema01_pos_.csv',index_col=0)
#df_fentop.01_pos=pd.read_csv('../PlayerData/2005/posession/fentop.01_pos_.csv',index_col=0)
df_finlejo01_pos=pd.read_csv('../PlayerData/2005/posession/finlejo01_pos_.csv',index_col=0)
df_flattda01_pos=pd.read_csv('../PlayerData/2005/posession/flattda01_pos_.csv',index_col=0)
df_flattjo01_pos=pd.read_csv('../PlayerData/2005/posession/flattjo01_pos_.csv',index_col=0)
df_fostebr01_pos=pd.read_csv('../PlayerData/2005/posession/fostebr01_pos_.csv',index_col=0)
df_fransco01_pos=pd.read_csv('../PlayerData/2005/posession/fransco01_pos_.csv',index_col=0)
df_frasema01_pos=pd.read_csv('../PlayerData/2005/posession/frasema01_pos_.csv',index_col=0)
df_frazeje01_pos=pd.read_csv('../PlayerData/2005/posession/frazeje01_pos_.csv',index_col=0)
df_fredhkr01_pos=pd.read_csv('../PlayerData/2005/posession/fredhkr01_pos_.csv',index_col=0)
df_fritsto01_pos=pd.read_csv('../PlayerData/2005/posession/fritsto01_pos_.csv',index_col=0)
df_gauthmi01_pos=pd.read_csv('../PlayerData/2005/posession/gauthmi01_pos_.csv',index_col=0)
df_generma01_pos=pd.read_csv('../PlayerData/2005/posession/generma01_pos_.csv',index_col=0)
df_gerbena01_pos=pd.read_csv('../PlayerData/2005/posession/gerbena01_pos_.csv',index_col=0)
df_gergemi01_pos=pd.read_csv('../PlayerData/2005/posession/gergemi01_pos_.csv',index_col=0)
df_glassma01_pos=pd.read_csv('../PlayerData/2005/posession/glassma01_pos_.csv',index_col=0)
df_gogulph01_pos=pd.read_csv('../PlayerData/2005/posession/gogulph01_pos_.csv',index_col=0)
df_gragnma01_pos=pd.read_csv('../PlayerData/2005/posession/gragnma01_pos_.csv',index_col=0)
df_greenco01_pos=pd.read_csv('../PlayerData/2005/posession/greenco01_pos_.csv',index_col=0)
df_guthrsh01_pos=pd.read_csv('../PlayerData/2005/posession/guthrsh01_pos_.csv',index_col=0)
df_hagemna01_pos=pd.read_csv('../PlayerData/2005/posession/hagemna01_pos_.csv',index_col=0)
df_hanzama01_pos=pd.read_csv('../PlayerData/2005/posession/hanzama01_pos_.csv',index_col=0)
df_helmda01_pos=pd.read_csv('../PlayerData/2005/posession/helmda01_pos_.csv',index_col=0)
df_hendrtr01_pos=pd.read_csv('../PlayerData/2005/posession/hendrtr01_pos_.csv',index_col=0)
df_hensitj01_pos=pd.read_csv('../PlayerData/2005/posession/hensitj01_pos_.csv',index_col=0)
df_herslpa01_pos=pd.read_csv('../PlayerData/2005/posession/herslpa01_pos_.csv',index_col=0)
df_hjalmni01_pos=pd.read_csv('../PlayerData/2005/posession/hjalmni01_pos_.csv',index_col=0)
df_hobsoad01_pos=pd.read_csv('../PlayerData/2005/posession/hobsoad01_pos_.csv',index_col=0)
df_hornqpa01_pos=pd.read_csv('../PlayerData/2005/posession/hornqpa01_pos_.csv',index_col=0)
df_istomde01_pos=pd.read_csv('../PlayerData/2005/posession/istomde01_pos_.csv',index_col=0)
df_jackssc01_pos=pd.read_csv('../PlayerData/2005/posession/jackssc01_pos_.csv',index_col=0)
df_johnsja02_pos=pd.read_csv('../PlayerData/2005/posession/johnsja02_pos_.csv',index_col=0)
df_jonesbl01_pos=pd.read_csv('../PlayerData/2005/posession/jonesbl01_pos_.csv',index_col=0)
df_joslide01_pos=pd.read_csv('../PlayerData/2005/posession/joslide01_pos_.csv',index_col=0)
df_kaluspe01_pos=pd.read_csv('../PlayerData/2005/posession/kaluspe01_pos_.csv',index_col=0)
df_kassima01_pos=pd.read_csv('../PlayerData/2005/posession/kassima01_pos_.csv',index_col=0)
df_keetlma01_pos=pd.read_csv('../PlayerData/2005/posession/keetlma01_pos_.csv',index_col=0)
df_kenneti01_pos=pd.read_csv('../PlayerData/2005/posession/kenneti01_pos_.csv',index_col=0)
df_kindlja01_pos=pd.read_csv('../PlayerData/2005/posession/kindlja01_pos_.csv',index_col=0)
df_kohndu01_pos=pd.read_csv('../PlayerData/2005/posession/kohndu01_pos_.csv',index_col=0)
df_kolehja01_pos=pd.read_csv('../PlayerData/2005/posession/kolehja01_pos_.csv',index_col=0)
df_kopitan01_pos=pd.read_csv('../PlayerData/2005/posession/kopitan01_pos_.csv',index_col=0)
df_korhori01_pos=pd.read_csv('../PlayerData/2005/posession/korhori01_pos_.csv',index_col=0)
df_kostise01_pos=pd.read_csv('../PlayerData/2005/posession/kostise01_pos_.csv',index_col=0)
df_kovertr01_pos=pd.read_csv('../PlayerData/2005/posession/kovertr01_pos_.csv',index_col=0)
df_kozekan01_pos=pd.read_csv('../PlayerData/2005/posession/kozekan01_pos_.csv',index_col=0)
df_krysaan01_pos=pd.read_csv('../PlayerData/2005/posession/krysaan01_pos_.csv',index_col=0)
df_kucheda01_pos=pd.read_csv('../PlayerData/2005/posession/kucheda01_pos_.csv',index_col=0)
df_kudelto01_pos=pd.read_csv('../PlayerData/2005/posession/kudelto01_pos_.csv',index_col=0)
df_kunesti01_pos=pd.read_csv('../PlayerData/2005/posession/kunesti01_pos_.csv',index_col=0)
df_kvapima01_pos=pd.read_csv('../PlayerData/2005/posession/kvapima01_pos_.csv',index_col=0)
df_laakste01_pos=pd.read_csv('../PlayerData/2005/posession/laakste01_pos_.csv',index_col=0)
df_lalanke01_pos=pd.read_csv('../PlayerData/2005/posession/lalanke01_pos_.csv',index_col=0)
df_lascest01_pos=pd.read_csv('../PlayerData/2005/posession/lascest01_pos_.csv',index_col=0)
df_lashoma01_pos=pd.read_csv('../PlayerData/2005/posession/lashoma01_pos_.csv',index_col=0)
df_latengu01_pos=pd.read_csv('../PlayerData/2005/posession/latengu01_pos_.csv',index_col=0)
df_lavaljo01_pos=pd.read_csv('../PlayerData/2005/posession/lavaljo01_pos_.csv',index_col=0)
df_lawrech01_pos=pd.read_csv('../PlayerData/2005/posession/lawrech01_pos_.csv',index_col=0)
df_lawsoky01_pos=pd.read_csv('../PlayerData/2005/posession/lawsoky01_pos_.csv',index_col=0)
df_leebr01_pos=pd.read_csv('../PlayerData/2005/posession/leebr01_pos_.csv',index_col=0)
df_legauol01_pos=pd.read_csv('../PlayerData/2005/posession/legauol01_pos_.csv',index_col=0)
df_lehtomi02_pos=pd.read_csv('../PlayerData/2005/posession/lehtomi02_pos_.csv',index_col=0)
df_leinoto01_pos=pd.read_csv('../PlayerData/2005/posession/leinoto01_pos_.csv',index_col=0)
df_lemtyni01_pos=pd.read_csv('../PlayerData/2005/posession/lemtyni01_pos_.csv',index_col=0)
df_letankr01_pos=pd.read_csv('../PlayerData/2005/posession/letankr01_pos_.csv',index_col=0)
df_levasje02_pos=pd.read_csv('../PlayerData/2005/posession/levasje02_pos_.csv',index_col=0)
df_lindgpe01_pos=pd.read_csv('../PlayerData/2005/posession/lindgpe01_pos_.csv',index_col=0)
df_lofbech01_pos=pd.read_csv('../PlayerData/2005/posession/lofbech01_pos_.csv',index_col=0)
df_luciato01_pos=pd.read_csv('../PlayerData/2005/posession/luciato01_pos_.csv',index_col=0)
df_lynchja02_pos=pd.read_csv('../PlayerData/2005/posession/lynchja02_pos_.csv',index_col=0)
df_macheda01_pos=pd.read_csv('../PlayerData/2005/posession/macheda01_pos_.csv',index_col=0)
df_maciara01_pos=pd.read_csv('../PlayerData/2005/posession/maciara01_pos_.csv',index_col=0)
df_madsemo01_pos=pd.read_csv('../PlayerData/2005/posession/madsemo01_pos_.csv',index_col=0)
df_makiry01_pos=pd.read_csv('../PlayerData/2005/posession/makiry01_pos_.csv',index_col=0)
df_marjama01_pos=pd.read_csv('../PlayerData/2005/posession/marjama01_pos_.csv',index_col=0)
df_masonty01_pos=pd.read_csv('../PlayerData/2005/posession/masonty01_pos_.csv',index_col=0)
df_mayje01_pos=pd.read_csv('../PlayerData/2005/posession/mayje01_pos_.csv',index_col=0)
df_mcardke01_pos=pd.read_csv('../PlayerData/2005/posession/mcardke01_pos_.csv',index_col=0)
df_mcganpa01_pos=pd.read_csv('../PlayerData/2005/posession/mcganpa01_pos_.csv',index_col=0)
df_mcginry01_pos=pd.read_csv('../PlayerData/2005/posession/mcginry01_pos_.csv',index_col=0)
df_mcneipa01_pos=pd.read_csv('../PlayerData/2005/posession/mcneipa01_pos_.csv',index_col=0)
df_mcquaad01_pos=pd.read_csv('../PlayerData/2005/posession/mcquaad01_pos_.csv',index_col=0)
df_megaldm01_pos=pd.read_csv('../PlayerData/2005/posession/megaldm01_pos_.csv',index_col=0)
df_merciju01_pos=pd.read_csv('../PlayerData/2005/posession/merciju01_pos_.csv',index_col=0)
df_meyerjo01_pos=pd.read_csv('../PlayerData/2005/posession/meyerjo01_pos_.csv',index_col=0)
df_mieloju01_pos=pd.read_csv('../PlayerData/2005/posession/mieloju01_pos_.csv',index_col=0)
df_mihalvl01_pos=pd.read_csv('../PlayerData/2005/posession/mihalvl01_pos_.csv',index_col=0)
df_mikkebr01_pos=pd.read_csv('../PlayerData/2005/posession/mikkebr01_pos_.csv',index_col=0)
df_mikusju01_pos=pd.read_csv('../PlayerData/2005/posession/mikusju01_pos_.csv',index_col=0)
df_nealja01_pos=pd.read_csv('../PlayerData/2005/posession/nealja01_pos_.csv',index_col=0)
df_niskama01_pos=pd.read_csv('../PlayerData/2005/posession/niskama01_pos_.csv',index_col=0)
df_omarrry01_pos=pd.read_csv('../PlayerData/2005/posession/omarrry01_pos_.csv',index_col=0)
df_oreilca01_pos=pd.read_csv('../PlayerData/2005/posession/oreilca01_pos_.csv',index_col=0)
df_oreskph01_pos=pd.read_csv('../PlayerData/2005/posession/oreskph01_pos_.csv',index_col=0)
df_orpikan01_pos=pd.read_csv('../PlayerData/2005/posession/orpikan01_pos_.csv',index_col=0)
df_oshietj01_pos=pd.read_csv('../PlayerData/2005/posession/oshietj01_pos_.csv',index_col=0)
df_otcenon01_pos=pd.read_csv('../PlayerData/2005/posession/otcenon01_pos_.csv',index_col=0)
df_paqueje01_pos=pd.read_csv('../PlayerData/2005/posession/paqueje01_pos_.csv',index_col=0)
df_paqueph01_pos=pd.read_csv('../PlayerData/2005/posession/paqueph01_pos_.csv',index_col=0)
df_parenry01_pos=pd.read_csv('../PlayerData/2005/posession/parenry01_pos_.csv',index_col=0)
df_pavelon01_pos=pd.read_csv('../PlayerData/2005/posession/pavelon01_pos_.csv',index_col=0)
df_pelecma01_pos=pd.read_csv('../PlayerData/2005/posession/pelecma01_pos_.csv',index_col=0)
df_pellepi01_pos=pd.read_csv('../PlayerData/2005/posession/pellepi01_pos_.csv',index_col=0)
df_pettefr01_pos=pd.read_csv('../PlayerData/2005/posession/pettefr01_pos_.csv',index_col=0)
df_plantty01_pos=pd.read_csv('../PlayerData/2005/posession/plantty01_pos_.csv',index_col=0)
df_pokulsa01_pos=pd.read_csv('../PlayerData/2005/posession/pokulsa01_pos_.csv',index_col=0)
df_poppeto01_pos=pd.read_csv('../PlayerData/2005/posession/poppeto01_pos_.csv',index_col=0)
df_pospito01_pos=pd.read_csv('../PlayerData/2005/posession/pospito01_pos_.csv',index_col=0)
df_poulibe01_pos=pd.read_csv('../PlayerData/2005/posession/poulibe01_pos_.csv',index_col=0)
df_priceca01_pos=pd.read_csv('../PlayerData/2005/posession/priceca01_pos_.csv',index_col=0)
df_pyattto01_pos=pd.read_csv('../PlayerData/2005/posession/pyattto01_pos_.csv',index_col=0)
df_quickjo01_pos=pd.read_csv('../PlayerData/2005/posession/quickjo01_pos_.csv',index_col=0)
df_rabbiwa01_pos=pd.read_csv('../PlayerData/2005/posession/rabbiwa01_pos_.csv',index_col=0)
df_rasktu01_pos=pd.read_csv('../PlayerData/2005/posession/rasktu01_pos_.csv',index_col=0)
df_rauch01_pos=pd.read_csv('../PlayerData/2005/posession/rauch01_pos_.csv',index_col=0)
df_raymoma01_pos=pd.read_csv('../PlayerData/2005/posession/raymoma01_pos_.csv',index_col=0)
df_reavery01_pos=pd.read_csv('../PlayerData/2005/posession/reavery01_pos_.csv',index_col=0)
df_reinhde01_pos=pd.read_csv('../PlayerData/2005/posession/reinhde01_pos_.csv',index_col=0)
df_ritolma01_pos=pd.read_csv('../PlayerData/2005/posession/ritolma01_pos_.csv',index_col=0)
df_roussda01_pos=pd.read_csv('../PlayerData/2005/posession/roussda01_pos_.csv',index_col=0)
df_rumsemy01_pos=pd.read_csv('../PlayerData/2005/posession/rumsemy01_pos_.csv',index_col=0)
df_russekr01_pos=pd.read_csv('../PlayerData/2005/posession/russekr01_pos_.csv',index_col=0)
df_russery01_pos=pd.read_csv('../PlayerData/2005/posession/russery01_pos_.csv',index_col=0)
df_ryanbo01_pos=pd.read_csv('../PlayerData/2005/posession/ryanbo01_pos_.csv',index_col=0)
df_ryderda01_pos=pd.read_csv('../PlayerData/2005/posession/ryderda01_pos_.csv',index_col=0)
df_rynojo01_pos=pd.read_csv('../PlayerData/2005/posession/rynojo01_pos_.csv',index_col=0)
df_salcibr01_pos=pd.read_csv('../PlayerData/2005/posession/salcibr01_pos_.csv',index_col=0)
df_sauermi01_pos=pd.read_csv('../PlayerData/2005/posession/sauermi01_pos_.csv',index_col=0)
df_setogde01_pos=pd.read_csv('../PlayerData/2005/posession/setogde01_pos_.csv',index_col=0)
df_seymojo01_pos=pd.read_csv('../PlayerData/2005/posession/seymojo01_pos_.csv',index_col=0)
df_sigaljo02_pos=pd.read_csv('../PlayerData/2005/posession/sigaljo02_pos_.csv',index_col=0)
df_skillja01_pos=pd.read_csv('../PlayerData/2005/posession/skillja01_pos_.csv',index_col=0)
df_smolera01_pos=pd.read_csv('../PlayerData/2005/posession/smolera01_pos_.csv',index_col=0)
df_sobotvl01_pos=pd.read_csv('../PlayerData/2005/posession/sobotvl01_pos_.csv',index_col=0)
df_staalma01_pos=pd.read_csv('../PlayerData/2005/posession/staalma01_pos_.csv',index_col=0)
df_staloal01_pos=pd.read_csv('../PlayerData/2005/posession/staloal01_pos_.csv',index_col=0)
df_stamlbr01_pos=pd.read_csv('../PlayerData/2005/posession/stamlbr01_pos_.csv',index_col=0)
df_starkki01_pos=pd.read_csv('../PlayerData/2005/posession/starkki01_pos_.csv',index_col=0)
df_stastpa01_pos=pd.read_csv('../PlayerData/2005/posession/stastpa01_pos_.csv',index_col=0)
df_stoary01_pos=pd.read_csv('../PlayerData/2005/posession/stoary01_pos_.csv',index_col=0)
df_stoesmy01_pos=pd.read_csv('../PlayerData/2005/posession/stoesmy01_pos_.csv',index_col=0)
df_stralan01_pos=pd.read_csv('../PlayerData/2005/posession/stralan01_pos_.csv',index_col=0)
df_sundsal01_pos=pd.read_csv('../PlayerData/2005/posession/sundsal01_pos_.csv',index_col=0)
df_suttebr04_pos=pd.read_csv('../PlayerData/2005/posession/suttebr04_pos_.csv',index_col=0)
df_syvreda01_pos=pd.read_csv('../PlayerData/2005/posession/syvreda01_pos_.csv',index_col=0)
df_thomaan01_pos=pd.read_csv('../PlayerData/2005/posession/thomaan01_pos_.csv',index_col=0)
df_toddsc01_pos=pd.read_csv('../PlayerData/2005/posession/toddsc01_pos_.csv',index_col=0)
df_trukhvi01_pos=pd.read_csv('../PlayerData/2005/posession/trukhvi01_pos_.csv',index_col=0)
df_turnebr02_pos=pd.read_csv('../PlayerData/2005/posession/turnebr02_pos_.csv',index_col=0)
df_tuzzoni01_pos=pd.read_csv('../PlayerData/2005/posession/tuzzoni01_pos_.csv',index_col=0)
df_vandech01_pos=pd.read_csv('../PlayerData/2005/posession/vandech01_pos_.csv',index_col=0)
df_vantulu01_pos=pd.read_csv('../PlayerData/2005/posession/vantulu01_pos_.csv',index_col=0)
df_vinceal01_pos=pd.read_csv('../PlayerData/2005/posession/vinceal01_pos_.csv',index_col=0)
df_vitaljo01_pos=pd.read_csv('../PlayerData/2005/posession/vitaljo01_pos_.csv',index_col=0)
df_vlasima01_pos=pd.read_csv('../PlayerData/2005/posession/vlasima01_pos_.csv',index_col=0)
df_vojtaja01_pos=pd.read_csv('../PlayerData/2005/posession/vojtaja01_pos_.csv',index_col=0)
df_wandeto01_pos=pd.read_csv('../PlayerData/2005/posession/wandeto01_pos_.csv',index_col=0)
df_watkima01_pos=pd.read_csv('../PlayerData/2005/posession/watkima01_pos_.csv',index_col=0)
#df_wattj.01_pos=pd.read_csv('../PlayerData/2005/posession/wattj.01_pos_.csv',index_col=0)
df_wessbjo01_pos=pd.read_csv('../PlayerData/2005/posession/wessbjo01_pos_.csv',index_col=0)
df_westbkr01_pos=pd.read_csv('../PlayerData/2005/posession/westbkr01_pos_.csv',index_col=0)
df_yandlke01_pos=pd.read_csv('../PlayerData/2005/posession/yandlke01_pos_.csv',index_col=0)
df_zagrama01_pos=pd.read_csv('../PlayerData/2005/posession/zagrama01_pos_.csv',index_col=0)
df_zimmese01_pos=pd.read_csv('../PlayerData/2005/posession/zimmese01_pos_.csv',index_col=0)
df_zubaran01_pos=pd.read_csv('../PlayerData/2005/posession/zubaran01_pos_.csv',index_col=0)
df_zubovil01_pos=pd.read_csv('../PlayerData/2005/posession/zubovil01_pos_.csv',index_col=0)

# %%
#df_adamscr01_pos['name']='adamscr01'

# %%
#listcsv

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"[name]="+elem[:-9]
# Out:
# df_abdelju01_pos[name]=abdelju01
# df_aiellan01_pos[name]=aiellan01
# df_anikevi01_pos[name]=anikevi01
# df_aquinlu01_pos[name]=aquinlu01
# df_aubinma01_pos[name]=aubinma01
# df_baileja01_pos[name]=baileja01
# df_baileky01_pos[name]=baileky01
# df_baldwgo01_pos[name]=baldwgo01
# df_barnejo01_pos[name]=barnejo01
# df_bartama01_pos[name]=bartama01
# df_bartuos01_pos[name]=bartuos01
# df_bassco01_pos[name]=bassco01
# df_bearsza01_pos[name]=bearsza01
# df_beauljo01_pos[name]=beauljo01
# df_beechke01_pos[name]=beechke01
# df_bellegr01_pos[name]=bellegr01
# df_bergfni01_pos[name]=bergfni01
# df_berryal01_pos[name]=berryal01
# df_bertrda01_pos[name]=bertrda01
# df_bishobe01_pos[name]=bishobe01
# df_blancni01_pos[name]=blancni01
# df_bliznma01_pos[name]=bliznma01
# df_blundmi01_pos[name]=blundmi01
# df_bollja01_pos[name]=bollja01
# df_boltbo01_pos[name]=boltbo01
# df_bourdlu01_pos[name]=bourdlu01
# df_bourral01_pos[name]=bourral01
# df_bradfbr01_pos[name]=bradfbr01
# ...

# %%
df_abdelju01_pos['name']='abdelju01'
df_aiellan01_pos['name']='aiellan01'
df_anikevi01_pos['name']='anikevi01'
df_aquinlu01_pos['name']='aquinlu01'
df_aubinma01_pos['name']='aubinma01'
df_baileja01_pos['name']='baileja01'
df_baileky01_pos['name']='baileky01'
df_baldwgo01_pos['name']='baldwgo01'
df_barnejo01_pos['name']='barnejo01'
df_bartama01_pos['name']='bartama01'
df_bartuos01_pos['name']='bartuos01'
df_bassco01_pos['name']='bassco01'
df_bearsza01_pos['name']='bearsza01'
df_beauljo01_pos['name']='beauljo01'
df_beechke01_pos['name']='beechke01'
df_bellegr01_pos['name']='bellegr01'
df_bergfni01_pos['name']='bergfni01'
df_berryal01_pos['name']='berryal01'
df_bertrda01_pos['name']='bertrda01'
df_bishobe01_pos['name']='bishobe01'
df_blancni01_pos['name']='blancni01'
df_bliznma01_pos['name']='bliznma01'
df_blundmi01_pos['name']='blundmi01'
df_bollja01_pos['name']='bollja01'
df_boltbo01_pos['name']='boltbo01'
df_bourdlu01_pos['name']='bourdlu01'
df_bourral01_pos['name']='bourral01'
df_bradfbr01_pos['name']='bradfbr01'
df_brophev01_pos['name']='brophev01'
df_brosnpa01_pos['name']='brosnpa01'
df_brulegi01_pos['name']='brulegi01'
df_buravvy01_pos['name']='buravvy01'
df_butchma01_pos['name']='butchma01'
df_butlech01_pos['name']='butlech01'
df_charljo01_pos['name']='charljo01'
df_chornta01_pos['name']='chornta01'
df_clackma01_pos['name']='clackma01'
df_clichma01_pos['name']='clichma01'
df_cluneri01_pos['name']='cluneri01'
df_coglian01_pos['name']='coglian01'
df_colbewi01_pos['name']='colbewi01'
df_collida01_pos['name']='collida01'
df_crosbsi01_pos['name']='crosbsi01'
df_crowdti01_pos['name']='crowdti01'
df_cumisky01_pos['name']='cumisky01'
df_dagosma01_pos['name']='dagosma01'
df_dahlbjo01_pos['name']='dahlbjo01'
df_dakerta01_pos['name']='dakerta01'
df_davisna01_pos['name']='davisna01'
df_davispa01_pos['name']='davispa01'
df_deero01_pos['name']='deero01'
df_denniad01_pos['name']='denniad01'
df_dennych01_pos['name']='dennych01'
df_derlyro01_pos['name']='derlyro01'
df_dovgavi01_pos['name']='dovgavi01'
df_downist01_pos['name']='downist01'
df_drazeni01_pos['name']='drazeni01'
df_ducheje01_pos['name']='ducheje01'
df_duffyma01_pos['name']='duffyma01'
df_duponbr01_pos['name']='duponbr01'
df_duranch01_pos['name']='duranch01'
df_emmerri01_pos['name']='emmerri01'
df_fallojo01_pos['name']='fallojo01'
#df_fastt.01_pos['name']='fastt.01'
df_faynema01_pos['name']='faynema01'
#df_fentop.01_pos['name']='fentop.01'
df_finlejo01_pos['name']='finlejo01'
df_flattda01_pos['name']='flattda01'
df_flattjo01_pos['name']='flattjo01'
df_fostebr01_pos['name']='fostebr01'
df_fransco01_pos['name']='fransco01'
df_frasema01_pos['name']='frasema01'
df_frazeje01_pos['name']='frazeje01'
df_fredhkr01_pos['name']='fredhkr01'
df_fritsto01_pos['name']='fritsto01'
df_gauthmi01_pos['name']='gauthmi01'
df_generma01_pos['name']='generma01'
df_gerbena01_pos['name']='gerbena01'
df_gergemi01_pos['name']='gergemi01'
df_glassma01_pos['name']='glassma01'
df_gogulph01_pos['name']='gogulph01'
df_gragnma01_pos['name']='gragnma01'
df_greenco01_pos['name']='greenco01'
df_guthrsh01_pos['name']='guthrsh01'
df_hagemna01_pos['name']='hagemna01'
df_hanzama01_pos['name']='hanzama01'
df_helmda01_pos['name']='helmda01'
df_hendrtr01_pos['name']='hendrtr01'
df_hensitj01_pos['name']='hensitj01'
df_herslpa01_pos['name']='herslpa01'
df_hjalmni01_pos['name']='hjalmni01'
df_hobsoad01_pos['name']='hobsoad01'
df_hornqpa01_pos['name']='hornqpa01'
df_istomde01_pos['name']='istomde01'
df_jackssc01_pos['name']='jackssc01'
df_johnsja02_pos['name']='johnsja02'
df_jonesbl01_pos['name']='jonesbl01'
df_joslide01_pos['name']='joslide01'
df_kaluspe01_pos['name']='kaluspe01'
df_kassima01_pos['name']='kassima01'
df_keetlma01_pos['name']='keetlma01'
df_kenneti01_pos['name']='kenneti01'
df_kindlja01_pos['name']='kindlja01'
df_kohndu01_pos['name']='kohndu01'
df_kolehja01_pos['name']='kolehja01'
df_kopitan01_pos['name']='kopitan01'
df_korhori01_pos['name']='korhori01'
df_kostise01_pos['name']='kostise01'
df_kovertr01_pos['name']='kovertr01'
df_kozekan01_pos['name']='kozekan01'
df_krysaan01_pos['name']='krysaan01'
df_kucheda01_pos['name']='kucheda01'
df_kudelto01_pos['name']='kudelto01'
df_kunesti01_pos['name']='kunesti01'
df_kvapima01_pos['name']='kvapima01'
df_laakste01_pos['name']='laakste01'
df_lalanke01_pos['name']='lalanke01'
df_lascest01_pos['name']='lascest01'
df_lashoma01_pos['name']='lashoma01'
df_latengu01_pos['name']='latengu01'
df_lavaljo01_pos['name']='lavaljo01'
df_lawrech01_pos['name']='lawrech01'
df_lawsoky01_pos['name']='lawsoky01'
df_leebr01_pos['name']='leebr01'
df_legauol01_pos['name']='legauol01'
df_lehtomi02_pos['name']='lehtomi02'
df_leinoto01_pos['name']='leinoto01'
df_lemtyni01_pos['name']='lemtyni01'
df_letankr01_pos['name']='letankr01'
df_levasje02_pos['name']='levasje02'
df_lindgpe01_pos['name']='lindgpe01'
df_lofbech01_pos['name']='lofbech01'
df_luciato01_pos['name']='luciato01'
df_lynchja02_pos['name']='lynchja02'
df_macheda01_pos['name']='macheda01'
df_maciara01_pos['name']='maciara01'
df_madsemo01_pos['name']='madsemo01'
df_makiry01_pos['name']='makiry01'
df_marjama01_pos['name']='marjama01'
df_masonty01_pos['name']='masonty01'
df_mayje01_pos['name']='mayje01'
df_mcardke01_pos['name']='mcardke01'
df_mcganpa01_pos['name']='mcganpa01'
df_mcginry01_pos['name']='mcginry01'
df_mcneipa01_pos['name']='mcneipa01'
df_mcquaad01_pos['name']='mcquaad01'
df_megaldm01_pos['name']='megaldm01'
df_merciju01_pos['name']='merciju01'
df_meyerjo01_pos['name']='meyerjo01'
df_mieloju01_pos['name']='mieloju01'
df_mihalvl01_pos['name']='mihalvl01'
df_mikkebr01_pos['name']='mikkebr01'
df_mikusju01_pos['name']='mikusju01'
df_nealja01_pos['name']='nealja01'
df_niskama01_pos['name']='niskama01'
df_omarrry01_pos['name']='omarrry01'
df_oreilca01_pos['name']='oreilca01'
df_oreskph01_pos['name']='oreskph01'
df_orpikan01_pos['name']='orpikan01'
df_oshietj01_pos['name']='oshietj01'
df_otcenon01_pos['name']='otcenon01'
df_paqueje01_pos['name']='paqueje01'
df_paqueph01_pos['name']='paqueph01'
df_parenry01_pos['name']='parenry01'
df_pavelon01_pos['name']='pavelon01'
df_pelecma01_pos['name']='pelecma01'
df_pellepi01_pos['name']='pellepi01'
df_pettefr01_pos['name']='pettefr01'
df_plantty01_pos['name']='plantty01'
df_pokulsa01_pos['name']='pokulsa01'
df_poppeto01_pos['name']='poppeto01'
df_pospito01_pos['name']='pospito01'
df_poulibe01_pos['name']='poulibe01'
df_priceca01_pos['name']='priceca01'
df_pyattto01_pos['name']='pyattto01'
df_quickjo01_pos['name']='quickjo01'
df_rabbiwa01_pos['name']='rabbiwa01'
df_rasktu01_pos['name']='rasktu01'
df_rauch01_pos['name']='rauch01'
df_raymoma01_pos['name']='raymoma01'
df_reavery01_pos['name']='reavery01'
df_reinhde01_pos['name']='reinhde01'
df_ritolma01_pos['name']='ritolma01'
df_roussda01_pos['name']='roussda01'
df_rumsemy01_pos['name']='rumsemy01'
df_russekr01_pos['name']='russekr01'
df_russery01_pos['name']='russery01'
df_ryanbo01_pos['name']='ryanbo01'
df_ryderda01_pos['name']='ryderda01'
df_rynojo01_pos['name']='rynojo01'
df_salcibr01_pos['name']='salcibr01'
df_sauermi01_pos['name']='sauermi01'
df_setogde01_pos['name']='setogde01'
df_seymojo01_pos['name']='seymojo01'
df_sigaljo02_pos['name']='sigaljo02'
df_skillja01_pos['name']='skillja01'
df_smolera01_pos['name']='smolera01'
df_sobotvl01_pos['name']='sobotvl01'
df_staalma01_pos['name']='staalma01'
df_staloal01_pos['name']='staloal01'
df_stamlbr01_pos['name']='stamlbr01'
df_starkki01_pos['name']='starkki01'
df_stastpa01_pos['name']='stastpa01'
df_stoary01_pos['name']='stoary01'
df_stoesmy01_pos['name']='stoesmy01'
df_stralan01_pos['name']='stralan01'
df_sundsal01_pos['name']='sundsal01'
df_suttebr04_pos['name']='suttebr04'
df_syvreda01_pos['name']='syvreda01'
df_thomaan01_pos['name']='thomaan01'
df_toddsc01_pos['name']='toddsc01'
df_trukhvi01_pos['name']='trukhvi01'
df_turnebr02_pos['name']='turnebr02'
df_tuzzoni01_pos['name']='tuzzoni01'
df_vandech01_pos['name']='vandech01'
df_vantulu01_pos['name']='vantulu01'
df_vinceal01_pos['name']='vinceal01'
df_vitaljo01_pos['name']='vitaljo01'
df_vlasima01_pos['name']='vlasima01'
df_vojtaja01_pos['name']='vojtaja01'
df_wandeto01_pos['name']='wandeto01'
df_watkima01_pos['name']='watkima01'
#df_wattj.01_pos['name']='wattj.01'
df_wessbjo01_pos['name']='wessbjo01'
df_westbkr01_pos['name']='westbkr01'
df_yandlke01_pos['name']='yandlke01'
df_zagrama01_pos['name']='zagrama01'
df_zimmese01_pos['name']='zimmese01'
df_zubaran01_pos['name']='zubaran01'
df_zubovil01_pos['name']='zubovil01'

# %%
#df_aebisda01_pos

# %%
for elem in listcsv:
    print "df_"+elem[:-5]
# Out:
# df_abdelju01_pos
# df_aiellan01_pos
# df_anikevi01_pos
# df_aquinlu01_pos
# df_aubinma01_pos
# df_baileja01_pos
# df_baileky01_pos
# df_baldwgo01_pos
# df_barnejo01_pos
# df_bartama01_pos
# df_bartuos01_pos
# df_bassco01_pos
# df_bearsza01_pos
# df_beauljo01_pos
# df_beechke01_pos
# df_bellegr01_pos
# df_bergfni01_pos
# df_berryal01_pos
# df_bertrda01_pos
# df_bishobe01_pos
# df_blancni01_pos
# df_bliznma01_pos
# df_blundmi01_pos
# df_bollja01_pos
# df_boltbo01_pos
# df_bourdlu01_pos
# df_bourral01_pos
# df_bradfbr01_pos
# df_brophev01_pos
# df_brosnpa01_pos
# df_brulegi01_pos
# df_buravvy01_pos
# df_butchma01_pos
# df_butlech01_pos
# df_charljo01_pos
# df_chornta01_pos
# df_clackma01_pos
# df_clichma01_pos
# df_cluneri01_pos
# df_coglian01_pos
# df_colbewi01_pos
# df_collida01_pos
# df_crosbsi01_pos
# df_crowdti01_pos
# df_cumisky01_pos
# df_dagosma01_pos
# df_dahlbjo01_pos
# df_dakerta01_pos
# df_davisna01_pos
# df_davispa01_pos
# df_deero01_pos
# df_denniad01_pos
# ...

# %%
pos_frames=[df_abdelju01_pos,
df_aiellan01_pos,
df_anikevi01_pos,
df_aquinlu01_pos,
df_aubinma01_pos,
df_baileja01_pos,
df_baileky01_pos,
df_baldwgo01_pos,
df_barnejo01_pos,
df_bartama01_pos,
df_bartuos01_pos,
df_bassco01_pos,
df_bearsza01_pos,
df_beauljo01_pos,
df_beechke01_pos,
df_bellegr01_pos,
df_bergfni01_pos,
df_berryal01_pos,
df_bertrda01_pos,
df_bishobe01_pos,
df_blancni01_pos,
df_bliznma01_pos,
df_blundmi01_pos,
df_bollja01_pos,
df_boltbo01_pos,
df_bourdlu01_pos,
df_bourral01_pos,
df_bradfbr01_pos,
df_brophev01_pos,
df_brosnpa01_pos,
df_brulegi01_pos,
df_buravvy01_pos,
df_butchma01_pos,
df_butlech01_pos,
df_charljo01_pos,
df_chornta01_pos,
df_clackma01_pos,
df_clichma01_pos,
df_cluneri01_pos,
df_coglian01_pos,
df_colbewi01_pos,
df_collida01_pos,
df_crosbsi01_pos,
df_crowdti01_pos,
df_cumisky01_pos,
df_dagosma01_pos,
df_dahlbjo01_pos,
df_dakerta01_pos,
df_davisna01_pos,
df_davispa01_pos,
df_deero01_pos,
df_denniad01_pos,
df_dennych01_pos,
df_derlyro01_pos,
df_dovgavi01_pos,
df_downist01_pos,
df_drazeni01_pos,
df_ducheje01_pos,
df_duffyma01_pos,
df_duponbr01_pos,
df_duranch01_pos,
df_emmerri01_pos,
df_fallojo01_pos,
#df_fastt.01_pos,
df_faynema01_pos,
#df_fentop.01_pos,
df_finlejo01_pos,
df_flattda01_pos,
df_flattjo01_pos,
df_fostebr01_pos,
df_fransco01_pos,
df_frasema01_pos,
df_frazeje01_pos,
df_fredhkr01_pos,
df_fritsto01_pos,
df_gauthmi01_pos,
df_generma01_pos,
df_gerbena01_pos,
df_gergemi01_pos,
df_glassma01_pos,
df_gogulph01_pos,
df_gragnma01_pos,
df_greenco01_pos,
df_guthrsh01_pos,
df_hagemna01_pos,
df_hanzama01_pos,
df_helmda01_pos,
df_hendrtr01_pos,
df_hensitj01_pos,
df_herslpa01_pos,
df_hjalmni01_pos,
df_hobsoad01_pos,
df_hornqpa01_pos,
df_istomde01_pos,
df_jackssc01_pos,
df_johnsja02_pos,
df_jonesbl01_pos,
df_joslide01_pos,
df_kaluspe01_pos,
df_kassima01_pos,
df_keetlma01_pos,
df_kenneti01_pos,
df_kindlja01_pos,
df_kohndu01_pos,
df_kolehja01_pos,
df_kopitan01_pos,
df_korhori01_pos,
df_kostise01_pos,
df_kovertr01_pos,
df_kozekan01_pos,
df_krysaan01_pos,
df_kucheda01_pos,
df_kudelto01_pos,
df_kunesti01_pos,
df_kvapima01_pos,
df_laakste01_pos,
df_lalanke01_pos,
df_lascest01_pos,
df_lashoma01_pos,
df_latengu01_pos,
df_lavaljo01_pos,
df_lawrech01_pos,
df_lawsoky01_pos,
df_leebr01_pos,
df_legauol01_pos,
df_lehtomi02_pos,
df_leinoto01_pos,
df_lemtyni01_pos,
df_letankr01_pos,
df_levasje02_pos,
df_lindgpe01_pos,
df_lofbech01_pos,
df_luciato01_pos,
df_lynchja02_pos,
df_macheda01_pos,
df_maciara01_pos,
df_madsemo01_pos,
df_makiry01_pos,
df_marjama01_pos,
df_masonty01_pos,
df_mayje01_pos,
df_mcardke01_pos,
df_mcganpa01_pos,
df_mcginry01_pos,
df_mcneipa01_pos,
df_mcquaad01_pos,
df_megaldm01_pos,
df_merciju01_pos,
df_meyerjo01_pos,
df_mieloju01_pos,
df_mihalvl01_pos,
df_mikkebr01_pos,
df_mikusju01_pos,
df_nealja01_pos,
df_niskama01_pos,
df_omarrry01_pos,
df_oreilca01_pos,
df_oreskph01_pos,
df_orpikan01_pos,
df_oshietj01_pos,
df_otcenon01_pos,
df_paqueje01_pos,
df_paqueph01_pos,
df_parenry01_pos,
df_pavelon01_pos,
df_pelecma01_pos,
df_pellepi01_pos,
df_pettefr01_pos,
df_plantty01_pos,
df_pokulsa01_pos,
df_poppeto01_pos,
df_pospito01_pos,
df_poulibe01_pos,
df_priceca01_pos,
df_pyattto01_pos,
df_quickjo01_pos,
df_rabbiwa01_pos,
df_rasktu01_pos,
df_rauch01_pos,
df_raymoma01_pos,
df_reavery01_pos,
df_reinhde01_pos,
df_ritolma01_pos,
df_roussda01_pos,
df_rumsemy01_pos,
df_russekr01_pos,
df_russery01_pos,
df_ryanbo01_pos,
df_ryderda01_pos,
df_rynojo01_pos,
df_salcibr01_pos,
df_sauermi01_pos,
df_setogde01_pos,
df_seymojo01_pos,
df_sigaljo02_pos,
df_skillja01_pos,
df_smolera01_pos,
df_sobotvl01_pos,
df_staalma01_pos,
df_staloal01_pos,
df_stamlbr01_pos,
df_starkki01_pos,
df_stastpa01_pos,
df_stoary01_pos,
df_stoesmy01_pos,
df_stralan01_pos,
df_sundsal01_pos,
df_suttebr04_pos,
df_syvreda01_pos,
df_thomaan01_pos,
df_toddsc01_pos,
df_trukhvi01_pos,
df_turnebr02_pos,
df_tuzzoni01_pos,
df_vandech01_pos,
df_vantulu01_pos,
df_vinceal01_pos,
df_vitaljo01_pos,
df_vlasima01_pos,
df_vojtaja01_pos,
df_wandeto01_pos,
df_watkima01_pos,
#df_wattj.01_pos,
df_wessbjo01_pos,
df_westbkr01_pos,
df_yandlke01_pos,
df_zagrama01_pos,
df_zimmese01_pos,
df_zubaran01_pos,
df_zubovil01_pos]

# %%
result_pos = pd.concat(pos_frames)

# %%
result_pos
# Out:
#      season  TOT   age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2007-08  DET  20.0       19.0           18.0       51.4           -10
# 2   2008-09  DET  21.0       22.0            9.0       71.0          14.6
# 3   2009-10  DET  22.0      409.0          376.0       52.1          -2.2
# 4   2010-11  DET  23.0      765.0          628.0       54.9          -0.4
# 5   2011-12  DET  24.0      794.0          698.0       53.2          -3.2
# 6   2012-13  DET  25.0      614.0          479.0       56.2           3.8
# 7   2013-14  DET  26.0      841.0          821.0       50.6          -3.1
# 8   2014-15  DET  27.0      909.0          704.0       56.4             4
# 9   2015-16  DET  28.0      986.0          995.0       49.8          -2.9
# 10  2016-17  DET  29.0      233.0          271.0       46.2           0.3
# 1   2009-10  PHI  23.0      616.0          736.0       45.6           -10
# 2   2010-11  PHI  24.0      135.0          187.0       41.9          -8.6
# ...

# %%
len(pos_frames)
# Out:
# 227

# %%
df_abdelju01_strd=pd.read_csv('../PlayerData/2005/standard/abdelju01_strd_.csv',index_col=0)
df_aiellan01_strd=pd.read_csv('../PlayerData/2005/standard/aiellan01_strd_.csv',index_col=0)
df_anikevi01_strd=pd.read_csv('../PlayerData/2005/standard/anikevi01_strd_.csv',index_col=0)
df_aquinlu01_strd=pd.read_csv('../PlayerData/2005/standard/aquinlu01_strd_.csv',index_col=0)
df_aubinma01_strd=pd.read_csv('../PlayerData/2005/standard/aubinma01_strd_.csv',index_col=0)
df_baileja01_strd=pd.read_csv('../PlayerData/2005/standard/baileja01_strd_.csv',index_col=0)
df_baileky01_strd=pd.read_csv('../PlayerData/2005/standard/baileky01_strd_.csv',index_col=0)
df_baldwgo01_strd=pd.read_csv('../PlayerData/2005/standard/baldwgo01_strd_.csv',index_col=0)
df_barnejo01_strd=pd.read_csv('../PlayerData/2005/standard/barnejo01_strd_.csv',index_col=0)
df_bartama01_strd=pd.read_csv('../PlayerData/2005/standard/bartama01_strd_.csv',index_col=0)
df_bartuos01_strd=pd.read_csv('../PlayerData/2005/standard/bartuos01_strd_.csv',index_col=0)
df_bassco01_strd=pd.read_csv('../PlayerData/2005/standard/bassco01_strd_.csv',index_col=0)
df_bearsza01_strd=pd.read_csv('../PlayerData/2005/standard/bearsza01_strd_.csv',index_col=0)
df_beauljo01_strd=pd.read_csv('../PlayerData/2005/standard/beauljo01_strd_.csv',index_col=0)
df_beechke01_strd=pd.read_csv('../PlayerData/2005/standard/beechke01_strd_.csv',index_col=0)
df_bellegr01_strd=pd.read_csv('../PlayerData/2005/standard/bellegr01_strd_.csv',index_col=0)
df_bergfni01_strd=pd.read_csv('../PlayerData/2005/standard/bergfni01_strd_.csv',index_col=0)
df_berryal01_strd=pd.read_csv('../PlayerData/2005/standard/berryal01_strd_.csv',index_col=0)
df_bertrda01_strd=pd.read_csv('../PlayerData/2005/standard/bertrda01_strd_.csv',index_col=0)
df_bishobe01_strd=pd.read_csv('../PlayerData/2005/standard/bishobe01_strd_.csv',index_col=0)
df_blancni01_strd=pd.read_csv('../PlayerData/2005/standard/blancni01_strd_.csv',index_col=0)
df_bliznma01_strd=pd.read_csv('../PlayerData/2005/standard/bliznma01_strd_.csv',index_col=0)
df_blundmi01_strd=pd.read_csv('../PlayerData/2005/standard/blundmi01_strd_.csv',index_col=0)
df_bollja01_strd=pd.read_csv('../PlayerData/2005/standard/bollja01_strd_.csv',index_col=0)
df_boltbo01_strd=pd.read_csv('../PlayerData/2005/standard/boltbo01_strd_.csv',index_col=0)
df_bourdlu01_strd=pd.read_csv('../PlayerData/2005/standard/bourdlu01_strd_.csv',index_col=0)
df_bourral01_strd=pd.read_csv('../PlayerData/2005/standard/bourral01_strd_.csv',index_col=0)
df_bradfbr01_strd=pd.read_csv('../PlayerData/2005/standard/bradfbr01_strd_.csv',index_col=0)
df_brophev01_strd=pd.read_csv('../PlayerData/2005/standard/brophev01_strd_.csv',index_col=0)
df_brosnpa01_strd=pd.read_csv('../PlayerData/2005/standard/brosnpa01_strd_.csv',index_col=0)
df_brulegi01_strd=pd.read_csv('../PlayerData/2005/standard/brulegi01_strd_.csv',index_col=0)
df_buravvy01_strd=pd.read_csv('../PlayerData/2005/standard/buravvy01_strd_.csv',index_col=0)
df_butchma01_strd=pd.read_csv('../PlayerData/2005/standard/butchma01_strd_.csv',index_col=0)
df_butlech01_strd=pd.read_csv('../PlayerData/2005/standard/butlech01_strd_.csv',index_col=0)
df_charljo01_strd=pd.read_csv('../PlayerData/2005/standard/charljo01_strd_.csv',index_col=0)
df_chornta01_strd=pd.read_csv('../PlayerData/2005/standard/chornta01_strd_.csv',index_col=0)
df_clackma01_strd=pd.read_csv('../PlayerData/2005/standard/clackma01_strd_.csv',index_col=0)
df_clichma01_strd=pd.read_csv('../PlayerData/2005/standard/clichma01_strd_.csv',index_col=0)
df_cluneri01_strd=pd.read_csv('../PlayerData/2005/standard/cluneri01_strd_.csv',index_col=0)
df_coglian01_strd=pd.read_csv('../PlayerData/2005/standard/coglian01_strd_.csv',index_col=0)
df_colbewi01_strd=pd.read_csv('../PlayerData/2005/standard/colbewi01_strd_.csv',index_col=0)
df_collida01_strd=pd.read_csv('../PlayerData/2005/standard/collida01_strd_.csv',index_col=0)
df_crosbsi01_strd=pd.read_csv('../PlayerData/2005/standard/crosbsi01_strd_.csv',index_col=0)
df_crowdti01_strd=pd.read_csv('../PlayerData/2005/standard/crowdti01_strd_.csv',index_col=0)
df_cumisky01_strd=pd.read_csv('../PlayerData/2005/standard/cumisky01_strd_.csv',index_col=0)
df_dagosma01_strd=pd.read_csv('../PlayerData/2005/standard/dagosma01_strd_.csv',index_col=0)
df_dahlbjo01_strd=pd.read_csv('../PlayerData/2005/standard/dahlbjo01_strd_.csv',index_col=0)
df_dakerta01_strd=pd.read_csv('../PlayerData/2005/standard/dakerta01_strd_.csv',index_col=0)
df_davisna01_strd=pd.read_csv('../PlayerData/2005/standard/davisna01_strd_.csv',index_col=0)
df_davispa01_strd=pd.read_csv('../PlayerData/2005/standard/davispa01_strd_.csv',index_col=0)
df_deero01_strd=pd.read_csv('../PlayerData/2005/standard/deero01_strd_.csv',index_col=0)
df_denniad01_strd=pd.read_csv('../PlayerData/2005/standard/denniad01_strd_.csv',index_col=0)
df_dennych01_strd=pd.read_csv('../PlayerData/2005/standard/dennych01_strd_.csv',index_col=0)
df_derlyro01_strd=pd.read_csv('../PlayerData/2005/standard/derlyro01_strd_.csv',index_col=0)
df_dovgavi01_strd=pd.read_csv('../PlayerData/2005/standard/dovgavi01_strd_.csv',index_col=0)
df_downist01_strd=pd.read_csv('../PlayerData/2005/standard/downist01_strd_.csv',index_col=0)
df_drazeni01_strd=pd.read_csv('../PlayerData/2005/standard/drazeni01_strd_.csv',index_col=0)
df_ducheje01_strd=pd.read_csv('../PlayerData/2005/standard/ducheje01_strd_.csv',index_col=0)
df_duffyma01_strd=pd.read_csv('../PlayerData/2005/standard/duffyma01_strd_.csv',index_col=0)
df_duponbr01_strd=pd.read_csv('../PlayerData/2005/standard/duponbr01_strd_.csv',index_col=0)
df_duranch01_strd=pd.read_csv('../PlayerData/2005/standard/duranch01_strd_.csv',index_col=0)
df_emmerri01_strd=pd.read_csv('../PlayerData/2005/standard/emmerri01_strd_.csv',index_col=0)
df_fallojo01_strd=pd.read_csv('../PlayerData/2005/standard/fallojo01_strd_.csv',index_col=0)
#df_fastt.01_strd=pd.read_csv('../PlayerData/2005/standard/fastt.01_strd_.csv',index_col=0)
df_faynema01_strd=pd.read_csv('../PlayerData/2005/standard/faynema01_strd_.csv',index_col=0)
#df_fentop.01_strd=pd.read_csv('../PlayerData/2005/standard/fentop.01_strd_.csv',index_col=0)
df_finlejo01_strd=pd.read_csv('../PlayerData/2005/standard/finlejo01_strd_.csv',index_col=0)
df_flattda01_strd=pd.read_csv('../PlayerData/2005/standard/flattda01_strd_.csv',index_col=0)
df_flattjo01_strd=pd.read_csv('../PlayerData/2005/standard/flattjo01_strd_.csv',index_col=0)
df_fostebr01_strd=pd.read_csv('../PlayerData/2005/standard/fostebr01_strd_.csv',index_col=0)
df_fransco01_strd=pd.read_csv('../PlayerData/2005/standard/fransco01_strd_.csv',index_col=0)
df_frasema01_strd=pd.read_csv('../PlayerData/2005/standard/frasema01_strd_.csv',index_col=0)
df_frazeje01_strd=pd.read_csv('../PlayerData/2005/standard/frazeje01_strd_.csv',index_col=0)
df_fredhkr01_strd=pd.read_csv('../PlayerData/2005/standard/fredhkr01_strd_.csv',index_col=0)
df_fritsto01_strd=pd.read_csv('../PlayerData/2005/standard/fritsto01_strd_.csv',index_col=0)
df_gauthmi01_strd=pd.read_csv('../PlayerData/2005/standard/gauthmi01_strd_.csv',index_col=0)
df_generma01_strd=pd.read_csv('../PlayerData/2005/standard/generma01_strd_.csv',index_col=0)
df_gerbena01_strd=pd.read_csv('../PlayerData/2005/standard/gerbena01_strd_.csv',index_col=0)
df_gergemi01_strd=pd.read_csv('../PlayerData/2005/standard/gergemi01_strd_.csv',index_col=0)
df_glassma01_strd=pd.read_csv('../PlayerData/2005/standard/glassma01_strd_.csv',index_col=0)
df_gogulph01_strd=pd.read_csv('../PlayerData/2005/standard/gogulph01_strd_.csv',index_col=0)
df_gragnma01_strd=pd.read_csv('../PlayerData/2005/standard/gragnma01_strd_.csv',index_col=0)
df_greenco01_strd=pd.read_csv('../PlayerData/2005/standard/greenco01_strd_.csv',index_col=0)
df_guthrsh01_strd=pd.read_csv('../PlayerData/2005/standard/guthrsh01_strd_.csv',index_col=0)
df_hagemna01_strd=pd.read_csv('../PlayerData/2005/standard/hagemna01_strd_.csv',index_col=0)
df_hanzama01_strd=pd.read_csv('../PlayerData/2005/standard/hanzama01_strd_.csv',index_col=0)
df_helmda01_strd=pd.read_csv('../PlayerData/2005/standard/helmda01_strd_.csv',index_col=0)
df_hendrtr01_strd=pd.read_csv('../PlayerData/2005/standard/hendrtr01_strd_.csv',index_col=0)
df_hensitj01_strd=pd.read_csv('../PlayerData/2005/standard/hensitj01_strd_.csv',index_col=0)
df_herslpa01_strd=pd.read_csv('../PlayerData/2005/standard/herslpa01_strd_.csv',index_col=0)
df_hjalmni01_strd=pd.read_csv('../PlayerData/2005/standard/hjalmni01_strd_.csv',index_col=0)
df_hobsoad01_strd=pd.read_csv('../PlayerData/2005/standard/hobsoad01_strd_.csv',index_col=0)
df_hornqpa01_strd=pd.read_csv('../PlayerData/2005/standard/hornqpa01_strd_.csv',index_col=0)
df_istomde01_strd=pd.read_csv('../PlayerData/2005/standard/istomde01_strd_.csv',index_col=0)
df_jackssc01_strd=pd.read_csv('../PlayerData/2005/standard/jackssc01_strd_.csv',index_col=0)
df_johnsja02_strd=pd.read_csv('../PlayerData/2005/standard/johnsja02_strd_.csv',index_col=0)
df_jonesbl01_strd=pd.read_csv('../PlayerData/2005/standard/jonesbl01_strd_.csv',index_col=0)
df_joslide01_strd=pd.read_csv('../PlayerData/2005/standard/joslide01_strd_.csv',index_col=0)
df_kaluspe01_strd=pd.read_csv('../PlayerData/2005/standard/kaluspe01_strd_.csv',index_col=0)
df_kassima01_strd=pd.read_csv('../PlayerData/2005/standard/kassima01_strd_.csv',index_col=0)
df_keetlma01_strd=pd.read_csv('../PlayerData/2005/standard/keetlma01_strd_.csv',index_col=0)
df_kenneti01_strd=pd.read_csv('../PlayerData/2005/standard/kenneti01_strd_.csv',index_col=0)
df_kindlja01_strd=pd.read_csv('../PlayerData/2005/standard/kindlja01_strd_.csv',index_col=0)
df_kohndu01_strd=pd.read_csv('../PlayerData/2005/standard/kohndu01_strd_.csv',index_col=0)
df_kolehja01_strd=pd.read_csv('../PlayerData/2005/standard/kolehja01_strd_.csv',index_col=0)
df_kopitan01_strd=pd.read_csv('../PlayerData/2005/standard/kopitan01_strd_.csv',index_col=0)
df_korhori01_strd=pd.read_csv('../PlayerData/2005/standard/korhori01_strd_.csv',index_col=0)
df_kostise01_strd=pd.read_csv('../PlayerData/2005/standard/kostise01_strd_.csv',index_col=0)
df_kovertr01_strd=pd.read_csv('../PlayerData/2005/standard/kovertr01_strd_.csv',index_col=0)
df_kozekan01_strd=pd.read_csv('../PlayerData/2005/standard/kozekan01_strd_.csv',index_col=0)
df_krysaan01_strd=pd.read_csv('../PlayerData/2005/standard/krysaan01_strd_.csv',index_col=0)
df_kucheda01_strd=pd.read_csv('../PlayerData/2005/standard/kucheda01_strd_.csv',index_col=0)
df_kudelto01_strd=pd.read_csv('../PlayerData/2005/standard/kudelto01_strd_.csv',index_col=0)
df_kunesti01_strd=pd.read_csv('../PlayerData/2005/standard/kunesti01_strd_.csv',index_col=0)
df_kvapima01_strd=pd.read_csv('../PlayerData/2005/standard/kvapima01_strd_.csv',index_col=0)
df_laakste01_strd=pd.read_csv('../PlayerData/2005/standard/laakste01_strd_.csv',index_col=0)
df_lalanke01_strd=pd.read_csv('../PlayerData/2005/standard/lalanke01_strd_.csv',index_col=0)
df_lascest01_strd=pd.read_csv('../PlayerData/2005/standard/lascest01_strd_.csv',index_col=0)
df_lashoma01_strd=pd.read_csv('../PlayerData/2005/standard/lashoma01_strd_.csv',index_col=0)
df_latengu01_strd=pd.read_csv('../PlayerData/2005/standard/latengu01_strd_.csv',index_col=0)
df_lavaljo01_strd=pd.read_csv('../PlayerData/2005/standard/lavaljo01_strd_.csv',index_col=0)
df_lawrech01_strd=pd.read_csv('../PlayerData/2005/standard/lawrech01_strd_.csv',index_col=0)
df_lawsoky01_strd=pd.read_csv('../PlayerData/2005/standard/lawsoky01_strd_.csv',index_col=0)
df_leebr01_strd=pd.read_csv('../PlayerData/2005/standard/leebr01_strd_.csv',index_col=0)
df_legauol01_strd=pd.read_csv('../PlayerData/2005/standard/legauol01_strd_.csv',index_col=0)
df_lehtomi02_strd=pd.read_csv('../PlayerData/2005/standard/lehtomi02_strd_.csv',index_col=0)
df_leinoto01_strd=pd.read_csv('../PlayerData/2005/standard/leinoto01_strd_.csv',index_col=0)
df_lemtyni01_strd=pd.read_csv('../PlayerData/2005/standard/lemtyni01_strd_.csv',index_col=0)
df_letankr01_strd=pd.read_csv('../PlayerData/2005/standard/letankr01_strd_.csv',index_col=0)
df_levasje02_strd=pd.read_csv('../PlayerData/2005/standard/levasje02_strd_.csv',index_col=0)
df_lindgpe01_strd=pd.read_csv('../PlayerData/2005/standard/lindgpe01_strd_.csv',index_col=0)
df_lofbech01_strd=pd.read_csv('../PlayerData/2005/standard/lofbech01_strd_.csv',index_col=0)
df_luciato01_strd=pd.read_csv('../PlayerData/2005/standard/luciato01_strd_.csv',index_col=0)
df_lynchja02_strd=pd.read_csv('../PlayerData/2005/standard/lynchja02_strd_.csv',index_col=0)
df_macheda01_strd=pd.read_csv('../PlayerData/2005/standard/macheda01_strd_.csv',index_col=0)
df_maciara01_strd=pd.read_csv('../PlayerData/2005/standard/maciara01_strd_.csv',index_col=0)
df_madsemo01_strd=pd.read_csv('../PlayerData/2005/standard/madsemo01_strd_.csv',index_col=0)
df_makiry01_strd=pd.read_csv('../PlayerData/2005/standard/makiry01_strd_.csv',index_col=0)
df_marjama01_strd=pd.read_csv('../PlayerData/2005/standard/marjama01_strd_.csv',index_col=0)
df_masonty01_strd=pd.read_csv('../PlayerData/2005/standard/masonty01_strd_.csv',index_col=0)
df_mayje01_strd=pd.read_csv('../PlayerData/2005/standard/mayje01_strd_.csv',index_col=0)
df_mcardke01_strd=pd.read_csv('../PlayerData/2005/standard/mcardke01_strd_.csv',index_col=0)
df_mcganpa01_strd=pd.read_csv('../PlayerData/2005/standard/mcganpa01_strd_.csv',index_col=0)
df_mcginry01_strd=pd.read_csv('../PlayerData/2005/standard/mcginry01_strd_.csv',index_col=0)
df_mcneipa01_strd=pd.read_csv('../PlayerData/2005/standard/mcneipa01_strd_.csv',index_col=0)
df_mcquaad01_strd=pd.read_csv('../PlayerData/2005/standard/mcquaad01_strd_.csv',index_col=0)
df_megaldm01_strd=pd.read_csv('../PlayerData/2005/standard/megaldm01_strd_.csv',index_col=0)
df_merciju01_strd=pd.read_csv('../PlayerData/2005/standard/merciju01_strd_.csv',index_col=0)
df_meyerjo01_strd=pd.read_csv('../PlayerData/2005/standard/meyerjo01_strd_.csv',index_col=0)
df_mieloju01_strd=pd.read_csv('../PlayerData/2005/standard/mieloju01_strd_.csv',index_col=0)
df_mihalvl01_strd=pd.read_csv('../PlayerData/2005/standard/mihalvl01_strd_.csv',index_col=0)
df_mikkebr01_strd=pd.read_csv('../PlayerData/2005/standard/mikkebr01_strd_.csv',index_col=0)
df_mikusju01_strd=pd.read_csv('../PlayerData/2005/standard/mikusju01_strd_.csv',index_col=0)
df_nealja01_strd=pd.read_csv('../PlayerData/2005/standard/nealja01_strd_.csv',index_col=0)
df_niskama01_strd=pd.read_csv('../PlayerData/2005/standard/niskama01_strd_.csv',index_col=0)
df_omarrry01_strd=pd.read_csv('../PlayerData/2005/standard/omarrry01_strd_.csv',index_col=0)
df_oreilca01_strd=pd.read_csv('../PlayerData/2005/standard/oreilca01_strd_.csv',index_col=0)
df_oreskph01_strd=pd.read_csv('../PlayerData/2005/standard/oreskph01_strd_.csv',index_col=0)
df_orpikan01_strd=pd.read_csv('../PlayerData/2005/standard/orpikan01_strd_.csv',index_col=0)
df_oshietj01_strd=pd.read_csv('../PlayerData/2005/standard/oshietj01_strd_.csv',index_col=0)
df_otcenon01_strd=pd.read_csv('../PlayerData/2005/standard/otcenon01_strd_.csv',index_col=0)
df_paqueje01_strd=pd.read_csv('../PlayerData/2005/standard/paqueje01_strd_.csv',index_col=0)
df_paqueph01_strd=pd.read_csv('../PlayerData/2005/standard/paqueph01_strd_.csv',index_col=0)
df_parenry01_strd=pd.read_csv('../PlayerData/2005/standard/parenry01_strd_.csv',index_col=0)
df_pavelon01_strd=pd.read_csv('../PlayerData/2005/standard/pavelon01_strd_.csv',index_col=0)
df_pelecma01_strd=pd.read_csv('../PlayerData/2005/standard/pelecma01_strd_.csv',index_col=0)
df_pellepi01_strd=pd.read_csv('../PlayerData/2005/standard/pellepi01_strd_.csv',index_col=0)
df_pettefr01_strd=pd.read_csv('../PlayerData/2005/standard/pettefr01_strd_.csv',index_col=0)
df_plantty01_strd=pd.read_csv('../PlayerData/2005/standard/plantty01_strd_.csv',index_col=0)
df_pokulsa01_strd=pd.read_csv('../PlayerData/2005/standard/pokulsa01_strd_.csv',index_col=0)
df_poppeto01_strd=pd.read_csv('../PlayerData/2005/standard/poppeto01_strd_.csv',index_col=0)
df_pospito01_strd=pd.read_csv('../PlayerData/2005/standard/pospito01_strd_.csv',index_col=0)
df_poulibe01_strd=pd.read_csv('../PlayerData/2005/standard/poulibe01_strd_.csv',index_col=0)
df_priceca01_strd=pd.read_csv('../PlayerData/2005/standard/priceca01_strd_.csv',index_col=0)
df_pyattto01_strd=pd.read_csv('../PlayerData/2005/standard/pyattto01_strd_.csv',index_col=0)
df_quickjo01_strd=pd.read_csv('../PlayerData/2005/standard/quickjo01_strd_.csv',index_col=0)
df_rabbiwa01_strd=pd.read_csv('../PlayerData/2005/standard/rabbiwa01_strd_.csv',index_col=0)
df_rasktu01_strd=pd.read_csv('../PlayerData/2005/standard/rasktu01_strd_.csv',index_col=0)
df_rauch01_strd=pd.read_csv('../PlayerData/2005/standard/rauch01_strd_.csv',index_col=0)
df_raymoma01_strd=pd.read_csv('../PlayerData/2005/standard/raymoma01_strd_.csv',index_col=0)
df_reavery01_strd=pd.read_csv('../PlayerData/2005/standard/reavery01_strd_.csv',index_col=0)
df_reinhde01_strd=pd.read_csv('../PlayerData/2005/standard/reinhde01_strd_.csv',index_col=0)
df_ritolma01_strd=pd.read_csv('../PlayerData/2005/standard/ritolma01_strd_.csv',index_col=0)
df_roussda01_strd=pd.read_csv('../PlayerData/2005/standard/roussda01_strd_.csv',index_col=0)
df_rumsemy01_strd=pd.read_csv('../PlayerData/2005/standard/rumsemy01_strd_.csv',index_col=0)
df_russekr01_strd=pd.read_csv('../PlayerData/2005/standard/russekr01_strd_.csv',index_col=0)
df_russery01_strd=pd.read_csv('../PlayerData/2005/standard/russery01_strd_.csv',index_col=0)
df_ryanbo01_strd=pd.read_csv('../PlayerData/2005/standard/ryanbo01_strd_.csv',index_col=0)
df_ryderda01_strd=pd.read_csv('../PlayerData/2005/standard/ryderda01_strd_.csv',index_col=0)
df_rynojo01_strd=pd.read_csv('../PlayerData/2005/standard/rynojo01_strd_.csv',index_col=0)
df_salcibr01_strd=pd.read_csv('../PlayerData/2005/standard/salcibr01_strd_.csv',index_col=0)
df_sauermi01_strd=pd.read_csv('../PlayerData/2005/standard/sauermi01_strd_.csv',index_col=0)
df_setogde01_strd=pd.read_csv('../PlayerData/2005/standard/setogde01_strd_.csv',index_col=0)
df_seymojo01_strd=pd.read_csv('../PlayerData/2005/standard/seymojo01_strd_.csv',index_col=0)
df_sigaljo02_strd=pd.read_csv('../PlayerData/2005/standard/sigaljo02_strd_.csv',index_col=0)
df_skillja01_strd=pd.read_csv('../PlayerData/2005/standard/skillja01_strd_.csv',index_col=0)
df_smolera01_strd=pd.read_csv('../PlayerData/2005/standard/smolera01_strd_.csv',index_col=0)
df_sobotvl01_strd=pd.read_csv('../PlayerData/2005/standard/sobotvl01_strd_.csv',index_col=0)
df_staalma01_strd=pd.read_csv('../PlayerData/2005/standard/staalma01_strd_.csv',index_col=0)
df_staloal01_strd=pd.read_csv('../PlayerData/2005/standard/staloal01_strd_.csv',index_col=0)
df_stamlbr01_strd=pd.read_csv('../PlayerData/2005/standard/stamlbr01_strd_.csv',index_col=0)
df_starkki01_strd=pd.read_csv('../PlayerData/2005/standard/starkki01_strd_.csv',index_col=0)
df_stastpa01_strd=pd.read_csv('../PlayerData/2005/standard/stastpa01_strd_.csv',index_col=0)
df_stoary01_strd=pd.read_csv('../PlayerData/2005/standard/stoary01_strd_.csv',index_col=0)
df_stoesmy01_strd=pd.read_csv('../PlayerData/2005/standard/stoesmy01_strd_.csv',index_col=0)
df_stralan01_strd=pd.read_csv('../PlayerData/2005/standard/stralan01_strd_.csv',index_col=0)
df_sundsal01_strd=pd.read_csv('../PlayerData/2005/standard/sundsal01_strd_.csv',index_col=0)
df_suttebr04_strd=pd.read_csv('../PlayerData/2005/standard/suttebr04_strd_.csv',index_col=0)
df_syvreda01_strd=pd.read_csv('../PlayerData/2005/standard/syvreda01_strd_.csv',index_col=0)
df_thomaan01_strd=pd.read_csv('../PlayerData/2005/standard/thomaan01_strd_.csv',index_col=0)
df_toddsc01_strd=pd.read_csv('../PlayerData/2005/standard/toddsc01_strd_.csv',index_col=0)
df_trukhvi01_strd=pd.read_csv('../PlayerData/2005/standard/trukhvi01_strd_.csv',index_col=0)
df_turnebr02_strd=pd.read_csv('../PlayerData/2005/standard/turnebr02_strd_.csv',index_col=0)
df_tuzzoni01_strd=pd.read_csv('../PlayerData/2005/standard/tuzzoni01_strd_.csv',index_col=0)
df_vandech01_strd=pd.read_csv('../PlayerData/2005/standard/vandech01_strd_.csv',index_col=0)
df_vantulu01_strd=pd.read_csv('../PlayerData/2005/standard/vantulu01_strd_.csv',index_col=0)
df_vinceal01_strd=pd.read_csv('../PlayerData/2005/standard/vinceal01_strd_.csv',index_col=0)
df_vitaljo01_strd=pd.read_csv('../PlayerData/2005/standard/vitaljo01_strd_.csv',index_col=0)
df_vlasima01_strd=pd.read_csv('../PlayerData/2005/standard/vlasima01_strd_.csv',index_col=0)
df_vojtaja01_strd=pd.read_csv('../PlayerData/2005/standard/vojtaja01_strd_.csv',index_col=0)
df_wandeto01_strd=pd.read_csv('../PlayerData/2005/standard/wandeto01_strd_.csv',index_col=0)
df_watkima01_strd=pd.read_csv('../PlayerData/2005/standard/watkima01_strd_.csv',index_col=0)
#df_wattj.01_strd=pd.read_csv('../PlayerData/2005/standard/wattj.01_strd_.csv',index_col=0)
df_wessbjo01_strd=pd.read_csv('../PlayerData/2005/standard/wessbjo01_strd_.csv',index_col=0)
df_westbkr01_strd=pd.read_csv('../PlayerData/2005/standard/westbkr01_strd_.csv',index_col=0)
df_yandlke01_strd=pd.read_csv('../PlayerData/2005/standard/yandlke01_strd_.csv',index_col=0)
df_zagrama01_strd=pd.read_csv('../PlayerData/2005/standard/zagrama01_strd_.csv',index_col=0)
df_zimmese01_strd=pd.read_csv('../PlayerData/2005/standard/zimmese01_strd_.csv',index_col=0)
df_zubaran01_strd=pd.read_csv('../PlayerData/2005/standard/zubaran01_strd_.csv',index_col=0)
df_zubovil01_strd=pd.read_csv('../PlayerData/2005/standard/zubovil01_strd_.csv',index_col=0)

# %%
df_abdelju01_strd['name']='abdelju01'
df_aiellan01_strd['name']='aiellan01'
df_anikevi01_strd['name']='anikevi01'
df_aquinlu01_strd['name']='aquinlu01'
df_aubinma01_strd['name']='aubinma01'
df_baileja01_strd['name']='baileja01'
df_baileky01_strd['name']='baileky01'
df_baldwgo01_strd['name']='baldwgo01'
df_barnejo01_strd['name']='barnejo01'
df_bartama01_strd['name']='bartama01'
df_bartuos01_strd['name']='bartuos01'
df_bassco01_strd['name']='bassco01'
df_bearsza01_strd['name']='bearsza01'
df_beauljo01_strd['name']='beauljo01'
df_beechke01_strd['name']='beechke01'
df_bellegr01_strd['name']='bellegr01'
df_bergfni01_strd['name']='bergfni01'
df_berryal01_strd['name']='berryal01'
df_bertrda01_strd['name']='bertrda01'
df_bishobe01_strd['name']='bishobe01'
df_blancni01_strd['name']='blancni01'
df_bliznma01_strd['name']='bliznma01'
df_blundmi01_strd['name']='blundmi01'
df_bollja01_strd['name']='bollja01'
df_boltbo01_strd['name']='boltbo01'
df_bourdlu01_strd['name']='bourdlu01'
df_bourral01_strd['name']='bourral01'
df_bradfbr01_strd['name']='bradfbr01'
df_brophev01_strd['name']='brophev01'
df_brosnpa01_strd['name']='brosnpa01'
df_brulegi01_strd['name']='brulegi01'
df_buravvy01_strd['name']='buravvy01'
df_butchma01_strd['name']='butchma01'
df_butlech01_strd['name']='butlech01'
df_charljo01_strd['name']='charljo01'
df_chornta01_strd['name']='chornta01'
df_clackma01_strd['name']='clackma01'
df_clichma01_strd['name']='clichma01'
df_cluneri01_strd['name']='cluneri01'
df_coglian01_strd['name']='coglian01'
df_colbewi01_strd['name']='colbewi01'
df_collida01_strd['name']='collida01'
df_crosbsi01_strd['name']='crosbsi01'
df_crowdti01_strd['name']='crowdti01'
df_cumisky01_strd['name']='cumisky01'
df_dagosma01_strd['name']='dagosma01'
df_dahlbjo01_strd['name']='dahlbjo01'
df_dakerta01_strd['name']='dakerta01'
df_davisna01_strd['name']='davisna01'
df_davispa01_strd['name']='davispa01'
df_deero01_strd['name']='deero01'
df_denniad01_strd['name']='denniad01'
df_dennych01_strd['name']='dennych01'
df_derlyro01_strd['name']='derlyro01'
df_dovgavi01_strd['name']='dovgavi01'
df_downist01_strd['name']='downist01'
df_drazeni01_strd['name']='drazeni01'
df_ducheje01_strd['name']='ducheje01'
df_duffyma01_strd['name']='duffyma01'
df_duponbr01_strd['name']='duponbr01'
df_duranch01_strd['name']='duranch01'
df_emmerri01_strd['name']='emmerri01'
df_fallojo01_strd['name']='fallojo01'
#df_fastt.01_strd['name']='fastt.01'
df_faynema01_strd['name']='faynema01'
#df_fentop.01_strd['name']='fentop.01'
df_finlejo01_strd['name']='finlejo01'
df_flattda01_strd['name']='flattda01'
df_flattjo01_strd['name']='flattjo01'
df_fostebr01_strd['name']='fostebr01'
df_fransco01_strd['name']='fransco01'
df_frasema01_strd['name']='frasema01'
df_frazeje01_strd['name']='frazeje01'
df_fredhkr01_strd['name']='fredhkr01'
df_fritsto01_strd['name']='fritsto01'
df_gauthmi01_strd['name']='gauthmi01'
df_generma01_strd['name']='generma01'
df_gerbena01_strd['name']='gerbena01'
df_gergemi01_strd['name']='gergemi01'
df_glassma01_strd['name']='glassma01'
df_gogulph01_strd['name']='gogulph01'
df_gragnma01_strd['name']='gragnma01'
df_greenco01_strd['name']='greenco01'
df_guthrsh01_strd['name']='guthrsh01'
df_hagemna01_strd['name']='hagemna01'
df_hanzama01_strd['name']='hanzama01'
df_helmda01_strd['name']='helmda01'
df_hendrtr01_strd['name']='hendrtr01'
df_hensitj01_strd['name']='hensitj01'
df_herslpa01_strd['name']='herslpa01'
df_hjalmni01_strd['name']='hjalmni01'
df_hobsoad01_strd['name']='hobsoad01'
df_hornqpa01_strd['name']='hornqpa01'
df_istomde01_strd['name']='istomde01'
df_jackssc01_strd['name']='jackssc01'
df_johnsja02_strd['name']='johnsja02'
df_jonesbl01_strd['name']='jonesbl01'
df_joslide01_strd['name']='joslide01'
df_kaluspe01_strd['name']='kaluspe01'
df_kassima01_strd['name']='kassima01'
df_keetlma01_strd['name']='keetlma01'
df_kenneti01_strd['name']='kenneti01'
df_kindlja01_strd['name']='kindlja01'
df_kohndu01_strd['name']='kohndu01'
df_kolehja01_strd['name']='kolehja01'
df_kopitan01_strd['name']='kopitan01'
df_korhori01_strd['name']='korhori01'
df_kostise01_strd['name']='kostise01'
df_kovertr01_strd['name']='kovertr01'
df_kozekan01_strd['name']='kozekan01'
df_krysaan01_strd['name']='krysaan01'
df_kucheda01_strd['name']='kucheda01'
df_kudelto01_strd['name']='kudelto01'
df_kunesti01_strd['name']='kunesti01'
df_kvapima01_strd['name']='kvapima01'
df_laakste01_strd['name']='laakste01'
df_lalanke01_strd['name']='lalanke01'
df_lascest01_strd['name']='lascest01'
df_lashoma01_strd['name']='lashoma01'
df_latengu01_strd['name']='latengu01'
df_lavaljo01_strd['name']='lavaljo01'
df_lawrech01_strd['name']='lawrech01'
df_lawsoky01_strd['name']='lawsoky01'
df_leebr01_strd['name']='leebr01'
df_legauol01_strd['name']='legauol01'
df_lehtomi02_strd['name']='lehtomi02'
df_leinoto01_strd['name']='leinoto01'
df_lemtyni01_strd['name']='lemtyni01'
df_letankr01_strd['name']='letankr01'
df_levasje02_strd['name']='levasje02'
df_lindgpe01_strd['name']='lindgpe01'
df_lofbech01_strd['name']='lofbech01'
df_luciato01_strd['name']='luciato01'
df_lynchja02_strd['name']='lynchja02'
df_macheda01_strd['name']='macheda01'
df_maciara01_strd['name']='maciara01'
df_madsemo01_strd['name']='madsemo01'
df_makiry01_strd['name']='makiry01'
df_marjama01_strd['name']='marjama01'
df_masonty01_strd['name']='masonty01'
df_mayje01_strd['name']='mayje01'
df_mcardke01_strd['name']='mcardke01'
df_mcganpa01_strd['name']='mcganpa01'
df_mcginry01_strd['name']='mcginry01'
df_mcneipa01_strd['name']='mcneipa01'
df_mcquaad01_strd['name']='mcquaad01'
df_megaldm01_strd['name']='megaldm01'
df_merciju01_strd['name']='merciju01'
df_meyerjo01_strd['name']='meyerjo01'
df_mieloju01_strd['name']='mieloju01'
df_mihalvl01_strd['name']='mihalvl01'
df_mikkebr01_strd['name']='mikkebr01'
df_mikusju01_strd['name']='mikusju01'
df_nealja01_strd['name']='nealja01'
df_niskama01_strd['name']='niskama01'
df_omarrry01_strd['name']='omarrry01'
df_oreilca01_strd['name']='oreilca01'
df_oreskph01_strd['name']='oreskph01'
df_orpikan01_strd['name']='orpikan01'
df_oshietj01_strd['name']='oshietj01'
df_otcenon01_strd['name']='otcenon01'
df_paqueje01_strd['name']='paqueje01'
df_paqueph01_strd['name']='paqueph01'
df_parenry01_strd['name']='parenry01'
df_pavelon01_strd['name']='pavelon01'
df_pelecma01_strd['name']='pelecma01'
df_pellepi01_strd['name']='pellepi01'
df_pettefr01_strd['name']='pettefr01'
df_plantty01_strd['name']='plantty01'
df_pokulsa01_strd['name']='pokulsa01'
df_poppeto01_strd['name']='poppeto01'
df_pospito01_strd['name']='pospito01'
df_poulibe01_strd['name']='poulibe01'
df_priceca01_strd['name']='priceca01'
df_pyattto01_strd['name']='pyattto01'
df_quickjo01_strd['name']='quickjo01'
df_rabbiwa01_strd['name']='rabbiwa01'
df_rasktu01_strd['name']='rasktu01'
df_rauch01_strd['name']='rauch01'
df_raymoma01_strd['name']='raymoma01'
df_reavery01_strd['name']='reavery01'
df_reinhde01_strd['name']='reinhde01'
df_ritolma01_strd['name']='ritolma01'
df_roussda01_strd['name']='roussda01'
df_rumsemy01_strd['name']='rumsemy01'
df_russekr01_strd['name']='russekr01'
df_russery01_strd['name']='russery01'
df_ryanbo01_strd['name']='ryanbo01'
df_ryderda01_strd['name']='ryderda01'
df_rynojo01_strd['name']='rynojo01'
df_salcibr01_strd['name']='salcibr01'
df_sauermi01_strd['name']='sauermi01'
df_setogde01_strd['name']='setogde01'
df_seymojo01_strd['name']='seymojo01'
df_sigaljo02_strd['name']='sigaljo02'
df_skillja01_strd['name']='skillja01'
df_smolera01_strd['name']='smolera01'
df_sobotvl01_strd['name']='sobotvl01'
df_staalma01_strd['name']='staalma01'
df_staloal01_strd['name']='staloal01'
df_stamlbr01_strd['name']='stamlbr01'
df_starkki01_strd['name']='starkki01'
df_stastpa01_strd['name']='stastpa01'
df_stoary01_strd['name']='stoary01'
df_stoesmy01_strd['name']='stoesmy01'
df_stralan01_strd['name']='stralan01'
df_sundsal01_strd['name']='sundsal01'
df_suttebr04_strd['name']='suttebr04'
df_syvreda01_strd['name']='syvreda01'
df_thomaan01_strd['name']='thomaan01'
df_toddsc01_strd['name']='toddsc01'
df_trukhvi01_strd['name']='trukhvi01'
df_turnebr02_strd['name']='turnebr02'
df_tuzzoni01_strd['name']='tuzzoni01'
df_vandech01_strd['name']='vandech01'
df_vantulu01_strd['name']='vantulu01'
df_vinceal01_strd['name']='vinceal01'
df_vitaljo01_strd['name']='vitaljo01'
df_vlasima01_strd['name']='vlasima01'
df_vojtaja01_strd['name']='vojtaja01'
df_wandeto01_strd['name']='wandeto01'
df_watkima01_strd['name']='watkima01'
#df_wattj.01_strd['name']='wattj.01'
df_wessbjo01_strd['name']='wessbjo01'
df_westbkr01_strd['name']='westbkr01'
df_yandlke01_strd['name']='yandlke01'
df_zagrama01_strd['name']='zagrama01'
df_zimmese01_strd['name']='zimmese01'
df_zubaran01_strd['name']='zubaran01'
df_zubovil01_strd['name']='zubovil01'

# %%
strd_frames=[df_abdelju01_strd,
df_aiellan01_strd,
df_anikevi01_strd,
df_aquinlu01_strd,
df_aubinma01_strd,
df_baileja01_strd,
df_baileky01_strd,
df_baldwgo01_strd,
df_barnejo01_strd,
df_bartama01_strd,
df_bartuos01_strd,
df_bassco01_strd,
df_bearsza01_strd,
df_beauljo01_strd,
df_beechke01_strd,
df_bellegr01_strd,
df_bergfni01_strd,
df_berryal01_strd,
df_bertrda01_strd,
df_bishobe01_strd,
df_blancni01_strd,
df_bliznma01_strd,
df_blundmi01_strd,
df_bollja01_strd,
df_boltbo01_strd,
df_bourdlu01_strd,
df_bourral01_strd,
df_bradfbr01_strd,
df_brophev01_strd,
df_brosnpa01_strd,
df_brulegi01_strd,
df_buravvy01_strd,
df_butchma01_strd,
df_butlech01_strd,
df_charljo01_strd,
df_chornta01_strd,
df_clackma01_strd,
df_clichma01_strd,
df_cluneri01_strd,
df_coglian01_strd,
df_colbewi01_strd,
df_collida01_strd,
df_crosbsi01_strd,
df_crowdti01_strd,
df_cumisky01_strd,
df_dagosma01_strd,
df_dahlbjo01_strd,
df_dakerta01_strd,
df_davisna01_strd,
df_davispa01_strd,
df_deero01_strd,
df_denniad01_strd,
df_dennych01_strd,
df_derlyro01_strd,
df_dovgavi01_strd,
df_downist01_strd,
df_drazeni01_strd,
df_ducheje01_strd,
df_duffyma01_strd,
df_duponbr01_strd,
df_duranch01_strd,
df_emmerri01_strd,
df_fallojo01_strd,
#df_fastt.01_strd,
df_faynema01_strd,
#df_fentop.01_strd,
df_finlejo01_strd,
df_flattda01_strd,
df_flattjo01_strd,
df_fostebr01_strd,
df_fransco01_strd,
df_frasema01_strd,
df_frazeje01_strd,
df_fredhkr01_strd,
df_fritsto01_strd,
df_gauthmi01_strd,
df_generma01_strd,
df_gerbena01_strd,
df_gergemi01_strd,
df_glassma01_strd,
df_gogulph01_strd,
df_gragnma01_strd,
df_greenco01_strd,
df_guthrsh01_strd,
df_hagemna01_strd,
df_hanzama01_strd,
df_helmda01_strd,
df_hendrtr01_strd,
df_hensitj01_strd,
df_herslpa01_strd,
df_hjalmni01_strd,
df_hobsoad01_strd,
df_hornqpa01_strd,
df_istomde01_strd,
df_jackssc01_strd,
df_johnsja02_strd,
df_jonesbl01_strd,
df_joslide01_strd,
df_kaluspe01_strd,
df_kassima01_strd,
df_keetlma01_strd,
df_kenneti01_strd,
df_kindlja01_strd,
df_kohndu01_strd,
df_kolehja01_strd,
df_kopitan01_strd,
df_korhori01_strd,
df_kostise01_strd,
df_kovertr01_strd,
df_kozekan01_strd,
df_krysaan01_strd,
df_kucheda01_strd,
df_kudelto01_strd,
df_kunesti01_strd,
df_kvapima01_strd,
df_laakste01_strd,
df_lalanke01_strd,
df_lascest01_strd,
df_lashoma01_strd,
df_latengu01_strd,
df_lavaljo01_strd,
df_lawrech01_strd,
df_lawsoky01_strd,
df_leebr01_strd,
df_legauol01_strd,
df_lehtomi02_strd,
df_leinoto01_strd,
df_lemtyni01_strd,
df_letankr01_strd,
df_levasje02_strd,
df_lindgpe01_strd,
df_lofbech01_strd,
df_luciato01_strd,
df_lynchja02_strd,
df_macheda01_strd,
df_maciara01_strd,
df_madsemo01_strd,
df_makiry01_strd,
df_marjama01_strd,
df_masonty01_strd,
df_mayje01_strd,
df_mcardke01_strd,
df_mcganpa01_strd,
df_mcginry01_strd,
df_mcneipa01_strd,
df_mcquaad01_strd,
df_megaldm01_strd,
df_merciju01_strd,
df_meyerjo01_strd,
df_mieloju01_strd,
df_mihalvl01_strd,
df_mikkebr01_strd,
df_mikusju01_strd,
df_nealja01_strd,
df_niskama01_strd,
df_omarrry01_strd,
df_oreilca01_strd,
df_oreskph01_strd,
df_orpikan01_strd,
df_oshietj01_strd,
df_otcenon01_strd,
df_paqueje01_strd,
df_paqueph01_strd,
df_parenry01_strd,
df_pavelon01_strd,
df_pelecma01_strd,
df_pellepi01_strd,
df_pettefr01_strd,
df_plantty01_strd,
df_pokulsa01_strd,
df_poppeto01_strd,
df_pospito01_strd,
df_poulibe01_strd,
df_priceca01_strd,
df_pyattto01_strd,
df_quickjo01_strd,
df_rabbiwa01_strd,
df_rasktu01_strd,
df_rauch01_strd,
df_raymoma01_strd,
df_reavery01_strd,
df_reinhde01_strd,
df_ritolma01_strd,
df_roussda01_strd,
df_rumsemy01_strd,
df_russekr01_strd,
df_russery01_strd,
df_ryanbo01_strd,
df_ryderda01_strd,
df_rynojo01_strd,
df_salcibr01_strd,
df_sauermi01_strd,
df_setogde01_strd,
df_seymojo01_strd,
df_sigaljo02_strd,
df_skillja01_strd,
df_smolera01_strd,
df_sobotvl01_strd,
df_staalma01_strd,
df_staloal01_strd,
df_stamlbr01_strd,
df_starkki01_strd,
df_stastpa01_strd,
df_stoary01_strd,
df_stoesmy01_strd,
df_stralan01_strd,
df_sundsal01_strd,
df_suttebr04_strd,
df_syvreda01_strd,
df_thomaan01_strd,
df_toddsc01_strd,
df_trukhvi01_strd,
df_turnebr02_strd,
df_tuzzoni01_strd,
df_vandech01_strd,
df_vantulu01_strd,
df_vinceal01_strd,
df_vitaljo01_strd,
df_vlasima01_strd,
df_vojtaja01_strd,
df_wandeto01_strd,
df_watkima01_strd,
#df_wattj.01_strd,
df_wessbjo01_strd,
df_westbkr01_strd,
df_yandlke01_strd,
df_zagrama01_strd,
df_zimmese01_strd,
df_zubaran01_strd,
df_zubovil01_strd]

# %%
result_strd = pd.concat(strd_frames)

# %%
result_strd
# Out:
#      season  TOT   age  games_played pen_min  plus_minus  goals_ev  goals_pp  \
# 1   2007-08  DET  20.0           2.0       2         0.0       0.0       0.0
# 2   2008-09  DET  21.0           2.0       0         0.0       0.0       0.0
# 3   2009-10  DET  22.0          50.0      35       -11.0       3.0       0.0
# 4   2010-11  DET  23.0          74.0      61        15.0       7.0       0.0
# 5   2011-12  DET  24.0          81.0      62         4.0       8.0       0.0
# 6   2012-13  DET  25.0          48.0      34         6.0      10.0       0.0
# 7   2013-14  DET  26.0          70.0      31         2.0       9.0       1.0
# 8   2014-15  DET  27.0          71.0      72         3.0      15.0       8.0
# 9   2015-16  DET  28.0          82.0     120       -16.0      13.0       6.0
# 10  2016-17  DET  29.0          21.0      13        -4.0       2.0       2.0
# 1   2009-10  PHI  23.0          53.0      28       -12.0       1.0       0.0
# ...

# %%
result_pos
# Out:
#      season  TOT   age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2007-08  DET  20.0       19.0           18.0       51.4           -10
# 2   2008-09  DET  21.0       22.0            9.0       71.0          14.6
# 3   2009-10  DET  22.0      409.0          376.0       52.1          -2.2
# 4   2010-11  DET  23.0      765.0          628.0       54.9          -0.4
# 5   2011-12  DET  24.0      794.0          698.0       53.2          -3.2
# 6   2012-13  DET  25.0      614.0          479.0       56.2           3.8
# 7   2013-14  DET  26.0      841.0          821.0       50.6          -3.1
# 8   2014-15  DET  27.0      909.0          704.0       56.4             4
# 9   2015-16  DET  28.0      986.0          995.0       49.8          -2.9
# 10  2016-17  DET  29.0      233.0          271.0       46.2           0.3
# 1   2009-10  PHI  23.0      616.0          736.0       45.6           -10
# 2   2010-11  PHI  24.0      135.0          187.0       41.9          -8.6
# ...

# %%
result_all = pd.merge(result_strd, result_pos, how ='left', on=['name','season','TOT'])

# %%
result_all
# Out:
#       season  TOT  age_x  games_played pen_min  plus_minus  goals_ev  \
# 0    2007-08  DET   20.0           2.0       2         0.0       0.0
# 1    2008-09  DET   21.0           2.0       0         0.0       0.0
# 2    2009-10  DET   22.0          50.0      35       -11.0       3.0
# 3    2010-11  DET   23.0          74.0      61        15.0       7.0
# 4    2011-12  DET   24.0          81.0      62         4.0       8.0
# 5    2012-13  DET   25.0          48.0      34         6.0      10.0
# 6    2013-14  DET   26.0          70.0      31         2.0       9.0
# 7    2014-15  DET   27.0          71.0      72         3.0      15.0
# 8    2015-16  DET   28.0          82.0     120       -16.0      13.0
# 9    2016-17  DET   29.0          21.0      13        -4.0       2.0
# 10   2009-10  PHI   23.0          53.0      28       -12.0       1.0
# 11   2010-11  PHI   24.0          13.0       4        -4.0       0.0
# 12   2007-08  OTT   21.0          21.0      19        -1.0       1.0
# ...

# %%
import copy
seasonlist=result_all['season']
teamlist=result_all['TOT']
namelist=result_all['name']

currseas=seasonlist[0]
currteam=teamlist[0]
currname=namelist[0]

remlist=[1]
for i in range(1,len(seasonlist)):
    if seasonlist[i]==currseas and currname==namelist[i]:
        remlist.append(0)
    
    else:
        remlist.append(1)
        currname=namelist[i]
        currseas=seasonlist[i]

result_all['uniqueseason']=remlist
result_all=result_all.loc[result_all['uniqueseason'] == 1]
result_all2=copy.deepcopy(result_all)

    
result_all2=result_all2.convert_objects(convert_numeric=True).dropna()

result_all2

result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')
result_all2.to_csv("../draft_year/df_2005.csv")
# Out:
# /Users/takehiromatsuzawa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
