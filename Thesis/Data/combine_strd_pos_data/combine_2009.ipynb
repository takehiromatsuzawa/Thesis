# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
csv_list=[]
for i in range(2009,2010):
    filename="../PlayerData/"+str(i)+"/posession"
    filename2=[]
    for elem in os.listdir(filename):
        filename2.append(filename+'/'+elem)
    csv_list.append(os.listdir(filename))
    print os.listdir(filename)
# Out:
# ['abneyca01_pos_.csv', 'adamsma01_pos_.csv', 'almqvad01_pos_.csv', 'anderpe04_pos_.csv', 'androse01_pos_.csv', 'anthost01_pos_.csv', 'ashtoca01_pos_.csv', 'avtsial01_pos_.csv', 'barrity01_pos_.csv', 'bathgan02_pos_.csv', 'beckta01_pos_.csv', 'bennema02_pos_.csv', 'bennesp01_pos_.csv', 'bernaas01_pos_.csv', 'bertisi01_pos_.csv', 'berubje02_pos_.csv', 'bielkdo01_pos_.csv', 'bigosky01_pos_.csv', 'birkhjo01_pos_.csv', 'bjorkhe01_pos_.csv', 'blackje01_pos_.csv', 'blomqan01_pos_.csv', 'bloodev01_pos_.csv', 'bobkoig01_pos_.csv', 'bourqga01_pos_.csv', 'bourqry01_pos_.csv', 'brownch01_pos_.csv', 'bubniji01_pos_.csv', 'budisza01_pos_.csv', 'buttory01_pos_.csv', 'callami01_pos_.csv', 'cannajo01_pos_.csv', 'caronjo01_pos_.csv', 'casavbe01_pos_.csv', 'chiarbe01_pos_.csv', 'chiasal01_pos_.csv', 'cichymi01_pos_.csv', 'cizikca01_pos_.csv', 'clarkma01_pos_.csv', 'cliffky01_pos_.csv', 'connake01_pos_.csv', 'costeje01_pos_.csv', 'cowenja01_pos_.csv', 'cowicco01_pos_.csv', 'damigje01_pos_.csv', 'dehaaca
# ...

# %%
listcsv=csv_list[0]

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"=pd.read_csv(./PlayerData/2009/posession/"+elem+",index_col=0)"
# Out:
# df_abneyca01_pos=pd.read_csv(./PlayerData/2009/posession/abneyca01_pos_.csv,index_col=0)
# df_adamsma01_pos=pd.read_csv(./PlayerData/2009/posession/adamsma01_pos_.csv,index_col=0)
# df_almqvad01_pos=pd.read_csv(./PlayerData/2009/posession/almqvad01_pos_.csv,index_col=0)
# df_anderpe04_pos=pd.read_csv(./PlayerData/2009/posession/anderpe04_pos_.csv,index_col=0)
# df_androse01_pos=pd.read_csv(./PlayerData/2009/posession/androse01_pos_.csv,index_col=0)
# df_anthost01_pos=pd.read_csv(./PlayerData/2009/posession/anthost01_pos_.csv,index_col=0)
# df_ashtoca01_pos=pd.read_csv(./PlayerData/2009/posession/ashtoca01_pos_.csv,index_col=0)
# df_avtsial01_pos=pd.read_csv(./PlayerData/2009/posession/avtsial01_pos_.csv,index_col=0)
# df_barrity01_pos=pd.read_csv(./PlayerData/2009/posession/barrity01_pos_.csv,index_col=0)
# df_bathgan02_pos=pd.read_csv(./PlayerData/2009/posession/bathgan02_pos_.csv,index_col=0)
# df_beckta01_pos=pd.read_csv(./PlayerData/2009/posession/beckta01_pos_.csv,index_col=0)
# ...

# %%
#df_adamscr01_pos=pd.read_csv('./PlayerData/1997/posession/aebisda01_pos_.csv',index_col=0)

# %%
df_abneyca01_pos=pd.read_csv('../PlayerData/2009/posession/abneyca01_pos_.csv',index_col=0)
df_adamsma01_pos=pd.read_csv('../PlayerData/2009/posession/adamsma01_pos_.csv',index_col=0)
df_almqvad01_pos=pd.read_csv('../PlayerData/2009/posession/almqvad01_pos_.csv',index_col=0)
df_anderpe04_pos=pd.read_csv('../PlayerData/2009/posession/anderpe04_pos_.csv',index_col=0)
df_androse01_pos=pd.read_csv('../PlayerData/2009/posession/androse01_pos_.csv',index_col=0)
df_anthost01_pos=pd.read_csv('../PlayerData/2009/posession/anthost01_pos_.csv',index_col=0)
df_ashtoca01_pos=pd.read_csv('../PlayerData/2009/posession/ashtoca01_pos_.csv',index_col=0)
df_avtsial01_pos=pd.read_csv('../PlayerData/2009/posession/avtsial01_pos_.csv',index_col=0)
df_barrity01_pos=pd.read_csv('../PlayerData/2009/posession/barrity01_pos_.csv',index_col=0)
df_bathgan02_pos=pd.read_csv('../PlayerData/2009/posession/bathgan02_pos_.csv',index_col=0)
df_beckta01_pos=pd.read_csv('../PlayerData/2009/posession/beckta01_pos_.csv',index_col=0)
df_bennema02_pos=pd.read_csv('../PlayerData/2009/posession/bennema02_pos_.csv',index_col=0)
df_bennesp01_pos=pd.read_csv('../PlayerData/2009/posession/bennesp01_pos_.csv',index_col=0)
df_bernaas01_pos=pd.read_csv('../PlayerData/2009/posession/bernaas01_pos_.csv',index_col=0)
df_bertisi01_pos=pd.read_csv('../PlayerData/2009/posession/bertisi01_pos_.csv',index_col=0)
df_berubje02_pos=pd.read_csv('../PlayerData/2009/posession/berubje02_pos_.csv',index_col=0)
df_bielkdo01_pos=pd.read_csv('../PlayerData/2009/posession/bielkdo01_pos_.csv',index_col=0)
df_bigosky01_pos=pd.read_csv('../PlayerData/2009/posession/bigosky01_pos_.csv',index_col=0)
df_birkhjo01_pos=pd.read_csv('../PlayerData/2009/posession/birkhjo01_pos_.csv',index_col=0)
df_bjorkhe01_pos=pd.read_csv('../PlayerData/2009/posession/bjorkhe01_pos_.csv',index_col=0)
df_blackje01_pos=pd.read_csv('../PlayerData/2009/posession/blackje01_pos_.csv',index_col=0)
df_blomqan01_pos=pd.read_csv('../PlayerData/2009/posession/blomqan01_pos_.csv',index_col=0)
df_bloodev01_pos=pd.read_csv('../PlayerData/2009/posession/bloodev01_pos_.csv',index_col=0)
df_bobkoig01_pos=pd.read_csv('../PlayerData/2009/posession/bobkoig01_pos_.csv',index_col=0)
df_bourqga01_pos=pd.read_csv('../PlayerData/2009/posession/bourqga01_pos_.csv',index_col=0)
df_bourqry01_pos=pd.read_csv('../PlayerData/2009/posession/bourqry01_pos_.csv',index_col=0)
df_brownch01_pos=pd.read_csv('../PlayerData/2009/posession/brownch01_pos_.csv',index_col=0)
df_bubniji01_pos=pd.read_csv('../PlayerData/2009/posession/bubniji01_pos_.csv',index_col=0)
df_budisza01_pos=pd.read_csv('../PlayerData/2009/posession/budisza01_pos_.csv',index_col=0)
df_buttory01_pos=pd.read_csv('../PlayerData/2009/posession/buttory01_pos_.csv',index_col=0)
df_callami01_pos=pd.read_csv('../PlayerData/2009/posession/callami01_pos_.csv',index_col=0)
df_cannajo01_pos=pd.read_csv('../PlayerData/2009/posession/cannajo01_pos_.csv',index_col=0)
df_caronjo01_pos=pd.read_csv('../PlayerData/2009/posession/caronjo01_pos_.csv',index_col=0)
df_casavbe01_pos=pd.read_csv('../PlayerData/2009/posession/casavbe01_pos_.csv',index_col=0)
df_chiarbe01_pos=pd.read_csv('../PlayerData/2009/posession/chiarbe01_pos_.csv',index_col=0)
df_chiasal01_pos=pd.read_csv('../PlayerData/2009/posession/chiasal01_pos_.csv',index_col=0)
df_cichymi01_pos=pd.read_csv('../PlayerData/2009/posession/cichymi01_pos_.csv',index_col=0)
df_cizikca01_pos=pd.read_csv('../PlayerData/2009/posession/cizikca01_pos_.csv',index_col=0)
df_clarkma01_pos=pd.read_csv('../PlayerData/2009/posession/clarkma01_pos_.csv',index_col=0)
df_cliffky01_pos=pd.read_csv('../PlayerData/2009/posession/cliffky01_pos_.csv',index_col=0)
df_connake01_pos=pd.read_csv('../PlayerData/2009/posession/connake01_pos_.csv',index_col=0)
df_costeje01_pos=pd.read_csv('../PlayerData/2009/posession/costeje01_pos_.csv',index_col=0)
df_cowenja01_pos=pd.read_csv('../PlayerData/2009/posession/cowenja01_pos_.csv',index_col=0)
df_cowicco01_pos=pd.read_csv('../PlayerData/2009/posession/cowicco01_pos_.csv',index_col=0)
df_damigje01_pos=pd.read_csv('../PlayerData/2009/posession/damigje01_pos_.csv',index_col=0)
df_dehaaca01_pos=pd.read_csv('../PlayerData/2009/posession/dehaaca01_pos_.csv',index_col=0)
df_delisda01_pos=pd.read_csv('../PlayerData/2009/posession/delisda01_pos_.csv',index_col=0)
df_deslani01_pos=pd.read_csv('../PlayerData/2009/posession/deslani01_pos_.csv',index_col=0)
df_desprsi01_pos=pd.read_csv('../PlayerData/2009/posession/desprsi01_pos_.csv',index_col=0)
df_devanja01_pos=pd.read_csv('../PlayerData/2009/posession/devanja01_pos_.csv',index_col=0)
df_doherta01_pos=pd.read_csv('../PlayerData/2009/posession/doherta01_pos_.csv',index_col=0)
df_dowdni01_pos=pd.read_csv('../PlayerData/2009/posession/dowdni01_pos_.csv',index_col=0)
df_duchema01_pos=pd.read_csv('../PlayerData/2009/posession/duchema01_pos_.csv',index_col=0)
df_dumonga01_pos=pd.read_csv('../PlayerData/2009/posession/dumonga01_pos_.csv',index_col=0)
df_dumoubr01_pos=pd.read_csv('../PlayerData/2009/posession/dumoubr01_pos_.csv',index_col=0)
df_eakinco01_pos=pd.read_csv('../PlayerData/2009/posession/eakinco01_pos_.csv',index_col=0)
df_ekbomvi01_pos=pd.read_csv('../PlayerData/2009/posession/ekbomvi01_pos_.csv',index_col=0)
df_ekholma01_pos=pd.read_csv('../PlayerData/2009/posession/ekholma01_pos_.csv',index_col=0)
df_ekmanol01_pos=pd.read_csv('../PlayerData/2009/posession/ekmanol01_pos_.csv',index_col=0)
df_elliost01_pos=pd.read_csv('../PlayerData/2009/posession/elliost01_pos_.csv',index_col=0)
df_ellisry01_pos=pd.read_csv('../PlayerData/2009/posession/ellisry01_pos_.csv',index_col=0)
df_erixoti01_pos=pd.read_csv('../PlayerData/2009/posession/erixoti01_pos_.csv',index_col=0)
df_fallsal01_pos=pd.read_csv('../PlayerData/2009/posession/fallsal01_pos_.csv',index_col=0)
df_ferrala01_pos=pd.read_csv('../PlayerData/2009/posession/ferrala01_pos_.csv',index_col=0)
df_flemmbr01_pos=pd.read_csv('../PlayerData/2009/posession/flemmbr01_pos_.csv',index_col=0)
df_foligma01_pos=pd.read_csv('../PlayerData/2009/posession/foligma01_pos_.csv',index_col=0)
df_foucakr01_pos=pd.read_csv('../PlayerData/2009/posession/foucakr01_pos_.csv',index_col=0)
df_fourngl01_pos=pd.read_csv('../PlayerData/2009/posession/fourngl01_pos_.csv',index_col=0)
df_froesby01_pos=pd.read_csv('../PlayerData/2009/posession/froesby01_pos_.csv',index_col=0)
df_gedigcu01_pos=pd.read_csv('../PlayerData/2009/posession/gedigcu01_pos_.csv',index_col=0)
df_geliner01_pos=pd.read_csv('../PlayerData/2009/posession/geliner01_pos_.csv',index_col=0)
df_gilbeda01_pos=pd.read_csv('../PlayerData/2009/posession/gilbeda01_pos_.csv',index_col=0)
df_glennsc01_pos=pd.read_csv('../PlayerData/2009/posession/glennsc01_pos_.csv',index_col=0)
df_gotovki01_pos=pd.read_csv('../PlayerData/2009/posession/gotovki01_pos_.csv',index_col=0)
df_hackema01_pos=pd.read_csv('../PlayerData/2009/posession/hackema01_pos_.csv',index_col=0)
df_hambuan01_pos=pd.read_csv('../PlayerData/2009/posession/hambuan01_pos_.csv',index_col=0)
df_hanowbe01_pos=pd.read_csv('../PlayerData/2009/posession/hanowbe01_pos_.csv',index_col=0)
df_haulaer01_pos=pd.read_csv('../PlayerData/2009/posession/haulaer01_pos_.csv',index_col=0)
df_hedmavi01_pos=pd.read_csv('../PlayerData/2009/posession/hedmavi01_pos_.csv',index_col=0)
df_helgese01_pos=pd.read_csv('../PlayerData/2009/posession/helgese01_pos_.csv',index_col=0)
df_hesketr01_pos=pd.read_csv('../PlayerData/2009/posession/hesketr01_pos_.csv',index_col=0)
df_hoffmmi02_pos=pd.read_csv('../PlayerData/2009/posession/hoffmmi02_pos_.csv',index_col=0)
df_hollape01_pos=pd.read_csv('../PlayerData/2009/posession/hollape01_pos_.csv',index_col=0)
df_horakro01_pos=pd.read_csv('../PlayerData/2009/posession/horakro01_pos_.csv',index_col=0)
df_howsery01_pos=pd.read_csv('../PlayerData/2009/posession/howsery01_pos_.csv',index_col=0)
df_hutchal01_pos=pd.read_csv('../PlayerData/2009/posession/hutchal01_pos_.csv',index_col=0)
df_illora01_pos=pd.read_csv('../PlayerData/2009/posession/illora01_pos_.csv',index_col=0)
df_janusja01_pos=pd.read_csv('../PlayerData/2009/posession/janusja01_pos_.csv',index_col=0)
df_jenseni02_pos=pd.read_csv('../PlayerData/2009/posession/jenseni02_pos_.csv',index_col=0)
df_johanma03_pos=pd.read_csv('../PlayerData/2009/posession/johanma03_pos_.csv',index_col=0)
df_josefja01_pos=pd.read_csv('../PlayerData/2009/posession/josefja01_pos_.csv',index_col=0)
df_kadrina01_pos=pd.read_csv('../PlayerData/2009/posession/kadrina01_pos_.csv',index_col=0)
df_kaneev01_pos=pd.read_csv('../PlayerData/2009/posession/kaneev01_pos_.csv',index_col=0)
df_kassiza01_pos=pd.read_csv('../PlayerData/2009/posession/kassiza01_pos_.csv',index_col=0)
df_kennema01_pos=pd.read_csv('../PlayerData/2009/posession/kennema01_pos_.csv',index_col=0)
df_kivisto01_pos=pd.read_csv('../PlayerData/2009/posession/kivisto01_pos_.csv',index_col=0)
df_klemean01_pos=pd.read_csv('../PlayerData/2009/posession/klemean01_pos_.csv',index_col=0)
df_klingca01_pos=pd.read_csv('../PlayerData/2009/posession/klingca01_pos_.csv',index_col=0)
df_knappco01_pos=pd.read_csv('../PlayerData/2009/posession/knappco01_pos_.csv',index_col=0)
df_knighco01_pos=pd.read_csv('../PlayerData/2009/posession/knighco01_pos_.csv',index_col=0)
df_knodeer01_pos=pd.read_csv('../PlayerData/2009/posession/knodeer01_pos_.csv',index_col=0)
df_kolomda01_pos=pd.read_csv('../PlayerData/2009/posession/kolomda01_pos_.csv',index_col=0)
df_koperle01_pos=pd.read_csv('../PlayerData/2009/posession/koperle01_pos_.csv',index_col=0)
df_koskimi01_pos=pd.read_csv('../PlayerData/2009/posession/koskimi01_pos_.csv',index_col=0)
df_kozunbr01_pos=pd.read_csv('../PlayerData/2009/posession/kozunbr01_pos_.csv',index_col=0)
df_kreidch01_pos=pd.read_csv('../PlayerData/2009/posession/kreidch01_pos_.csv',index_col=0)
df_krugema01_pos=pd.read_csv('../PlayerData/2009/posession/krugema01_pos_.csv',index_col=0)
df_kuempda01_pos=pd.read_csv('../PlayerData/2009/posession/kuempda01_pos_.csv',index_col=0)
df_kulikdm01_pos=pd.read_csv('../PlayerData/2009/posession/kulikdm01_pos_.csv',index_col=0)
df_labreda01_pos=pd.read_csv('../PlayerData/2009/posession/labreda01_pos_.csv',index_col=0)
df_landean01_pos=pd.read_csv('../PlayerData/2009/posession/landean01_pos_.csv',index_col=0)
df_larkith01_pos=pd.read_csv('../PlayerData/2009/posession/larkith01_pos_.csv',index_col=0)
df_lattami01_pos=pd.read_csv('../PlayerData/2009/posession/lattami01_pos_.csv',index_col=0)
df_lauriol01_pos=pd.read_csv('../PlayerData/2009/posession/lauriol01_pos_.csv',index_col=0)
df_leblalo01_pos=pd.read_csv('../PlayerData/2009/posession/leblalo01_pos_.csv',index_col=0)
df_leddyni01_pos=pd.read_csv('../PlayerData/2009/posession/leddyni01_pos_.csv',index_col=0)
df_leean01_pos=pd.read_csv('../PlayerData/2009/posession/leean01_pos_.csv',index_col=0)
df_leemi01_pos=pd.read_csv('../PlayerData/2009/posession/leemi01_pos_.csv',index_col=0)
df_legauma01_pos=pd.read_csv('../PlayerData/2009/posession/legauma01_pos_.csv',index_col=0)
df_lehnero01_pos=pd.read_csv('../PlayerData/2009/posession/lehnero01_pos_.csv',index_col=0)
df_lindsma01_pos=pd.read_csv('../PlayerData/2009/posession/lindsma01_pos_.csv',index_col=0)
df_lynchke01_pos=pd.read_csv('../PlayerData/2009/posession/lynchke01_pos_.csv',index_col=0)
df_macdela01_pos=pd.read_csv('../PlayerData/2009/posession/macdela01_pos_.csv',index_col=0)
df_maggida01_pos=pd.read_csv('../PlayerData/2009/posession/maggida01_pos_.csv',index_col=0)
df_maxwebr03_pos=pd.read_csv('../PlayerData/2009/posession/maxwebr03_pos_.csv',index_col=0)
df_mckencu01_pos=pd.read_csv('../PlayerData/2009/posession/mckencu01_pos_.csv',index_col=0)
df_mcnabbr01_pos=pd.read_csv('../PlayerData/2009/posession/mcnabbr01_pos_.csv',index_col=0)
df_meganwa01_pos=pd.read_csv('../PlayerData/2009/posession/meganwa01_pos_.csv',index_col=0)
df_millaki01_pos=pd.read_csv('../PlayerData/2009/posession/millaki01_pos_.csv',index_col=0)
df_mitchga01_pos=pd.read_csv('../PlayerData/2009/posession/mitchga01_pos_.csv',index_col=0)
df_moorejo01_pos=pd.read_csv('../PlayerData/2009/posession/moorejo01_pos_.csv',index_col=0)
df_morinje01_pos=pd.read_csv('../PlayerData/2009/posession/morinje01_pos_.csv',index_col=0)
df_morriad01_pos=pd.read_csv('../PlayerData/2009/posession/morriad01_pos_.csv',index_col=0)
df_nattijo01_pos=pd.read_csv('../PlayerData/2009/posession/nattijo01_pos_.csv',index_col=0)
df_nestran01_pos=pd.read_csv('../PlayerData/2009/posession/nestran01_pos_.csv',index_col=0)
df_neubeky01_pos=pd.read_csv('../PlayerData/2009/posession/neubeky01_pos_.csv',index_col=0)
df_nilssan01_pos=pd.read_csv('../PlayerData/2009/posession/nilssan01_pos_.csv',index_col=0)
df_nolanjo01_pos=pd.read_csv('../PlayerData/2009/posession/nolanjo01_pos_.csv',index_col=0)
df_oliveni01_pos=pd.read_csv('../PlayerData/2009/posession/oliveni01_pos_.csv',index_col=0)
df_olsendy01_pos=pd.read_csv('../PlayerData/2009/posession/olsendy01_pos_.csv',index_col=0)
df_oreilry01_pos=pd.read_csv('../PlayerData/2009/posession/oreilry01_pos_.csv',index_col=0)
df_orlovdm01_pos=pd.read_csv('../PlayerData/2009/posession/orlovdm01_pos_.csv',index_col=0)
df_ortiojo01_pos=pd.read_csv('../PlayerData/2009/posession/ortiojo01_pos_.csv',index_col=0)
df_paajama01_pos=pd.read_csv('../PlayerData/2009/posession/paajama01_pos_.csv',index_col=0)
df_pacanda01_pos=pd.read_csv('../PlayerData/2009/posession/pacanda01_pos_.csv',index_col=0)
df_palmiky01_pos=pd.read_csv('../PlayerData/2009/posession/palmiky01_pos_.csv',index_col=0)
df_panikri01_pos=pd.read_csv('../PlayerData/2009/posession/panikri01_pos_.csv',index_col=0)
df_paradph01_pos=pd.read_csv('../PlayerData/2009/posession/paradph01_pos_.csv',index_col=0)
df_pashnmi01_pos=pd.read_csv('../PlayerData/2009/posession/pashnmi01_pos_.csv',index_col=0)
df_pasqued01_pos=pd.read_csv('../PlayerData/2009/posession/pasqued01_pos_.csv',index_col=0)
df_pattega01_pos=pd.read_csv('../PlayerData/2009/posession/pattega01_pos_.csv',index_col=0)
df_pelecmi01_pos=pd.read_csv('../PlayerData/2009/posession/pelecmi01_pos_.csv',index_col=0)
df_peltzbr01_pos=pd.read_csv('../PlayerData/2009/posession/peltzbr01_pos_.csv',index_col=0)
df_peterni01_pos=pd.read_csv('../PlayerData/2009/posession/peterni01_pos_.csv',index_col=0)
df_phillpa01_pos=pd.read_csv('../PlayerData/2009/posession/phillpa01_pos_.csv',index_col=0)
df_pirribr01_pos=pd.read_csv('../PlayerData/2009/posession/pirribr01_pos_.csv',index_col=0)
df_ponicbr01_pos=pd.read_csv('../PlayerData/2009/posession/ponicbr01_pos_.csv',index_col=0)
df_priceje01_pos=pd.read_csv('../PlayerData/2009/posession/priceje01_pos_.csv',index_col=0)
df_rajalto01_pos=pd.read_csv('../PlayerData/2009/posession/rajalto01_pos_.csv',index_col=0)
df_randety01_pos=pd.read_csv('../PlayerData/2009/posession/randety01_pos_.csv',index_col=0)
df_reidca01_pos=pd.read_csv('../PlayerData/2009/posession/reidca01_pos_.csv',index_col=0)
df_riopeni01_pos=pd.read_csv('../PlayerData/2009/posession/riopeni01_pos_.csv',index_col=0)
df_rissara01_pos=pd.read_csv('../PlayerData/2009/posession/rissara01_pos_.csv',index_col=0)
df_rodinan01_pos=pd.read_csv('../PlayerData/2009/posession/rodinan01_pos_.csv',index_col=0)
df_rodwede01_pos=pd.read_csv('../PlayerData/2009/posession/rodwede01_pos_.csv',index_col=0)
df_roussch01_pos=pd.read_csv('../PlayerData/2009/posession/roussch01_pos_.csv',index_col=0)
df_royol01_pos=pd.read_csv('../PlayerData/2009/posession/royol01_pos_.csv',index_col=0)
df_rundbda01_pos=pd.read_csv('../PlayerData/2009/posession/rundbda01_pos_.csv',index_col=0)
df_ryanke01_pos=pd.read_csv('../PlayerData/2009/posession/ryanke01_pos_.csv',index_col=0)
df_sallije01_pos=pd.read_csv('../PlayerData/2009/posession/sallije01_pos_.csv',index_col=0)
df_samuejo01_pos=pd.read_csv('../PlayerData/2009/posession/samuejo01_pos_.csv',index_col=0)
df_samueph01_pos=pd.read_csv('../PlayerData/2009/posession/samueph01_pos_.csv',index_col=0)
df_savarda01_pos=pd.read_csv('../PlayerData/2009/posession/savarda01_pos_.csv',index_col=0)
df_schenbr01_pos=pd.read_csv('../PlayerData/2009/posession/schenbr01_pos_.csv',index_col=0)
df_schrojo01_pos=pd.read_csv('../PlayerData/2009/posession/schrojo01_pos_.csv',index_col=0)
df_sdaomi01_pos=pd.read_csv('../PlayerData/2009/posession/sdaomi01_pos_.csv',index_col=0)
df_sextobe01_pos=pd.read_csv('../PlayerData/2009/posession/sextobe01_pos_.csv',index_col=0)
df_shattty01_pos=pd.read_csv('../PlayerData/2009/posession/shattty01_pos_.csv',index_col=0)
df_shielda01_pos=pd.read_csv('../PlayerData/2009/posession/shielda01_pos_.csv',index_col=0)
df_shoredr01_pos=pd.read_csv('../PlayerData/2009/posession/shoredr01_pos_.csv',index_col=0)
df_silfvja01_pos=pd.read_csv('../PlayerData/2009/posession/silfvja01_pos_.csv',index_col=0)
df_similpe01_pos=pd.read_csv('../PlayerData/2009/posession/similpe01_pos_.csv',index_col=0)
df_smithba02_pos=pd.read_csv('../PlayerData/2009/posession/smithba02_pos_.csv',index_col=0)
df_smithcr01_pos=pd.read_csv('../PlayerData/2009/posession/smithcr01_pos_.csv',index_col=0)
df_smithre01_pos=pd.read_csv('../PlayerData/2009/posession/smithre01_pos_.csv',index_col=0)
df_solco01_pos=pd.read_csv('../PlayerData/2009/posession/solco01_pos_.csv',index_col=0)
df_stajcsc01_pos=pd.read_csv('../PlayerData/2009/posession/stajcsc01_pos_.csv',index_col=0)
df_szwarjo01_pos=pd.read_csv('../PlayerData/2009/posession/szwarjo01_pos_.csv',index_col=0)
df_tardyma01_pos=pd.read_csv('../PlayerData/2009/posession/tardyma01_pos_.csv',index_col=0)
df_tatarto01_pos=pd.read_csv('../PlayerData/2009/posession/tatarto01_pos_.csv',index_col=0)
df_tavarjo01_pos=pd.read_csv('../PlayerData/2009/posession/tavarjo01_pos_.csv',index_col=0)
df_timmisc01_pos=pd.read_csv('../PlayerData/2009/posession/timmisc01_pos_.csv',index_col=0)
df_urbomal01_pos=pd.read_csv('../PlayerData/2009/posession/urbomal01_pos_.csv',index_col=0)
df_valensc01_pos=pd.read_csv('../PlayerData/2009/posession/valensc01_pos_.csv',index_col=0)
df_varonph01_pos=pd.read_csv('../PlayerData/2009/posession/varonph01_pos_.csv',index_col=0)
df_vatansa01_pos=pd.read_csv('../PlayerData/2009/posession/vatansa01_pos_.csv',index_col=0)
df_velisal01_pos=pd.read_csv('../PlayerData/2009/posession/velisal01_pos_.csv',index_col=0)
df_veyli01_pos=pd.read_csv('../PlayerData/2009/posession/veyli01_pos_.csv',index_col=0)
df_viedema01_pos=pd.read_csv('../PlayerData/2009/posession/viedema01_pos_.csv',index_col=0)
df_vincoto01_pos=pd.read_csv('../PlayerData/2009/posession/vincoto01_pos_.csv',index_col=0)
df_walshdu01_pos=pd.read_csv('../PlayerData/2009/posession/walshdu01_pos_.csv',index_col=0)
df_welleju01_pos=pd.read_csv('../PlayerData/2009/posession/welleju01_pos_.csv',index_col=0)
df_wellwer01_pos=pd.read_csv('../PlayerData/2009/posession/wellwer01_pos_.csv',index_col=0)
df_wereket01_pos=pd.read_csv('../PlayerData/2009/posession/wereket01_pos_.csv',index_col=0)
df_weypa01_pos=pd.read_csv('../PlayerData/2009/posession/weypa01_pos_.csv',index_col=0)
df_widemch01_pos=pd.read_csv('../PlayerData/2009/posession/widemch01_pos_.csv',index_col=0)
df_wilsoga01_pos=pd.read_csv('../PlayerData/2009/posession/wilsoga01_pos_.csv',index_col=0)
df_wrennwi01_pos=pd.read_csv('../PlayerData/2009/posession/wrennwi01_pos_.csv',index_col=0)
df_younggu01_pos=pd.read_csv('../PlayerData/2009/posession/younggu01_pos_.csv',index_col=0)
df_zadormi01_pos=pd.read_csv('../PlayerData/2009/posession/zadormi01_pos_.csv',index_col=0)

# %%
#df_adamscr01_pos['name']='adamscr01'

# %%
#listcsv

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"[name]="+elem[:-9]
# Out:
# df_abneyca01_pos[name]=abneyca01
# df_adamsma01_pos[name]=adamsma01
# df_almqvad01_pos[name]=almqvad01
# df_anderpe04_pos[name]=anderpe04
# df_androse01_pos[name]=androse01
# df_anthost01_pos[name]=anthost01
# df_ashtoca01_pos[name]=ashtoca01
# df_avtsial01_pos[name]=avtsial01
# df_barrity01_pos[name]=barrity01
# df_bathgan02_pos[name]=bathgan02
# df_beckta01_pos[name]=beckta01
# df_bennema02_pos[name]=bennema02
# df_bennesp01_pos[name]=bennesp01
# df_bernaas01_pos[name]=bernaas01
# df_bertisi01_pos[name]=bertisi01
# df_berubje02_pos[name]=berubje02
# df_bielkdo01_pos[name]=bielkdo01
# df_bigosky01_pos[name]=bigosky01
# df_birkhjo01_pos[name]=birkhjo01
# df_bjorkhe01_pos[name]=bjorkhe01
# df_blackje01_pos[name]=blackje01
# df_blomqan01_pos[name]=blomqan01
# df_bloodev01_pos[name]=bloodev01
# df_bobkoig01_pos[name]=bobkoig01
# df_bourqga01_pos[name]=bourqga01
# df_bourqry01_pos[name]=bourqry01
# df_brownch01_pos[name]=brownch01
# df_bubniji01_pos[name]=bubniji01
# ...

# %%
df_abneyca01_pos['name']='abneyca01'
df_adamsma01_pos['name']='adamsma01'
df_almqvad01_pos['name']='almqvad01'
df_anderpe04_pos['name']='anderpe04'
df_androse01_pos['name']='androse01'
df_anthost01_pos['name']='anthost01'
df_ashtoca01_pos['name']='ashtoca01'
df_avtsial01_pos['name']='avtsial01'
df_barrity01_pos['name']='barrity01'
df_bathgan02_pos['name']='bathgan02'
df_beckta01_pos['name']='beckta01'
df_bennema02_pos['name']='bennema02'
df_bennesp01_pos['name']='bennesp01'
df_bernaas01_pos['name']='bernaas01'
df_bertisi01_pos['name']='bertisi01'
df_berubje02_pos['name']='berubje02'
df_bielkdo01_pos['name']='bielkdo01'
df_bigosky01_pos['name']='bigosky01'
df_birkhjo01_pos['name']='birkhjo01'
df_bjorkhe01_pos['name']='bjorkhe01'
df_blackje01_pos['name']='blackje01'
df_blomqan01_pos['name']='blomqan01'
df_bloodev01_pos['name']='bloodev01'
df_bobkoig01_pos['name']='bobkoig01'
df_bourqga01_pos['name']='bourqga01'
df_bourqry01_pos['name']='bourqry01'
df_brownch01_pos['name']='brownch01'
df_bubniji01_pos['name']='bubniji01'
df_budisza01_pos['name']='budisza01'
df_buttory01_pos['name']='buttory01'
df_callami01_pos['name']='callami01'
df_cannajo01_pos['name']='cannajo01'
df_caronjo01_pos['name']='caronjo01'
df_casavbe01_pos['name']='casavbe01'
df_chiarbe01_pos['name']='chiarbe01'
df_chiasal01_pos['name']='chiasal01'
df_cichymi01_pos['name']='cichymi01'
df_cizikca01_pos['name']='cizikca01'
df_clarkma01_pos['name']='clarkma01'
df_cliffky01_pos['name']='cliffky01'
df_connake01_pos['name']='connake01'
df_costeje01_pos['name']='costeje01'
df_cowenja01_pos['name']='cowenja01'
df_cowicco01_pos['name']='cowicco01'
df_damigje01_pos['name']='damigje01'
df_dehaaca01_pos['name']='dehaaca01'
df_delisda01_pos['name']='delisda01'
df_deslani01_pos['name']='deslani01'
df_desprsi01_pos['name']='desprsi01'
df_devanja01_pos['name']='devanja01'
df_doherta01_pos['name']='doherta01'
df_dowdni01_pos['name']='dowdni01'
df_duchema01_pos['name']='duchema01'
df_dumonga01_pos['name']='dumonga01'
df_dumoubr01_pos['name']='dumoubr01'
df_eakinco01_pos['name']='eakinco01'
df_ekbomvi01_pos['name']='ekbomvi01'
df_ekholma01_pos['name']='ekholma01'
df_ekmanol01_pos['name']='ekmanol01'
df_elliost01_pos['name']='elliost01'
df_ellisry01_pos['name']='ellisry01'
df_erixoti01_pos['name']='erixoti01'
df_fallsal01_pos['name']='fallsal01'
df_ferrala01_pos['name']='ferrala01'
df_flemmbr01_pos['name']='flemmbr01'
df_foligma01_pos['name']='foligma01'
df_foucakr01_pos['name']='foucakr01'
df_fourngl01_pos['name']='fourngl01'
df_froesby01_pos['name']='froesby01'
df_gedigcu01_pos['name']='gedigcu01'
df_geliner01_pos['name']='geliner01'
df_gilbeda01_pos['name']='gilbeda01'
df_glennsc01_pos['name']='glennsc01'
df_gotovki01_pos['name']='gotovki01'
df_hackema01_pos['name']='hackema01'
df_hambuan01_pos['name']='hambuan01'
df_hanowbe01_pos['name']='hanowbe01'
df_haulaer01_pos['name']='haulaer01'
df_hedmavi01_pos['name']='hedmavi01'
df_helgese01_pos['name']='helgese01'
df_hesketr01_pos['name']='hesketr01'
df_hoffmmi02_pos['name']='hoffmmi02'
df_hollape01_pos['name']='hollape01'
df_horakro01_pos['name']='horakro01'
df_howsery01_pos['name']='howsery01'
df_hutchal01_pos['name']='hutchal01'
df_illora01_pos['name']='illora01'
df_janusja01_pos['name']='janusja01'
df_jenseni02_pos['name']='jenseni02'
df_johanma03_pos['name']='johanma03'
df_josefja01_pos['name']='josefja01'
df_kadrina01_pos['name']='kadrina01'
df_kaneev01_pos['name']='kaneev01'
df_kassiza01_pos['name']='kassiza01'
df_kennema01_pos['name']='kennema01'
df_kivisto01_pos['name']='kivisto01'
df_klemean01_pos['name']='klemean01'
df_klingca01_pos['name']='klingca01'
df_knappco01_pos['name']='knappco01'
df_knighco01_pos['name']='knighco01'
df_knodeer01_pos['name']='knodeer01'
df_kolomda01_pos['name']='kolomda01'
df_koperle01_pos['name']='koperle01'
df_koskimi01_pos['name']='koskimi01'
df_kozunbr01_pos['name']='kozunbr01'
df_kreidch01_pos['name']='kreidch01'
df_krugema01_pos['name']='krugema01'
df_kuempda01_pos['name']='kuempda01'
df_kulikdm01_pos['name']='kulikdm01'
df_labreda01_pos['name']='labreda01'
df_landean01_pos['name']='landean01'
df_larkith01_pos['name']='larkith01'
df_lattami01_pos['name']='lattami01'
df_lauriol01_pos['name']='lauriol01'
df_leblalo01_pos['name']='leblalo01'
df_leddyni01_pos['name']='leddyni01'
df_leean01_pos['name']='leean01'
df_leemi01_pos['name']='leemi01'
df_legauma01_pos['name']='legauma01'
df_lehnero01_pos['name']='lehnero01'
df_lindsma01_pos['name']='lindsma01'
df_lynchke01_pos['name']='lynchke01'
df_macdela01_pos['name']='macdela01'
df_maggida01_pos['name']='maggida01'
df_maxwebr03_pos['name']='maxwebr03'
df_mckencu01_pos['name']='mckencu01'
df_mcnabbr01_pos['name']='mcnabbr01'
df_meganwa01_pos['name']='meganwa01'
df_millaki01_pos['name']='millaki01'
df_mitchga01_pos['name']='mitchga01'
df_moorejo01_pos['name']='moorejo01'
df_morinje01_pos['name']='morinje01'
df_morriad01_pos['name']='morriad01'
df_nattijo01_pos['name']='nattijo01'
df_nestran01_pos['name']='nestran01'
df_neubeky01_pos['name']='neubeky01'
df_nilssan01_pos['name']='nilssan01'
df_nolanjo01_pos['name']='nolanjo01'
df_oliveni01_pos['name']='oliveni01'
df_olsendy01_pos['name']='olsendy01'
df_oreilry01_pos['name']='oreilry01'
df_orlovdm01_pos['name']='orlovdm01'
df_ortiojo01_pos['name']='ortiojo01'
df_paajama01_pos['name']='paajama01'
df_pacanda01_pos['name']='pacanda01'
df_palmiky01_pos['name']='palmiky01'
df_panikri01_pos['name']='panikri01'
df_paradph01_pos['name']='paradph01'
df_pashnmi01_pos['name']='pashnmi01'
df_pasqued01_pos['name']='pasqued01'
df_pattega01_pos['name']='pattega01'
df_pelecmi01_pos['name']='pelecmi01'
df_peltzbr01_pos['name']='peltzbr01'
df_peterni01_pos['name']='peterni01'
df_phillpa01_pos['name']='phillpa01'
df_pirribr01_pos['name']='pirribr01'
df_ponicbr01_pos['name']='ponicbr01'
df_priceje01_pos['name']='priceje01'
df_rajalto01_pos['name']='rajalto01'
df_randety01_pos['name']='randety01'
df_reidca01_pos['name']='reidca01'
df_riopeni01_pos['name']='riopeni01'
df_rissara01_pos['name']='rissara01'
df_rodinan01_pos['name']='rodinan01'
df_rodwede01_pos['name']='rodwede01'
df_roussch01_pos['name']='roussch01'
df_royol01_pos['name']='royol01'
df_rundbda01_pos['name']='rundbda01'
df_ryanke01_pos['name']='ryanke01'
df_sallije01_pos['name']='sallije01'
df_samuejo01_pos['name']='samuejo01'
df_samueph01_pos['name']='samueph01'
df_savarda01_pos['name']='savarda01'
df_schenbr01_pos['name']='schenbr01'
df_schrojo01_pos['name']='schrojo01'
df_sdaomi01_pos['name']='sdaomi01'
df_sextobe01_pos['name']='sextobe01'
df_shattty01_pos['name']='shattty01'
df_shielda01_pos['name']='shielda01'
df_shoredr01_pos['name']='shoredr01'
df_silfvja01_pos['name']='silfvja01'
df_similpe01_pos['name']='similpe01'
df_smithba02_pos['name']='smithba02'
df_smithcr01_pos['name']='smithcr01'
df_smithre01_pos['name']='smithre01'
df_solco01_pos['name']='solco01'
df_stajcsc01_pos['name']='stajcsc01'
df_szwarjo01_pos['name']='szwarjo01'
df_tardyma01_pos['name']='tardyma01'
df_tatarto01_pos['name']='tatarto01'
df_tavarjo01_pos['name']='tavarjo01'
df_timmisc01_pos['name']='timmisc01'
df_urbomal01_pos['name']='urbomal01'
df_valensc01_pos['name']='valensc01'
df_varonph01_pos['name']='varonph01'
df_vatansa01_pos['name']='vatansa01'
df_velisal01_pos['name']='velisal01'
df_veyli01_pos['name']='veyli01'
df_viedema01_pos['name']='viedema01'
df_vincoto01_pos['name']='vincoto01'
df_walshdu01_pos['name']='walshdu01'
df_welleju01_pos['name']='welleju01'
df_wellwer01_pos['name']='wellwer01'
df_wereket01_pos['name']='wereket01'
df_weypa01_pos['name']='weypa01'
df_widemch01_pos['name']='widemch01'
df_wilsoga01_pos['name']='wilsoga01'
df_wrennwi01_pos['name']='wrennwi01'
df_younggu01_pos['name']='younggu01'
df_zadormi01_pos['name']='zadormi01'

# %%
#df_aebisda01_pos

# %%
for elem in listcsv:
    print "df_"+elem[:-5]
# Out:
# df_abneyca01_pos
# df_adamsma01_pos
# df_almqvad01_pos
# df_anderpe04_pos
# df_androse01_pos
# df_anthost01_pos
# df_ashtoca01_pos
# df_avtsial01_pos
# df_barrity01_pos
# df_bathgan02_pos
# df_beckta01_pos
# df_bennema02_pos
# df_bennesp01_pos
# df_bernaas01_pos
# df_bertisi01_pos
# df_berubje02_pos
# df_bielkdo01_pos
# df_bigosky01_pos
# df_birkhjo01_pos
# df_bjorkhe01_pos
# df_blackje01_pos
# df_blomqan01_pos
# df_bloodev01_pos
# df_bobkoig01_pos
# df_bourqga01_pos
# df_bourqry01_pos
# df_brownch01_pos
# df_bubniji01_pos
# df_budisza01_pos
# df_buttory01_pos
# df_callami01_pos
# df_cannajo01_pos
# df_caronjo01_pos
# df_casavbe01_pos
# df_chiarbe01_pos
# df_chiasal01_pos
# df_cichymi01_pos
# df_cizikca01_pos
# df_clarkma01_pos
# df_cliffky01_pos
# df_connake01_pos
# df_costeje01_pos
# df_cowenja01_pos
# df_cowicco01_pos
# df_damigje01_pos
# df_dehaaca01_pos
# df_delisda01_pos
# df_deslani01_pos
# df_desprsi01_pos
# df_devanja01_pos
# df_doherta01_pos
# df_dowdni01_pos
# ...

# %%
pos_frames=[df_abneyca01_pos,
df_adamsma01_pos,
df_almqvad01_pos,
df_anderpe04_pos,
df_androse01_pos,
df_anthost01_pos,
df_ashtoca01_pos,
df_avtsial01_pos,
df_barrity01_pos,
df_bathgan02_pos,
df_beckta01_pos,
df_bennema02_pos,
df_bennesp01_pos,
df_bernaas01_pos,
df_bertisi01_pos,
df_berubje02_pos,
df_bielkdo01_pos,
df_bigosky01_pos,
df_birkhjo01_pos,
df_bjorkhe01_pos,
df_blackje01_pos,
df_blomqan01_pos,
df_bloodev01_pos,
df_bobkoig01_pos,
df_bourqga01_pos,
df_bourqry01_pos,
df_brownch01_pos,
df_bubniji01_pos,
df_budisza01_pos,
df_buttory01_pos,
df_callami01_pos,
df_cannajo01_pos,
df_caronjo01_pos,
df_casavbe01_pos,
df_chiarbe01_pos,
df_chiasal01_pos,
df_cichymi01_pos,
df_cizikca01_pos,
df_clarkma01_pos,
df_cliffky01_pos,
df_connake01_pos,
df_costeje01_pos,
df_cowenja01_pos,
df_cowicco01_pos,
df_damigje01_pos,
df_dehaaca01_pos,
df_delisda01_pos,
df_deslani01_pos,
df_desprsi01_pos,
df_devanja01_pos,
df_doherta01_pos,
df_dowdni01_pos,
df_duchema01_pos,
df_dumonga01_pos,
df_dumoubr01_pos,
df_eakinco01_pos,
df_ekbomvi01_pos,
df_ekholma01_pos,
df_ekmanol01_pos,
df_elliost01_pos,
df_ellisry01_pos,
df_erixoti01_pos,
df_fallsal01_pos,
df_ferrala01_pos,
df_flemmbr01_pos,
df_foligma01_pos,
df_foucakr01_pos,
df_fourngl01_pos,
df_froesby01_pos,
df_gedigcu01_pos,
df_geliner01_pos,
df_gilbeda01_pos,
df_glennsc01_pos,
df_gotovki01_pos,
df_hackema01_pos,
df_hambuan01_pos,
df_hanowbe01_pos,
df_haulaer01_pos,
df_hedmavi01_pos,
df_helgese01_pos,
df_hesketr01_pos,
df_hoffmmi02_pos,
df_hollape01_pos,
df_horakro01_pos,
df_howsery01_pos,
df_hutchal01_pos,
df_illora01_pos,
df_janusja01_pos,
df_jenseni02_pos,
df_johanma03_pos,
df_josefja01_pos,
df_kadrina01_pos,
df_kaneev01_pos,
df_kassiza01_pos,
df_kennema01_pos,
df_kivisto01_pos,
df_klemean01_pos,
df_klingca01_pos,
df_knappco01_pos,
df_knighco01_pos,
df_knodeer01_pos,
df_kolomda01_pos,
df_koperle01_pos,
df_koskimi01_pos,
df_kozunbr01_pos,
df_kreidch01_pos,
df_krugema01_pos,
df_kuempda01_pos,
df_kulikdm01_pos,
df_labreda01_pos,
df_landean01_pos,
df_larkith01_pos,
df_lattami01_pos,
df_lauriol01_pos,
df_leblalo01_pos,
df_leddyni01_pos,
df_leean01_pos,
df_leemi01_pos,
df_legauma01_pos,
df_lehnero01_pos,
df_lindsma01_pos,
df_lynchke01_pos,
df_macdela01_pos,
df_maggida01_pos,
df_maxwebr03_pos,
df_mckencu01_pos,
df_mcnabbr01_pos,
df_meganwa01_pos,
df_millaki01_pos,
df_mitchga01_pos,
df_moorejo01_pos,
df_morinje01_pos,
df_morriad01_pos,
df_nattijo01_pos,
df_nestran01_pos,
df_neubeky01_pos,
df_nilssan01_pos,
df_nolanjo01_pos,
df_oliveni01_pos,
df_olsendy01_pos,
df_oreilry01_pos,
df_orlovdm01_pos,
df_ortiojo01_pos,
df_paajama01_pos,
df_pacanda01_pos,
df_palmiky01_pos,
df_panikri01_pos,
df_paradph01_pos,
df_pashnmi01_pos,
df_pasqued01_pos,
df_pattega01_pos,
df_pelecmi01_pos,
df_peltzbr01_pos,
df_peterni01_pos,
df_phillpa01_pos,
df_pirribr01_pos,
df_ponicbr01_pos,
df_priceje01_pos,
df_rajalto01_pos,
df_randety01_pos,
df_reidca01_pos,
df_riopeni01_pos,
df_rissara01_pos,
df_rodinan01_pos,
df_rodwede01_pos,
df_roussch01_pos,
df_royol01_pos,
df_rundbda01_pos,
df_ryanke01_pos,
df_sallije01_pos,
df_samuejo01_pos,
df_samueph01_pos,
df_savarda01_pos,
df_schenbr01_pos,
df_schrojo01_pos,
df_sdaomi01_pos,
df_sextobe01_pos,
df_shattty01_pos,
df_shielda01_pos,
df_shoredr01_pos,
df_silfvja01_pos,
df_similpe01_pos,
df_smithba02_pos,
df_smithcr01_pos,
df_smithre01_pos,
df_solco01_pos,
df_stajcsc01_pos,
df_szwarjo01_pos,
df_tardyma01_pos,
df_tatarto01_pos,
df_tavarjo01_pos,
df_timmisc01_pos,
df_urbomal01_pos,
df_valensc01_pos,
df_varonph01_pos,
df_vatansa01_pos,
df_velisal01_pos,
df_veyli01_pos,
df_viedema01_pos,
df_vincoto01_pos,
df_walshdu01_pos,
df_welleju01_pos,
df_wellwer01_pos,
df_wereket01_pos,
df_weypa01_pos,
df_widemch01_pos,
df_wilsoga01_pos,
df_wrennwi01_pos,
df_younggu01_pos,
df_zadormi01_pos]

# %%
result_pos = pd.concat(pos_frames)

# %%
result_pos
# Out:
#      season  TOT   age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2013-14  DET  22.0       22.0           24.0       47.8            -4
# 1   2011-12  TOR  20.0      116.0          137.0       45.8          -3.7
# 2   2013-14  TOR  22.0      151.0          194.0       43.8          -0.3
# 3   2014-15  TOR  23.0       28.0           43.0       39.4          -1.8
# 1   2011-12  COL  20.0      172.0          142.0       54.8             5
# 2   2012-13  COL  21.0      544.0          533.0       50.5           0.6
# 3   2013-14  COL  22.0      985.0          949.0       50.9           3.9
# 4   2014-15  COL  23.0     1257.0         1473.0       46.0           3.4
# 5   2015-16  COL  24.0     1342.0         1586.0       45.8             2
# 6   2016-17  COL  25.0      355.0          392.0       47.5          -1.9
# 1   2012-13  NSH  21.0      197.0          202.0       49.4           1.3
# 2   2013-14  NSH  22.0       67.0           54.0       55.4           5.4
# ...

# %%
df_abneyca01_strd=pd.read_csv('../PlayerData/2009/standard/abneyca01_strd_.csv',index_col=0)
df_adamsma01_strd=pd.read_csv('../PlayerData/2009/standard/adamsma01_strd_.csv',index_col=0)
df_almqvad01_strd=pd.read_csv('../PlayerData/2009/standard/almqvad01_strd_.csv',index_col=0)
df_anderpe04_strd=pd.read_csv('../PlayerData/2009/standard/anderpe04_strd_.csv',index_col=0)
df_androse01_strd=pd.read_csv('../PlayerData/2009/standard/androse01_strd_.csv',index_col=0)
df_anthost01_strd=pd.read_csv('../PlayerData/2009/standard/anthost01_strd_.csv',index_col=0)
df_ashtoca01_strd=pd.read_csv('../PlayerData/2009/standard/ashtoca01_strd_.csv',index_col=0)
df_avtsial01_strd=pd.read_csv('../PlayerData/2009/standard/avtsial01_strd_.csv',index_col=0)
df_barrity01_strd=pd.read_csv('../PlayerData/2009/standard/barrity01_strd_.csv',index_col=0)
df_bathgan02_strd=pd.read_csv('../PlayerData/2009/standard/bathgan02_strd_.csv',index_col=0)
df_beckta01_strd=pd.read_csv('../PlayerData/2009/standard/beckta01_strd_.csv',index_col=0)
df_bennema02_strd=pd.read_csv('../PlayerData/2009/standard/bennema02_strd_.csv',index_col=0)
df_bennesp01_strd=pd.read_csv('../PlayerData/2009/standard/bennesp01_strd_.csv',index_col=0)
df_bernaas01_strd=pd.read_csv('../PlayerData/2009/standard/bernaas01_strd_.csv',index_col=0)
df_bertisi01_strd=pd.read_csv('../PlayerData/2009/standard/bertisi01_strd_.csv',index_col=0)
df_berubje02_strd=pd.read_csv('../PlayerData/2009/standard/berubje02_strd_.csv',index_col=0)
df_bielkdo01_strd=pd.read_csv('../PlayerData/2009/standard/bielkdo01_strd_.csv',index_col=0)
df_bigosky01_strd=pd.read_csv('../PlayerData/2009/standard/bigosky01_strd_.csv',index_col=0)
df_birkhjo01_strd=pd.read_csv('../PlayerData/2009/standard/birkhjo01_strd_.csv',index_col=0)
df_bjorkhe01_strd=pd.read_csv('../PlayerData/2009/standard/bjorkhe01_strd_.csv',index_col=0)
df_blackje01_strd=pd.read_csv('../PlayerData/2009/standard/blackje01_strd_.csv',index_col=0)
df_blomqan01_strd=pd.read_csv('../PlayerData/2009/standard/blomqan01_strd_.csv',index_col=0)
df_bloodev01_strd=pd.read_csv('../PlayerData/2009/standard/bloodev01_strd_.csv',index_col=0)
df_bobkoig01_strd=pd.read_csv('../PlayerData/2009/standard/bobkoig01_strd_.csv',index_col=0)
df_bourqga01_strd=pd.read_csv('../PlayerData/2009/standard/bourqga01_strd_.csv',index_col=0)
df_bourqry01_strd=pd.read_csv('../PlayerData/2009/standard/bourqry01_strd_.csv',index_col=0)
df_brownch01_strd=pd.read_csv('../PlayerData/2009/standard/brownch01_strd_.csv',index_col=0)
df_bubniji01_strd=pd.read_csv('../PlayerData/2009/standard/bubniji01_strd_.csv',index_col=0)
df_budisza01_strd=pd.read_csv('../PlayerData/2009/standard/budisza01_strd_.csv',index_col=0)
df_buttory01_strd=pd.read_csv('../PlayerData/2009/standard/buttory01_strd_.csv',index_col=0)
df_callami01_strd=pd.read_csv('../PlayerData/2009/standard/callami01_strd_.csv',index_col=0)
df_cannajo01_strd=pd.read_csv('../PlayerData/2009/standard/cannajo01_strd_.csv',index_col=0)
df_caronjo01_strd=pd.read_csv('../PlayerData/2009/standard/caronjo01_strd_.csv',index_col=0)
df_casavbe01_strd=pd.read_csv('../PlayerData/2009/standard/casavbe01_strd_.csv',index_col=0)
df_chiarbe01_strd=pd.read_csv('../PlayerData/2009/standard/chiarbe01_strd_.csv',index_col=0)
df_chiasal01_strd=pd.read_csv('../PlayerData/2009/standard/chiasal01_strd_.csv',index_col=0)
df_cichymi01_strd=pd.read_csv('../PlayerData/2009/standard/cichymi01_strd_.csv',index_col=0)
df_cizikca01_strd=pd.read_csv('../PlayerData/2009/standard/cizikca01_strd_.csv',index_col=0)
df_clarkma01_strd=pd.read_csv('../PlayerData/2009/standard/clarkma01_strd_.csv',index_col=0)
df_cliffky01_strd=pd.read_csv('../PlayerData/2009/standard/cliffky01_strd_.csv',index_col=0)
df_connake01_strd=pd.read_csv('../PlayerData/2009/standard/connake01_strd_.csv',index_col=0)
df_costeje01_strd=pd.read_csv('../PlayerData/2009/standard/costeje01_strd_.csv',index_col=0)
df_cowenja01_strd=pd.read_csv('../PlayerData/2009/standard/cowenja01_strd_.csv',index_col=0)
df_cowicco01_strd=pd.read_csv('../PlayerData/2009/standard/cowicco01_strd_.csv',index_col=0)
df_damigje01_strd=pd.read_csv('../PlayerData/2009/standard/damigje01_strd_.csv',index_col=0)
df_dehaaca01_strd=pd.read_csv('../PlayerData/2009/standard/dehaaca01_strd_.csv',index_col=0)
df_delisda01_strd=pd.read_csv('../PlayerData/2009/standard/delisda01_strd_.csv',index_col=0)
df_deslani01_strd=pd.read_csv('../PlayerData/2009/standard/deslani01_strd_.csv',index_col=0)
df_desprsi01_strd=pd.read_csv('../PlayerData/2009/standard/desprsi01_strd_.csv',index_col=0)
df_devanja01_strd=pd.read_csv('../PlayerData/2009/standard/devanja01_strd_.csv',index_col=0)
df_doherta01_strd=pd.read_csv('../PlayerData/2009/standard/doherta01_strd_.csv',index_col=0)
df_dowdni01_strd=pd.read_csv('../PlayerData/2009/standard/dowdni01_strd_.csv',index_col=0)
df_duchema01_strd=pd.read_csv('../PlayerData/2009/standard/duchema01_strd_.csv',index_col=0)
df_dumonga01_strd=pd.read_csv('../PlayerData/2009/standard/dumonga01_strd_.csv',index_col=0)
df_dumoubr01_strd=pd.read_csv('../PlayerData/2009/standard/dumoubr01_strd_.csv',index_col=0)
df_eakinco01_strd=pd.read_csv('../PlayerData/2009/standard/eakinco01_strd_.csv',index_col=0)
df_ekbomvi01_strd=pd.read_csv('../PlayerData/2009/standard/ekbomvi01_strd_.csv',index_col=0)
df_ekholma01_strd=pd.read_csv('../PlayerData/2009/standard/ekholma01_strd_.csv',index_col=0)
df_ekmanol01_strd=pd.read_csv('../PlayerData/2009/standard/ekmanol01_strd_.csv',index_col=0)
df_elliost01_strd=pd.read_csv('../PlayerData/2009/standard/elliost01_strd_.csv',index_col=0)
df_ellisry01_strd=pd.read_csv('../PlayerData/2009/standard/ellisry01_strd_.csv',index_col=0)
df_erixoti01_strd=pd.read_csv('../PlayerData/2009/standard/erixoti01_strd_.csv',index_col=0)
df_fallsal01_strd=pd.read_csv('../PlayerData/2009/standard/fallsal01_strd_.csv',index_col=0)
df_ferrala01_strd=pd.read_csv('../PlayerData/2009/standard/ferrala01_strd_.csv',index_col=0)
df_flemmbr01_strd=pd.read_csv('../PlayerData/2009/standard/flemmbr01_strd_.csv',index_col=0)
df_foligma01_strd=pd.read_csv('../PlayerData/2009/standard/foligma01_strd_.csv',index_col=0)
df_foucakr01_strd=pd.read_csv('../PlayerData/2009/standard/foucakr01_strd_.csv',index_col=0)
df_fourngl01_strd=pd.read_csv('../PlayerData/2009/standard/fourngl01_strd_.csv',index_col=0)
df_froesby01_strd=pd.read_csv('../PlayerData/2009/standard/froesby01_strd_.csv',index_col=0)
df_gedigcu01_strd=pd.read_csv('../PlayerData/2009/standard/gedigcu01_strd_.csv',index_col=0)
df_geliner01_strd=pd.read_csv('../PlayerData/2009/standard/geliner01_strd_.csv',index_col=0)
df_gilbeda01_strd=pd.read_csv('../PlayerData/2009/standard/gilbeda01_strd_.csv',index_col=0)
df_glennsc01_strd=pd.read_csv('../PlayerData/2009/standard/glennsc01_strd_.csv',index_col=0)
df_gotovki01_strd=pd.read_csv('../PlayerData/2009/standard/gotovki01_strd_.csv',index_col=0)
df_hackema01_strd=pd.read_csv('../PlayerData/2009/standard/hackema01_strd_.csv',index_col=0)
df_hambuan01_strd=pd.read_csv('../PlayerData/2009/standard/hambuan01_strd_.csv',index_col=0)
df_hanowbe01_strd=pd.read_csv('../PlayerData/2009/standard/hanowbe01_strd_.csv',index_col=0)
df_haulaer01_strd=pd.read_csv('../PlayerData/2009/standard/haulaer01_strd_.csv',index_col=0)
df_hedmavi01_strd=pd.read_csv('../PlayerData/2009/standard/hedmavi01_strd_.csv',index_col=0)
df_helgese01_strd=pd.read_csv('../PlayerData/2009/standard/helgese01_strd_.csv',index_col=0)
df_hesketr01_strd=pd.read_csv('../PlayerData/2009/standard/hesketr01_strd_.csv',index_col=0)
df_hoffmmi02_strd=pd.read_csv('../PlayerData/2009/standard/hoffmmi02_strd_.csv',index_col=0)
df_hollape01_strd=pd.read_csv('../PlayerData/2009/standard/hollape01_strd_.csv',index_col=0)
df_horakro01_strd=pd.read_csv('../PlayerData/2009/standard/horakro01_strd_.csv',index_col=0)
df_howsery01_strd=pd.read_csv('../PlayerData/2009/standard/howsery01_strd_.csv',index_col=0)
df_hutchal01_strd=pd.read_csv('../PlayerData/2009/standard/hutchal01_strd_.csv',index_col=0)
df_illora01_strd=pd.read_csv('../PlayerData/2009/standard/illora01_strd_.csv',index_col=0)
df_janusja01_strd=pd.read_csv('../PlayerData/2009/standard/janusja01_strd_.csv',index_col=0)
df_jenseni02_strd=pd.read_csv('../PlayerData/2009/standard/jenseni02_strd_.csv',index_col=0)
df_johanma03_strd=pd.read_csv('../PlayerData/2009/standard/johanma03_strd_.csv',index_col=0)
df_josefja01_strd=pd.read_csv('../PlayerData/2009/standard/josefja01_strd_.csv',index_col=0)
df_kadrina01_strd=pd.read_csv('../PlayerData/2009/standard/kadrina01_strd_.csv',index_col=0)
df_kaneev01_strd=pd.read_csv('../PlayerData/2009/standard/kaneev01_strd_.csv',index_col=0)
df_kassiza01_strd=pd.read_csv('../PlayerData/2009/standard/kassiza01_strd_.csv',index_col=0)
df_kennema01_strd=pd.read_csv('../PlayerData/2009/standard/kennema01_strd_.csv',index_col=0)
df_kivisto01_strd=pd.read_csv('../PlayerData/2009/standard/kivisto01_strd_.csv',index_col=0)
df_klemean01_strd=pd.read_csv('../PlayerData/2009/standard/klemean01_strd_.csv',index_col=0)
df_klingca01_strd=pd.read_csv('../PlayerData/2009/standard/klingca01_strd_.csv',index_col=0)
df_knappco01_strd=pd.read_csv('../PlayerData/2009/standard/knappco01_strd_.csv',index_col=0)
df_knighco01_strd=pd.read_csv('../PlayerData/2009/standard/knighco01_strd_.csv',index_col=0)
df_knodeer01_strd=pd.read_csv('../PlayerData/2009/standard/knodeer01_strd_.csv',index_col=0)
df_kolomda01_strd=pd.read_csv('../PlayerData/2009/standard/kolomda01_strd_.csv',index_col=0)
df_koperle01_strd=pd.read_csv('../PlayerData/2009/standard/koperle01_strd_.csv',index_col=0)
df_koskimi01_strd=pd.read_csv('../PlayerData/2009/standard/koskimi01_strd_.csv',index_col=0)
df_kozunbr01_strd=pd.read_csv('../PlayerData/2009/standard/kozunbr01_strd_.csv',index_col=0)
df_kreidch01_strd=pd.read_csv('../PlayerData/2009/standard/kreidch01_strd_.csv',index_col=0)
df_krugema01_strd=pd.read_csv('../PlayerData/2009/standard/krugema01_strd_.csv',index_col=0)
df_kuempda01_strd=pd.read_csv('../PlayerData/2009/standard/kuempda01_strd_.csv',index_col=0)
df_kulikdm01_strd=pd.read_csv('../PlayerData/2009/standard/kulikdm01_strd_.csv',index_col=0)
df_labreda01_strd=pd.read_csv('../PlayerData/2009/standard/labreda01_strd_.csv',index_col=0)
df_landean01_strd=pd.read_csv('../PlayerData/2009/standard/landean01_strd_.csv',index_col=0)
df_larkith01_strd=pd.read_csv('../PlayerData/2009/standard/larkith01_strd_.csv',index_col=0)
df_lattami01_strd=pd.read_csv('../PlayerData/2009/standard/lattami01_strd_.csv',index_col=0)
df_lauriol01_strd=pd.read_csv('../PlayerData/2009/standard/lauriol01_strd_.csv',index_col=0)
df_leblalo01_strd=pd.read_csv('../PlayerData/2009/standard/leblalo01_strd_.csv',index_col=0)
df_leddyni01_strd=pd.read_csv('../PlayerData/2009/standard/leddyni01_strd_.csv',index_col=0)
df_leean01_strd=pd.read_csv('../PlayerData/2009/standard/leean01_strd_.csv',index_col=0)
df_leemi01_strd=pd.read_csv('../PlayerData/2009/standard/leemi01_strd_.csv',index_col=0)
df_legauma01_strd=pd.read_csv('../PlayerData/2009/standard/legauma01_strd_.csv',index_col=0)
df_lehnero01_strd=pd.read_csv('../PlayerData/2009/standard/lehnero01_strd_.csv',index_col=0)
df_lindsma01_strd=pd.read_csv('../PlayerData/2009/standard/lindsma01_strd_.csv',index_col=0)
df_lynchke01_strd=pd.read_csv('../PlayerData/2009/standard/lynchke01_strd_.csv',index_col=0)
df_macdela01_strd=pd.read_csv('../PlayerData/2009/standard/macdela01_strd_.csv',index_col=0)
df_maggida01_strd=pd.read_csv('../PlayerData/2009/standard/maggida01_strd_.csv',index_col=0)
df_maxwebr03_strd=pd.read_csv('../PlayerData/2009/standard/maxwebr03_strd_.csv',index_col=0)
df_mckencu01_strd=pd.read_csv('../PlayerData/2009/standard/mckencu01_strd_.csv',index_col=0)
df_mcnabbr01_strd=pd.read_csv('../PlayerData/2009/standard/mcnabbr01_strd_.csv',index_col=0)
df_meganwa01_strd=pd.read_csv('../PlayerData/2009/standard/meganwa01_strd_.csv',index_col=0)
df_millaki01_strd=pd.read_csv('../PlayerData/2009/standard/millaki01_strd_.csv',index_col=0)
df_mitchga01_strd=pd.read_csv('../PlayerData/2009/standard/mitchga01_strd_.csv',index_col=0)
df_moorejo01_strd=pd.read_csv('../PlayerData/2009/standard/moorejo01_strd_.csv',index_col=0)
df_morinje01_strd=pd.read_csv('../PlayerData/2009/standard/morinje01_strd_.csv',index_col=0)
df_morriad01_strd=pd.read_csv('../PlayerData/2009/standard/morriad01_strd_.csv',index_col=0)
df_nattijo01_strd=pd.read_csv('../PlayerData/2009/standard/nattijo01_strd_.csv',index_col=0)
df_nestran01_strd=pd.read_csv('../PlayerData/2009/standard/nestran01_strd_.csv',index_col=0)
df_neubeky01_strd=pd.read_csv('../PlayerData/2009/standard/neubeky01_strd_.csv',index_col=0)
df_nilssan01_strd=pd.read_csv('../PlayerData/2009/standard/nilssan01_strd_.csv',index_col=0)
df_nolanjo01_strd=pd.read_csv('../PlayerData/2009/standard/nolanjo01_strd_.csv',index_col=0)
df_oliveni01_strd=pd.read_csv('../PlayerData/2009/standard/oliveni01_strd_.csv',index_col=0)
df_olsendy01_strd=pd.read_csv('../PlayerData/2009/standard/olsendy01_strd_.csv',index_col=0)
df_oreilry01_strd=pd.read_csv('../PlayerData/2009/standard/oreilry01_strd_.csv',index_col=0)
df_orlovdm01_strd=pd.read_csv('../PlayerData/2009/standard/orlovdm01_strd_.csv',index_col=0)
df_ortiojo01_strd=pd.read_csv('../PlayerData/2009/standard/ortiojo01_strd_.csv',index_col=0)
df_paajama01_strd=pd.read_csv('../PlayerData/2009/standard/paajama01_strd_.csv',index_col=0)
df_pacanda01_strd=pd.read_csv('../PlayerData/2009/standard/pacanda01_strd_.csv',index_col=0)
df_palmiky01_strd=pd.read_csv('../PlayerData/2009/standard/palmiky01_strd_.csv',index_col=0)
df_panikri01_strd=pd.read_csv('../PlayerData/2009/standard/panikri01_strd_.csv',index_col=0)
df_paradph01_strd=pd.read_csv('../PlayerData/2009/standard/paradph01_strd_.csv',index_col=0)
df_pashnmi01_strd=pd.read_csv('../PlayerData/2009/standard/pashnmi01_strd_.csv',index_col=0)
df_pasqued01_strd=pd.read_csv('../PlayerData/2009/standard/pasqued01_strd_.csv',index_col=0)
df_pattega01_strd=pd.read_csv('../PlayerData/2009/standard/pattega01_strd_.csv',index_col=0)
df_pelecmi01_strd=pd.read_csv('../PlayerData/2009/standard/pelecmi01_strd_.csv',index_col=0)
df_peltzbr01_strd=pd.read_csv('../PlayerData/2009/standard/peltzbr01_strd_.csv',index_col=0)
df_peterni01_strd=pd.read_csv('../PlayerData/2009/standard/peterni01_strd_.csv',index_col=0)
df_phillpa01_strd=pd.read_csv('../PlayerData/2009/standard/phillpa01_strd_.csv',index_col=0)
df_pirribr01_strd=pd.read_csv('../PlayerData/2009/standard/pirribr01_strd_.csv',index_col=0)
df_ponicbr01_strd=pd.read_csv('../PlayerData/2009/standard/ponicbr01_strd_.csv',index_col=0)
df_priceje01_strd=pd.read_csv('../PlayerData/2009/standard/priceje01_strd_.csv',index_col=0)
df_rajalto01_strd=pd.read_csv('../PlayerData/2009/standard/rajalto01_strd_.csv',index_col=0)
df_randety01_strd=pd.read_csv('../PlayerData/2009/standard/randety01_strd_.csv',index_col=0)
df_reidca01_strd=pd.read_csv('../PlayerData/2009/standard/reidca01_strd_.csv',index_col=0)
df_riopeni01_strd=pd.read_csv('../PlayerData/2009/standard/riopeni01_strd_.csv',index_col=0)
df_rissara01_strd=pd.read_csv('../PlayerData/2009/standard/rissara01_strd_.csv',index_col=0)
df_rodinan01_strd=pd.read_csv('../PlayerData/2009/standard/rodinan01_strd_.csv',index_col=0)
df_rodwede01_strd=pd.read_csv('../PlayerData/2009/standard/rodwede01_strd_.csv',index_col=0)
df_roussch01_strd=pd.read_csv('../PlayerData/2009/standard/roussch01_strd_.csv',index_col=0)
df_royol01_strd=pd.read_csv('../PlayerData/2009/standard/royol01_strd_.csv',index_col=0)
df_rundbda01_strd=pd.read_csv('../PlayerData/2009/standard/rundbda01_strd_.csv',index_col=0)
df_ryanke01_strd=pd.read_csv('../PlayerData/2009/standard/ryanke01_strd_.csv',index_col=0)
df_sallije01_strd=pd.read_csv('../PlayerData/2009/standard/sallije01_strd_.csv',index_col=0)
df_samuejo01_strd=pd.read_csv('../PlayerData/2009/standard/samuejo01_strd_.csv',index_col=0)
df_samueph01_strd=pd.read_csv('../PlayerData/2009/standard/samueph01_strd_.csv',index_col=0)
df_savarda01_strd=pd.read_csv('../PlayerData/2009/standard/savarda01_strd_.csv',index_col=0)
df_schenbr01_strd=pd.read_csv('../PlayerData/2009/standard/schenbr01_strd_.csv',index_col=0)
df_schrojo01_strd=pd.read_csv('../PlayerData/2009/standard/schrojo01_strd_.csv',index_col=0)
df_sdaomi01_strd=pd.read_csv('../PlayerData/2009/standard/sdaomi01_strd_.csv',index_col=0)
df_sextobe01_strd=pd.read_csv('../PlayerData/2009/standard/sextobe01_strd_.csv',index_col=0)
df_shattty01_strd=pd.read_csv('../PlayerData/2009/standard/shattty01_strd_.csv',index_col=0)
df_shielda01_strd=pd.read_csv('../PlayerData/2009/standard/shielda01_strd_.csv',index_col=0)
df_shoredr01_strd=pd.read_csv('../PlayerData/2009/standard/shoredr01_strd_.csv',index_col=0)
df_silfvja01_strd=pd.read_csv('../PlayerData/2009/standard/silfvja01_strd_.csv',index_col=0)
df_similpe01_strd=pd.read_csv('../PlayerData/2009/standard/similpe01_strd_.csv',index_col=0)
df_smithba02_strd=pd.read_csv('../PlayerData/2009/standard/smithba02_strd_.csv',index_col=0)
df_smithcr01_strd=pd.read_csv('../PlayerData/2009/standard/smithcr01_strd_.csv',index_col=0)
df_smithre01_strd=pd.read_csv('../PlayerData/2009/standard/smithre01_strd_.csv',index_col=0)
df_solco01_strd=pd.read_csv('../PlayerData/2009/standard/solco01_strd_.csv',index_col=0)
df_stajcsc01_strd=pd.read_csv('../PlayerData/2009/standard/stajcsc01_strd_.csv',index_col=0)
df_szwarjo01_strd=pd.read_csv('../PlayerData/2009/standard/szwarjo01_strd_.csv',index_col=0)
df_tardyma01_strd=pd.read_csv('../PlayerData/2009/standard/tardyma01_strd_.csv',index_col=0)
df_tatarto01_strd=pd.read_csv('../PlayerData/2009/standard/tatarto01_strd_.csv',index_col=0)
df_tavarjo01_strd=pd.read_csv('../PlayerData/2009/standard/tavarjo01_strd_.csv',index_col=0)
df_timmisc01_strd=pd.read_csv('../PlayerData/2009/standard/timmisc01_strd_.csv',index_col=0)
df_urbomal01_strd=pd.read_csv('../PlayerData/2009/standard/urbomal01_strd_.csv',index_col=0)
df_valensc01_strd=pd.read_csv('../PlayerData/2009/standard/valensc01_strd_.csv',index_col=0)
df_varonph01_strd=pd.read_csv('../PlayerData/2009/standard/varonph01_strd_.csv',index_col=0)
df_vatansa01_strd=pd.read_csv('../PlayerData/2009/standard/vatansa01_strd_.csv',index_col=0)
df_velisal01_strd=pd.read_csv('../PlayerData/2009/standard/velisal01_strd_.csv',index_col=0)
df_veyli01_strd=pd.read_csv('../PlayerData/2009/standard/veyli01_strd_.csv',index_col=0)
df_viedema01_strd=pd.read_csv('../PlayerData/2009/standard/viedema01_strd_.csv',index_col=0)
df_vincoto01_strd=pd.read_csv('../PlayerData/2009/standard/vincoto01_strd_.csv',index_col=0)
df_walshdu01_strd=pd.read_csv('../PlayerData/2009/standard/walshdu01_strd_.csv',index_col=0)
df_welleju01_strd=pd.read_csv('../PlayerData/2009/standard/welleju01_strd_.csv',index_col=0)
df_wellwer01_strd=pd.read_csv('../PlayerData/2009/standard/wellwer01_strd_.csv',index_col=0)
df_wereket01_strd=pd.read_csv('../PlayerData/2009/standard/wereket01_strd_.csv',index_col=0)
df_weypa01_strd=pd.read_csv('../PlayerData/2009/standard/weypa01_strd_.csv',index_col=0)
df_widemch01_strd=pd.read_csv('../PlayerData/2009/standard/widemch01_strd_.csv',index_col=0)
df_wilsoga01_strd=pd.read_csv('../PlayerData/2009/standard/wilsoga01_strd_.csv',index_col=0)
df_wrennwi01_strd=pd.read_csv('../PlayerData/2009/standard/wrennwi01_strd_.csv',index_col=0)
df_younggu01_strd=pd.read_csv('../PlayerData/2009/standard/younggu01_strd_.csv',index_col=0)
df_zadormi01_strd=pd.read_csv('../PlayerData/2009/standard/zadormi01_strd_.csv',index_col=0)

# %%
df_abneyca01_strd['name']='abneyca01'
df_adamsma01_strd['name']='adamsma01'
df_almqvad01_strd['name']='almqvad01'
df_anderpe04_strd['name']='anderpe04'
df_androse01_strd['name']='androse01'
df_anthost01_strd['name']='anthost01'
df_ashtoca01_strd['name']='ashtoca01'
df_avtsial01_strd['name']='avtsial01'
df_barrity01_strd['name']='barrity01'
df_bathgan02_strd['name']='bathgan02'
df_beckta01_strd['name']='beckta01'
df_bennema02_strd['name']='bennema02'
df_bennesp01_strd['name']='bennesp01'
df_bernaas01_strd['name']='bernaas01'
df_bertisi01_strd['name']='bertisi01'
df_berubje02_strd['name']='berubje02'
df_bielkdo01_strd['name']='bielkdo01'
df_bigosky01_strd['name']='bigosky01'
df_birkhjo01_strd['name']='birkhjo01'
df_bjorkhe01_strd['name']='bjorkhe01'
df_blackje01_strd['name']='blackje01'
df_blomqan01_strd['name']='blomqan01'
df_bloodev01_strd['name']='bloodev01'
df_bobkoig01_strd['name']='bobkoig01'
df_bourqga01_strd['name']='bourqga01'
df_bourqry01_strd['name']='bourqry01'
df_brownch01_strd['name']='brownch01'
df_bubniji01_strd['name']='bubniji01'
df_budisza01_strd['name']='budisza01'
df_buttory01_strd['name']='buttory01'
df_callami01_strd['name']='callami01'
df_cannajo01_strd['name']='cannajo01'
df_caronjo01_strd['name']='caronjo01'
df_casavbe01_strd['name']='casavbe01'
df_chiarbe01_strd['name']='chiarbe01'
df_chiasal01_strd['name']='chiasal01'
df_cichymi01_strd['name']='cichymi01'
df_cizikca01_strd['name']='cizikca01'
df_clarkma01_strd['name']='clarkma01'
df_cliffky01_strd['name']='cliffky01'
df_connake01_strd['name']='connake01'
df_costeje01_strd['name']='costeje01'
df_cowenja01_strd['name']='cowenja01'
df_cowicco01_strd['name']='cowicco01'
df_damigje01_strd['name']='damigje01'
df_dehaaca01_strd['name']='dehaaca01'
df_delisda01_strd['name']='delisda01'
df_deslani01_strd['name']='deslani01'
df_desprsi01_strd['name']='desprsi01'
df_devanja01_strd['name']='devanja01'
df_doherta01_strd['name']='doherta01'
df_dowdni01_strd['name']='dowdni01'
df_duchema01_strd['name']='duchema01'
df_dumonga01_strd['name']='dumonga01'
df_dumoubr01_strd['name']='dumoubr01'
df_eakinco01_strd['name']='eakinco01'
df_ekbomvi01_strd['name']='ekbomvi01'
df_ekholma01_strd['name']='ekholma01'
df_ekmanol01_strd['name']='ekmanol01'
df_elliost01_strd['name']='elliost01'
df_ellisry01_strd['name']='ellisry01'
df_erixoti01_strd['name']='erixoti01'
df_fallsal01_strd['name']='fallsal01'
df_ferrala01_strd['name']='ferrala01'
df_flemmbr01_strd['name']='flemmbr01'
df_foligma01_strd['name']='foligma01'
df_foucakr01_strd['name']='foucakr01'
df_fourngl01_strd['name']='fourngl01'
df_froesby01_strd['name']='froesby01'
df_gedigcu01_strd['name']='gedigcu01'
df_geliner01_strd['name']='geliner01'
df_gilbeda01_strd['name']='gilbeda01'
df_glennsc01_strd['name']='glennsc01'
df_gotovki01_strd['name']='gotovki01'
df_hackema01_strd['name']='hackema01'
df_hambuan01_strd['name']='hambuan01'
df_hanowbe01_strd['name']='hanowbe01'
df_haulaer01_strd['name']='haulaer01'
df_hedmavi01_strd['name']='hedmavi01'
df_helgese01_strd['name']='helgese01'
df_hesketr01_strd['name']='hesketr01'
df_hoffmmi02_strd['name']='hoffmmi02'
df_hollape01_strd['name']='hollape01'
df_horakro01_strd['name']='horakro01'
df_howsery01_strd['name']='howsery01'
df_hutchal01_strd['name']='hutchal01'
df_illora01_strd['name']='illora01'
df_janusja01_strd['name']='janusja01'
df_jenseni02_strd['name']='jenseni02'
df_johanma03_strd['name']='johanma03'
df_josefja01_strd['name']='josefja01'
df_kadrina01_strd['name']='kadrina01'
df_kaneev01_strd['name']='kaneev01'
df_kassiza01_strd['name']='kassiza01'
df_kennema01_strd['name']='kennema01'
df_kivisto01_strd['name']='kivisto01'
df_klemean01_strd['name']='klemean01'
df_klingca01_strd['name']='klingca01'
df_knappco01_strd['name']='knappco01'
df_knighco01_strd['name']='knighco01'
df_knodeer01_strd['name']='knodeer01'
df_kolomda01_strd['name']='kolomda01'
df_koperle01_strd['name']='koperle01'
df_koskimi01_strd['name']='koskimi01'
df_kozunbr01_strd['name']='kozunbr01'
df_kreidch01_strd['name']='kreidch01'
df_krugema01_strd['name']='krugema01'
df_kuempda01_strd['name']='kuempda01'
df_kulikdm01_strd['name']='kulikdm01'
df_labreda01_strd['name']='labreda01'
df_landean01_strd['name']='landean01'
df_larkith01_strd['name']='larkith01'
df_lattami01_strd['name']='lattami01'
df_lauriol01_strd['name']='lauriol01'
df_leblalo01_strd['name']='leblalo01'
df_leddyni01_strd['name']='leddyni01'
df_leean01_strd['name']='leean01'
df_leemi01_strd['name']='leemi01'
df_legauma01_strd['name']='legauma01'
df_lehnero01_strd['name']='lehnero01'
df_lindsma01_strd['name']='lindsma01'
df_lynchke01_strd['name']='lynchke01'
df_macdela01_strd['name']='macdela01'
df_maggida01_strd['name']='maggida01'
df_maxwebr03_strd['name']='maxwebr03'
df_mckencu01_strd['name']='mckencu01'
df_mcnabbr01_strd['name']='mcnabbr01'
df_meganwa01_strd['name']='meganwa01'
df_millaki01_strd['name']='millaki01'
df_mitchga01_strd['name']='mitchga01'
df_moorejo01_strd['name']='moorejo01'
df_morinje01_strd['name']='morinje01'
df_morriad01_strd['name']='morriad01'
df_nattijo01_strd['name']='nattijo01'
df_nestran01_strd['name']='nestran01'
df_neubeky01_strd['name']='neubeky01'
df_nilssan01_strd['name']='nilssan01'
df_nolanjo01_strd['name']='nolanjo01'
df_oliveni01_strd['name']='oliveni01'
df_olsendy01_strd['name']='olsendy01'
df_oreilry01_strd['name']='oreilry01'
df_orlovdm01_strd['name']='orlovdm01'
df_ortiojo01_strd['name']='ortiojo01'
df_paajama01_strd['name']='paajama01'
df_pacanda01_strd['name']='pacanda01'
df_palmiky01_strd['name']='palmiky01'
df_panikri01_strd['name']='panikri01'
df_paradph01_strd['name']='paradph01'
df_pashnmi01_strd['name']='pashnmi01'
df_pasqued01_strd['name']='pasqued01'
df_pattega01_strd['name']='pattega01'
df_pelecmi01_strd['name']='pelecmi01'
df_peltzbr01_strd['name']='peltzbr01'
df_peterni01_strd['name']='peterni01'
df_phillpa01_strd['name']='phillpa01'
df_pirribr01_strd['name']='pirribr01'
df_ponicbr01_strd['name']='ponicbr01'
df_priceje01_strd['name']='priceje01'
df_rajalto01_strd['name']='rajalto01'
df_randety01_strd['name']='randety01'
df_reidca01_strd['name']='reidca01'
df_riopeni01_strd['name']='riopeni01'
df_rissara01_strd['name']='rissara01'
df_rodinan01_strd['name']='rodinan01'
df_rodwede01_strd['name']='rodwede01'
df_roussch01_strd['name']='roussch01'
df_royol01_strd['name']='royol01'
df_rundbda01_strd['name']='rundbda01'
df_ryanke01_strd['name']='ryanke01'
df_sallije01_strd['name']='sallije01'
df_samuejo01_strd['name']='samuejo01'
df_samueph01_strd['name']='samueph01'
df_savarda01_strd['name']='savarda01'
df_schenbr01_strd['name']='schenbr01'
df_schrojo01_strd['name']='schrojo01'
df_sdaomi01_strd['name']='sdaomi01'
df_sextobe01_strd['name']='sextobe01'
df_shattty01_strd['name']='shattty01'
df_shielda01_strd['name']='shielda01'
df_shoredr01_strd['name']='shoredr01'
df_silfvja01_strd['name']='silfvja01'
df_similpe01_strd['name']='similpe01'
df_smithba02_strd['name']='smithba02'
df_smithcr01_strd['name']='smithcr01'
df_smithre01_strd['name']='smithre01'
df_solco01_strd['name']='solco01'
df_stajcsc01_strd['name']='stajcsc01'
df_szwarjo01_strd['name']='szwarjo01'
df_tardyma01_strd['name']='tardyma01'
df_tatarto01_strd['name']='tatarto01'
df_tavarjo01_strd['name']='tavarjo01'
df_timmisc01_strd['name']='timmisc01'
df_urbomal01_strd['name']='urbomal01'
df_valensc01_strd['name']='valensc01'
df_varonph01_strd['name']='varonph01'
df_vatansa01_strd['name']='vatansa01'
df_velisal01_strd['name']='velisal01'
df_veyli01_strd['name']='veyli01'
df_viedema01_strd['name']='viedema01'
df_vincoto01_strd['name']='vincoto01'
df_walshdu01_strd['name']='walshdu01'
df_welleju01_strd['name']='welleju01'
df_wellwer01_strd['name']='wellwer01'
df_wereket01_strd['name']='wereket01'
df_weypa01_strd['name']='weypa01'
df_widemch01_strd['name']='widemch01'
df_wilsoga01_strd['name']='wilsoga01'
df_wrennwi01_strd['name']='wrennwi01'
df_younggu01_strd['name']='younggu01'
df_zadormi01_strd['name']='zadormi01'

# %%
strd_frames=[df_abneyca01_strd,
df_adamsma01_strd,
df_almqvad01_strd,
df_anderpe04_strd,
df_androse01_strd,
df_anthost01_strd,
df_ashtoca01_strd,
df_avtsial01_strd,
df_barrity01_strd,
df_bathgan02_strd,
df_beckta01_strd,
df_bennema02_strd,
df_bennesp01_strd,
df_bernaas01_strd,
df_bertisi01_strd,
df_berubje02_strd,
df_bielkdo01_strd,
df_bigosky01_strd,
df_birkhjo01_strd,
df_bjorkhe01_strd,
df_blackje01_strd,
df_blomqan01_strd,
df_bloodev01_strd,
df_bobkoig01_strd,
df_bourqga01_strd,
df_bourqry01_strd,
df_brownch01_strd,
df_bubniji01_strd,
df_budisza01_strd,
df_buttory01_strd,
df_callami01_strd,
df_cannajo01_strd,
df_caronjo01_strd,
df_casavbe01_strd,
df_chiarbe01_strd,
df_chiasal01_strd,
df_cichymi01_strd,
df_cizikca01_strd,
df_clarkma01_strd,
df_cliffky01_strd,
df_connake01_strd,
df_costeje01_strd,
df_cowenja01_strd,
df_cowicco01_strd,
df_damigje01_strd,
df_dehaaca01_strd,
df_delisda01_strd,
df_deslani01_strd,
df_desprsi01_strd,
df_devanja01_strd,
df_doherta01_strd,
df_dowdni01_strd,
df_duchema01_strd,
df_dumonga01_strd,
df_dumoubr01_strd,
df_eakinco01_strd,
df_ekbomvi01_strd,
df_ekholma01_strd,
df_ekmanol01_strd,
df_elliost01_strd,
df_ellisry01_strd,
df_erixoti01_strd,
df_fallsal01_strd,
df_ferrala01_strd,
df_flemmbr01_strd,
df_foligma01_strd,
df_foucakr01_strd,
df_fourngl01_strd,
df_froesby01_strd,
df_gedigcu01_strd,
df_geliner01_strd,
df_gilbeda01_strd,
df_glennsc01_strd,
df_gotovki01_strd,
df_hackema01_strd,
df_hambuan01_strd,
df_hanowbe01_strd,
df_haulaer01_strd,
df_hedmavi01_strd,
df_helgese01_strd,
df_hesketr01_strd,
df_hoffmmi02_strd,
df_hollape01_strd,
df_horakro01_strd,
df_howsery01_strd,
df_hutchal01_strd,
df_illora01_strd,
df_janusja01_strd,
df_jenseni02_strd,
df_johanma03_strd,
df_josefja01_strd,
df_kadrina01_strd,
df_kaneev01_strd,
df_kassiza01_strd,
df_kennema01_strd,
df_kivisto01_strd,
df_klemean01_strd,
df_klingca01_strd,
df_knappco01_strd,
df_knighco01_strd,
df_knodeer01_strd,
df_kolomda01_strd,
df_koperle01_strd,
df_koskimi01_strd,
df_kozunbr01_strd,
df_kreidch01_strd,
df_krugema01_strd,
df_kuempda01_strd,
df_kulikdm01_strd,
df_labreda01_strd,
df_landean01_strd,
df_larkith01_strd,
df_lattami01_strd,
df_lauriol01_strd,
df_leblalo01_strd,
df_leddyni01_strd,
df_leean01_strd,
df_leemi01_strd,
df_legauma01_strd,
df_lehnero01_strd,
df_lindsma01_strd,
df_lynchke01_strd,
df_macdela01_strd,
df_maggida01_strd,
df_maxwebr03_strd,
df_mckencu01_strd,
df_mcnabbr01_strd,
df_meganwa01_strd,
df_millaki01_strd,
df_mitchga01_strd,
df_moorejo01_strd,
df_morinje01_strd,
df_morriad01_strd,
df_nattijo01_strd,
df_nestran01_strd,
df_neubeky01_strd,
df_nilssan01_strd,
df_nolanjo01_strd,
df_oliveni01_strd,
df_olsendy01_strd,
df_oreilry01_strd,
df_orlovdm01_strd,
df_ortiojo01_strd,
df_paajama01_strd,
df_pacanda01_strd,
df_palmiky01_strd,
df_panikri01_strd,
df_paradph01_strd,
df_pashnmi01_strd,
df_pasqued01_strd,
df_pattega01_strd,
df_pelecmi01_strd,
df_peltzbr01_strd,
df_peterni01_strd,
df_phillpa01_strd,
df_pirribr01_strd,
df_ponicbr01_strd,
df_priceje01_strd,
df_rajalto01_strd,
df_randety01_strd,
df_reidca01_strd,
df_riopeni01_strd,
df_rissara01_strd,
df_rodinan01_strd,
df_rodwede01_strd,
df_roussch01_strd,
df_royol01_strd,
df_rundbda01_strd,
df_ryanke01_strd,
df_sallije01_strd,
df_samuejo01_strd,
df_samueph01_strd,
df_savarda01_strd,
df_schenbr01_strd,
df_schrojo01_strd,
df_sdaomi01_strd,
df_sextobe01_strd,
df_shattty01_strd,
df_shielda01_strd,
df_shoredr01_strd,
df_silfvja01_strd,
df_similpe01_strd,
df_smithba02_strd,
df_smithcr01_strd,
df_smithre01_strd,
df_solco01_strd,
df_stajcsc01_strd,
df_szwarjo01_strd,
df_tardyma01_strd,
df_tatarto01_strd,
df_tavarjo01_strd,
df_timmisc01_strd,
df_urbomal01_strd,
df_valensc01_strd,
df_varonph01_strd,
df_vatansa01_strd,
df_velisal01_strd,
df_veyli01_strd,
df_viedema01_strd,
df_vincoto01_strd,
df_walshdu01_strd,
df_welleju01_strd,
df_wellwer01_strd,
df_wereket01_strd,
df_weypa01_strd,
df_widemch01_strd,
df_wilsoga01_strd,
df_wrennwi01_strd,
df_younggu01_strd,
df_zadormi01_strd]

# %%
result_strd = pd.concat(strd_frames)

# %%
result_strd
# Out:
#      season  TOT   age  games_played  pen_min  plus_minus  goals_ev  goals_pp  \
# 1   2013-14  DET  22.0           2.0      0.0        -1.0       1.0       0.0
# 1   2011-12  TOR  20.0          15.0     13.0       -10.0       0.0       0.0
# 2   2013-14  TOR  22.0          32.0     19.0         1.0       0.0       0.0
# 3   2014-15  TOR  23.0           7.0      0.0        -3.0       0.0       0.0
# 1   2011-12  COL  20.0          10.0      0.0        -2.0       0.0       0.0
# 2   2012-13  COL  21.0          32.0     10.0       -11.0       1.0       1.0
# 3   2013-14  COL  22.0          64.0     20.0        17.0       9.0       4.0
# 4   2014-15  COL  23.0          80.0     26.0         5.0      10.0       2.0
# 5   2015-16  COL  24.0          78.0     31.0       -16.0       9.0       3.0
# 6   2016-17  COL  25.0          21.0      6.0       -10.0       2.0       0.0
# 1   2012-13  NSH  21.0          16.0      2.0         0.0       2.0       1.0
# ...

# %%
result_pos
# Out:
#      season  TOT   age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2013-14  DET  22.0       22.0           24.0       47.8            -4
# 1   2011-12  TOR  20.0      116.0          137.0       45.8          -3.7
# 2   2013-14  TOR  22.0      151.0          194.0       43.8          -0.3
# 3   2014-15  TOR  23.0       28.0           43.0       39.4          -1.8
# 1   2011-12  COL  20.0      172.0          142.0       54.8             5
# 2   2012-13  COL  21.0      544.0          533.0       50.5           0.6
# 3   2013-14  COL  22.0      985.0          949.0       50.9           3.9
# 4   2014-15  COL  23.0     1257.0         1473.0       46.0           3.4
# 5   2015-16  COL  24.0     1342.0         1586.0       45.8             2
# 6   2016-17  COL  25.0      355.0          392.0       47.5          -1.9
# 1   2012-13  NSH  21.0      197.0          202.0       49.4           1.3
# 2   2013-14  NSH  22.0       67.0           54.0       55.4           5.4
# ...

# %%
result_all = pd.merge(result_strd, result_pos, how ='left', on=['name','season','TOT'])

# %%
result_all
# Out:
#       season  TOT  age_x  games_played  pen_min  plus_minus  goals_ev  \
# 0    2013-14  DET   22.0           2.0      0.0        -1.0       1.0
# 1    2011-12  TOR   20.0          15.0     13.0       -10.0       0.0
# 2    2013-14  TOR   22.0          32.0     19.0         1.0       0.0
# 3    2014-15  TOR   23.0           7.0      0.0        -3.0       0.0
# 4    2011-12  COL   20.0          10.0      0.0        -2.0       0.0
# 5    2012-13  COL   21.0          32.0     10.0       -11.0       1.0
# 6    2013-14  COL   22.0          64.0     20.0        17.0       9.0
# 7    2014-15  COL   23.0          80.0     26.0         5.0      10.0
# 8    2015-16  COL   24.0          78.0     31.0       -16.0       9.0
# 9    2016-17  COL   25.0          21.0      6.0       -10.0       2.0
# 10   2012-13  NSH   21.0          16.0      2.0         0.0       2.0
# 11   2013-14  NSH   22.0           7.0      6.0        -2.0       0.0
# ...

# %%
import copy
seasonlist=result_all['season']
teamlist=result_all['TOT']
namelist=result_all['name']

currseas=seasonlist[0]
currteam=teamlist[0]
currname=namelist[0]

remlist=[1]
for i in range(1,len(seasonlist)):
    if seasonlist[i]==currseas and currname==namelist[i]:
        remlist.append(0)
    
    else:
        remlist.append(1)
        currname=namelist[i]
        currseas=seasonlist[i]

result_all['uniqueseason']=remlist
result_all=result_all.loc[result_all['uniqueseason'] == 1]
result_all2=copy.deepcopy(result_all)

    
result_all2=result_all2.convert_objects(convert_numeric=True).dropna()

result_all2

result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')
result_all2.to_csv("../draft_year/df_2009.csv")
# Out:
# /Users/takehiromatsuzawa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
