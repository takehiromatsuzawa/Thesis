# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
csv_list=[]
for i in range(2003,2004):
    filename="../PlayerData/"+str(i)+"/posession"
    filename2=[]
    for elem in os.listdir(filename):
        filename2.append(filename+'/'+elem)
    csv_list.append(os.listdir(filename))
    print os.listdir(filename)
# Out:
# ['aaltoju01_pos_.csv', 'alenju01_pos_.csv', 'anderjo04_pos_.csv', 'backeda01_pos_.csv', 'bagnadr01_pos_.csv', 'baraniv01_pos_.csv', 'barinmi01_pos_.csv', 'barulko01_pos_.csv', 'beaucre01_pos_.csv', 'beckfch01_pos_.csv', 'bellesh01_pos_.csv', 'belleth01_pos_.csv', 'bergepa01_pos_.csv', 'bernima01_pos_.csv', 'bernist01_pos_.csv', 'bissopa01_pos_.csv', 'bitzby01_pos_.csv', 'blahost01_pos_.csv', 'blansco01_pos_.csv', 'blomst01_pos_.csv', 'bodietr01_pos_.csv', 'boldual01_pos_.csv', 'bolduje01_pos_.csv', 'bolflu01_pos_.csv', 'bondaar01_pos_.csv', 'bonneji01_pos_.csv', 'boutijo01_pos_.csv', 'boylebr01_pos_.csv', 'brodemi01_pos_.csv', 'brodzky01_pos_.csv', 'brownch03_pos_.csv', 'browndu01_pos_.csv', 'brownmi03_pos_.csv', 'brownpa01_pos_.csv', 'burkhlo01_pos_.csv', 'burnsbr01_pos_.csv', 'byfugdu01_pos_.csv', 'carcida01_pos_.csv', 'carlema01_pos_.csv', 'carteje01_pos_.csv', 'cherndm01_pos_.csv', 'chiodan01_pos_.csv', 'coburbr01_pos_.csv', 'colbewi01_pos_.csv', 'colemge01_pos_.csv', 'collije01_
# ...

# %%
listcsv=csv_list[0]

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"=pd.read_csv(../PlayerData/2003/posession/"+elem+",index_col=0)"
# Out:
# df_aaltoju01_pos=pd.read_csv(../PlayerData/2003/posession/aaltoju01_pos_.csv,index_col=0)
# df_alenju01_pos=pd.read_csv(../PlayerData/2003/posession/alenju01_pos_.csv,index_col=0)
# df_anderjo04_pos=pd.read_csv(../PlayerData/2003/posession/anderjo04_pos_.csv,index_col=0)
# df_backeda01_pos=pd.read_csv(../PlayerData/2003/posession/backeda01_pos_.csv,index_col=0)
# df_bagnadr01_pos=pd.read_csv(../PlayerData/2003/posession/bagnadr01_pos_.csv,index_col=0)
# df_baraniv01_pos=pd.read_csv(../PlayerData/2003/posession/baraniv01_pos_.csv,index_col=0)
# df_barinmi01_pos=pd.read_csv(../PlayerData/2003/posession/barinmi01_pos_.csv,index_col=0)
# df_barulko01_pos=pd.read_csv(../PlayerData/2003/posession/barulko01_pos_.csv,index_col=0)
# df_beaucre01_pos=pd.read_csv(../PlayerData/2003/posession/beaucre01_pos_.csv,index_col=0)
# df_beckfch01_pos=pd.read_csv(../PlayerData/2003/posession/beckfch01_pos_.csv,index_col=0)
# ...

# %%
df_aaltoju01_pos=pd.read_csv('../PlayerData/2003/posession/aaltoju01_pos_.csv',index_col=0)
df_alenju01_pos=pd.read_csv('../PlayerData/2003/posession/alenju01_pos_.csv',index_col=0)
df_anderjo04_pos=pd.read_csv('../PlayerData/2003/posession/anderjo04_pos_.csv',index_col=0)
df_backeda01_pos=pd.read_csv('../PlayerData/2003/posession/backeda01_pos_.csv',index_col=0)
df_bagnadr01_pos=pd.read_csv('../PlayerData/2003/posession/bagnadr01_pos_.csv',index_col=0)
df_baraniv01_pos=pd.read_csv('../PlayerData/2003/posession/baraniv01_pos_.csv',index_col=0)
df_barinmi01_pos=pd.read_csv('../PlayerData/2003/posession/barinmi01_pos_.csv',index_col=0)
df_barulko01_pos=pd.read_csv('../PlayerData/2003/posession/barulko01_pos_.csv',index_col=0)
df_beaucre01_pos=pd.read_csv('../PlayerData/2003/posession/beaucre01_pos_.csv',index_col=0)
df_beckfch01_pos=pd.read_csv('../PlayerData/2003/posession/beckfch01_pos_.csv',index_col=0)
df_bellesh01_pos=pd.read_csv('../PlayerData/2003/posession/bellesh01_pos_.csv',index_col=0)
df_belleth01_pos=pd.read_csv('../PlayerData/2003/posession/belleth01_pos_.csv',index_col=0)
df_bergepa01_pos=pd.read_csv('../PlayerData/2003/posession/bergepa01_pos_.csv',index_col=0)
df_bernima01_pos=pd.read_csv('../PlayerData/2003/posession/bernima01_pos_.csv',index_col=0)
df_bernist01_pos=pd.read_csv('../PlayerData/2003/posession/bernist01_pos_.csv',index_col=0)
df_bissopa01_pos=pd.read_csv('../PlayerData/2003/posession/bissopa01_pos_.csv',index_col=0)
df_bitzby01_pos=pd.read_csv('../PlayerData/2003/posession/bitzby01_pos_.csv',index_col=0)
df_blahost01_pos=pd.read_csv('../PlayerData/2003/posession/blahost01_pos_.csv',index_col=0)
df_blansco01_pos=pd.read_csv('../PlayerData/2003/posession/blansco01_pos_.csv',index_col=0)
df_blomst01_pos=pd.read_csv('../PlayerData/2003/posession/blomst01_pos_.csv',index_col=0)
df_bodietr01_pos=pd.read_csv('../PlayerData/2003/posession/bodietr01_pos_.csv',index_col=0)
df_boldual01_pos=pd.read_csv('../PlayerData/2003/posession/boldual01_pos_.csv',index_col=0)
df_bolduje01_pos=pd.read_csv('../PlayerData/2003/posession/bolduje01_pos_.csv',index_col=0)
df_bolflu01_pos=pd.read_csv('../PlayerData/2003/posession/bolflu01_pos_.csv',index_col=0)
df_bondaar01_pos=pd.read_csv('../PlayerData/2003/posession/bondaar01_pos_.csv',index_col=0)
df_bonneji01_pos=pd.read_csv('../PlayerData/2003/posession/bonneji01_pos_.csv',index_col=0)
df_boutijo01_pos=pd.read_csv('../PlayerData/2003/posession/boutijo01_pos_.csv',index_col=0)
df_boylebr01_pos=pd.read_csv('../PlayerData/2003/posession/boylebr01_pos_.csv',index_col=0)
df_brodemi01_pos=pd.read_csv('../PlayerData/2003/posession/brodemi01_pos_.csv',index_col=0)
df_brodzky01_pos=pd.read_csv('../PlayerData/2003/posession/brodzky01_pos_.csv',index_col=0)
df_brownch03_pos=pd.read_csv('../PlayerData/2003/posession/brownch03_pos_.csv',index_col=0)
df_browndu01_pos=pd.read_csv('../PlayerData/2003/posession/browndu01_pos_.csv',index_col=0)
df_brownmi03_pos=pd.read_csv('../PlayerData/2003/posession/brownmi03_pos_.csv',index_col=0)
df_brownpa01_pos=pd.read_csv('../PlayerData/2003/posession/brownpa01_pos_.csv',index_col=0)
df_burkhlo01_pos=pd.read_csv('../PlayerData/2003/posession/burkhlo01_pos_.csv',index_col=0)
df_burnsbr01_pos=pd.read_csv('../PlayerData/2003/posession/burnsbr01_pos_.csv',index_col=0)
df_byfugdu01_pos=pd.read_csv('../PlayerData/2003/posession/byfugdu01_pos_.csv',index_col=0)
df_carcida01_pos=pd.read_csv('../PlayerData/2003/posession/carcida01_pos_.csv',index_col=0)
df_carlema01_pos=pd.read_csv('../PlayerData/2003/posession/carlema01_pos_.csv',index_col=0)
df_carteje01_pos=pd.read_csv('../PlayerData/2003/posession/carteje01_pos_.csv',index_col=0)
df_cherndm01_pos=pd.read_csv('../PlayerData/2003/posession/cherndm01_pos_.csv',index_col=0)
df_chiodan01_pos=pd.read_csv('../PlayerData/2003/posession/chiodan01_pos_.csv',index_col=0)
df_coburbr01_pos=pd.read_csv('../PlayerData/2003/posession/coburbr01_pos_.csv',index_col=0)
df_colbewi01_pos=pd.read_csv('../PlayerData/2003/posession/colbewi01_pos_.csv',index_col=0)
df_colemge01_pos=pd.read_csv('../PlayerData/2003/posession/colemge01_pos_.csv',index_col=0)
df_collije01_pos=pd.read_csv('../PlayerData/2003/posession/collije01_pos_.csv',index_col=0)
df_cookti01_pos=pd.read_csv('../PlayerData/2003/posession/cookti01_pos_.csv',index_col=0)
df_courcad01_pos=pd.read_csv('../PlayerData/2003/posession/courcad01_pos_.csv',index_col=0)
df_crawfco01_pos=pd.read_csv('../PlayerData/2003/posession/crawfco01_pos_.csv',index_col=0)
df_crombbj01_pos=pd.read_csv('../PlayerData/2003/posession/crombbj01_pos_.csv',index_col=0)
df_cunnica01_pos=pd.read_csv('../PlayerData/2003/posession/cunnica01_pos_.csv',index_col=0)
df_danieni01_pos=pd.read_csv('../PlayerData/2003/posession/danieni01_pos_.csv',index_col=0)
df_danilra01_pos=pd.read_csv('../PlayerData/2003/posession/danilra01_pos_.csv',index_col=0)
df_darzila01_pos=pd.read_csv('../PlayerData/2003/posession/darzila01_pos_.csv',index_col=0)
df_dawesni01_pos=pd.read_csv('../PlayerData/2003/posession/dawesni01_pos_.csv',index_col=0)
df_dawsoaa01_pos=pd.read_csv('../PlayerData/2003/posession/dawsoaa01_pos_.csv',index_col=0)
df_desbigu01_pos=pd.read_csv('../PlayerData/2003/posession/desbigu01_pos_.csv',index_col=0)
df_dixonst01_pos=pd.read_csv('../PlayerData/2003/posession/dixonst01_pos_.csv',index_col=0)
df_doherjo01_pos=pd.read_csv('../PlayerData/2003/posession/doherjo01_pos_.csv',index_col=0)
df_donalry01_pos=pd.read_csv('../PlayerData/2003/posession/donalry01_pos_.csv',index_col=0)
df_dorniiv01_pos=pd.read_csv('../PlayerData/2003/posession/dorniiv01_pos_.csv',index_col=0)
df_dupuiph01_pos=pd.read_csv('../PlayerData/2003/posession/dupuiph01_pos_.csv',index_col=0)
df_eavespa01_pos=pd.read_csv('../PlayerData/2003/posession/eavespa01_pos_.csv',index_col=0)
df_egenemi01_pos=pd.read_csv('../PlayerData/2003/posession/egenemi01_pos_.csv',index_col=0)
df_ehelepa01_pos=pd.read_csv('../PlayerData/2003/posession/ehelepa01_pos_.csv',index_col=0)
df_elliobr01_pos=pd.read_csv('../PlayerData/2003/posession/elliobr01_pos_.csv',index_col=0)
df_enstrto01_pos=pd.read_csv('../PlayerData/2003/posession/enstrto01_pos_.csv',index_col=0)
df_erikslo01_pos=pd.read_csv('../PlayerData/2003/posession/erikslo01_pos_.csv',index_col=0)
df_ezhovde01_pos=pd.read_csv('../PlayerData/2003/posession/ezhovde01_pos_.csv',index_col=0)
df_fabrybr01_pos=pd.read_csv('../PlayerData/2003/posession/fabrybr01_pos_.csv',index_col=0)
df_fehrer01_pos=pd.read_csv('../PlayerData/2003/posession/fehrer01_pos_.csv',index_col=0)
df_filewjo01_pos=pd.read_csv('../PlayerData/2003/posession/filewjo01_pos_.csv',index_col=0)
df_fitzgza01_pos=pd.read_csv('../PlayerData/2003/posession/fitzgza01_pos_.csv',index_col=0)
df_fleurma01_pos=pd.read_csv('../PlayerData/2003/posession/fleurma01_pos_.csv',index_col=0)
df_floodma01_pos=pd.read_csv('../PlayerData/2003/posession/floodma01_pos_.csv',index_col=0)
df_fraseco01_pos=pd.read_csv('../PlayerData/2003/posession/fraseco01_pos_.csv',index_col=0)
df_fritsda01_pos=pd.read_csv('../PlayerData/2003/posession/fritsda01_pos_.csv',index_col=0)
df_furreph01_pos=pd.read_csv('../PlayerData/2003/posession/furreph01_pos_.csv',index_col=0)
df_gelecra01_pos=pd.read_csv('../PlayerData/2003/posession/gelecra01_pos_.csv',index_col=0)
df_gervabr01_pos=pd.read_csv('../PlayerData/2003/posession/gervabr01_pos_.csv',index_col=0)
df_getzlry01_pos=pd.read_csv('../PlayerData/2003/posession/getzlry01_pos_.csv',index_col=0)
df_gibbory01_pos=pd.read_csv('../PlayerData/2003/posession/gibbory01_pos_.csv',index_col=0)
df_gimayse01_pos=pd.read_csv('../PlayerData/2003/posession/gimayse01_pos_.csv',index_col=0)
df_glassta01_pos=pd.read_csv('../PlayerData/2003/posession/glassta01_pos_.csv',index_col=0)
df_glazako01_pos=pd.read_csv('../PlayerData/2003/posession/glazako01_pos_.csv',index_col=0)
df_granael01_pos=pd.read_csv('../PlayerData/2003/posession/granael01_pos_.csv',index_col=0)
df_gravema01_pos=pd.read_csv('../PlayerData/2003/posession/gravema01_pos_.csv',index_col=0)
df_grecobr01_pos=pd.read_csv('../PlayerData/2003/posession/grecobr01_pos_.csv',index_col=0)
df_grenzmi01_pos=pd.read_csv('../PlayerData/2003/posession/grenzmi01_pos_.csv',index_col=0)
df_guenefr01_pos=pd.read_csv('../PlayerData/2003/posession/guenefr01_pos_.csv',index_col=0)
df_guerima01_pos=pd.read_csv('../PlayerData/2003/posession/guerima01_pos_.csv',index_col=0)
df_guskoal01_pos=pd.read_csv('../PlayerData/2003/posession/guskoal01_pos_.csv',index_col=0)
df_guyergi01_pos=pd.read_csv('../PlayerData/2003/posession/guyergi01_pos_.csv',index_col=0)
df_halakja01_pos=pd.read_csv('../PlayerData/2003/posession/halakja01_pos_.csv',index_col=0)
df_hamilmi01_pos=pd.read_csv('../PlayerData/2003/posession/hamilmi01_pos_.csv',index_col=0)
df_hansema01_pos=pd.read_csv('../PlayerData/2003/posession/hansema01_pos_.csv',index_col=0)
df_hanulmi01_pos=pd.read_csv('../PlayerData/2003/posession/hanulmi01_pos_.csv',index_col=0)
df_harveke01_pos=pd.read_csv('../PlayerData/2003/posession/harveke01_pos_.csv',index_col=0)
df_hecimjo01_pos=pd.read_csv('../PlayerData/2003/posession/hecimjo01_pos_.csv',index_col=0)
df_heinoch01_pos=pd.read_csv('../PlayerData/2003/posession/heinoch01_pos_.csv',index_col=0)
df_hejdaja01_pos=pd.read_csv('../PlayerData/2003/posession/hejdaja01_pos_.csv',index_col=0)
df_heminbr01_pos=pd.read_csv('../PlayerData/2003/posession/heminbr01_pos_.csv',index_col=0)
df_hendrtr01_pos=pd.read_csv('../PlayerData/2003/posession/hendrtr01_pos_.csv',index_col=0)
df_hennejo01_pos=pd.read_csv('../PlayerData/2003/posession/hennejo01_pos_.csv',index_col=0)
df_hoffmja01_pos=pd.read_csv('../PlayerData/2003/posession/hoffmja01_pos_.csv',index_col=0)
df_holtch01_pos=pd.read_csv('../PlayerData/2003/posession/holtch01_pos_.csv',index_col=0)
df_hortona01_pos=pd.read_csv('../PlayerData/2003/posession/hortona01_pos_.csv',index_col=0)
df_hospeka01_pos=pd.read_csv('../PlayerData/2003/posession/hospeka01_pos_.csv',index_col=0)
df_hostivi01_pos=pd.read_csv('../PlayerData/2003/posession/hostivi01_pos_.csv',index_col=0)
df_howarja02_pos=pd.read_csv('../PlayerData/2003/posession/howarja02_pos_.csv',index_col=0)
df_hrabajo01_pos=pd.read_csv('../PlayerData/2003/posession/hrabajo01_pos_.csv',index_col=0)
df_hrdelzb01_pos=pd.read_csv('../PlayerData/2003/posession/hrdelzb01_pos_.csv',index_col=0)
df_hultal01_pos=pd.read_csv('../PlayerData/2003/posession/hultal01_pos_.csv',index_col=0)
df_hynessh01_pos=pd.read_csv('../PlayerData/2003/posession/hynessh01_pos_.csv',index_col=0)
df_irmenda01_pos=pd.read_csv('../PlayerData/2003/posession/irmenda01_pos_.csv',index_col=0)
df_isakoev01_pos=pd.read_csv('../PlayerData/2003/posession/isakoev01_pos_.csv',index_col=0)
df_ivanoal01_pos=pd.read_csv('../PlayerData/2003/posession/ivanoal01_pos_.csv',index_col=0)
df_jacquje01_pos=pd.read_csv('../PlayerData/2003/posession/jacquje01_pos_.csv',index_col=0)
df_jarmake01_pos=pd.read_csv('../PlayerData/2003/posession/jarmake01_pos_.csv',index_col=0)
df_jensejo01_pos=pd.read_csv('../PlayerData/2003/posession/jensejo01_pos_.csv',index_col=0)
df_jessihu01_pos=pd.read_csv('../PlayerData/2003/posession/jessihu01_pos_.csv',index_col=0)
df_johanmi01_pos=pd.read_csv('../PlayerData/2003/posession/johanmi01_pos_.csv',index_col=0)
df_jonesda01_pos=pd.read_csv('../PlayerData/2003/posession/jonesda01_pos_.csv',index_col=0)
df_joudran01_pos=pd.read_csv('../PlayerData/2003/posession/joudran01_pos_.csv',index_col=0)
df_kadlepe01_pos=pd.read_csv('../PlayerData/2003/posession/kadlepe01_pos_.csv',index_col=0)
df_kaipry01_pos=pd.read_csv('../PlayerData/2003/posession/kaipry01_pos_.csv',index_col=0)
df_karlsma01_pos=pd.read_csv('../PlayerData/2003/posession/karlsma01_pos_.csv',index_col=0)
df_keslery01_pos=pd.read_csv('../PlayerData/2003/posession/keslery01_pos_.csv',index_col=0)
df_khomuiv01_pos=pd.read_csv('../PlayerData/2003/posession/khomuiv01_pos_.csv',index_col=0)
df_kilpeee01_pos=pd.read_csv('../PlayerData/2003/posession/kilpeee01_pos_.csv',index_col=0)
df_kleinke01_pos=pd.read_csv('../PlayerData/2003/posession/kleinke01_pos_.csv',index_col=0)
df_kollato01_pos=pd.read_csv('../PlayerData/2003/posession/kollato01_pos_.csv',index_col=0)
df_kolusma01_pos=pd.read_csv('../PlayerData/2003/posession/kolusma01_pos_.csv',index_col=0)
df_koprimi01_pos=pd.read_csv('../PlayerData/2003/posession/koprimi01_pos_.csv',index_col=0)
df_korpios01_pos=pd.read_csv('../PlayerData/2003/posession/korpios01_pos_.csv',index_col=0)
df_kosmadm01_pos=pd.read_csv('../PlayerData/2003/posession/kosmadm01_pos_.csv',index_col=0)
df_kostian01_pos=pd.read_csv('../PlayerData/2003/posession/kostian01_pos_.csv',index_col=0)
df_kozakri01_pos=pd.read_csv('../PlayerData/2003/posession/kozakri01_pos_.csv',index_col=0)
df_krepska01_pos=pd.read_csv('../PlayerData/2003/posession/krepska01_pos_.csv',index_col=0)
df_kukkola01_pos=pd.read_csv('../PlayerData/2003/posession/kukkola01_pos_.csv',index_col=0)
df_kutnyvl01_pos=pd.read_csv('../PlayerData/2003/posession/kutnyvl01_pos_.csv',index_col=0)
df_landosh01_pos=pd.read_csv('../PlayerData/2003/posession/landosh01_pos_.csv',index_col=0)
df_lapiema01_pos=pd.read_csv('../PlayerData/2003/posession/lapiema01_pos_.csv',index_col=0)
df_lassite01_pos=pd.read_csv('../PlayerData/2003/posession/lassite01_pos_.csv',index_col=0)
df_leeca01_pos=pd.read_csv('../PlayerData/2003/posession/leeca01_pos_.csv',index_col=0)
df_lehunjo01_pos=pd.read_csv('../PlayerData/2003/posession/lehunjo01_pos_.csv',index_col=0)
df_lewaned01_pos=pd.read_csv('../PlayerData/2003/posession/lewaned01_pos_.csv',index_col=0)
df_liffida01_pos=pd.read_csv('../PlayerData/2003/posession/liffida01_pos_.csv',index_col=0)
df_lindsli01_pos=pd.read_csv('../PlayerData/2003/posession/lindsli01_pos_.csv',index_col=0)
df_lockeco01_pos=pd.read_csv('../PlayerData/2003/posession/lockeco01_pos_.csv',index_col=0)
df_loginde01_pos=pd.read_csv('../PlayerData/2003/posession/loginde01_pos_.csv',index_col=0)
df_lojekma01_pos=pd.read_csv('../PlayerData/2003/posession/lojekma01_pos_.csv',index_col=0)
df_louhios01_pos=pd.read_csv('../PlayerData/2003/posession/louhios01_pos_.csv',index_col=0)
df_macarcl01_pos=pd.read_csv('../PlayerData/2003/posession/macarcl01_pos_.csv',index_col=0)
df_mantyvi01_pos=pd.read_csv('../PlayerData/2003/posession/mantyvi01_pos_.csv',index_col=0)
df_marekja01_pos=pd.read_csv('../PlayerData/2003/posession/marekja01_pos_.csv',index_col=0)
df_marjama01_pos=pd.read_csv('../PlayerData/2003/posession/marjama01_pos_.csv',index_col=0)
df_martilo01_pos=pd.read_csv('../PlayerData/2003/posession/martilo01_pos_.csv',index_col=0)
df_mccutma01_pos=pd.read_csv('../PlayerData/2003/posession/mccutma01_pos_.csv',index_col=0)
df_mcdonco01_pos=pd.read_csv('../PlayerData/2003/posession/mcdonco01_pos_.csv',index_col=0)
df_mcivena01_pos=pd.read_csv('../PlayerData/2003/posession/mcivena01_pos_.csv',index_col=0)
df_melanma01_pos=pd.read_csv('../PlayerData/2003/posession/melanma01_pos_.csv',index_col=0)
df_methoma01_pos=pd.read_csv('../PlayerData/2003/posession/methoma01_pos_.csv',index_col=0)
df_meyerst01_pos=pd.read_csv('../PlayerData/2003/posession/meyerst01_pos_.csv',index_col=0)
df_michami01_pos=pd.read_csv('../PlayerData/2003/posession/michami01_pos_.csv',index_col=0)
df_milledr01_pos=pd.read_csv('../PlayerData/2003/posession/milledr01_pos_.csv',index_col=0)
df_mirnoig01_pos=pd.read_csv('../PlayerData/2003/posession/mirnoig01_pos_.csv',index_col=0)
df_mishage01_pos=pd.read_csv('../PlayerData/2003/posession/mishage01_pos_.csv',index_col=0)
df_mitchjo01_pos=pd.read_csv('../PlayerData/2003/posession/mitchjo01_pos_.csv',index_col=0)
df_mondobe01_pos=pd.read_csv('../PlayerData/2003/posession/mondobe01_pos_.csv',index_col=0)
df_mooregr01_pos=pd.read_csv('../PlayerData/2003/posession/mooregr01_pos_.csv',index_col=0)
df_morrity01_pos=pd.read_csv('../PlayerData/2003/posession/morrity01_pos_.csv',index_col=0)
df_morroth01_pos=pd.read_csv('../PlayerData/2003/posession/morroth01_pos_.csv',index_col=0)
df_moulsma01_pos=pd.read_csv('../PlayerData/2003/posession/moulsma01_pos_.csv',index_col=0)
df_mukhaan01_pos=pd.read_csv('../PlayerData/2003/posession/mukhaan01_pos_.csv',index_col=0)
df_muncery01_pos=pd.read_csv('../PlayerData/2003/posession/muncery01_pos_.csv',index_col=0)
df_murrabr01_pos=pd.read_csv('../PlayerData/2003/posession/murrabr01_pos_.csv',index_col=0)
df_nastike01_pos=pd.read_csv('../PlayerData/2003/posession/nastike01_pos_.csv',index_col=0)
df_nauroal01_pos=pd.read_csv('../PlayerData/2003/posession/nauroal01_pos_.csv',index_col=0)
df_nickema01_pos=pd.read_csv('../PlayerData/2003/posession/nickema01_pos_.csv',index_col=0)
df_nilssro01_pos=pd.read_csv('../PlayerData/2003/posession/nilssro01_pos_.csv',index_col=0)
df_nolanbr01_pos=pd.read_csv('../PlayerData/2003/posession/nolanbr01_pos_.csv',index_col=0)
df_obriedo01_pos=pd.read_csv('../PlayerData/2003/posession/obriedo01_pos_.csv',index_col=0)
df_obriesh01_pos=pd.read_csv('../PlayerData/2003/posession/obriesh01_pos_.csv',index_col=0)
df_obyrnry01_pos=pd.read_csv('../PlayerData/2003/posession/obyrnry01_pos_.csv',index_col=0)
df_ohanlbr01_pos=pd.read_csv('../PlayerData/2003/posession/ohanlbr01_pos_.csv',index_col=0)
df_olafsma01_pos=pd.read_csv('../PlayerData/2003/posession/olafsma01_pos_.csv',index_col=0)
df_olssoka01_pos=pd.read_csv('../PlayerData/2003/posession/olssoka01_pos_.csv',index_col=0)
df_osullpa01_pos=pd.read_csv('../PlayerData/2003/posession/osullpa01_pos_.csv',index_col=0)
df_oulahry01_pos=pd.read_csv('../PlayerData/2003/posession/oulahry01_pos_.csv',index_col=0)
df_paetsna01_pos=pd.read_csv('../PlayerData/2003/posession/paetsna01_pos_.csv',index_col=0)
df_parisza01_pos=pd.read_csv('../PlayerData/2003/posession/parisza01_pos_.csv',index_col=0)
df_paveljo01_pos=pd.read_csv('../PlayerData/2003/posession/paveljo01_pos_.csv',index_col=0)
df_pembeja01_pos=pd.read_csv('../PlayerData/2003/posession/pembeja01_pos_.csv',index_col=0)
df_perryco01_pos=pd.read_csv('../PlayerData/2003/posession/perryco01_pos_.csv',index_col=0)
df_pervyan01_pos=pd.read_csv('../PlayerData/2003/posession/pervyan01_pos_.csv',index_col=0)
df_pestudm01_pos=pd.read_csv('../PlayerData/2003/posession/pestudm01_pos_.csv',index_col=0)
df_phanedi01_pos=pd.read_csv('../PlayerData/2003/posession/phanedi01_pos_.csv',index_col=0)
df_picaral01_pos=pd.read_csv('../PlayerData/2003/posession/picaral01_pos_.csv',index_col=0)
df_piispar01_pos=pd.read_csv('../PlayerData/2003/posession/piispar01_pos_.csv',index_col=0)
df_pirnees01_pos=pd.read_csv('../PlayerData/2003/posession/pirnees01_pos_.csv',index_col=0)
df_polakvo01_pos=pd.read_csv('../PlayerData/2003/posession/polakvo01_pos_.csv',index_col=0)
df_portech01_pos=pd.read_csv('../PlayerData/2003/posession/portech01_pos_.csv',index_col=0)
df_potteco01_pos=pd.read_csv('../PlayerData/2003/posession/potteco01_pos_.csv',index_col=0)
df_potulry01_pos=pd.read_csv('../PlayerData/2003/posession/potulry01_pos_.csv',index_col=0)
df_poulima01_pos=pd.read_csv('../PlayerData/2003/posession/poulima01_pos_.csv',index_col=0)
df_pushkko01_pos=pd.read_csv('../PlayerData/2003/posession/pushkko01_pos_.csv',index_col=0)
df_quincky01_pos=pd.read_csv('../PlayerData/2003/posession/quincky01_pos_.csv',index_col=0)
df_ramhoti01_pos=pd.read_csv('../PlayerData/2003/posession/ramhoti01_pos_.csv',index_col=0)
df_redenty01_pos=pd.read_csv('../PlayerData/2003/posession/redenty01_pos_.csv',index_col=0)
df_redikfr01_pos=pd.read_csv('../PlayerData/2003/posession/redikfr01_pos_.csv',index_col=0)
df_reesedy01_pos=pd.read_csv('../PlayerData/2003/posession/reesedy01_pos_.csv',index_col=0)
df_reganke01_pos=pd.read_csv('../PlayerData/2003/posession/reganke01_pos_.csv',index_col=0)
df_rehakde01_pos=pd.read_csv('../PlayerData/2003/posession/rehakde01_pos_.csv',index_col=0)
df_richabr02_pos=pd.read_csv('../PlayerData/2003/posession/richabr02_pos_.csv',index_col=0)
df_richami02_pos=pd.read_csv('../PlayerData/2003/posession/richami02_pos_.csv',index_col=0)
df_richmda01_pos=pd.read_csv('../PlayerData/2003/posession/richmda01_pos_.csv',index_col=0)
df_roberjo02_pos=pd.read_csv('../PlayerData/2003/posession/roberjo02_pos_.csv',index_col=0)
df_rocheke01_pos=pd.read_csv('../PlayerData/2003/posession/rocheke01_pos_.csv',index_col=0)
df_rohlfda01_pos=pd.read_csv('../PlayerData/2003/posession/rohlfda01_pos_.csv',index_col=0)
df_romyke01_pos=pd.read_csv('../PlayerData/2003/posession/romyke01_pos_.csv',index_col=0)
df_rorabry01_pos=pd.read_csv('../PlayerData/2003/posession/rorabry01_pos_.csv',index_col=0)
df_rosehja01_pos=pd.read_csv('../PlayerData/2003/posession/rosehja01_pos_.csv',index_col=0)
df_roussda01_pos=pd.read_csv('../PlayerData/2003/posession/roussda01_pos_.csv',index_col=0)
df_royma01_pos=pd.read_csv('../PlayerData/2003/posession/royma01_pos_.csv',index_col=0)
df_ruzicst01_pos=pd.read_csv('../PlayerData/2003/posession/ruzicst01_pos_.csv',index_col=0)
df_sagatma01_pos=pd.read_csv('../PlayerData/2003/posession/sagatma01_pos_.csv',index_col=0)
df_saundna01_pos=pd.read_csv('../PlayerData/2003/posession/saundna01_pos_.csv',index_col=0)
df_seabrbr01_pos=pd.read_csv('../PlayerData/2003/posession/seabrbr01_pos_.csv',index_col=0)
df_seydoph01_pos=pd.read_csv('../PlayerData/2003/posession/seydoph01_pos_.csv',index_col=0)
df_shafigr01_pos=pd.read_csv('../PlayerData/2003/posession/shafigr01_pos_.csv',index_col=0)
df_sharrji01_pos=pd.read_csv('../PlayerData/2003/posession/sharrji01_pos_.csv',index_col=0)
df_sidikru01_pos=pd.read_csv('../PlayerData/2003/posession/sidikru01_pos_.csv',index_col=0)
df_skachev01_pos=pd.read_csv('../PlayerData/2003/posession/skachev01_pos_.csv',index_col=0)
df_smabyma01_pos=pd.read_csv('../PlayerData/2003/posession/smabyma01_pos_.csv',index_col=0)
df_smithja02_pos=pd.read_csv('../PlayerData/2003/posession/smithja02_pos_.csv',index_col=0)
df_southdi01_pos=pd.read_csv('../PlayerData/2003/posession/southdi01_pos_.csv',index_col=0)
df_staaler01_pos=pd.read_csv('../PlayerData/2003/posession/staaler01_pos_.csv',index_col=0)
df_stasyde01_pos=pd.read_csv('../PlayerData/2003/posession/stasyde01_pos_.csv',index_col=0)
df_stehlri01_pos=pd.read_csv('../PlayerData/2003/posession/stehlri01_pos_.csv',index_col=0)
df_stemple01_pos=pd.read_csv('../PlayerData/2003/posession/stemple01_pos_.csv',index_col=0)
df_stephsh01_pos=pd.read_csv('../PlayerData/2003/posession/stephsh01_pos_.csv',index_col=0)
df_sterlbr01_pos=pd.read_csv('../PlayerData/2003/posession/sterlbr01_pos_.csv',index_col=0)
df_stewaan01_pos=pd.read_csv('../PlayerData/2003/posession/stewaan01_pos_.csv',index_col=0)
df_stewada01_pos=pd.read_csv('../PlayerData/2003/posession/stewada01_pos_.csv',index_col=0)
df_stonery01_pos=pd.read_csv('../PlayerData/2003/posession/stonery01_pos_.csv',index_col=0)
df_stortza01_pos=pd.read_csv('../PlayerData/2003/posession/stortza01_pos_.csv',index_col=0)
df_stracty01_pos=pd.read_csv('../PlayerData/2003/posession/stracty01_pos_.csv',index_col=0)
df_stuarma01_pos=pd.read_csv('../PlayerData/2003/posession/stuarma01_pos_.csv',index_col=0)
df_sullimi02_pos=pd.read_csv('../PlayerData/2003/posession/sullimi02_pos_.csv',index_col=0)
df_sullise01_pos=pd.read_csv('../PlayerData/2003/posession/sullise01_pos_.csv',index_col=0)
df_sulzeal01_pos=pd.read_csv('../PlayerData/2003/posession/sulzeal01_pos_.csv',index_col=0)
df_sundian01_pos=pd.read_csv('../PlayerData/2003/posession/sundian01_pos_.csv',index_col=0)
df_suterry01_pos=pd.read_csv('../PlayerData/2003/posession/suterry01_pos_.csv',index_col=0)
df_svagrda01_pos=pd.read_csv('../PlayerData/2003/posession/svagrda01_pos_.csv',index_col=0)
df_tambeje01_pos=pd.read_csv('../PlayerData/2003/posession/tambeje01_pos_.csv',index_col=0)
df_tardija01_pos=pd.read_csv('../PlayerData/2003/posession/tardija01_pos_.csv',index_col=0)
df_tarkiza01_pos=pd.read_csv('../PlayerData/2003/posession/tarkiza01_pos_.csv',index_col=0)
df_tarnani01_pos=pd.read_csv('../PlayerData/2003/posession/tarnani01_pos_.csv',index_col=0)
df_tenutjo01_pos=pd.read_csv('../PlayerData/2003/posession/tenutjo01_pos_.csv',index_col=0)
df_thompna01_pos=pd.read_csv('../PlayerData/2003/posession/thompna01_pos_.csv',index_col=0)
df_topolse01_pos=pd.read_csv('../PlayerData/2003/posession/topolse01_pos_.csv',index_col=0)
df_travida01_pos=pd.read_csv('../PlayerData/2003/posession/travida01_pos_.csv',index_col=0)
df_trembda01_pos=pd.read_csv('../PlayerData/2003/posession/trembda01_pos_.csv',index_col=0)
df_trembjo01_pos=pd.read_csv('../PlayerData/2003/posession/trembjo01_pos_.csv',index_col=0)
df_trojoma01_pos=pd.read_csv('../PlayerData/2003/posession/trojoma01_pos_.csv',index_col=0)
df_tumama01_pos=pd.read_csv('../PlayerData/2003/posession/tumama01_pos_.csv',index_col=0)
df_tunikev01_pos=pd.read_csv('../PlayerData/2003/posession/tunikev01_pos_.csv',index_col=0)
df_umicedr01_pos=pd.read_csv('../PlayerData/2003/posession/umicedr01_pos_.csv',index_col=0)
df_urquhco01_pos=pd.read_csv('../PlayerData/2003/posession/urquhco01_pos_.csv',index_col=0)
df_vainini01_pos=pd.read_csv('../PlayerData/2003/posession/vainini01_pos_.csv',index_col=0)
df_valcapa01_pos=pd.read_csv('../PlayerData/2003/posession/valcapa01_pos_.csv',index_col=0)
df_valdian01_pos=pd.read_csv('../PlayerData/2003/posession/valdian01_pos_.csv',index_col=0)
df_vanekth01_pos=pd.read_csv('../PlayerData/2003/posession/vanekth01_pos_.csv',index_col=0)
df_vannemi01_pos=pd.read_csv('../PlayerData/2003/posession/vannemi01_pos_.csv',index_col=0)
df_videlli01_pos=pd.read_csv('../PlayerData/2003/posession/videlli01_pos_.csv',index_col=0)
df_vishnal01_pos=pd.read_csv('../PlayerData/2003/posession/vishnal01_pos_.csv',index_col=0)
df_volkoig01_pos=pd.read_csv('../PlayerData/2003/posession/volkoig01_pos_.csv',index_col=0)
df_volkoko01_pos=pd.read_csv('../PlayerData/2003/posession/volkoko01_pos_.csv',index_col=0)
df_vorospa01_pos=pd.read_csv('../PlayerData/2003/posession/vorospa01_pos_.csv',index_col=0)
df_vranape01_pos=pd.read_csv('../PlayerData/2003/posession/vranape01_pos_.csv',index_col=0)
df_wathifr01_pos=pd.read_csv('../PlayerData/2003/posession/wathifr01_pos_.csv',index_col=0)
df_weberje01_pos=pd.read_csv('../PlayerData/2003/posession/weberje01_pos_.csv',index_col=0)
df_webersh01_pos=pd.read_csv('../PlayerData/2003/posession/webersh01_pos_.csv',index_col=0)
df_wernest01_pos=pd.read_csv('../PlayerData/2003/posession/wernest01_pos_.csv',index_col=0)
df_willije01_pos=pd.read_csv('../PlayerData/2003/posession/willije01_pos_.csv',index_col=0)
df_yacboda01_pos=pd.read_csv('../PlayerData/2003/posession/yacboda01_pos_.csv',index_col=0)
df_zabama01_pos=pd.read_csv('../PlayerData/2003/posession/zabama01_pos_.csv',index_col=0)
df_zakhako01_pos=pd.read_csv('../PlayerData/2003/posession/zakhako01_pos_.csv',index_col=0)
df_zherdni01_pos=pd.read_csv('../PlayerData/2003/posession/zherdni01_pos_.csv',index_col=0)
df_zhukomi01_pos=pd.read_csv('../PlayerData/2003/posession/zhukomi01_pos_.csv',index_col=0)

# %%
listcsv
# Out:
# ['aaltoju01_pos_.csv',
#  'alenju01_pos_.csv',
#  'anderjo04_pos_.csv',
#  'backeda01_pos_.csv',
#  'bagnadr01_pos_.csv',
#  'baraniv01_pos_.csv',
#  'barinmi01_pos_.csv',
#  'barulko01_pos_.csv',
#  'beaucre01_pos_.csv',
#  'beckfch01_pos_.csv',
#  'bellesh01_pos_.csv',
#  'belleth01_pos_.csv',
#  'bergepa01_pos_.csv',
#  'bernima01_pos_.csv',
#  'bernist01_pos_.csv',
#  'bissopa01_pos_.csv',
#  'bitzby01_pos_.csv',
#  'blahost01_pos_.csv',
#  'blansco01_pos_.csv',
#  'blomst01_pos_.csv',
#  'bodietr01_pos_.csv',
#  'boldual01_pos_.csv',
#  'bolduje01_pos_.csv',
#  'bolflu01_pos_.csv',
#  'bondaar01_pos_.csv',
#  'bonneji01_pos_.csv',
#  'boutijo01_pos_.csv',
#  'boylebr01_pos_.csv',
#  'brodemi01_pos_.csv',
#  'brodzky01_pos_.csv',
#  'brownch03_pos_.csv',
#  'browndu01_pos_.csv',
#  'brownmi03_pos_.csv',
#  'brownpa01_pos_.csv',
#  'burkhlo01_pos_.csv',
#  'burnsbr01_pos_.csv',
#  'byfugdu01_pos_.csv',
#  'carcida01_pos_.csv',
#  'carlema01_pos_.csv',
#  'carteje01_pos_.csv',
# ...

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"[name]="+elem[:-9]
# Out:
# df_aaltoju01_pos[name]=aaltoju01
# df_alenju01_pos[name]=alenju01
# df_anderjo04_pos[name]=anderjo04
# df_backeda01_pos[name]=backeda01
# df_bagnadr01_pos[name]=bagnadr01
# df_baraniv01_pos[name]=baraniv01
# df_barinmi01_pos[name]=barinmi01
# df_barulko01_pos[name]=barulko01
# df_beaucre01_pos[name]=beaucre01
# df_beckfch01_pos[name]=beckfch01
# df_bellesh01_pos[name]=bellesh01
# df_belleth01_pos[name]=belleth01
# df_bergepa01_pos[name]=bergepa01
# df_bernima01_pos[name]=bernima01
# df_bernist01_pos[name]=bernist01
# df_bissopa01_pos[name]=bissopa01
# df_bitzby01_pos[name]=bitzby01
# df_blahost01_pos[name]=blahost01
# df_blansco01_pos[name]=blansco01
# df_blomst01_pos[name]=blomst01
# df_bodietr01_pos[name]=bodietr01
# df_boldual01_pos[name]=boldual01
# df_bolduje01_pos[name]=bolduje01
# df_bolflu01_pos[name]=bolflu01
# df_bondaar01_pos[name]=bondaar01
# df_bonneji01_pos[name]=bonneji01
# df_boutijo01_pos[name]=boutijo01
# df_boylebr01_pos[name]=boylebr01
# ...

# %%
df_aaltoju01_pos['name']='aaltoju01'
df_alenju01_pos['name']='alenju01'
df_anderjo04_pos['name']='anderjo04'
df_backeda01_pos['name']='backeda01'
df_bagnadr01_pos['name']='bagnadr01'
df_baraniv01_pos['name']='baraniv01'
df_barinmi01_pos['name']='barinmi01'
df_barulko01_pos['name']='barulko01'
df_beaucre01_pos['name']='beaucre01'
df_beckfch01_pos['name']='beckfch01'
df_bellesh01_pos['name']='bellesh01'
df_belleth01_pos['name']='belleth01'
df_bergepa01_pos['name']='bergepa01'
df_bernima01_pos['name']='bernima01'
df_bernist01_pos['name']='bernist01'
df_bissopa01_pos['name']='bissopa01'
df_bitzby01_pos['name']='bitzby01'
df_blahost01_pos['name']='blahost01'
df_blansco01_pos['name']='blansco01'
df_blomst01_pos['name']='blomst01'
df_bodietr01_pos['name']='bodietr01'
df_boldual01_pos['name']='boldual01'
df_bolduje01_pos['name']='bolduje01'
df_bolflu01_pos['name']='bolflu01'
df_bondaar01_pos['name']='bondaar01'
df_bonneji01_pos['name']='bonneji01'
df_boutijo01_pos['name']='boutijo01'
df_boylebr01_pos['name']='boylebr01'
df_brodemi01_pos['name']='brodemi01'
df_brodzky01_pos['name']='brodzky01'
df_brownch03_pos['name']='brownch03'
df_browndu01_pos['name']='browndu01'
df_brownmi03_pos['name']='brownmi03'
df_brownpa01_pos['name']='brownpa01'
df_burkhlo01_pos['name']='burkhlo01'
df_burnsbr01_pos['name']='burnsbr01'
df_byfugdu01_pos['name']='byfugdu01'
df_carcida01_pos['name']='carcida01'
df_carlema01_pos['name']='carlema01'
df_carteje01_pos['name']='carteje01'
df_cherndm01_pos['name']='cherndm01'
df_chiodan01_pos['name']='chiodan01'
df_coburbr01_pos['name']='coburbr01'
df_colbewi01_pos['name']='colbewi01'
df_colemge01_pos['name']='colemge01'
df_collije01_pos['name']='collije01'
df_cookti01_pos['name']='cookti01'
df_courcad01_pos['name']='courcad01'
df_crawfco01_pos['name']='crawfco01'
df_crombbj01_pos['name']='crombbj01'
df_cunnica01_pos['name']='cunnica01'
df_danieni01_pos['name']='danieni01'
df_danilra01_pos['name']='danilra01'
df_darzila01_pos['name']='darzila01'
df_dawesni01_pos['name']='dawesni01'
df_dawsoaa01_pos['name']='dawsoaa01'
df_desbigu01_pos['name']='desbigu01'
df_dixonst01_pos['name']='dixonst01'
df_doherjo01_pos['name']='doherjo01'
df_donalry01_pos['name']='donalry01'
df_dorniiv01_pos['name']='dorniiv01'
df_dupuiph01_pos['name']='dupuiph01'
df_eavespa01_pos['name']='eavespa01'
df_egenemi01_pos['name']='egenemi01'
df_ehelepa01_pos['name']='ehelepa01'
df_elliobr01_pos['name']='elliobr01'
df_enstrto01_pos['name']='enstrto01'
df_erikslo01_pos['name']='erikslo01'
df_ezhovde01_pos['name']='ezhovde01'
df_fabrybr01_pos['name']='fabrybr01'
df_fehrer01_pos['name']='fehrer01'
df_filewjo01_pos['name']='filewjo01'
df_fitzgza01_pos['name']='fitzgza01'
df_fleurma01_pos['name']='fleurma01'
df_floodma01_pos['name']='floodma01'
df_fraseco01_pos['name']='fraseco01'
df_fritsda01_pos['name']='fritsda01'
df_furreph01_pos['name']='furreph01'
df_gelecra01_pos['name']='gelecra01'
df_gervabr01_pos['name']='gervabr01'
df_getzlry01_pos['name']='getzlry01'
df_gibbory01_pos['name']='gibbory01'
df_gimayse01_pos['name']='gimayse01'
df_glassta01_pos['name']='glassta01'
df_glazako01_pos['name']='glazako01'
df_granael01_pos['name']='granael01'
df_gravema01_pos['name']='gravema01'
df_grecobr01_pos['name']='grecobr01'
df_grenzmi01_pos['name']='grenzmi01'
df_guenefr01_pos['name']='guenefr01'
df_guerima01_pos['name']='guerima01'
df_guskoal01_pos['name']='guskoal01'
df_guyergi01_pos['name']='guyergi01'
df_halakja01_pos['name']='halakja01'
df_hamilmi01_pos['name']='hamilmi01'
df_hansema01_pos['name']='hansema01'
df_hanulmi01_pos['name']='hanulmi01'
df_harveke01_pos['name']='harveke01'
df_hecimjo01_pos['name']='hecimjo01'
df_heinoch01_pos['name']='heinoch01'
df_hejdaja01_pos['name']='hejdaja01'
df_heminbr01_pos['name']='heminbr01'
df_hendrtr01_pos['name']='hendrtr01'
df_hennejo01_pos['name']='hennejo01'
df_hoffmja01_pos['name']='hoffmja01'
df_holtch01_pos['name']='holtch01'
df_hortona01_pos['name']='hortona01'
df_hospeka01_pos['name']='hospeka01'
df_hostivi01_pos['name']='hostivi01'
df_howarja02_pos['name']='howarja02'
df_hrabajo01_pos['name']='hrabajo01'
df_hrdelzb01_pos['name']='hrdelzb01'
df_hultal01_pos['name']='hultal01'
df_hynessh01_pos['name']='hynessh01'
df_irmenda01_pos['name']='irmenda01'
df_isakoev01_pos['name']='isakoev01'
df_ivanoal01_pos['name']='ivanoal01'
df_jacquje01_pos['name']='jacquje01'
df_jarmake01_pos['name']='jarmake01'
df_jensejo01_pos['name']='jensejo01'
df_jessihu01_pos['name']='jessihu01'
df_johanmi01_pos['name']='johanmi01'
df_jonesda01_pos['name']='jonesda01'
df_joudran01_pos['name']='joudran01'
df_kadlepe01_pos['name']='kadlepe01'
df_kaipry01_pos['name']='kaipry01'
df_karlsma01_pos['name']='karlsma01'
df_keslery01_pos['name']='keslery01'
df_khomuiv01_pos['name']='khomuiv01'
df_kilpeee01_pos['name']='kilpeee01'
df_kleinke01_pos['name']='kleinke01'
df_kollato01_pos['name']='kollato01'
df_kolusma01_pos['name']='kolusma01'
df_koprimi01_pos['name']='koprimi01'
df_korpios01_pos['name']='korpios01'
df_kosmadm01_pos['name']='kosmadm01'
df_kostian01_pos['name']='kostian01'
df_kozakri01_pos['name']='kozakri01'
df_krepska01_pos['name']='krepska01'
df_kukkola01_pos['name']='kukkola01'
df_kutnyvl01_pos['name']='kutnyvl01'
df_landosh01_pos['name']='landosh01'
df_lapiema01_pos['name']='lapiema01'
df_lassite01_pos['name']='lassite01'
df_leeca01_pos['name']='leeca01'
df_lehunjo01_pos['name']='lehunjo01'
df_lewaned01_pos['name']='lewaned01'
df_liffida01_pos['name']='liffida01'
df_lindsli01_pos['name']='lindsli01'
df_lockeco01_pos['name']='lockeco01'
df_loginde01_pos['name']='loginde01'
df_lojekma01_pos['name']='lojekma01'
df_louhios01_pos['name']='louhios01'
df_macarcl01_pos['name']='macarcl01'
df_mantyvi01_pos['name']='mantyvi01'
df_marekja01_pos['name']='marekja01'
df_marjama01_pos['name']='marjama01'
df_martilo01_pos['name']='martilo01'
df_mccutma01_pos['name']='mccutma01'
df_mcdonco01_pos['name']='mcdonco01'
df_mcivena01_pos['name']='mcivena01'
df_melanma01_pos['name']='melanma01'
df_methoma01_pos['name']='methoma01'
df_meyerst01_pos['name']='meyerst01'
df_michami01_pos['name']='michami01'
df_milledr01_pos['name']='milledr01'
df_mirnoig01_pos['name']='mirnoig01'
df_mishage01_pos['name']='mishage01'
df_mitchjo01_pos['name']='mitchjo01'
df_mondobe01_pos['name']='mondobe01'
df_mooregr01_pos['name']='mooregr01'
df_morrity01_pos['name']='morrity01'
df_morroth01_pos['name']='morroth01'
df_moulsma01_pos['name']='moulsma01'
df_mukhaan01_pos['name']='mukhaan01'
df_muncery01_pos['name']='muncery01'
df_murrabr01_pos['name']='murrabr01'
df_nastike01_pos['name']='nastike01'
df_nauroal01_pos['name']='nauroal01'
df_nickema01_pos['name']='nickema01'
df_nilssro01_pos['name']='nilssro01'
df_nolanbr01_pos['name']='nolanbr01'
df_obriedo01_pos['name']='obriedo01'
df_obriesh01_pos['name']='obriesh01'
df_obyrnry01_pos['name']='obyrnry01'
df_ohanlbr01_pos['name']='ohanlbr01'
df_olafsma01_pos['name']='olafsma01'
df_olssoka01_pos['name']='olssoka01'
df_osullpa01_pos['name']='osullpa01'
df_oulahry01_pos['name']='oulahry01'
df_paetsna01_pos['name']='paetsna01'
df_parisza01_pos['name']='parisza01'
df_paveljo01_pos['name']='paveljo01'
df_pembeja01_pos['name']='pembeja01'
df_perryco01_pos['name']='perryco01'
df_pervyan01_pos['name']='pervyan01'
df_pestudm01_pos['name']='pestudm01'
df_phanedi01_pos['name']='phanedi01'
df_picaral01_pos['name']='picaral01'
df_piispar01_pos['name']='piispar01'
df_pirnees01_pos['name']='pirnees01'
df_polakvo01_pos['name']='polakvo01'
df_portech01_pos['name']='portech01'
df_potteco01_pos['name']='potteco01'
df_potulry01_pos['name']='potulry01'
df_poulima01_pos['name']='poulima01'
df_pushkko01_pos['name']='pushkko01'
df_quincky01_pos['name']='quincky01'
df_ramhoti01_pos['name']='ramhoti01'
df_redenty01_pos['name']='redenty01'
df_redikfr01_pos['name']='redikfr01'
df_reesedy01_pos['name']='reesedy01'
df_reganke01_pos['name']='reganke01'
df_rehakde01_pos['name']='rehakde01'
df_richabr02_pos['name']='richabr02'
df_richami02_pos['name']='richami02'
df_richmda01_pos['name']='richmda01'
df_roberjo02_pos['name']='roberjo02'
df_rocheke01_pos['name']='rocheke01'
df_rohlfda01_pos['name']='rohlfda01'
df_romyke01_pos['name']='romyke01'
df_rorabry01_pos['name']='rorabry01'
df_rosehja01_pos['name']='rosehja01'
df_roussda01_pos['name']='roussda01'
df_royma01_pos['name']='royma01'
df_ruzicst01_pos['name']='ruzicst01'
df_sagatma01_pos['name']='sagatma01'
df_saundna01_pos['name']='saundna01'
df_seabrbr01_pos['name']='seabrbr01'
df_seydoph01_pos['name']='seydoph01'
df_shafigr01_pos['name']='shafigr01'
df_sharrji01_pos['name']='sharrji01'
df_sidikru01_pos['name']='sidikru01'
df_skachev01_pos['name']='skachev01'
df_smabyma01_pos['name']='smabyma01'
df_smithja02_pos['name']='smithja02'
df_southdi01_pos['name']='southdi01'
df_staaler01_pos['name']='staaler01'
df_stasyde01_pos['name']='stasyde01'
df_stehlri01_pos['name']='stehlri01'
df_stemple01_pos['name']='stemple01'
df_stephsh01_pos['name']='stephsh01'
df_sterlbr01_pos['name']='sterlbr01'
df_stewaan01_pos['name']='stewaan01'
df_stewada01_pos['name']='stewada01'
df_stonery01_pos['name']='stonery01'
df_stortza01_pos['name']='stortza01'
df_stracty01_pos['name']='stracty01'
df_stuarma01_pos['name']='stuarma01'
df_sullimi02_pos['name']='sullimi02'
df_sullise01_pos['name']='sullise01'
df_sulzeal01_pos['name']='sulzeal01'
df_sundian01_pos['name']='sundian01'
df_suterry01_pos['name']='suterry01'
df_svagrda01_pos['name']='svagrda01'
df_tambeje01_pos['name']='tambeje01'
df_tardija01_pos['name']='tardija01'
df_tarkiza01_pos['name']='tarkiza01'
df_tarnani01_pos['name']='tarnani01'
df_tenutjo01_pos['name']='tenutjo01'
df_thompna01_pos['name']='thompna01'
df_topolse01_pos['name']='topolse01'
df_travida01_pos['name']='travida01'
df_trembda01_pos['name']='trembda01'
df_trembjo01_pos['name']='trembjo01'
df_trojoma01_pos['name']='trojoma01'
df_tumama01_pos['name']='tumama01'
df_tunikev01_pos['name']='tunikev01'
df_umicedr01_pos['name']='umicedr01'
df_urquhco01_pos['name']='urquhco01'
df_vainini01_pos['name']='vainini01'
df_valcapa01_pos['name']='valcapa01'
df_valdian01_pos['name']='valdian01'
df_vanekth01_pos['name']='vanekth01'
df_vannemi01_pos['name']='vannemi01'
df_videlli01_pos['name']='videlli01'
df_vishnal01_pos['name']='vishnal01'
df_volkoig01_pos['name']='volkoig01'
df_volkoko01_pos['name']='volkoko01'
df_vorospa01_pos['name']='vorospa01'
df_vranape01_pos['name']='vranape01'
df_wathifr01_pos['name']='wathifr01'
df_weberje01_pos['name']='weberje01'
df_webersh01_pos['name']='webersh01'
df_wernest01_pos['name']='wernest01'
df_willije01_pos['name']='willije01'
df_yacboda01_pos['name']='yacboda01'
df_zabama01_pos['name']='zabama01'
df_zakhako01_pos['name']='zakhako01'
df_zherdni01_pos['name']='zherdni01'
df_zhukomi01_pos['name']='zhukomi01'

# %%
#df_aebisda01_pos

# %%
for elem in listcsv:
    print "df_"+elem[:-5]
# Out:
# df_aaltoju01_pos
# df_alenju01_pos
# df_anderjo04_pos
# df_backeda01_pos
# df_bagnadr01_pos
# df_baraniv01_pos
# df_barinmi01_pos
# df_barulko01_pos
# df_beaucre01_pos
# df_beckfch01_pos
# df_bellesh01_pos
# df_belleth01_pos
# df_bergepa01_pos
# df_bernima01_pos
# df_bernist01_pos
# df_bissopa01_pos
# df_bitzby01_pos
# df_blahost01_pos
# df_blansco01_pos
# df_blomst01_pos
# df_bodietr01_pos
# df_boldual01_pos
# df_bolduje01_pos
# df_bolflu01_pos
# df_bondaar01_pos
# df_bonneji01_pos
# df_boutijo01_pos
# df_boylebr01_pos
# df_brodemi01_pos
# df_brodzky01_pos
# df_brownch03_pos
# df_browndu01_pos
# df_brownmi03_pos
# df_brownpa01_pos
# df_burkhlo01_pos
# df_burnsbr01_pos
# df_byfugdu01_pos
# df_carcida01_pos
# df_carlema01_pos
# df_carteje01_pos
# df_cherndm01_pos
# df_chiodan01_pos
# df_coburbr01_pos
# df_colbewi01_pos
# df_colemge01_pos
# df_collije01_pos
# df_cookti01_pos
# df_courcad01_pos
# df_crawfco01_pos
# df_crombbj01_pos
# df_cunnica01_pos
# df_danieni01_pos
# ...

# %%
pos_frames = [df_aaltoju01_pos,
df_alenju01_pos,
df_anderjo04_pos,
df_backeda01_pos,
df_bagnadr01_pos,
df_baraniv01_pos,
df_barinmi01_pos,
df_barulko01_pos,
df_beaucre01_pos,
df_beckfch01_pos,
df_bellesh01_pos,
df_belleth01_pos,
df_bergepa01_pos,
df_bernima01_pos,
df_bernist01_pos,
df_bissopa01_pos,
df_bitzby01_pos,
df_blahost01_pos,
df_blansco01_pos,
df_blomst01_pos,
df_bodietr01_pos,
df_boldual01_pos,
df_bolduje01_pos,
df_bolflu01_pos,
df_bondaar01_pos,
df_bonneji01_pos,
df_boutijo01_pos,
df_boylebr01_pos,
df_brodemi01_pos,
df_brodzky01_pos,
df_brownch03_pos,
df_browndu01_pos,
df_brownmi03_pos,
df_brownpa01_pos,
df_burkhlo01_pos,
df_burnsbr01_pos,
df_byfugdu01_pos,
df_carcida01_pos,
df_carlema01_pos,
df_carteje01_pos,
df_cherndm01_pos,
df_chiodan01_pos,
df_coburbr01_pos,
df_colbewi01_pos,
df_colemge01_pos,
df_collije01_pos,
df_cookti01_pos,
df_courcad01_pos,
df_crawfco01_pos,
df_crombbj01_pos,
df_cunnica01_pos,
df_danieni01_pos,
df_danilra01_pos,
df_darzila01_pos,
df_dawesni01_pos,
df_dawsoaa01_pos,
df_desbigu01_pos,
df_dixonst01_pos,
df_doherjo01_pos,
df_donalry01_pos,
df_dorniiv01_pos,
df_dupuiph01_pos,
df_eavespa01_pos,
df_egenemi01_pos,
df_ehelepa01_pos,
df_elliobr01_pos,
df_enstrto01_pos,
df_erikslo01_pos,
df_ezhovde01_pos,
df_fabrybr01_pos,
df_fehrer01_pos,
df_filewjo01_pos,
df_fitzgza01_pos,
df_fleurma01_pos,
df_floodma01_pos,
df_fraseco01_pos,
df_fritsda01_pos,
df_furreph01_pos,
df_gelecra01_pos,
df_gervabr01_pos,
df_getzlry01_pos,
df_gibbory01_pos,
df_gimayse01_pos,
df_glassta01_pos,
df_glazako01_pos,
df_granael01_pos,
df_gravema01_pos,
df_grecobr01_pos,
df_grenzmi01_pos,
df_guenefr01_pos,
df_guerima01_pos,
df_guskoal01_pos,
df_guyergi01_pos,
df_halakja01_pos,
df_hamilmi01_pos,
df_hansema01_pos,
df_hanulmi01_pos,
df_harveke01_pos,
df_hecimjo01_pos,
df_heinoch01_pos,
df_hejdaja01_pos,
df_heminbr01_pos,
df_hendrtr01_pos,
df_hennejo01_pos,
df_hoffmja01_pos,
df_holtch01_pos,
df_hortona01_pos,
df_hospeka01_pos,
df_hostivi01_pos,
df_howarja02_pos,
df_hrabajo01_pos,
df_hrdelzb01_pos,
df_hultal01_pos,
df_hynessh01_pos,
df_irmenda01_pos,
df_isakoev01_pos,
df_ivanoal01_pos,
df_jacquje01_pos,
df_jarmake01_pos,
df_jensejo01_pos,
df_jessihu01_pos,
df_johanmi01_pos,
df_jonesda01_pos,
df_joudran01_pos,
df_kadlepe01_pos,
df_kaipry01_pos,
df_karlsma01_pos,
df_keslery01_pos,
df_khomuiv01_pos,
df_kilpeee01_pos,
df_kleinke01_pos,
df_kollato01_pos,
df_kolusma01_pos,
df_koprimi01_pos,
df_korpios01_pos,
df_kosmadm01_pos,
df_kostian01_pos,
df_kozakri01_pos,
df_krepska01_pos,
df_kukkola01_pos,
df_kutnyvl01_pos,
df_landosh01_pos,
df_lapiema01_pos,
df_lassite01_pos,
df_leeca01_pos,
df_lehunjo01_pos,
df_lewaned01_pos,
df_liffida01_pos,
df_lindsli01_pos,
df_lockeco01_pos,
df_loginde01_pos,
df_lojekma01_pos,
df_louhios01_pos,
df_macarcl01_pos,
df_mantyvi01_pos,
df_marekja01_pos,
df_marjama01_pos,
df_martilo01_pos,
df_mccutma01_pos,
df_mcdonco01_pos,
df_mcivena01_pos,
df_melanma01_pos,
df_methoma01_pos,
df_meyerst01_pos,
df_michami01_pos,
df_milledr01_pos,
df_mirnoig01_pos,
df_mishage01_pos,
df_mitchjo01_pos,
df_mondobe01_pos,
df_mooregr01_pos,
df_morrity01_pos,
df_morroth01_pos,
df_moulsma01_pos,
df_mukhaan01_pos,
df_muncery01_pos,
df_murrabr01_pos,
df_nastike01_pos,
df_nauroal01_pos,
df_nickema01_pos,
df_nilssro01_pos,
df_nolanbr01_pos,
df_obriedo01_pos,
df_obriesh01_pos,
df_obyrnry01_pos,
df_ohanlbr01_pos,
df_olafsma01_pos,
df_olssoka01_pos,
df_osullpa01_pos,
df_oulahry01_pos,
df_paetsna01_pos,
df_parisza01_pos,
df_paveljo01_pos,
df_pembeja01_pos,
df_perryco01_pos,
df_pervyan01_pos,
df_pestudm01_pos,
df_phanedi01_pos,
df_picaral01_pos,
df_piispar01_pos,
df_pirnees01_pos,
df_polakvo01_pos,
df_portech01_pos,
df_potteco01_pos,
df_potulry01_pos,
df_poulima01_pos,
df_pushkko01_pos,
df_quincky01_pos,
df_ramhoti01_pos,
df_redenty01_pos,
df_redikfr01_pos,
df_reesedy01_pos,
df_reganke01_pos,
df_rehakde01_pos,
df_richabr02_pos,
df_richami02_pos,
df_richmda01_pos,
df_roberjo02_pos,
df_rocheke01_pos,
df_rohlfda01_pos,
df_romyke01_pos,
df_rorabry01_pos,
df_rosehja01_pos,
df_roussda01_pos,
df_royma01_pos,
df_ruzicst01_pos,
df_sagatma01_pos,
df_saundna01_pos,
df_seabrbr01_pos,
df_seydoph01_pos,
df_shafigr01_pos,
df_sharrji01_pos,
df_sidikru01_pos,
df_skachev01_pos,
df_smabyma01_pos,
df_smithja02_pos,
df_southdi01_pos,
df_staaler01_pos,
df_stasyde01_pos,
df_stehlri01_pos,
df_stemple01_pos,
df_stephsh01_pos,
df_sterlbr01_pos,
df_stewaan01_pos,
df_stewada01_pos,
df_stonery01_pos,
df_stortza01_pos,
df_stracty01_pos,
df_stuarma01_pos,
df_sullimi02_pos,
df_sullise01_pos,
df_sulzeal01_pos,
df_sundian01_pos,
df_suterry01_pos,
df_svagrda01_pos,
df_tambeje01_pos,
df_tardija01_pos,
df_tarkiza01_pos,
df_tarnani01_pos,
df_tenutjo01_pos,
df_thompna01_pos,
df_topolse01_pos,
df_travida01_pos,
df_trembda01_pos,
df_trembjo01_pos,
df_trojoma01_pos,
df_tumama01_pos,
df_tunikev01_pos,
df_umicedr01_pos,
df_urquhco01_pos,
df_vainini01_pos,
df_valcapa01_pos,
df_valdian01_pos,
df_vanekth01_pos,
df_vannemi01_pos,
df_videlli01_pos,
df_vishnal01_pos,
df_volkoig01_pos,
df_volkoko01_pos,
df_vorospa01_pos,
df_vranape01_pos,
df_wathifr01_pos,
df_weberje01_pos,
df_webersh01_pos,
df_wernest01_pos,
df_willije01_pos,
df_yacboda01_pos,
df_zabama01_pos,
df_zakhako01_pos,
df_zherdni01_pos,
df_zhukomi01_pos]

# %%
result_pos = pd.concat(pos_frames)

# %%
result_pos
# Out:
#      season  TOT   age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2007-08  STL  23.0      713.0          696.0       50.6           2.4
# 2   2008-09  STL  24.0      934.0          920.0       50.4           1.6
# 3   2009-10  STL  25.0     1035.0          915.0       53.1           1.5
# 4   2010-11  STL  26.0     1270.0         1073.0       54.2           3.3
# 5   2011-12  STL  27.0     1301.0         1075.0       54.8          -0.7
# 6   2012-13  STL  28.0      675.0          618.0       52.2           2.1
# 7   2013-14  STL  29.0     1100.0          893.0       55.2           0.7
# 8   2014-15  STL  30.0     1085.0         1078.0       50.2          -2.7
# 9   2015-16  STL  31.0     1088.0         1043.0       51.1          -0.9
# 10  2016-17  BOS  32.0      277.0          227.0       55.0           0.2
# 1   2010-11  MIN  27.0       13.0           22.0       37.1           -18
# 1   2007-08  NYR  22.0        9.0           12.0       42.9          </td
# ...

# %%
df_aaltoju01_strd=pd.read_csv('../PlayerData/2003/standard/aaltoju01_strd_.csv',index_col=0)
df_alenju01_strd=pd.read_csv('../PlayerData/2003/standard/alenju01_strd_.csv',index_col=0)
df_anderjo04_strd=pd.read_csv('../PlayerData/2003/standard/anderjo04_strd_.csv',index_col=0)
df_backeda01_strd=pd.read_csv('../PlayerData/2003/standard/backeda01_strd_.csv',index_col=0)
df_bagnadr01_strd=pd.read_csv('../PlayerData/2003/standard/bagnadr01_strd_.csv',index_col=0)
df_baraniv01_strd=pd.read_csv('../PlayerData/2003/standard/baraniv01_strd_.csv',index_col=0)
df_barinmi01_strd=pd.read_csv('../PlayerData/2003/standard/barinmi01_strd_.csv',index_col=0)
df_barulko01_strd=pd.read_csv('../PlayerData/2003/standard/barulko01_strd_.csv',index_col=0)
df_beaucre01_strd=pd.read_csv('../PlayerData/2003/standard/beaucre01_strd_.csv',index_col=0)
df_beckfch01_strd=pd.read_csv('../PlayerData/2003/standard/beckfch01_strd_.csv',index_col=0)
df_bellesh01_strd=pd.read_csv('../PlayerData/2003/standard/bellesh01_strd_.csv',index_col=0)
df_belleth01_strd=pd.read_csv('../PlayerData/2003/standard/belleth01_strd_.csv',index_col=0)
df_bergepa01_strd=pd.read_csv('../PlayerData/2003/standard/bergepa01_strd_.csv',index_col=0)
df_bernima01_strd=pd.read_csv('../PlayerData/2003/standard/bernima01_strd_.csv',index_col=0)
df_bernist01_strd=pd.read_csv('../PlayerData/2003/standard/bernist01_strd_.csv',index_col=0)
df_bissopa01_strd=pd.read_csv('../PlayerData/2003/standard/bissopa01_strd_.csv',index_col=0)
df_bitzby01_strd=pd.read_csv('../PlayerData/2003/standard/bitzby01_strd_.csv',index_col=0)
df_blahost01_strd=pd.read_csv('../PlayerData/2003/standard/blahost01_strd_.csv',index_col=0)
df_blansco01_strd=pd.read_csv('../PlayerData/2003/standard/blansco01_strd_.csv',index_col=0)
df_blomst01_strd=pd.read_csv('../PlayerData/2003/standard/blomst01_strd_.csv',index_col=0)
df_bodietr01_strd=pd.read_csv('../PlayerData/2003/standard/bodietr01_strd_.csv',index_col=0)
df_boldual01_strd=pd.read_csv('../PlayerData/2003/standard/boldual01_strd_.csv',index_col=0)
df_bolduje01_strd=pd.read_csv('../PlayerData/2003/standard/bolduje01_strd_.csv',index_col=0)
df_bolflu01_strd=pd.read_csv('../PlayerData/2003/standard/bolflu01_strd_.csv',index_col=0)
df_bondaar01_strd=pd.read_csv('../PlayerData/2003/standard/bondaar01_strd_.csv',index_col=0)
df_bonneji01_strd=pd.read_csv('../PlayerData/2003/standard/bonneji01_strd_.csv',index_col=0)
df_boutijo01_strd=pd.read_csv('../PlayerData/2003/standard/boutijo01_strd_.csv',index_col=0)
df_boylebr01_strd=pd.read_csv('../PlayerData/2003/standard/boylebr01_strd_.csv',index_col=0)
df_brodemi01_strd=pd.read_csv('../PlayerData/2003/standard/brodemi01_strd_.csv',index_col=0)
df_brodzky01_strd=pd.read_csv('../PlayerData/2003/standard/brodzky01_strd_.csv',index_col=0)
df_brownch03_strd=pd.read_csv('../PlayerData/2003/standard/brownch03_strd_.csv',index_col=0)
df_browndu01_strd=pd.read_csv('../PlayerData/2003/standard/browndu01_strd_.csv',index_col=0)
df_brownmi03_strd=pd.read_csv('../PlayerData/2003/standard/brownmi03_strd_.csv',index_col=0)
df_brownpa01_strd=pd.read_csv('../PlayerData/2003/standard/brownpa01_strd_.csv',index_col=0)
df_burkhlo01_strd=pd.read_csv('../PlayerData/2003/standard/burkhlo01_strd_.csv',index_col=0)
df_burnsbr01_strd=pd.read_csv('../PlayerData/2003/standard/burnsbr01_strd_.csv',index_col=0)
df_byfugdu01_strd=pd.read_csv('../PlayerData/2003/standard/byfugdu01_strd_.csv',index_col=0)
df_carcida01_strd=pd.read_csv('../PlayerData/2003/standard/carcida01_strd_.csv',index_col=0)
df_carlema01_strd=pd.read_csv('../PlayerData/2003/standard/carlema01_strd_.csv',index_col=0)
df_carteje01_strd=pd.read_csv('../PlayerData/2003/standard/carteje01_strd_.csv',index_col=0)
df_cherndm01_strd=pd.read_csv('../PlayerData/2003/standard/cherndm01_strd_.csv',index_col=0)
df_chiodan01_strd=pd.read_csv('../PlayerData/2003/standard/chiodan01_strd_.csv',index_col=0)
df_coburbr01_strd=pd.read_csv('../PlayerData/2003/standard/coburbr01_strd_.csv',index_col=0)
df_colbewi01_strd=pd.read_csv('../PlayerData/2003/standard/colbewi01_strd_.csv',index_col=0)
df_colemge01_strd=pd.read_csv('../PlayerData/2003/standard/colemge01_strd_.csv',index_col=0)
df_collije01_strd=pd.read_csv('../PlayerData/2003/standard/collije01_strd_.csv',index_col=0)
df_cookti01_strd=pd.read_csv('../PlayerData/2003/standard/cookti01_strd_.csv',index_col=0)
df_courcad01_strd=pd.read_csv('../PlayerData/2003/standard/courcad01_strd_.csv',index_col=0)
df_crawfco01_strd=pd.read_csv('../PlayerData/2003/standard/crawfco01_strd_.csv',index_col=0)
df_crombbj01_strd=pd.read_csv('../PlayerData/2003/standard/crombbj01_strd_.csv',index_col=0)
df_cunnica01_strd=pd.read_csv('../PlayerData/2003/standard/cunnica01_strd_.csv',index_col=0)
df_danieni01_strd=pd.read_csv('../PlayerData/2003/standard/danieni01_strd_.csv',index_col=0)
df_danilra01_strd=pd.read_csv('../PlayerData/2003/standard/danilra01_strd_.csv',index_col=0)
df_darzila01_strd=pd.read_csv('../PlayerData/2003/standard/darzila01_strd_.csv',index_col=0)
df_dawesni01_strd=pd.read_csv('../PlayerData/2003/standard/dawesni01_strd_.csv',index_col=0)
df_dawsoaa01_strd=pd.read_csv('../PlayerData/2003/standard/dawsoaa01_strd_.csv',index_col=0)
df_desbigu01_strd=pd.read_csv('../PlayerData/2003/standard/desbigu01_strd_.csv',index_col=0)
df_dixonst01_strd=pd.read_csv('../PlayerData/2003/standard/dixonst01_strd_.csv',index_col=0)
df_doherjo01_strd=pd.read_csv('../PlayerData/2003/standard/doherjo01_strd_.csv',index_col=0)
df_donalry01_strd=pd.read_csv('../PlayerData/2003/standard/donalry01_strd_.csv',index_col=0)
df_dorniiv01_strd=pd.read_csv('../PlayerData/2003/standard/dorniiv01_strd_.csv',index_col=0)
df_dupuiph01_strd=pd.read_csv('../PlayerData/2003/standard/dupuiph01_strd_.csv',index_col=0)
df_eavespa01_strd=pd.read_csv('../PlayerData/2003/standard/eavespa01_strd_.csv',index_col=0)
df_egenemi01_strd=pd.read_csv('../PlayerData/2003/standard/egenemi01_strd_.csv',index_col=0)
df_ehelepa01_strd=pd.read_csv('../PlayerData/2003/standard/ehelepa01_strd_.csv',index_col=0)
df_elliobr01_strd=pd.read_csv('../PlayerData/2003/standard/elliobr01_strd_.csv',index_col=0)
df_enstrto01_strd=pd.read_csv('../PlayerData/2003/standard/enstrto01_strd_.csv',index_col=0)
df_erikslo01_strd=pd.read_csv('../PlayerData/2003/standard/erikslo01_strd_.csv',index_col=0)
df_ezhovde01_strd=pd.read_csv('../PlayerData/2003/standard/ezhovde01_strd_.csv',index_col=0)
df_fabrybr01_strd=pd.read_csv('../PlayerData/2003/standard/fabrybr01_strd_.csv',index_col=0)
df_fehrer01_strd=pd.read_csv('../PlayerData/2003/standard/fehrer01_strd_.csv',index_col=0)
df_filewjo01_strd=pd.read_csv('../PlayerData/2003/standard/filewjo01_strd_.csv',index_col=0)
df_fitzgza01_strd=pd.read_csv('../PlayerData/2003/standard/fitzgza01_strd_.csv',index_col=0)
df_fleurma01_strd=pd.read_csv('../PlayerData/2003/standard/fleurma01_strd_.csv',index_col=0)
df_floodma01_strd=pd.read_csv('../PlayerData/2003/standard/floodma01_strd_.csv',index_col=0)
df_fraseco01_strd=pd.read_csv('../PlayerData/2003/standard/fraseco01_strd_.csv',index_col=0)
df_fritsda01_strd=pd.read_csv('../PlayerData/2003/standard/fritsda01_strd_.csv',index_col=0)
df_furreph01_strd=pd.read_csv('../PlayerData/2003/standard/furreph01_strd_.csv',index_col=0)
df_gelecra01_strd=pd.read_csv('../PlayerData/2003/standard/gelecra01_strd_.csv',index_col=0)
df_gervabr01_strd=pd.read_csv('../PlayerData/2003/standard/gervabr01_strd_.csv',index_col=0)
df_getzlry01_strd=pd.read_csv('../PlayerData/2003/standard/getzlry01_strd_.csv',index_col=0)
df_gibbory01_strd=pd.read_csv('../PlayerData/2003/standard/gibbory01_strd_.csv',index_col=0)
df_gimayse01_strd=pd.read_csv('../PlayerData/2003/standard/gimayse01_strd_.csv',index_col=0)
df_glassta01_strd=pd.read_csv('../PlayerData/2003/standard/glassta01_strd_.csv',index_col=0)
df_glazako01_strd=pd.read_csv('../PlayerData/2003/standard/glazako01_strd_.csv',index_col=0)
df_granael01_strd=pd.read_csv('../PlayerData/2003/standard/granael01_strd_.csv',index_col=0)
df_gravema01_strd=pd.read_csv('../PlayerData/2003/standard/gravema01_strd_.csv',index_col=0)
df_grecobr01_strd=pd.read_csv('../PlayerData/2003/standard/grecobr01_strd_.csv',index_col=0)
df_grenzmi01_strd=pd.read_csv('../PlayerData/2003/standard/grenzmi01_strd_.csv',index_col=0)
df_guenefr01_strd=pd.read_csv('../PlayerData/2003/standard/guenefr01_strd_.csv',index_col=0)
df_guerima01_strd=pd.read_csv('../PlayerData/2003/standard/guerima01_strd_.csv',index_col=0)
df_guskoal01_strd=pd.read_csv('../PlayerData/2003/standard/guskoal01_strd_.csv',index_col=0)
df_guyergi01_strd=pd.read_csv('../PlayerData/2003/standard/guyergi01_strd_.csv',index_col=0)
df_halakja01_strd=pd.read_csv('../PlayerData/2003/standard/halakja01_strd_.csv',index_col=0)
df_hamilmi01_strd=pd.read_csv('../PlayerData/2003/standard/hamilmi01_strd_.csv',index_col=0)
df_hansema01_strd=pd.read_csv('../PlayerData/2003/standard/hansema01_strd_.csv',index_col=0)
df_hanulmi01_strd=pd.read_csv('../PlayerData/2003/standard/hanulmi01_strd_.csv',index_col=0)
df_harveke01_strd=pd.read_csv('../PlayerData/2003/standard/harveke01_strd_.csv',index_col=0)
df_hecimjo01_strd=pd.read_csv('../PlayerData/2003/standard/hecimjo01_strd_.csv',index_col=0)
df_heinoch01_strd=pd.read_csv('../PlayerData/2003/standard/heinoch01_strd_.csv',index_col=0)
df_hejdaja01_strd=pd.read_csv('../PlayerData/2003/standard/hejdaja01_strd_.csv',index_col=0)
df_heminbr01_strd=pd.read_csv('../PlayerData/2003/standard/heminbr01_strd_.csv',index_col=0)
df_hendrtr01_strd=pd.read_csv('../PlayerData/2003/standard/hendrtr01_strd_.csv',index_col=0)
df_hennejo01_strd=pd.read_csv('../PlayerData/2003/standard/hennejo01_strd_.csv',index_col=0)
df_hoffmja01_strd=pd.read_csv('../PlayerData/2003/standard/hoffmja01_strd_.csv',index_col=0)
df_holtch01_strd=pd.read_csv('../PlayerData/2003/standard/holtch01_strd_.csv',index_col=0)
df_hortona01_strd=pd.read_csv('../PlayerData/2003/standard/hortona01_strd_.csv',index_col=0)
df_hospeka01_strd=pd.read_csv('../PlayerData/2003/standard/hospeka01_strd_.csv',index_col=0)
df_hostivi01_strd=pd.read_csv('../PlayerData/2003/standard/hostivi01_strd_.csv',index_col=0)
df_howarja02_strd=pd.read_csv('../PlayerData/2003/standard/howarja02_strd_.csv',index_col=0)
df_hrabajo01_strd=pd.read_csv('../PlayerData/2003/standard/hrabajo01_strd_.csv',index_col=0)
df_hrdelzb01_strd=pd.read_csv('../PlayerData/2003/standard/hrdelzb01_strd_.csv',index_col=0)
df_hultal01_strd=pd.read_csv('../PlayerData/2003/standard/hultal01_strd_.csv',index_col=0)
df_hynessh01_strd=pd.read_csv('../PlayerData/2003/standard/hynessh01_strd_.csv',index_col=0)
df_irmenda01_strd=pd.read_csv('../PlayerData/2003/standard/irmenda01_strd_.csv',index_col=0)
df_isakoev01_strd=pd.read_csv('../PlayerData/2003/standard/isakoev01_strd_.csv',index_col=0)
df_ivanoal01_strd=pd.read_csv('../PlayerData/2003/standard/ivanoal01_strd_.csv',index_col=0)
df_jacquje01_strd=pd.read_csv('../PlayerData/2003/standard/jacquje01_strd_.csv',index_col=0)
df_jarmake01_strd=pd.read_csv('../PlayerData/2003/standard/jarmake01_strd_.csv',index_col=0)
df_jensejo01_strd=pd.read_csv('../PlayerData/2003/standard/jensejo01_strd_.csv',index_col=0)
df_jessihu01_strd=pd.read_csv('../PlayerData/2003/standard/jessihu01_strd_.csv',index_col=0)
df_johanmi01_strd=pd.read_csv('../PlayerData/2003/standard/johanmi01_strd_.csv',index_col=0)
df_jonesda01_strd=pd.read_csv('../PlayerData/2003/standard/jonesda01_strd_.csv',index_col=0)
df_joudran01_strd=pd.read_csv('../PlayerData/2003/standard/joudran01_strd_.csv',index_col=0)
df_kadlepe01_strd=pd.read_csv('../PlayerData/2003/standard/kadlepe01_strd_.csv',index_col=0)
df_kaipry01_strd=pd.read_csv('../PlayerData/2003/standard/kaipry01_strd_.csv',index_col=0)
df_karlsma01_strd=pd.read_csv('../PlayerData/2003/standard/karlsma01_strd_.csv',index_col=0)
df_keslery01_strd=pd.read_csv('../PlayerData/2003/standard/keslery01_strd_.csv',index_col=0)
df_khomuiv01_strd=pd.read_csv('../PlayerData/2003/standard/khomuiv01_strd_.csv',index_col=0)
df_kilpeee01_strd=pd.read_csv('../PlayerData/2003/standard/kilpeee01_strd_.csv',index_col=0)
df_kleinke01_strd=pd.read_csv('../PlayerData/2003/standard/kleinke01_strd_.csv',index_col=0)
df_kollato01_strd=pd.read_csv('../PlayerData/2003/standard/kollato01_strd_.csv',index_col=0)
df_kolusma01_strd=pd.read_csv('../PlayerData/2003/standard/kolusma01_strd_.csv',index_col=0)
df_koprimi01_strd=pd.read_csv('../PlayerData/2003/standard/koprimi01_strd_.csv',index_col=0)
df_korpios01_strd=pd.read_csv('../PlayerData/2003/standard/korpios01_strd_.csv',index_col=0)
df_kosmadm01_strd=pd.read_csv('../PlayerData/2003/standard/kosmadm01_strd_.csv',index_col=0)
df_kostian01_strd=pd.read_csv('../PlayerData/2003/standard/kostian01_strd_.csv',index_col=0)
df_kozakri01_strd=pd.read_csv('../PlayerData/2003/standard/kozakri01_strd_.csv',index_col=0)
df_krepska01_strd=pd.read_csv('../PlayerData/2003/standard/krepska01_strd_.csv',index_col=0)
df_kukkola01_strd=pd.read_csv('../PlayerData/2003/standard/kukkola01_strd_.csv',index_col=0)
df_kutnyvl01_strd=pd.read_csv('../PlayerData/2003/standard/kutnyvl01_strd_.csv',index_col=0)
df_landosh01_strd=pd.read_csv('../PlayerData/2003/standard/landosh01_strd_.csv',index_col=0)
df_lapiema01_strd=pd.read_csv('../PlayerData/2003/standard/lapiema01_strd_.csv',index_col=0)
df_lassite01_strd=pd.read_csv('../PlayerData/2003/standard/lassite01_strd_.csv',index_col=0)
df_leeca01_strd=pd.read_csv('../PlayerData/2003/standard/leeca01_strd_.csv',index_col=0)
df_lehunjo01_strd=pd.read_csv('../PlayerData/2003/standard/lehunjo01_strd_.csv',index_col=0)
df_lewaned01_strd=pd.read_csv('../PlayerData/2003/standard/lewaned01_strd_.csv',index_col=0)
df_liffida01_strd=pd.read_csv('../PlayerData/2003/standard/liffida01_strd_.csv',index_col=0)
df_lindsli01_strd=pd.read_csv('../PlayerData/2003/standard/lindsli01_strd_.csv',index_col=0)
df_lockeco01_strd=pd.read_csv('../PlayerData/2003/standard/lockeco01_strd_.csv',index_col=0)
df_loginde01_strd=pd.read_csv('../PlayerData/2003/standard/loginde01_strd_.csv',index_col=0)
df_lojekma01_strd=pd.read_csv('../PlayerData/2003/standard/lojekma01_strd_.csv',index_col=0)
df_louhios01_strd=pd.read_csv('../PlayerData/2003/standard/louhios01_strd_.csv',index_col=0)
df_macarcl01_strd=pd.read_csv('../PlayerData/2003/standard/macarcl01_strd_.csv',index_col=0)
df_mantyvi01_strd=pd.read_csv('../PlayerData/2003/standard/mantyvi01_strd_.csv',index_col=0)
df_marekja01_strd=pd.read_csv('../PlayerData/2003/standard/marekja01_strd_.csv',index_col=0)
df_marjama01_strd=pd.read_csv('../PlayerData/2003/standard/marjama01_strd_.csv',index_col=0)
df_martilo01_strd=pd.read_csv('../PlayerData/2003/standard/martilo01_strd_.csv',index_col=0)
df_mccutma01_strd=pd.read_csv('../PlayerData/2003/standard/mccutma01_strd_.csv',index_col=0)
df_mcdonco01_strd=pd.read_csv('../PlayerData/2003/standard/mcdonco01_strd_.csv',index_col=0)
df_mcivena01_strd=pd.read_csv('../PlayerData/2003/standard/mcivena01_strd_.csv',index_col=0)
df_melanma01_strd=pd.read_csv('../PlayerData/2003/standard/melanma01_strd_.csv',index_col=0)
df_methoma01_strd=pd.read_csv('../PlayerData/2003/standard/methoma01_strd_.csv',index_col=0)
df_meyerst01_strd=pd.read_csv('../PlayerData/2003/standard/meyerst01_strd_.csv',index_col=0)
df_michami01_strd=pd.read_csv('../PlayerData/2003/standard/michami01_strd_.csv',index_col=0)
df_milledr01_strd=pd.read_csv('../PlayerData/2003/standard/milledr01_strd_.csv',index_col=0)
df_mirnoig01_strd=pd.read_csv('../PlayerData/2003/standard/mirnoig01_strd_.csv',index_col=0)
df_mishage01_strd=pd.read_csv('../PlayerData/2003/standard/mishage01_strd_.csv',index_col=0)
df_mitchjo01_strd=pd.read_csv('../PlayerData/2003/standard/mitchjo01_strd_.csv',index_col=0)
df_mondobe01_strd=pd.read_csv('../PlayerData/2003/standard/mondobe01_strd_.csv',index_col=0)
df_mooregr01_strd=pd.read_csv('../PlayerData/2003/standard/mooregr01_strd_.csv',index_col=0)
df_morrity01_strd=pd.read_csv('../PlayerData/2003/standard/morrity01_strd_.csv',index_col=0)
df_morroth01_strd=pd.read_csv('../PlayerData/2003/standard/morroth01_strd_.csv',index_col=0)
df_moulsma01_strd=pd.read_csv('../PlayerData/2003/standard/moulsma01_strd_.csv',index_col=0)
df_mukhaan01_strd=pd.read_csv('../PlayerData/2003/standard/mukhaan01_strd_.csv',index_col=0)
df_muncery01_strd=pd.read_csv('../PlayerData/2003/standard/muncery01_strd_.csv',index_col=0)
df_murrabr01_strd=pd.read_csv('../PlayerData/2003/standard/murrabr01_strd_.csv',index_col=0)
df_nastike01_strd=pd.read_csv('../PlayerData/2003/standard/nastike01_strd_.csv',index_col=0)
df_nauroal01_strd=pd.read_csv('../PlayerData/2003/standard/nauroal01_strd_.csv',index_col=0)
df_nickema01_strd=pd.read_csv('../PlayerData/2003/standard/nickema01_strd_.csv',index_col=0)
df_nilssro01_strd=pd.read_csv('../PlayerData/2003/standard/nilssro01_strd_.csv',index_col=0)
df_nolanbr01_strd=pd.read_csv('../PlayerData/2003/standard/nolanbr01_strd_.csv',index_col=0)
df_obriedo01_strd=pd.read_csv('../PlayerData/2003/standard/obriedo01_strd_.csv',index_col=0)
df_obriesh01_strd=pd.read_csv('../PlayerData/2003/standard/obriesh01_strd_.csv',index_col=0)
df_obyrnry01_strd=pd.read_csv('../PlayerData/2003/standard/obyrnry01_strd_.csv',index_col=0)
df_ohanlbr01_strd=pd.read_csv('../PlayerData/2003/standard/ohanlbr01_strd_.csv',index_col=0)
df_olafsma01_strd=pd.read_csv('../PlayerData/2003/standard/olafsma01_strd_.csv',index_col=0)
df_olssoka01_strd=pd.read_csv('../PlayerData/2003/standard/olssoka01_strd_.csv',index_col=0)
df_osullpa01_strd=pd.read_csv('../PlayerData/2003/standard/osullpa01_strd_.csv',index_col=0)
df_oulahry01_strd=pd.read_csv('../PlayerData/2003/standard/oulahry01_strd_.csv',index_col=0)
df_paetsna01_strd=pd.read_csv('../PlayerData/2003/standard/paetsna01_strd_.csv',index_col=0)
df_parisza01_strd=pd.read_csv('../PlayerData/2003/standard/parisza01_strd_.csv',index_col=0)
df_paveljo01_strd=pd.read_csv('../PlayerData/2003/standard/paveljo01_strd_.csv',index_col=0)
df_pembeja01_strd=pd.read_csv('../PlayerData/2003/standard/pembeja01_strd_.csv',index_col=0)
df_perryco01_strd=pd.read_csv('../PlayerData/2003/standard/perryco01_strd_.csv',index_col=0)
df_pervyan01_strd=pd.read_csv('../PlayerData/2003/standard/pervyan01_strd_.csv',index_col=0)
df_pestudm01_strd=pd.read_csv('../PlayerData/2003/standard/pestudm01_strd_.csv',index_col=0)
df_phanedi01_strd=pd.read_csv('../PlayerData/2003/standard/phanedi01_strd_.csv',index_col=0)
df_picaral01_strd=pd.read_csv('../PlayerData/2003/standard/picaral01_strd_.csv',index_col=0)
df_piispar01_strd=pd.read_csv('../PlayerData/2003/standard/piispar01_strd_.csv',index_col=0)
df_pirnees01_strd=pd.read_csv('../PlayerData/2003/standard/pirnees01_strd_.csv',index_col=0)
df_polakvo01_strd=pd.read_csv('../PlayerData/2003/standard/polakvo01_strd_.csv',index_col=0)
df_portech01_strd=pd.read_csv('../PlayerData/2003/standard/portech01_strd_.csv',index_col=0)
df_potteco01_strd=pd.read_csv('../PlayerData/2003/standard/potteco01_strd_.csv',index_col=0)
df_potulry01_strd=pd.read_csv('../PlayerData/2003/standard/potulry01_strd_.csv',index_col=0)
df_poulima01_strd=pd.read_csv('../PlayerData/2003/standard/poulima01_strd_.csv',index_col=0)
df_pushkko01_strd=pd.read_csv('../PlayerData/2003/standard/pushkko01_strd_.csv',index_col=0)
df_quincky01_strd=pd.read_csv('../PlayerData/2003/standard/quincky01_strd_.csv',index_col=0)
df_ramhoti01_strd=pd.read_csv('../PlayerData/2003/standard/ramhoti01_strd_.csv',index_col=0)
df_redenty01_strd=pd.read_csv('../PlayerData/2003/standard/redenty01_strd_.csv',index_col=0)
df_redikfr01_strd=pd.read_csv('../PlayerData/2003/standard/redikfr01_strd_.csv',index_col=0)
df_reesedy01_strd=pd.read_csv('../PlayerData/2003/standard/reesedy01_strd_.csv',index_col=0)
df_reganke01_strd=pd.read_csv('../PlayerData/2003/standard/reganke01_strd_.csv',index_col=0)
df_rehakde01_strd=pd.read_csv('../PlayerData/2003/standard/rehakde01_strd_.csv',index_col=0)
df_richabr02_strd=pd.read_csv('../PlayerData/2003/standard/richabr02_strd_.csv',index_col=0)
df_richami02_strd=pd.read_csv('../PlayerData/2003/standard/richami02_strd_.csv',index_col=0)
df_richmda01_strd=pd.read_csv('../PlayerData/2003/standard/richmda01_strd_.csv',index_col=0)
df_roberjo02_strd=pd.read_csv('../PlayerData/2003/standard/roberjo02_strd_.csv',index_col=0)
df_rocheke01_strd=pd.read_csv('../PlayerData/2003/standard/rocheke01_strd_.csv',index_col=0)
df_rohlfda01_strd=pd.read_csv('../PlayerData/2003/standard/rohlfda01_strd_.csv',index_col=0)
df_romyke01_strd=pd.read_csv('../PlayerData/2003/standard/romyke01_strd_.csv',index_col=0)
df_rorabry01_strd=pd.read_csv('../PlayerData/2003/standard/rorabry01_strd_.csv',index_col=0)
df_rosehja01_strd=pd.read_csv('../PlayerData/2003/standard/rosehja01_strd_.csv',index_col=0)
df_roussda01_strd=pd.read_csv('../PlayerData/2003/standard/roussda01_strd_.csv',index_col=0)
df_royma01_strd=pd.read_csv('../PlayerData/2003/standard/royma01_strd_.csv',index_col=0)
df_ruzicst01_strd=pd.read_csv('../PlayerData/2003/standard/ruzicst01_strd_.csv',index_col=0)
df_sagatma01_strd=pd.read_csv('../PlayerData/2003/standard/sagatma01_strd_.csv',index_col=0)
df_saundna01_strd=pd.read_csv('../PlayerData/2003/standard/saundna01_strd_.csv',index_col=0)
df_seabrbr01_strd=pd.read_csv('../PlayerData/2003/standard/seabrbr01_strd_.csv',index_col=0)
df_seydoph01_strd=pd.read_csv('../PlayerData/2003/standard/seydoph01_strd_.csv',index_col=0)
df_shafigr01_strd=pd.read_csv('../PlayerData/2003/standard/shafigr01_strd_.csv',index_col=0)
df_sharrji01_strd=pd.read_csv('../PlayerData/2003/standard/sharrji01_strd_.csv',index_col=0)
df_sidikru01_strd=pd.read_csv('../PlayerData/2003/standard/sidikru01_strd_.csv',index_col=0)
df_skachev01_strd=pd.read_csv('../PlayerData/2003/standard/skachev01_strd_.csv',index_col=0)
df_smabyma01_strd=pd.read_csv('../PlayerData/2003/standard/smabyma01_strd_.csv',index_col=0)
df_smithja02_strd=pd.read_csv('../PlayerData/2003/standard/smithja02_strd_.csv',index_col=0)
df_southdi01_strd=pd.read_csv('../PlayerData/2003/standard/southdi01_strd_.csv',index_col=0)
df_staaler01_strd=pd.read_csv('../PlayerData/2003/standard/staaler01_strd_.csv',index_col=0)
df_stasyde01_strd=pd.read_csv('../PlayerData/2003/standard/stasyde01_strd_.csv',index_col=0)
df_stehlri01_strd=pd.read_csv('../PlayerData/2003/standard/stehlri01_strd_.csv',index_col=0)
df_stemple01_strd=pd.read_csv('../PlayerData/2003/standard/stemple01_strd_.csv',index_col=0)
df_stephsh01_strd=pd.read_csv('../PlayerData/2003/standard/stephsh01_strd_.csv',index_col=0)
df_sterlbr01_strd=pd.read_csv('../PlayerData/2003/standard/sterlbr01_strd_.csv',index_col=0)
df_stewaan01_strd=pd.read_csv('../PlayerData/2003/standard/stewaan01_strd_.csv',index_col=0)
df_stewada01_strd=pd.read_csv('../PlayerData/2003/standard/stewada01_strd_.csv',index_col=0)
df_stonery01_strd=pd.read_csv('../PlayerData/2003/standard/stonery01_strd_.csv',index_col=0)
df_stortza01_strd=pd.read_csv('../PlayerData/2003/standard/stortza01_strd_.csv',index_col=0)
df_stracty01_strd=pd.read_csv('../PlayerData/2003/standard/stracty01_strd_.csv',index_col=0)
df_stuarma01_strd=pd.read_csv('../PlayerData/2003/standard/stuarma01_strd_.csv',index_col=0)
df_sullimi02_strd=pd.read_csv('../PlayerData/2003/standard/sullimi02_strd_.csv',index_col=0)
df_sullise01_strd=pd.read_csv('../PlayerData/2003/standard/sullise01_strd_.csv',index_col=0)
df_sulzeal01_strd=pd.read_csv('../PlayerData/2003/standard/sulzeal01_strd_.csv',index_col=0)
df_sundian01_strd=pd.read_csv('../PlayerData/2003/standard/sundian01_strd_.csv',index_col=0)
df_suterry01_strd=pd.read_csv('../PlayerData/2003/standard/suterry01_strd_.csv',index_col=0)
df_svagrda01_strd=pd.read_csv('../PlayerData/2003/standard/svagrda01_strd_.csv',index_col=0)
df_tambeje01_strd=pd.read_csv('../PlayerData/2003/standard/tambeje01_strd_.csv',index_col=0)
df_tardija01_strd=pd.read_csv('../PlayerData/2003/standard/tardija01_strd_.csv',index_col=0)
df_tarkiza01_strd=pd.read_csv('../PlayerData/2003/standard/tarkiza01_strd_.csv',index_col=0)
df_tarnani01_strd=pd.read_csv('../PlayerData/2003/standard/tarnani01_strd_.csv',index_col=0)
df_tenutjo01_strd=pd.read_csv('../PlayerData/2003/standard/tenutjo01_strd_.csv',index_col=0)
df_thompna01_strd=pd.read_csv('../PlayerData/2003/standard/thompna01_strd_.csv',index_col=0)
df_topolse01_strd=pd.read_csv('../PlayerData/2003/standard/topolse01_strd_.csv',index_col=0)
df_travida01_strd=pd.read_csv('../PlayerData/2003/standard/travida01_strd_.csv',index_col=0)
df_trembda01_strd=pd.read_csv('../PlayerData/2003/standard/trembda01_strd_.csv',index_col=0)
df_trembjo01_strd=pd.read_csv('../PlayerData/2003/standard/trembjo01_strd_.csv',index_col=0)
df_trojoma01_strd=pd.read_csv('../PlayerData/2003/standard/trojoma01_strd_.csv',index_col=0)
df_tumama01_strd=pd.read_csv('../PlayerData/2003/standard/tumama01_strd_.csv',index_col=0)
df_tunikev01_strd=pd.read_csv('../PlayerData/2003/standard/tunikev01_strd_.csv',index_col=0)
df_umicedr01_strd=pd.read_csv('../PlayerData/2003/standard/umicedr01_strd_.csv',index_col=0)
df_urquhco01_strd=pd.read_csv('../PlayerData/2003/standard/urquhco01_strd_.csv',index_col=0)
df_vainini01_strd=pd.read_csv('../PlayerData/2003/standard/vainini01_strd_.csv',index_col=0)
df_valcapa01_strd=pd.read_csv('../PlayerData/2003/standard/valcapa01_strd_.csv',index_col=0)
df_valdian01_strd=pd.read_csv('../PlayerData/2003/standard/valdian01_strd_.csv',index_col=0)
df_vanekth01_strd=pd.read_csv('../PlayerData/2003/standard/vanekth01_strd_.csv',index_col=0)
df_vannemi01_strd=pd.read_csv('../PlayerData/2003/standard/vannemi01_strd_.csv',index_col=0)
df_videlli01_strd=pd.read_csv('../PlayerData/2003/standard/videlli01_strd_.csv',index_col=0)
df_vishnal01_strd=pd.read_csv('../PlayerData/2003/standard/vishnal01_strd_.csv',index_col=0)
df_volkoig01_strd=pd.read_csv('../PlayerData/2003/standard/volkoig01_strd_.csv',index_col=0)
df_volkoko01_strd=pd.read_csv('../PlayerData/2003/standard/volkoko01_strd_.csv',index_col=0)
df_vorospa01_strd=pd.read_csv('../PlayerData/2003/standard/vorospa01_strd_.csv',index_col=0)
df_vranape01_strd=pd.read_csv('../PlayerData/2003/standard/vranape01_strd_.csv',index_col=0)
df_wathifr01_strd=pd.read_csv('../PlayerData/2003/standard/wathifr01_strd_.csv',index_col=0)
df_weberje01_strd=pd.read_csv('../PlayerData/2003/standard/weberje01_strd_.csv',index_col=0)
df_webersh01_strd=pd.read_csv('../PlayerData/2003/standard/webersh01_strd_.csv',index_col=0)
df_wernest01_strd=pd.read_csv('../PlayerData/2003/standard/wernest01_strd_.csv',index_col=0)
df_willije01_strd=pd.read_csv('../PlayerData/2003/standard/willije01_strd_.csv',index_col=0)
df_yacboda01_strd=pd.read_csv('../PlayerData/2003/standard/yacboda01_strd_.csv',index_col=0)
df_zabama01_strd=pd.read_csv('../PlayerData/2003/standard/zabama01_strd_.csv',index_col=0)
df_zakhako01_strd=pd.read_csv('../PlayerData/2003/standard/zakhako01_strd_.csv',index_col=0)
df_zherdni01_strd=pd.read_csv('../PlayerData/2003/standard/zherdni01_strd_.csv',index_col=0)
df_zhukomi01_strd=pd.read_csv('../PlayerData/2003/standard/zhukomi01_strd_.csv',index_col=0)

# %%
df_aaltoju01_strd['name']='aaltoju01'
df_alenju01_strd['name']='alenju01'
df_anderjo04_strd['name']='anderjo04'
df_backeda01_strd['name']='backeda01'
df_bagnadr01_strd['name']='bagnadr01'
df_baraniv01_strd['name']='baraniv01'
df_barinmi01_strd['name']='barinmi01'
df_barulko01_strd['name']='barulko01'
df_beaucre01_strd['name']='beaucre01'
df_beckfch01_strd['name']='beckfch01'
df_bellesh01_strd['name']='bellesh01'
df_belleth01_strd['name']='belleth01'
df_bergepa01_strd['name']='bergepa01'
df_bernima01_strd['name']='bernima01'
df_bernist01_strd['name']='bernist01'
df_bissopa01_strd['name']='bissopa01'
df_bitzby01_strd['name']='bitzby01'
df_blahost01_strd['name']='blahost01'
df_blansco01_strd['name']='blansco01'
df_blomst01_strd['name']='blomst01'
df_bodietr01_strd['name']='bodietr01'
df_boldual01_strd['name']='boldual01'
df_bolduje01_strd['name']='bolduje01'
df_bolflu01_strd['name']='bolflu01'
df_bondaar01_strd['name']='bondaar01'
df_bonneji01_strd['name']='bonneji01'
df_boutijo01_strd['name']='boutijo01'
df_boylebr01_strd['name']='boylebr01'
df_brodemi01_strd['name']='brodemi01'
df_brodzky01_strd['name']='brodzky01'
df_brownch03_strd['name']='brownch03'
df_browndu01_strd['name']='browndu01'
df_brownmi03_strd['name']='brownmi03'
df_brownpa01_strd['name']='brownpa01'
df_burkhlo01_strd['name']='burkhlo01'
df_burnsbr01_strd['name']='burnsbr01'
df_byfugdu01_strd['name']='byfugdu01'
df_carcida01_strd['name']='carcida01'
df_carlema01_strd['name']='carlema01'
df_carteje01_strd['name']='carteje01'
df_cherndm01_strd['name']='cherndm01'
df_chiodan01_strd['name']='chiodan01'
df_coburbr01_strd['name']='coburbr01'
df_colbewi01_strd['name']='colbewi01'
df_colemge01_strd['name']='colemge01'
df_collije01_strd['name']='collije01'
df_cookti01_strd['name']='cookti01'
df_courcad01_strd['name']='courcad01'
df_crawfco01_strd['name']='crawfco01'
df_crombbj01_strd['name']='crombbj01'
df_cunnica01_strd['name']='cunnica01'
df_danieni01_strd['name']='danieni01'
df_danilra01_strd['name']='danilra01'
df_darzila01_strd['name']='darzila01'
df_dawesni01_strd['name']='dawesni01'
df_dawsoaa01_strd['name']='dawsoaa01'
df_desbigu01_strd['name']='desbigu01'
df_dixonst01_strd['name']='dixonst01'
df_doherjo01_strd['name']='doherjo01'
df_donalry01_strd['name']='donalry01'
df_dorniiv01_strd['name']='dorniiv01'
df_dupuiph01_strd['name']='dupuiph01'
df_eavespa01_strd['name']='eavespa01'
df_egenemi01_strd['name']='egenemi01'
df_ehelepa01_strd['name']='ehelepa01'
df_elliobr01_strd['name']='elliobr01'
df_enstrto01_strd['name']='enstrto01'
df_erikslo01_strd['name']='erikslo01'
df_ezhovde01_strd['name']='ezhovde01'
df_fabrybr01_strd['name']='fabrybr01'
df_fehrer01_strd['name']='fehrer01'
df_filewjo01_strd['name']='filewjo01'
df_fitzgza01_strd['name']='fitzgza01'
df_fleurma01_strd['name']='fleurma01'
df_floodma01_strd['name']='floodma01'
df_fraseco01_strd['name']='fraseco01'
df_fritsda01_strd['name']='fritsda01'
df_furreph01_strd['name']='furreph01'
df_gelecra01_strd['name']='gelecra01'
df_gervabr01_strd['name']='gervabr01'
df_getzlry01_strd['name']='getzlry01'
df_gibbory01_strd['name']='gibbory01'
df_gimayse01_strd['name']='gimayse01'
df_glassta01_strd['name']='glassta01'
df_glazako01_strd['name']='glazako01'
df_granael01_strd['name']='granael01'
df_gravema01_strd['name']='gravema01'
df_grecobr01_strd['name']='grecobr01'
df_grenzmi01_strd['name']='grenzmi01'
df_guenefr01_strd['name']='guenefr01'
df_guerima01_strd['name']='guerima01'
df_guskoal01_strd['name']='guskoal01'
df_guyergi01_strd['name']='guyergi01'
df_halakja01_strd['name']='halakja01'
df_hamilmi01_strd['name']='hamilmi01'
df_hansema01_strd['name']='hansema01'
df_hanulmi01_strd['name']='hanulmi01'
df_harveke01_strd['name']='harveke01'
df_hecimjo01_strd['name']='hecimjo01'
df_heinoch01_strd['name']='heinoch01'
df_hejdaja01_strd['name']='hejdaja01'
df_heminbr01_strd['name']='heminbr01'
df_hendrtr01_strd['name']='hendrtr01'
df_hennejo01_strd['name']='hennejo01'
df_hoffmja01_strd['name']='hoffmja01'
df_holtch01_strd['name']='holtch01'
df_hortona01_strd['name']='hortona01'
df_hospeka01_strd['name']='hospeka01'
df_hostivi01_strd['name']='hostivi01'
df_howarja02_strd['name']='howarja02'
df_hrabajo01_strd['name']='hrabajo01'
df_hrdelzb01_strd['name']='hrdelzb01'
df_hultal01_strd['name']='hultal01'
df_hynessh01_strd['name']='hynessh01'
df_irmenda01_strd['name']='irmenda01'
df_isakoev01_strd['name']='isakoev01'
df_ivanoal01_strd['name']='ivanoal01'
df_jacquje01_strd['name']='jacquje01'
df_jarmake01_strd['name']='jarmake01'
df_jensejo01_strd['name']='jensejo01'
df_jessihu01_strd['name']='jessihu01'
df_johanmi01_strd['name']='johanmi01'
df_jonesda01_strd['name']='jonesda01'
df_joudran01_strd['name']='joudran01'
df_kadlepe01_strd['name']='kadlepe01'
df_kaipry01_strd['name']='kaipry01'
df_karlsma01_strd['name']='karlsma01'
df_keslery01_strd['name']='keslery01'
df_khomuiv01_strd['name']='khomuiv01'
df_kilpeee01_strd['name']='kilpeee01'
df_kleinke01_strd['name']='kleinke01'
df_kollato01_strd['name']='kollato01'
df_kolusma01_strd['name']='kolusma01'
df_koprimi01_strd['name']='koprimi01'
df_korpios01_strd['name']='korpios01'
df_kosmadm01_strd['name']='kosmadm01'
df_kostian01_strd['name']='kostian01'
df_kozakri01_strd['name']='kozakri01'
df_krepska01_strd['name']='krepska01'
df_kukkola01_strd['name']='kukkola01'
df_kutnyvl01_strd['name']='kutnyvl01'
df_landosh01_strd['name']='landosh01'
df_lapiema01_strd['name']='lapiema01'
df_lassite01_strd['name']='lassite01'
df_leeca01_strd['name']='leeca01'
df_lehunjo01_strd['name']='lehunjo01'
df_lewaned01_strd['name']='lewaned01'
df_liffida01_strd['name']='liffida01'
df_lindsli01_strd['name']='lindsli01'
df_lockeco01_strd['name']='lockeco01'
df_loginde01_strd['name']='loginde01'
df_lojekma01_strd['name']='lojekma01'
df_louhios01_strd['name']='louhios01'
df_macarcl01_strd['name']='macarcl01'
df_mantyvi01_strd['name']='mantyvi01'
df_marekja01_strd['name']='marekja01'
df_marjama01_strd['name']='marjama01'
df_martilo01_strd['name']='martilo01'
df_mccutma01_strd['name']='mccutma01'
df_mcdonco01_strd['name']='mcdonco01'
df_mcivena01_strd['name']='mcivena01'
df_melanma01_strd['name']='melanma01'
df_methoma01_strd['name']='methoma01'
df_meyerst01_strd['name']='meyerst01'
df_michami01_strd['name']='michami01'
df_milledr01_strd['name']='milledr01'
df_mirnoig01_strd['name']='mirnoig01'
df_mishage01_strd['name']='mishage01'
df_mitchjo01_strd['name']='mitchjo01'
df_mondobe01_strd['name']='mondobe01'
df_mooregr01_strd['name']='mooregr01'
df_morrity01_strd['name']='morrity01'
df_morroth01_strd['name']='morroth01'
df_moulsma01_strd['name']='moulsma01'
df_mukhaan01_strd['name']='mukhaan01'
df_muncery01_strd['name']='muncery01'
df_murrabr01_strd['name']='murrabr01'
df_nastike01_strd['name']='nastike01'
df_nauroal01_strd['name']='nauroal01'
df_nickema01_strd['name']='nickema01'
df_nilssro01_strd['name']='nilssro01'
df_nolanbr01_strd['name']='nolanbr01'
df_obriedo01_strd['name']='obriedo01'
df_obriesh01_strd['name']='obriesh01'
df_obyrnry01_strd['name']='obyrnry01'
df_ohanlbr01_strd['name']='ohanlbr01'
df_olafsma01_strd['name']='olafsma01'
df_olssoka01_strd['name']='olssoka01'
df_osullpa01_strd['name']='osullpa01'
df_oulahry01_strd['name']='oulahry01'
df_paetsna01_strd['name']='paetsna01'
df_parisza01_strd['name']='parisza01'
df_paveljo01_strd['name']='paveljo01'
df_pembeja01_strd['name']='pembeja01'
df_perryco01_strd['name']='perryco01'
df_pervyan01_strd['name']='pervyan01'
df_pestudm01_strd['name']='pestudm01'
df_phanedi01_strd['name']='phanedi01'
df_picaral01_strd['name']='picaral01'
df_piispar01_strd['name']='piispar01'
df_pirnees01_strd['name']='pirnees01'
df_polakvo01_strd['name']='polakvo01'
df_portech01_strd['name']='portech01'
df_potteco01_strd['name']='potteco01'
df_potulry01_strd['name']='potulry01'
df_poulima01_strd['name']='poulima01'
df_pushkko01_strd['name']='pushkko01'
df_quincky01_strd['name']='quincky01'
df_ramhoti01_strd['name']='ramhoti01'
df_redenty01_strd['name']='redenty01'
df_redikfr01_strd['name']='redikfr01'
df_reesedy01_strd['name']='reesedy01'
df_reganke01_strd['name']='reganke01'
df_rehakde01_strd['name']='rehakde01'
df_richabr02_strd['name']='richabr02'
df_richami02_strd['name']='richami02'
df_richmda01_strd['name']='richmda01'
df_roberjo02_strd['name']='roberjo02'
df_rocheke01_strd['name']='rocheke01'
df_rohlfda01_strd['name']='rohlfda01'
df_romyke01_strd['name']='romyke01'
df_rorabry01_strd['name']='rorabry01'
df_rosehja01_strd['name']='rosehja01'
df_roussda01_strd['name']='roussda01'
df_royma01_strd['name']='royma01'
df_ruzicst01_strd['name']='ruzicst01'
df_sagatma01_strd['name']='sagatma01'
df_saundna01_strd['name']='saundna01'
df_seabrbr01_strd['name']='seabrbr01'
df_seydoph01_strd['name']='seydoph01'
df_shafigr01_strd['name']='shafigr01'
df_sharrji01_strd['name']='sharrji01'
df_sidikru01_strd['name']='sidikru01'
df_skachev01_strd['name']='skachev01'
df_smabyma01_strd['name']='smabyma01'
df_smithja02_strd['name']='smithja02'
df_southdi01_strd['name']='southdi01'
df_staaler01_strd['name']='staaler01'
df_stasyde01_strd['name']='stasyde01'
df_stehlri01_strd['name']='stehlri01'
df_stemple01_strd['name']='stemple01'
df_stephsh01_strd['name']='stephsh01'
df_sterlbr01_strd['name']='sterlbr01'
df_stewaan01_strd['name']='stewaan01'
df_stewada01_strd['name']='stewada01'
df_stonery01_strd['name']='stonery01'
df_stortza01_strd['name']='stortza01'
df_stracty01_strd['name']='stracty01'
df_stuarma01_strd['name']='stuarma01'
df_sullimi02_strd['name']='sullimi02'
df_sullise01_strd['name']='sullise01'
df_sulzeal01_strd['name']='sulzeal01'
df_sundian01_strd['name']='sundian01'
df_suterry01_strd['name']='suterry01'
df_svagrda01_strd['name']='svagrda01'
df_tambeje01_strd['name']='tambeje01'
df_tardija01_strd['name']='tardija01'
df_tarkiza01_strd['name']='tarkiza01'
df_tarnani01_strd['name']='tarnani01'
df_tenutjo01_strd['name']='tenutjo01'
df_thompna01_strd['name']='thompna01'
df_topolse01_strd['name']='topolse01'
df_travida01_strd['name']='travida01'
df_trembda01_strd['name']='trembda01'
df_trembjo01_strd['name']='trembjo01'
df_trojoma01_strd['name']='trojoma01'
df_tumama01_strd['name']='tumama01'
df_tunikev01_strd['name']='tunikev01'
df_umicedr01_strd['name']='umicedr01'
df_urquhco01_strd['name']='urquhco01'
df_vainini01_strd['name']='vainini01'
df_valcapa01_strd['name']='valcapa01'
df_valdian01_strd['name']='valdian01'
df_vanekth01_strd['name']='vanekth01'
df_vannemi01_strd['name']='vannemi01'
df_videlli01_strd['name']='videlli01'
df_vishnal01_strd['name']='vishnal01'
df_volkoig01_strd['name']='volkoig01'
df_volkoko01_strd['name']='volkoko01'
df_vorospa01_strd['name']='vorospa01'
df_vranape01_strd['name']='vranape01'
df_wathifr01_strd['name']='wathifr01'
df_weberje01_strd['name']='weberje01'
df_webersh01_strd['name']='webersh01'
df_wernest01_strd['name']='wernest01'
df_willije01_strd['name']='willije01'
df_yacboda01_strd['name']='yacboda01'
df_zabama01_strd['name']='zabama01'
df_zakhako01_strd['name']='zakhako01'
df_zherdni01_strd['name']='zherdni01'
df_zhukomi01_strd['name']='zhukomi01'

# %%
strd_frames = [df_aaltoju01_strd,
df_alenju01_strd,
df_anderjo04_strd,
df_backeda01_strd,
df_bagnadr01_strd,
df_baraniv01_strd,
df_barinmi01_strd,
df_barulko01_strd,
df_beaucre01_strd,
df_beckfch01_strd,
df_bellesh01_strd,
df_belleth01_strd,
df_bergepa01_strd,
df_bernima01_strd,
df_bernist01_strd,
df_bissopa01_strd,
df_bitzby01_strd,
df_blahost01_strd,
df_blansco01_strd,
df_blomst01_strd,
df_bodietr01_strd,
df_boldual01_strd,
df_bolduje01_strd,
df_bolflu01_strd,
df_bondaar01_strd,
df_bonneji01_strd,
df_boutijo01_strd,
df_boylebr01_strd,
df_brodemi01_strd,
df_brodzky01_strd,
df_brownch03_strd,
df_browndu01_strd,
df_brownmi03_strd,
df_brownpa01_strd,
df_burkhlo01_strd,
df_burnsbr01_strd,
df_byfugdu01_strd,
df_carcida01_strd,
df_carlema01_strd,
df_carteje01_strd,
df_cherndm01_strd,
df_chiodan01_strd,
df_coburbr01_strd,
df_colbewi01_strd,
df_colemge01_strd,
df_collije01_strd,
df_cookti01_strd,
df_courcad01_strd,
df_crawfco01_strd,
df_crombbj01_strd,
df_cunnica01_strd,
df_danieni01_strd,
df_danilra01_strd,
df_darzila01_strd,
df_dawesni01_strd,
df_dawsoaa01_strd,
df_desbigu01_strd,
df_dixonst01_strd,
df_doherjo01_strd,
df_donalry01_strd,
df_dorniiv01_strd,
df_dupuiph01_strd,
df_eavespa01_strd,
df_egenemi01_strd,
df_ehelepa01_strd,
df_elliobr01_strd,
df_enstrto01_strd,
df_erikslo01_strd,
df_ezhovde01_strd,
df_fabrybr01_strd,
df_fehrer01_strd,
df_filewjo01_strd,
df_fitzgza01_strd,
df_fleurma01_strd,
df_floodma01_strd,
df_fraseco01_strd,
df_fritsda01_strd,
df_furreph01_strd,
df_gelecra01_strd,
df_gervabr01_strd,
df_getzlry01_strd,
df_gibbory01_strd,
df_gimayse01_strd,
df_glassta01_strd,
df_glazako01_strd,
df_granael01_strd,
df_gravema01_strd,
df_grecobr01_strd,
df_grenzmi01_strd,
df_guenefr01_strd,
df_guerima01_strd,
df_guskoal01_strd,
df_guyergi01_strd,
df_halakja01_strd,
df_hamilmi01_strd,
df_hansema01_strd,
df_hanulmi01_strd,
df_harveke01_strd,
df_hecimjo01_strd,
df_heinoch01_strd,
df_hejdaja01_strd,
df_heminbr01_strd,
df_hendrtr01_strd,
df_hennejo01_strd,
df_hoffmja01_strd,
df_holtch01_strd,
df_hortona01_strd,
df_hospeka01_strd,
df_hostivi01_strd,
df_howarja02_strd,
df_hrabajo01_strd,
df_hrdelzb01_strd,
df_hultal01_strd,
df_hynessh01_strd,
df_irmenda01_strd,
df_isakoev01_strd,
df_ivanoal01_strd,
df_jacquje01_strd,
df_jarmake01_strd,
df_jensejo01_strd,
df_jessihu01_strd,
df_johanmi01_strd,
df_jonesda01_strd,
df_joudran01_strd,
df_kadlepe01_strd,
df_kaipry01_strd,
df_karlsma01_strd,
df_keslery01_strd,
df_khomuiv01_strd,
df_kilpeee01_strd,
df_kleinke01_strd,
df_kollato01_strd,
df_kolusma01_strd,
df_koprimi01_strd,
df_korpios01_strd,
df_kosmadm01_strd,
df_kostian01_strd,
df_kozakri01_strd,
df_krepska01_strd,
df_kukkola01_strd,
df_kutnyvl01_strd,
df_landosh01_strd,
df_lapiema01_strd,
df_lassite01_strd,
df_leeca01_strd,
df_lehunjo01_strd,
df_lewaned01_strd,
df_liffida01_strd,
df_lindsli01_strd,
df_lockeco01_strd,
df_loginde01_strd,
df_lojekma01_strd,
df_louhios01_strd,
df_macarcl01_strd,
df_mantyvi01_strd,
df_marekja01_strd,
df_marjama01_strd,
df_martilo01_strd,
df_mccutma01_strd,
df_mcdonco01_strd,
df_mcivena01_strd,
df_melanma01_strd,
df_methoma01_strd,
df_meyerst01_strd,
df_michami01_strd,
df_milledr01_strd,
df_mirnoig01_strd,
df_mishage01_strd,
df_mitchjo01_strd,
df_mondobe01_strd,
df_mooregr01_strd,
df_morrity01_strd,
df_morroth01_strd,
df_moulsma01_strd,
df_mukhaan01_strd,
df_muncery01_strd,
df_murrabr01_strd,
df_nastike01_strd,
df_nauroal01_strd,
df_nickema01_strd,
df_nilssro01_strd,
df_nolanbr01_strd,
df_obriedo01_strd,
df_obriesh01_strd,
df_obyrnry01_strd,
df_ohanlbr01_strd,
df_olafsma01_strd,
df_olssoka01_strd,
df_osullpa01_strd,
df_oulahry01_strd,
df_paetsna01_strd,
df_parisza01_strd,
df_paveljo01_strd,
df_pembeja01_strd,
df_perryco01_strd,
df_pervyan01_strd,
df_pestudm01_strd,
df_phanedi01_strd,
df_picaral01_strd,
df_piispar01_strd,
df_pirnees01_strd,
df_polakvo01_strd,
df_portech01_strd,
df_potteco01_strd,
df_potulry01_strd,
df_poulima01_strd,
df_pushkko01_strd,
df_quincky01_strd,
df_ramhoti01_strd,
df_redenty01_strd,
df_redikfr01_strd,
df_reesedy01_strd,
df_reganke01_strd,
df_rehakde01_strd,
df_richabr02_strd,
df_richami02_strd,
df_richmda01_strd,
df_roberjo02_strd,
df_rocheke01_strd,
df_rohlfda01_strd,
df_romyke01_strd,
df_rorabry01_strd,
df_rosehja01_strd,
df_roussda01_strd,
df_royma01_strd,
df_ruzicst01_strd,
df_sagatma01_strd,
df_saundna01_strd,
df_seabrbr01_strd,
df_seydoph01_strd,
df_shafigr01_strd,
df_sharrji01_strd,
df_sidikru01_strd,
df_skachev01_strd,
df_smabyma01_strd,
df_smithja02_strd,
df_southdi01_strd,
df_staaler01_strd,
df_stasyde01_strd,
df_stehlri01_strd,
df_stemple01_strd,
df_stephsh01_strd,
df_sterlbr01_strd,
df_stewaan01_strd,
df_stewada01_strd,
df_stonery01_strd,
df_stortza01_strd,
df_stracty01_strd,
df_stuarma01_strd,
df_sullimi02_strd,
df_sullise01_strd,
df_sulzeal01_strd,
df_sundian01_strd,
df_suterry01_strd,
df_svagrda01_strd,
df_tambeje01_strd,
df_tardija01_strd,
df_tarkiza01_strd,
df_tarnani01_strd,
df_tenutjo01_strd,
df_thompna01_strd,
df_topolse01_strd,
df_travida01_strd,
df_trembda01_strd,
df_trembjo01_strd,
df_trojoma01_strd,
df_tumama01_strd,
df_tunikev01_strd,
df_umicedr01_strd,
df_urquhco01_strd,
df_vainini01_strd,
df_valcapa01_strd,
df_valdian01_strd,
df_vanekth01_strd,
df_vannemi01_strd,
df_videlli01_strd,
df_vishnal01_strd,
df_volkoig01_strd,
df_volkoko01_strd,
df_vorospa01_strd,
df_vranape01_strd,
df_wathifr01_strd,
df_weberje01_strd,
df_webersh01_strd,
df_wernest01_strd,
df_willije01_strd,
df_yacboda01_strd,
df_zabama01_strd,
df_zakhako01_strd,
df_zherdni01_strd,
df_zhukomi01_strd]

# %%
result_strd = pd.concat(strd_frames)

# %%
result_strd
# Out:
#      season  TOT   age  games_played pen_min plus_minus  goals_ev goals_pp  \
# 1   2006-07  STL  22.0          49.0      37          6       8.0        2
# 2   2007-08  STL  23.0          72.0      99        -11      10.0        3
# 3   2008-09  STL  24.0          82.0     165         -3      23.0        6
# 4   2009-10  STL  25.0          79.0     106         -4      12.0        5
# 5   2010-11  STL  26.0          82.0      93         32      26.0        5
# 6   2011-12  STL  27.0          82.0     101         15      14.0        8
# 7   2012-13  STL  28.0          48.0      62          5       5.0        1
# 8   2013-14  STL  29.0          74.0     119         14      17.0       10
# 9   2014-15  STL  30.0          80.0     104          7      16.0       10
# 10  2015-16  STL  31.0          79.0      83          4      13.0        8
# 11  2016-17  BOS  32.0          18.0      23          5       3.0        2
# ...

# %%
result_pos
# Out:
#      season  TOT   age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2007-08  STL  23.0      713.0          696.0       50.6           2.4
# 2   2008-09  STL  24.0      934.0          920.0       50.4           1.6
# 3   2009-10  STL  25.0     1035.0          915.0       53.1           1.5
# 4   2010-11  STL  26.0     1270.0         1073.0       54.2           3.3
# 5   2011-12  STL  27.0     1301.0         1075.0       54.8          -0.7
# 6   2012-13  STL  28.0      675.0          618.0       52.2           2.1
# 7   2013-14  STL  29.0     1100.0          893.0       55.2           0.7
# 8   2014-15  STL  30.0     1085.0         1078.0       50.2          -2.7
# 9   2015-16  STL  31.0     1088.0         1043.0       51.1          -0.9
# 10  2016-17  BOS  32.0      277.0          227.0       55.0           0.2
# 1   2010-11  MIN  27.0       13.0           22.0       37.1           -18
# 1   2007-08  NYR  22.0        9.0           12.0       42.9          </td
# ...

# %%
result_all = pd.merge(result_strd, result_pos, how ='left', on=['name','season','TOT'])

# %%
result_all
# Out:
#       season  TOT  age_x  games_played pen_min plus_minus  goals_ev goals_pp  \
# 0    2006-07  STL   22.0          49.0      37          6       8.0        2
# 1    2007-08  STL   23.0          72.0      99        -11      10.0        3
# 2    2008-09  STL   24.0          82.0     165         -3      23.0        6
# 3    2009-10  STL   25.0          79.0     106         -4      12.0        5
# 4    2010-11  STL   26.0          82.0      93         32      26.0        5
# 5    2011-12  STL   27.0          82.0     101         15      14.0        8
# 6    2012-13  STL   28.0          48.0      62          5       5.0        1
# 7    2013-14  STL   29.0          74.0     119         14      17.0       10
# 8    2014-15  STL   30.0          80.0     104          7      16.0       10
# 9    2015-16  STL   31.0          79.0      83          4      13.0        8
# 10   2016-17  BOS   32.0          18.0      23          5       3.0        2
# ...

# %%
import copy
seasonlist=result_all['season']
teamlist=result_all['TOT']
namelist=result_all['name']

currseas=seasonlist[0]
currteam=teamlist[0]
currname=namelist[0]

remlist=[1]
for i in range(1,len(seasonlist)):
    if seasonlist[i]==currseas and currname==namelist[i]:
        remlist.append(0)
    
    else:
        remlist.append(1)
        currname=namelist[i]
        currseas=seasonlist[i]

result_all['uniqueseason']=remlist
result_all=result_all.loc[result_all['uniqueseason'] == 1]
result_all2=copy.deepcopy(result_all)

    
result_all2=result_all2.convert_objects(convert_numeric=True).dropna()

result_all2

result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')
result_all2.to_csv("../draft_year/df_2003.csv")
# Out:
# /Users/takehiromatsuzawa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
