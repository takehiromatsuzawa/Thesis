# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
csv_list=[]
for i in range(2015,2016):
    filename="../PlayerData/"+str(i)+"/posession"
    filename2=[]
    for elem in os.listdir(filename):
        filename2.append(filename+'/'+elem)
    csv_list.append(os.listdir(filename))
    print os.listdir(filename)
# Out:
# ['_pos_.csv', 'addisje01_pos_.csv', 'ahlfi01_pos_.csv', 'ahose01_pos_.csv', 'anderra01_pos_.csv', 'applema01_pos_.csv', 'bachmka01_pos_.csv', 'balceru01_pos_.csv', 'barzama01_pos_.csv', 'bearet01_pos_.csv', 'beaudje01_pos_.csv', 'beauvan01_pos_.csv', 'beckeja01_pos_.csv', 'bednary01_pos_.csv', 'bernhda01_pos_.csv', 'bittnpa01_pos_.csv', 'blackma01_pos_.csv', 'boesebr01_pos_.csv', 'boikose01_pos_.csv', 'bokani01_pos_.csv', 'bondrra01_pos_.csv', 'boothca01_pos_.csv', 'borgewi01_pos_.csv', 'bouragu01_pos_.csv', 'bourqsi01_pos_.csv', 'braccje01_pos_.csv', 'bradlma02_pos_.csv', 'brisegu01_pos_.csv', 'bruceri01_pos_.csv', 'capobky01_pos_.csv', 'carlobr01_pos_.csv', 'carlsga01_pos_.csv', 'carrial01_pos_.csv', 'ceccojo01_pos_.csv', 'cernaer01_pos_.csv', 'chaboth01_pos_.csv', 'chlapfi01_pos_.csv', 'chukaiv01_pos_.csv', 'cirelan01_pos_.csv', 'connoky01_pos_.csv', 'cottoda01_pos_.csv', 'crousla01_pos_.csv', 'cukstka01_pos_.csv', 'daccojo01_pos_.csv', 'dahlsjo01_pos_.csv', 'debruja01_pos_.csv', 
# ...

# %%
listcsv=csv_list[0]

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"=pd.read_csv(../PlayerData/2015/posession/"+elem+",index_col=0)"
# Out:
# df__pos=pd.read_csv(../PlayerData/2015/posession/_pos_.csv,index_col=0)
# df_addisje01_pos=pd.read_csv(../PlayerData/2015/posession/addisje01_pos_.csv,index_col=0)
# df_ahlfi01_pos=pd.read_csv(../PlayerData/2015/posession/ahlfi01_pos_.csv,index_col=0)
# df_ahose01_pos=pd.read_csv(../PlayerData/2015/posession/ahose01_pos_.csv,index_col=0)
# df_anderra01_pos=pd.read_csv(../PlayerData/2015/posession/anderra01_pos_.csv,index_col=0)
# df_applema01_pos=pd.read_csv(../PlayerData/2015/posession/applema01_pos_.csv,index_col=0)
# df_bachmka01_pos=pd.read_csv(../PlayerData/2015/posession/bachmka01_pos_.csv,index_col=0)
# df_balceru01_pos=pd.read_csv(../PlayerData/2015/posession/balceru01_pos_.csv,index_col=0)
# df_barzama01_pos=pd.read_csv(../PlayerData/2015/posession/barzama01_pos_.csv,index_col=0)
# df_bearet01_pos=pd.read_csv(../PlayerData/2015/posession/bearet01_pos_.csv,index_col=0)
# df_beaudje01_pos=pd.read_csv(../PlayerData/2015/posession/beaudje01_pos_.csv,index_col=0)
# ...

# %%
df_addisje01_pos=pd.read_csv('../PlayerData/2015/posession/addisje01_pos_.csv',index_col=0)
df_ahlfi01_pos=pd.read_csv('../PlayerData/2015/posession/ahlfi01_pos_.csv',index_col=0)
df_ahose01_pos=pd.read_csv('../PlayerData/2015/posession/ahose01_pos_.csv',index_col=0)
df_anderra01_pos=pd.read_csv('../PlayerData/2015/posession/anderra01_pos_.csv',index_col=0)
df_applema01_pos=pd.read_csv('../PlayerData/2015/posession/applema01_pos_.csv',index_col=0)
df_bachmka01_pos=pd.read_csv('../PlayerData/2015/posession/bachmka01_pos_.csv',index_col=0)
df_balceru01_pos=pd.read_csv('../PlayerData/2015/posession/balceru01_pos_.csv',index_col=0)
df_barzama01_pos=pd.read_csv('../PlayerData/2015/posession/barzama01_pos_.csv',index_col=0)
df_bearet01_pos=pd.read_csv('../PlayerData/2015/posession/bearet01_pos_.csv',index_col=0)
df_beaudje01_pos=pd.read_csv('../PlayerData/2015/posession/beaudje01_pos_.csv',index_col=0)
df_beauvan01_pos=pd.read_csv('../PlayerData/2015/posession/beauvan01_pos_.csv',index_col=0)
df_beckeja01_pos=pd.read_csv('../PlayerData/2015/posession/beckeja01_pos_.csv',index_col=0)
df_bednary01_pos=pd.read_csv('../PlayerData/2015/posession/bednary01_pos_.csv',index_col=0)
df_bernhda01_pos=pd.read_csv('../PlayerData/2015/posession/bernhda01_pos_.csv',index_col=0)
df_bittnpa01_pos=pd.read_csv('../PlayerData/2015/posession/bittnpa01_pos_.csv',index_col=0)
df_blackma01_pos=pd.read_csv('../PlayerData/2015/posession/blackma01_pos_.csv',index_col=0)
df_boesebr01_pos=pd.read_csv('../PlayerData/2015/posession/boesebr01_pos_.csv',index_col=0)
df_boikose01_pos=pd.read_csv('../PlayerData/2015/posession/boikose01_pos_.csv',index_col=0)
df_bokani01_pos=pd.read_csv('../PlayerData/2015/posession/bokani01_pos_.csv',index_col=0)
df_bondrra01_pos=pd.read_csv('../PlayerData/2015/posession/bondrra01_pos_.csv',index_col=0)
df_boothca01_pos=pd.read_csv('../PlayerData/2015/posession/boothca01_pos_.csv',index_col=0)
df_borgewi01_pos=pd.read_csv('../PlayerData/2015/posession/borgewi01_pos_.csv',index_col=0)
df_bouragu01_pos=pd.read_csv('../PlayerData/2015/posession/bouragu01_pos_.csv',index_col=0)
df_bourqsi01_pos=pd.read_csv('../PlayerData/2015/posession/bourqsi01_pos_.csv',index_col=0)
df_braccje01_pos=pd.read_csv('../PlayerData/2015/posession/braccje01_pos_.csv',index_col=0)
df_bradlma02_pos=pd.read_csv('../PlayerData/2015/posession/bradlma02_pos_.csv',index_col=0)
df_brisegu01_pos=pd.read_csv('../PlayerData/2015/posession/brisegu01_pos_.csv',index_col=0)
df_bruceri01_pos=pd.read_csv('../PlayerData/2015/posession/bruceri01_pos_.csv',index_col=0)
df_capobky01_pos=pd.read_csv('../PlayerData/2015/posession/capobky01_pos_.csv',index_col=0)
df_carlobr01_pos=pd.read_csv('../PlayerData/2015/posession/carlobr01_pos_.csv',index_col=0)
df_carlsga01_pos=pd.read_csv('../PlayerData/2015/posession/carlsga01_pos_.csv',index_col=0)
df_carrial01_pos=pd.read_csv('../PlayerData/2015/posession/carrial01_pos_.csv',index_col=0)
df_ceccojo01_pos=pd.read_csv('../PlayerData/2015/posession/ceccojo01_pos_.csv',index_col=0)
df_cernaer01_pos=pd.read_csv('../PlayerData/2015/posession/cernaer01_pos_.csv',index_col=0)
df_chaboth01_pos=pd.read_csv('../PlayerData/2015/posession/chaboth01_pos_.csv',index_col=0)
df_chlapfi01_pos=pd.read_csv('../PlayerData/2015/posession/chlapfi01_pos_.csv',index_col=0)
df_chukaiv01_pos=pd.read_csv('../PlayerData/2015/posession/chukaiv01_pos_.csv',index_col=0)
df_cirelan01_pos=pd.read_csv('../PlayerData/2015/posession/cirelan01_pos_.csv',index_col=0)
df_connoky01_pos=pd.read_csv('../PlayerData/2015/posession/connoky01_pos_.csv',index_col=0)
df_cottoda01_pos=pd.read_csv('../PlayerData/2015/posession/cottoda01_pos_.csv',index_col=0)
df_crousla01_pos=pd.read_csv('../PlayerData/2015/posession/crousla01_pos_.csv',index_col=0)
df_cukstka01_pos=pd.read_csv('../PlayerData/2015/posession/cukstka01_pos_.csv',index_col=0)
df_daccojo01_pos=pd.read_csv('../PlayerData/2015/posession/daccojo01_pos_.csv',index_col=0)
df_dahlsjo01_pos=pd.read_csv('../PlayerData/2015/posession/dahlsjo01_pos_.csv',index_col=0)
df_debruja01_pos=pd.read_csv('../PlayerData/2015/posession/debruja01_pos_.csv',index_col=0)
df_dergaal01_pos=pd.read_csv('../PlayerData/2015/posession/dergaal01_pos_.csv',index_col=0)
df_dermotr01_pos=pd.read_csv('../PlayerData/2015/posession/dermotr01_pos_.csv',index_col=0)
df_desrost01_pos=pd.read_csv('../PlayerData/2015/posession/desrost01_pos_.csv',index_col=0)
df_dovemsa01_pos=pd.read_csv('../PlayerData/2015/posession/dovemsa01_pos_.csv',index_col=0)
df_dundali01_pos=pd.read_csv('../PlayerData/2015/posession/dundali01_pos_.csv',index_col=0)
df_dunnvi01_pos=pd.read_csv('../PlayerData/2015/posession/dunnvi01_pos_.csv',index_col=0)
df_dzierma01_pos=pd.read_csv('../PlayerData/2015/posession/dzierma01_pos_.csv',index_col=0)
df_eicheja01_pos=pd.read_csv('../PlayerData/2015/posession/eicheja01_pos_.csv',index_col=0)
df_eriksjo02_pos=pd.read_csv('../PlayerData/2015/posession/eriksjo02_pos_.csv',index_col=0)
df_estepgi01_pos=pd.read_csv('../PlayerData/2015/posession/estepgi01_pos_.csv',index_col=0)
df_fedotiv01_pos=pd.read_csv('../PlayerData/2015/posession/fedotiv01_pos_.csv',index_col=0)
df_fischch01_pos=pd.read_csv('../PlayerData/2015/posession/fischch01_pos_.csv',index_col=0)
df_foleyer01_pos=pd.read_csv('../PlayerData/2015/posession/foleyer01_pos_.csv',index_col=0)
df_forsbja01_pos=pd.read_csv('../PlayerData/2015/posession/forsbja01_pos_.csv',index_col=0)
df_gabrije01_pos=pd.read_csv('../PlayerData/2015/posession/gabrije01_pos_.csv',index_col=0)
df_gagnega01_pos=pd.read_csv('../PlayerData/2015/posession/gagnega01_pos_.csv',index_col=0)
df_garlaco01_pos=pd.read_csv('../PlayerData/2015/posession/garlaco01_pos_.csv',index_col=0)
df_gatesbr01_pos=pd.read_csv('../PlayerData/2015/posession/gatesbr01_pos_.csv',index_col=0)
df_gaudead01_pos=pd.read_csv('../PlayerData/2015/posession/gaudead01_pos_.csv',index_col=0)
df_gavrivl01_pos=pd.read_csv('../PlayerData/2015/posession/gavrivl01_pos_.csv',index_col=0)
df_gawdigl01_pos=pd.read_csv('../PlayerData/2015/posession/gawdigl01_pos_.csv',index_col=0)
df_gennama01_pos=pd.read_csv('../PlayerData/2015/posession/gennama01_pos_.csv',index_col=0)
df_gilbede01_pos=pd.read_csv('../PlayerData/2015/posession/gilbede01_pos_.csv',index_col=0)
df_greenjo02_pos=pd.read_csv('../PlayerData/2015/posession/greenjo02_pos_.csv',index_col=0)
df_greeraj01_pos=pd.read_csv('../PlayerData/2015/posession/greeraj01_pos_.csv',index_col=0)
df_groppry01_pos=pd.read_csv('../PlayerData/2015/posession/groppry01_pos_.csv',index_col=0)
df_guhlebr01_pos=pd.read_csv('../PlayerData/2015/posession/guhlebr01_pos_.csv',index_col=0)
df_guriade01_pos=pd.read_csv('../PlayerData/2015/posession/guriade01_pos_.csv',index_col=0)
df_hanifno01_pos=pd.read_csv('../PlayerData/2015/posession/hanifno01_pos_.csv',index_col=0)
df_hansspe01_pos=pd.read_csv('../PlayerData/2015/posession/hansspe01_pos_.csv',index_col=0)
df_harkija01_pos=pd.read_csv('../PlayerData/2015/posession/harkija01_pos_.csv',index_col=0)
df_helewad01_pos=pd.read_csv('../PlayerData/2015/posession/helewad01_pos_.csv',index_col=0)
df_hillad01_pos=pd.read_csv('../PlayerData/2015/posession/hillad01_pos_.csv',index_col=0)
df_hintzro01_pos=pd.read_csv('../PlayerData/2015/posession/hintzro01_pos_.csv',index_col=0)
df_hobbsco01_pos=pd.read_csv('../PlayerData/2015/posession/hobbsco01_pos_.csv',index_col=0)
df_holwapa01_pos=pd.read_csv('../PlayerData/2015/posession/holwapa01_pos_.csv',index_col=0)
df_hugheca01_pos=pd.read_csv('../PlayerData/2015/posession/hugheca01_pos_.csv',index_col=0)
df_huskaad01_pos=pd.read_csv('../PlayerData/2015/posession/huskaad01_pos_.csv',index_col=0)
df_imamabo01_pos=pd.read_csv('../PlayerData/2015/posession/imamabo01_pos_.csv',index_col=0)
df_jarosch01_pos=pd.read_csv('../PlayerData/2015/posession/jarosch01_pos_.csv',index_col=0)
df_jaseklu01_pos=pd.read_csv('../PlayerData/2015/posession/jaseklu01_pos_.csv',index_col=0)
df_jonesca01_pos=pd.read_csv('../PlayerData/2015/posession/jonesca01_pos_.csv',index_col=0)
df_josepma01_pos=pd.read_csv('../PlayerData/2015/posession/josepma01_pos_.csv',index_col=0)
df_juulsno01_pos=pd.read_csv('../PlayerData/2015/posession/juulsno01_pos_.csv',index_col=0)
df_kallger01_pos=pd.read_csv('../PlayerData/2015/posession/kallger01_pos_.csv',index_col=0)
df_kapriki01_pos=pd.read_csv('../PlayerData/2015/posession/kapriki01_pos_.csv',index_col=0)
df_karnapa01_pos=pd.read_csv('../PlayerData/2015/posession/karnapa01_pos_.csv',index_col=0)
df_kaseda01_pos=pd.read_csv('../PlayerData/2015/posession/kaseda01_pos_.csv',index_col=0)
df_knottgr01_pos=pd.read_csv('../PlayerData/2015/posession/knottgr01_pos_.csv',index_col=0)
df_koleske01_pos=pd.read_csv('../PlayerData/2015/posession/koleske01_pos_.csv',index_col=0)
df_konectr01_pos=pd.read_csv('../PlayerData/2015/posession/konectr01_pos_.csv',index_col=0)
df_korosni01_pos=pd.read_csv('../PlayerData/2015/posession/korosni01_pos_.csv',index_col=0)
df_kovacro01_pos=pd.read_csv('../PlayerData/2015/posession/kovacro01_pos_.csv',index_col=0)
df_kupskjo01_pos=pd.read_csv('../PlayerData/2015/posession/kupskjo01_pos_.csv',index_col=0)
df_kylinol01_pos=pd.read_csv('../PlayerData/2015/posession/kylinol01_pos_.csv',index_col=0)
df_larssja01_pos=pd.read_csv('../PlayerData/2015/posession/larssja01_pos_.csv',index_col=0)
df_lauzoje01_pos=pd.read_csv('../PlayerData/2015/posession/lauzoje01_pos_.csv',index_col=0)
df_lindgje01_pos=pd.read_csv('../PlayerData/2015/posession/lindgje01_pos_.csv',index_col=0)
df_lookeje01_pos=pd.read_csv('../PlayerData/2015/posession/lookeje01_pos_.csv',index_col=0)
df_lorenst01_pos=pd.read_csv('../PlayerData/2015/posession/lorenst01_pos_.csv',index_col=0)
df_malgide01_pos=pd.read_csv('../PlayerData/2015/posession/malgide01_pos_.csv',index_col=0)
df_mangian01_pos=pd.read_csv('../PlayerData/2015/posession/mangian01_pos_.csv',index_col=0)
df_marinjo01_pos=pd.read_csv('../PlayerData/2015/posession/marinjo01_pos_.csv',index_col=0)
df_marnemi01_pos=pd.read_csv('../PlayerData/2015/posession/marnemi01_pos_.csv',index_col=0)
df_marodco01_pos=pd.read_csv('../PlayerData/2015/posession/marodco01_pos_.csv',index_col=0)
df_marshad01_pos=pd.read_csv('../PlayerData/2015/posession/marshad01_pos_.csv',index_col=0)
df_martech01_pos=pd.read_csv('../PlayerData/2015/posession/martech01_pos_.csv',index_col=0)
df_massija01_pos=pd.read_csv('../PlayerData/2015/posession/massija01_pos_.csv',index_col=0)
df_mcdavco01_pos=pd.read_csv('../PlayerData/2015/posession/mcdavco01_pos_.csv',index_col=0)
df_meierti01_pos=pd.read_csv('../PlayerData/2015/posession/meierti01_pos_.csv',index_col=0)
df_melocni01_pos=pd.read_csv('../PlayerData/2015/posession/melocni01_pos_.csv',index_col=0)
df_merklni01_pos=pd.read_csv('../PlayerData/2015/posession/merklni01_pos_.csv',index_col=0)
df_metcaga01_pos=pd.read_csv('../PlayerData/2015/posession/metcaga01_pos_.csv',index_col=0)
df_mikkoni01_pos=pd.read_csv('../PlayerData/2015/posession/mikkoni01_pos_.csv',index_col=0)
df_mironan01_pos=pd.read_csv('../PlayerData/2015/posession/mironan01_pos_.csv',index_col=0)
df_montesa01_pos=pd.read_csv('../PlayerData/2015/posession/montesa01_pos_.csv',index_col=0)
df_morribr03_pos=pd.read_csv('../PlayerData/2015/posession/morribr03_pos_.csv',index_col=0)
df_moyty01_pos=pd.read_csv('../PlayerData/2015/posession/moyty01_pos_.csv',index_col=0)
df_musilad01_pos=pd.read_csv('../PlayerData/2015/posession/musilad01_pos_.csv',index_col=0)
df_nattiju01_pos=pd.read_csv('../PlayerData/2015/posession/nattiju01_pos_.csv',index_col=0)
df_neillca01_pos=pd.read_csv('../PlayerData/2015/posession/neillca01_pos_.csv',index_col=0)
df_nielsan01_pos=pd.read_csv('../PlayerData/2015/posession/nielsan01_pos_.csv',index_col=0)
df_nikusa01_pos=pd.read_csv('../PlayerData/2015/posession/nikusa01_pos_.csv',index_col=0)
df_novakth01_pos=pd.read_csv('../PlayerData/2015/posession/novakth01_pos_.csv',index_col=0)
df_nutivma01_pos=pd.read_csv('../PlayerData/2015/posession/nutivma01_pos_.csv',index_col=0)
df_oldhakr01_pos=pd.read_csv('../PlayerData/2015/posession/oldhakr01_pos_.csv',index_col=0)
df_olhavgu01_pos=pd.read_csv('../PlayerData/2015/posession/olhavgu01_pos_.csv',index_col=0)
df_olsonta01_pos=pd.read_csv('../PlayerData/2015/posession/olsonta01_pos_.csv',index_col=0)
df_opilklu01_pos=pd.read_csv('../PlayerData/2015/posession/opilklu01_pos_.csv',index_col=0)
df_paigizi01_pos=pd.read_csv('../PlayerData/2015/posession/paigizi01_pos_.csv',index_col=0)
df_parsead01_pos=pd.read_csv('../PlayerData/2015/posession/parsead01_pos_.csv',index_col=0)
df_pavlyni01_pos=pd.read_csv('../PlayerData/2015/posession/pavlyni01_pos_.csv',index_col=0)
df_pearsch01_pos=pd.read_csv('../PlayerData/2015/posession/pearsch01_pos_.csv',index_col=0)
df_pilonry01_pos=pd.read_csv('../PlayerData/2015/posession/pilonry01_pos_.csv',index_col=0)
df_provoiv01_pos=pd.read_csv('../PlayerData/2015/posession/provoiv01_pos_.csv',index_col=0)
df_radkero01_pos=pd.read_csv('../PlayerData/2015/posession/radkero01_pos_.csv',index_col=0)
df_rantami01_pos=pd.read_csv('../PlayerData/2015/posession/rantami01_pos_.csv',index_col=0)
df_reddech01_pos=pd.read_csv('../PlayerData/2015/posession/reddech01_pos_.csv',index_col=0)
df_richaan01_pos=pd.read_csv('../PlayerData/2015/posession/richaan01_pos_.csv',index_col=0)
df_robinmi01_pos=pd.read_csv('../PlayerData/2015/posession/robinmi01_pos_.csv',index_col=0)
df_rosloja01_pos=pd.read_csv('../PlayerData/2015/posession/rosloja01_pos_.csv',index_col=0)
df_royje02_pos=pd.read_csv('../PlayerData/2015/posession/royje02_pos_.csv',index_col=0)
df_royma04_pos=pd.read_csv('../PlayerData/2015/posession/royma04_pos_.csv',index_col=0)
df_royni01_pos=pd.read_csv('../PlayerData/2015/posession/royni01_pos_.csv',index_col=0)
df_ruggist01_pos=pd.read_csv('../PlayerData/2015/posession/ruggist01_pos_.csv',index_col=0)
df_ruoppsa01_pos=pd.read_csv('../PlayerData/2015/posession/ruoppsa01_pos_.csv',index_col=0)
df_ruusuma01_pos=pd.read_csv('../PlayerData/2015/posession/ruusuma01_pos_.csv',index_col=0)
df_saareal01_pos=pd.read_csv('../PlayerData/2015/posession/saareal01_pos_.csv',index_col=0)
df_saarivi01_pos=pd.read_csv('../PlayerData/2015/posession/saarivi01_pos_.csv',index_col=0)
df_sadekja01_pos=pd.read_csv('../PlayerData/2015/posession/sadekja01_pos_.csv',index_col=0)
df_samsoil01_pos=pd.read_csv('../PlayerData/2015/posession/samsoil01_pos_.csv',index_col=0)
df_sandsfe01_pos=pd.read_csv('../PlayerData/2015/posession/sandsfe01_pos_.csv',index_col=0)
df_schemth01_pos=pd.read_csv('../PlayerData/2015/posession/schemth01_pos_.csv',index_col=0)
df_schmama01_pos=pd.read_csv('../PlayerData/2015/posession/schmama01_pos_.csv',index_col=0)
df_seneybr01_pos=pd.read_csv('../PlayerData/2015/posession/seneybr01_pos_.csv',index_col=0)
df_senysza01_pos=pd.read_csv('../PlayerData/2015/posession/senysza01_pos_.csv',index_col=0)
df_sheapa02_pos=pd.read_csv('../PlayerData/2015/posession/sheapa02_pos_.csv',index_col=0)
df_sheary01_pos=pd.read_csv('../PlayerData/2015/posession/sheary01_pos_.csv',index_col=0)
df_siderde01_pos=pd.read_csv('../PlayerData/2015/posession/siderde01_pos_.csv',index_col=0)
df_siegejo01_pos=pd.read_csv('../PlayerData/2015/posession/siegejo01_pos_.csv',index_col=0)
df_simondo01_pos=pd.read_csv('../PlayerData/2015/posession/simondo01_pos_.csv',index_col=0)
df_smallsp01_pos=pd.read_csv('../PlayerData/2015/posession/smallsp01_pos_.csv',index_col=0)
df_smithev01_pos=pd.read_csv('../PlayerData/2015/posession/smithev01_pos_.csv',index_col=0)
df_songan01_pos=pd.read_csv('../PlayerData/2015/posession/songan01_pos_.csv',index_col=0)
df_spacemi01_pos=pd.read_csv('../PlayerData/2015/posession/spacemi01_pos_.csv',index_col=0)
df_speerbl01_pos=pd.read_csv('../PlayerData/2015/posession/speerbl01_pos_.csv',index_col=0)
df_spencma01_pos=pd.read_csv('../PlayerData/2015/posession/spencma01_pos_.csv',index_col=0)
df_spronda01_pos=pd.read_csv('../PlayerData/2015/posession/spronda01_pos_.csv',index_col=0)
df_stenlke01_pos=pd.read_csv('../PlayerData/2015/posession/stenlke01_pos_.csv',index_col=0)
df_stephde01_pos=pd.read_csv('../PlayerData/2015/posession/stephde01_pos_.csv',index_col=0)
df_stephmi01_pos=pd.read_csv('../PlayerData/2015/posession/stephmi01_pos_.csv',index_col=0)
df_stevelu01_pos=pd.read_csv('../PlayerData/2015/posession/stevelu01_pos_.csv',index_col=0)
df_stezkal01_pos=pd.read_csv('../PlayerData/2015/posession/stezkal01_pos_.csv',index_col=0)
df_stromdy01_pos=pd.read_csv('../PlayerData/2015/posession/stromdy01_pos_.csv',index_col=0)
df_svechev01_pos=pd.read_csv('../PlayerData/2015/posession/svechev01_pos_.csv',index_col=0)
df_svobomi01_pos=pd.read_csv('../PlayerData/2015/posession/svobomi01_pos_.csv',index_col=0)
df_tammejo01_pos=pd.read_csv('../PlayerData/2015/posession/tammejo01_pos_.csv',index_col=0)
df_terrytr01_pos=pd.read_csv('../PlayerData/2015/posession/terrytr01_pos_.csv',index_col=0)
df_tiffefr01_pos=pd.read_csv('../PlayerData/2015/posession/tiffefr01_pos_.csv',index_col=0)
df_timasdm01_pos=pd.read_csv('../PlayerData/2015/posession/timasdm01_pos_.csv',index_col=0)
df_tomekma01_pos=pd.read_csv('../PlayerData/2015/posession/tomekma01_pos_.csv',index_col=0)
df_treniya01_pos=pd.read_csv('../PlayerData/2015/posession/treniya01_pos_.csv',index_col=0)
df_tuulojo01_pos=pd.read_csv('../PlayerData/2015/posession/tuulojo01_pos_.csv',index_col=0)
df_vainive01_pos=pd.read_csv('../PlayerData/2015/posession/vainive01_pos_.csv',index_col=0)
df_vandemi01_pos=pd.read_csv('../PlayerData/2015/posession/vandemi01_pos_.csv',index_col=0)
df_vanpojo01_pos=pd.read_csv('../PlayerData/2015/posession/vanpojo01_pos_.csv',index_col=0)
df_vejdelu01_pos=pd.read_csv('../PlayerData/2015/posession/vejdelu01_pos_.csv',index_col=0)
df_vejmeka01_pos=pd.read_csv('../PlayerData/2015/posession/vejmeka01_pos_.csv',index_col=0)
df_velama01_pos=pd.read_csv('../PlayerData/2015/posession/velama01_pos_.csv',index_col=0)
df_vladada01_pos=pd.read_csv('../PlayerData/2015/posession/vladada01_pos_.csv',index_col=0)
df_vorobmi01_pos=pd.read_csv('../PlayerData/2015/posession/vorobmi01_pos_.csv',index_col=0)
df_wagneau01_pos=pd.read_csv('../PlayerData/2015/posession/wagneau01_pos_.csv',index_col=0)
df_warrebr01_pos=pd.read_csv('../PlayerData/2015/posession/warrebr01_pos_.csv',index_col=0)
df_werenza01_pos=pd.read_csv('../PlayerData/2015/posession/werenza01_pos_.csv',index_col=0)
df_whiteco02_pos=pd.read_csv('../PlayerData/2015/posession/whiteco02_pos_.csv',index_col=0)
df_whiteco03_pos=pd.read_csv('../PlayerData/2015/posession/whiteco03_pos_.csv',index_col=0)
df_wilkich01_pos=pd.read_csv('../PlayerData/2015/posession/wilkich01_pos_.csv',index_col=0)
df_willico01_pos=pd.read_csv('../PlayerData/2015/posession/willico01_pos_.csv',index_col=0)
df_wolanch01_pos=pd.read_csv('../PlayerData/2015/posession/wolanch01_pos_.csv',index_col=0)
df_wothepa01_pos=pd.read_csv('../PlayerData/2015/posession/wothepa01_pos_.csv',index_col=0)
df_yande01_pos=pd.read_csv('../PlayerData/2015/posession/yande01_pos_.csv',index_col=0)
df_zachapa01_pos=pd.read_csv('../PlayerData/2015/posession/zachapa01_pos_.csv',index_col=0)
df_zborija01_pos=pd.read_csv('../PlayerData/2015/posession/zborija01_pos_.csv',index_col=0)
df_zborose01_pos=pd.read_csv('../PlayerData/2015/posession/zborose01_pos_.csv',index_col=0)
df_zhukedm01_pos=pd.read_csv('../PlayerData/2015/posession/zhukedm01_pos_.csv',index_col=0)
df_zuhlsry01_pos=pd.read_csv('../PlayerData/2015/posession/zuhlsry01_pos_.csv',index_col=0)

# %%
for elem in listcsv:
    print "df_"+elem[:-5]+"[name]="+elem[:-9]
# Out:
# df__pos[name]=
# df_addisje01_pos[name]=addisje01
# df_ahlfi01_pos[name]=ahlfi01
# df_ahose01_pos[name]=ahose01
# df_anderra01_pos[name]=anderra01
# df_applema01_pos[name]=applema01
# df_bachmka01_pos[name]=bachmka01
# df_balceru01_pos[name]=balceru01
# df_barzama01_pos[name]=barzama01
# df_bearet01_pos[name]=bearet01
# df_beaudje01_pos[name]=beaudje01
# df_beauvan01_pos[name]=beauvan01
# df_beckeja01_pos[name]=beckeja01
# df_bednary01_pos[name]=bednary01
# df_bernhda01_pos[name]=bernhda01
# df_bittnpa01_pos[name]=bittnpa01
# df_blackma01_pos[name]=blackma01
# df_boesebr01_pos[name]=boesebr01
# df_boikose01_pos[name]=boikose01
# df_bokani01_pos[name]=bokani01
# df_bondrra01_pos[name]=bondrra01
# df_boothca01_pos[name]=boothca01
# df_borgewi01_pos[name]=borgewi01
# df_bouragu01_pos[name]=bouragu01
# df_bourqsi01_pos[name]=bourqsi01
# df_braccje01_pos[name]=braccje01
# df_bradlma02_pos[name]=bradlma02
# df_brisegu01_pos[name]=brisegu01
# df_bruceri01_pos[name]=bruceri01
# ...

# %%
df_addisje01_pos['name']='addisje01'
df_ahlfi01_pos['name']='ahlfi01'
df_ahose01_pos['name']='ahose01'
df_anderra01_pos['name']='anderra01'
df_applema01_pos['name']='applema01'
df_bachmka01_pos['name']='bachmka01'
df_balceru01_pos['name']='balceru01'
df_barzama01_pos['name']='barzama01'
df_bearet01_pos['name']='bearet01'
df_beaudje01_pos['name']='beaudje01'
df_beauvan01_pos['name']='beauvan01'
df_beckeja01_pos['name']='beckeja01'
df_bednary01_pos['name']='bednary01'
df_bernhda01_pos['name']='bernhda01'
df_bittnpa01_pos['name']='bittnpa01'
df_blackma01_pos['name']='blackma01'
df_boesebr01_pos['name']='boesebr01'
df_boikose01_pos['name']='boikose01'
df_bokani01_pos['name']='bokani01'
df_bondrra01_pos['name']='bondrra01'
df_boothca01_pos['name']='boothca01'
df_borgewi01_pos['name']='borgewi01'
df_bouragu01_pos['name']='bouragu01'
df_bourqsi01_pos['name']='bourqsi01'
df_braccje01_pos['name']='braccje01'
df_bradlma02_pos['name']='bradlma02'
df_brisegu01_pos['name']='brisegu01'
df_bruceri01_pos['name']='bruceri01'
df_capobky01_pos['name']='capobky01'
df_carlobr01_pos['name']='carlobr01'
df_carlsga01_pos['name']='carlsga01'
df_carrial01_pos['name']='carrial01'
df_ceccojo01_pos['name']='ceccojo01'
df_cernaer01_pos['name']='cernaer01'
df_chaboth01_pos['name']='chaboth01'
df_chlapfi01_pos['name']='chlapfi01'
df_chukaiv01_pos['name']='chukaiv01'
df_cirelan01_pos['name']='cirelan01'
df_connoky01_pos['name']='connoky01'
df_cottoda01_pos['name']='cottoda01'
df_crousla01_pos['name']='crousla01'
df_cukstka01_pos['name']='cukstka01'
df_daccojo01_pos['name']='daccojo01'
df_dahlsjo01_pos['name']='dahlsjo01'
df_debruja01_pos['name']='debruja01'
df_dergaal01_pos['name']='dergaal01'
df_dermotr01_pos['name']='dermotr01'
df_desrost01_pos['name']='desrost01'
df_dovemsa01_pos['name']='dovemsa01'
df_dundali01_pos['name']='dundali01'
df_dunnvi01_pos['name']='dunnvi01'
df_dzierma01_pos['name']='dzierma01'
df_eicheja01_pos['name']='eicheja01'
df_eriksjo02_pos['name']='eriksjo02'
df_estepgi01_pos['name']='estepgi01'
df_fedotiv01_pos['name']='fedotiv01'
df_fischch01_pos['name']='fischch01'
df_foleyer01_pos['name']='foleyer01'
df_forsbja01_pos['name']='forsbja01'
df_gabrije01_pos['name']='gabrije01'
df_gagnega01_pos['name']='gagnega01'
df_garlaco01_pos['name']='garlaco01'
df_gatesbr01_pos['name']='gatesbr01'
df_gaudead01_pos['name']='gaudead01'
df_gavrivl01_pos['name']='gavrivl01'
df_gawdigl01_pos['name']='gawdigl01'
df_gennama01_pos['name']='gennama01'
df_gilbede01_pos['name']='gilbede01'
df_greenjo02_pos['name']='greenjo02'
df_greeraj01_pos['name']='greeraj01'
df_groppry01_pos['name']='groppry01'
df_guhlebr01_pos['name']='guhlebr01'
df_guriade01_pos['name']='guriade01'
df_hanifno01_pos['name']='hanifno01'
df_hansspe01_pos['name']='hansspe01'
df_harkija01_pos['name']='harkija01'
df_helewad01_pos['name']='helewad01'
df_hillad01_pos['name']='hillad01'
df_hintzro01_pos['name']='hintzro01'
df_hobbsco01_pos['name']='hobbsco01'
df_holwapa01_pos['name']='holwapa01'
df_hugheca01_pos['name']='hugheca01'
df_huskaad01_pos['name']='huskaad01'
df_imamabo01_pos['name']='imamabo01'
df_jarosch01_pos['name']='jarosch01'
df_jaseklu01_pos['name']='jaseklu01'
df_jonesca01_pos['name']='jonesca01'
df_josepma01_pos['name']='josepma01'
df_juulsno01_pos['name']='juulsno01'
df_kallger01_pos['name']='kallger01'
df_kapriki01_pos['name']='kapriki01'
df_karnapa01_pos['name']='karnapa01'
df_kaseda01_pos['name']='kaseda01'
df_knottgr01_pos['name']='knottgr01'
df_koleske01_pos['name']='koleske01'
df_konectr01_pos['name']='konectr01'
df_korosni01_pos['name']='korosni01'
df_kovacro01_pos['name']='kovacro01'
df_kupskjo01_pos['name']='kupskjo01'
df_kylinol01_pos['name']='kylinol01'
df_larssja01_pos['name']='larssja01'
df_lauzoje01_pos['name']='lauzoje01'
df_lindgje01_pos['name']='lindgje01'
df_lookeje01_pos['name']='lookeje01'
df_lorenst01_pos['name']='lorenst01'
df_malgide01_pos['name']='malgide01'
df_mangian01_pos['name']='mangian01'
df_marinjo01_pos['name']='marinjo01'
df_marnemi01_pos['name']='marnemi01'
df_marodco01_pos['name']='marodco01'
df_marshad01_pos['name']='marshad01'
df_martech01_pos['name']='martech01'
df_massija01_pos['name']='massija01'
df_mcdavco01_pos['name']='mcdavco01'
df_meierti01_pos['name']='meierti01'
df_melocni01_pos['name']='melocni01'
df_merklni01_pos['name']='merklni01'
df_metcaga01_pos['name']='metcaga01'
df_mikkoni01_pos['name']='mikkoni01'
df_mironan01_pos['name']='mironan01'
df_montesa01_pos['name']='montesa01'
df_morribr03_pos['name']='morribr03'
df_moyty01_pos['name']='moyty01'
df_musilad01_pos['name']='musilad01'
df_nattiju01_pos['name']='nattiju01'
df_neillca01_pos['name']='neillca01'
df_nielsan01_pos['name']='nielsan01'
df_nikusa01_pos['name']='nikusa01'
df_novakth01_pos['name']='novakth01'
df_nutivma01_pos['name']='nutivma01'
df_oldhakr01_pos['name']='oldhakr01'
df_olhavgu01_pos['name']='olhavgu01'
df_olsonta01_pos['name']='olsonta01'
df_opilklu01_pos['name']='opilklu01'
df_paigizi01_pos['name']='paigizi01'
df_parsead01_pos['name']='parsead01'
df_pavlyni01_pos['name']='pavlyni01'
df_pearsch01_pos['name']='pearsch01'
df_pilonry01_pos['name']='pilonry01'
df_provoiv01_pos['name']='provoiv01'
df_radkero01_pos['name']='radkero01'
df_rantami01_pos['name']='rantami01'
df_reddech01_pos['name']='reddech01'
df_richaan01_pos['name']='richaan01'
df_robinmi01_pos['name']='robinmi01'
df_rosloja01_pos['name']='rosloja01'
df_royje02_pos['name']='royje02'
df_royma04_pos['name']='royma04'
df_royni01_pos['name']='royni01'
df_ruggist01_pos['name']='ruggist01'
df_ruoppsa01_pos['name']='ruoppsa01'
df_ruusuma01_pos['name']='ruusuma01'
df_saareal01_pos['name']='saareal01'
df_saarivi01_pos['name']='saarivi01'
df_sadekja01_pos['name']='sadekja01'
df_samsoil01_pos['name']='samsoil01'
df_sandsfe01_pos['name']='sandsfe01'
df_schemth01_pos['name']='schemth01'
df_schmama01_pos['name']='schmama01'
df_seneybr01_pos['name']='seneybr01'
df_senysza01_pos['name']='senysza01'
df_sheapa02_pos['name']='sheapa02'
df_sheary01_pos['name']='sheary01'
df_siderde01_pos['name']='siderde01'
df_siegejo01_pos['name']='siegejo01'
df_simondo01_pos['name']='simondo01'
df_smallsp01_pos['name']='smallsp01'
df_smithev01_pos['name']='smithev01'
df_songan01_pos['name']='songan01'
df_spacemi01_pos['name']='spacemi01'
df_speerbl01_pos['name']='speerbl01'
df_spencma01_pos['name']='spencma01'
df_spronda01_pos['name']='spronda01'
df_stenlke01_pos['name']='stenlke01'
df_stephde01_pos['name']='stephde01'
df_stephmi01_pos['name']='stephmi01'
df_stevelu01_pos['name']='stevelu01'
df_stezkal01_pos['name']='stezkal01'
df_stromdy01_pos['name']='stromdy01'
df_svechev01_pos['name']='svechev01'
df_svobomi01_pos['name']='svobomi01'
df_tammejo01_pos['name']='tammejo01'
df_terrytr01_pos['name']='terrytr01'
df_tiffefr01_pos['name']='tiffefr01'
df_timasdm01_pos['name']='timasdm01'
df_tomekma01_pos['name']='tomekma01'
df_treniya01_pos['name']='treniya01'
df_tuulojo01_pos['name']='tuulojo01'
df_vainive01_pos['name']='vainive01'
df_vandemi01_pos['name']='vandemi01'
df_vanpojo01_pos['name']='vanpojo01'
df_vejdelu01_pos['name']='vejdelu01'
df_vejmeka01_pos['name']='vejmeka01'
df_velama01_pos['name']='velama01'
df_vladada01_pos['name']='vladada01'
df_vorobmi01_pos['name']='vorobmi01'
df_wagneau01_pos['name']='wagneau01'
df_warrebr01_pos['name']='warrebr01'
df_werenza01_pos['name']='werenza01'
df_whiteco02_pos['name']='whiteco02'
df_whiteco03_pos['name']='whiteco03'
df_wilkich01_pos['name']='wilkich01'
df_willico01_pos['name']='willico01'
df_wolanch01_pos['name']='wolanch01'
df_wothepa01_pos['name']='wothepa01'
df_yande01_pos['name']='yande01'
df_zachapa01_pos['name']='zachapa01'
df_zborija01_pos['name']='zborija01'
df_zborose01_pos['name']='zborose01'
df_zhukedm01_pos['name']='zhukedm01'
df_zuhlsry01_pos['name']='zuhlsry01'

# %%
df_addisje01_pos
# Out:
# Empty DataFrame
# Columns: [season, TOT, age, corsi_for, corsi_against, corsi_pct, corsi_rel_pct, fenwick_for, fenwick_against, fenwick_pct, fenwick_rel_pct, on_ice_shot_pct, on_ice_sv_pct, pdo, zs_offense_pct, zs_defense_pct, name]
# Index: []

# %%
pos_frames=[df_addisje01_pos,
df_ahlfi01_pos,
df_ahose01_pos,
df_anderra01_pos,
df_applema01_pos,
df_bachmka01_pos,
df_balceru01_pos,
df_barzama01_pos,
df_bearet01_pos,
df_beaudje01_pos,
df_beauvan01_pos,
df_beckeja01_pos,
df_bednary01_pos,
df_bernhda01_pos,
df_bittnpa01_pos,
df_blackma01_pos,
df_boesebr01_pos,
df_boikose01_pos,
df_bokani01_pos,
df_bondrra01_pos,
df_boothca01_pos,
df_borgewi01_pos,
df_bouragu01_pos,
df_bourqsi01_pos,
df_braccje01_pos,
df_bradlma02_pos,
df_brisegu01_pos,
df_bruceri01_pos,
df_capobky01_pos,
df_carlobr01_pos,
df_carlsga01_pos,
df_carrial01_pos,
df_ceccojo01_pos,
df_cernaer01_pos,
df_chaboth01_pos,
df_chlapfi01_pos,
df_chukaiv01_pos,
df_cirelan01_pos,
df_connoky01_pos,
df_cottoda01_pos,
df_crousla01_pos,
df_cukstka01_pos,
df_daccojo01_pos,
df_dahlsjo01_pos,
df_debruja01_pos,
df_dergaal01_pos,
df_dermotr01_pos,
df_desrost01_pos,
df_dovemsa01_pos,
df_dundali01_pos,
df_dunnvi01_pos,
df_dzierma01_pos,
df_eicheja01_pos,
df_eriksjo02_pos,
df_estepgi01_pos,
df_fedotiv01_pos,
df_fischch01_pos,
df_foleyer01_pos,
df_forsbja01_pos,
df_gabrije01_pos,
df_gagnega01_pos,
df_garlaco01_pos,
df_gatesbr01_pos,
df_gaudead01_pos,
df_gavrivl01_pos,
df_gawdigl01_pos,
df_gennama01_pos,
df_gilbede01_pos,
df_greenjo02_pos,
df_greeraj01_pos,
df_groppry01_pos,
df_guhlebr01_pos,
df_guriade01_pos,
df_hanifno01_pos,
df_hansspe01_pos,
df_harkija01_pos,
df_helewad01_pos,
df_hillad01_pos,
df_hintzro01_pos,
df_hobbsco01_pos,
df_holwapa01_pos,
df_hugheca01_pos,
df_huskaad01_pos,
df_imamabo01_pos,
df_jarosch01_pos,
df_jaseklu01_pos,
df_jonesca01_pos,
df_josepma01_pos,
df_juulsno01_pos,
df_kallger01_pos,
df_kapriki01_pos,
df_karnapa01_pos,
df_kaseda01_pos,
df_knottgr01_pos,
df_koleske01_pos,
df_konectr01_pos,
df_korosni01_pos,
df_kovacro01_pos,
df_kupskjo01_pos,
df_kylinol01_pos,
df_larssja01_pos,
df_lauzoje01_pos,
df_lindgje01_pos,
df_lookeje01_pos,
df_lorenst01_pos,
df_malgide01_pos,
df_mangian01_pos,
df_marinjo01_pos,
df_marnemi01_pos,
df_marodco01_pos,
df_marshad01_pos,
df_martech01_pos,
df_massija01_pos,
df_mcdavco01_pos,
df_meierti01_pos,
df_melocni01_pos,
df_merklni01_pos,
df_metcaga01_pos,
df_mikkoni01_pos,
df_mironan01_pos,
df_montesa01_pos,
df_morribr03_pos,
df_moyty01_pos,
df_musilad01_pos,
df_nattiju01_pos,
df_neillca01_pos,
df_nielsan01_pos,
df_nikusa01_pos,
df_novakth01_pos,
df_nutivma01_pos,
df_oldhakr01_pos,
df_olhavgu01_pos,
df_olsonta01_pos,
df_opilklu01_pos,
df_paigizi01_pos,
df_parsead01_pos,
df_pavlyni01_pos,
df_pearsch01_pos,
df_pilonry01_pos,
df_provoiv01_pos,
df_radkero01_pos,
df_rantami01_pos,
df_reddech01_pos,
df_richaan01_pos,
df_robinmi01_pos,
df_rosloja01_pos,
df_royje02_pos,
df_royma04_pos,
df_royni01_pos,
df_ruggist01_pos,
df_ruoppsa01_pos,
df_ruusuma01_pos,
df_saareal01_pos,
df_saarivi01_pos,
df_sadekja01_pos,
df_samsoil01_pos,
df_sandsfe01_pos,
df_schemth01_pos,
df_schmama01_pos,
df_seneybr01_pos,
df_senysza01_pos,
df_sheapa02_pos,
df_sheary01_pos,
df_siderde01_pos,
df_siegejo01_pos,
df_simondo01_pos,
df_smallsp01_pos,
df_smithev01_pos,
df_songan01_pos,
df_spacemi01_pos,
df_speerbl01_pos,
df_spencma01_pos,
df_spronda01_pos,
df_stenlke01_pos,
df_stephde01_pos,
df_stephmi01_pos,
df_stevelu01_pos,
df_stezkal01_pos,
df_stromdy01_pos,
df_svechev01_pos,
df_svobomi01_pos,
df_tammejo01_pos,
df_terrytr01_pos,
df_tiffefr01_pos,
df_timasdm01_pos,
df_tomekma01_pos,
df_treniya01_pos,
df_tuulojo01_pos,
df_vainive01_pos,
df_vandemi01_pos,
df_vanpojo01_pos,
df_vejdelu01_pos,
df_vejmeka01_pos,
df_velama01_pos,
df_vladada01_pos,
df_vorobmi01_pos,
df_wagneau01_pos,
df_warrebr01_pos,
df_werenza01_pos,
df_whiteco02_pos,
df_whiteco03_pos,
df_wilkich01_pos,
df_willico01_pos,
df_wolanch01_pos,
df_wothepa01_pos,
df_yande01_pos,
df_zachapa01_pos,
df_zborija01_pos,
df_zborose01_pos,
df_zhukedm01_pos,
df_zuhlsry01_pos]

# %%
result_pos = pd.concat(pos_frames)

# %%
result_pos
# Out:
#     season  TOT   age  corsi_for  corsi_against  corsi_pct  corsi_rel_pct  \
# 1  2016-17  CAR  19.0      273.0          208.0       56.8            4.3
# 1  2016-17  NYI  19.0       11.0           28.0       28.2          -21.0
# 1  2016-17  NYI  19.0      200.0          213.0       48.4            4.1
# 1  2016-17  BOS  20.0      433.0          394.0       52.4           -3.3
# 1  2016-17  OTT  20.0        9.0           12.0       42.9           -5.5
# 1  2016-17  WPG  20.0      155.0          191.0       44.8           -4.2
# 1  2016-17  ARI  19.0      135.0          155.0       46.6           -0.1
# 1  2015-16  BUF  19.0     1124.0         1228.0       47.8            0.2
# 2  2016-17  BUF  20.0       16.0           15.0       51.6            9.2
# 1  2016-17  MIN  20.0       64.0           96.0       40.0          -11.0
# 1  2016-17  COL  20.0       61.0           56.0       52.1            8.7
# 1  2015-16  CAR  19.0     1108.0         1106.0       50.0           -1.4
# ...

# %%
len(pos_frames)
# Out:
# 211

# %%
#df_addisje01_strd

# %%
df_addisje01_strd=pd.read_csv('../PlayerData/2015/standard/addisje01_strd_.csv',index_col=0)
df_ahlfi01_strd=pd.read_csv('../PlayerData/2015/standard/ahlfi01_strd_.csv',index_col=0)
df_ahose01_strd=pd.read_csv('../PlayerData/2015/standard/ahose01_strd_.csv',index_col=0)
df_anderra01_strd=pd.read_csv('../PlayerData/2015/standard/anderra01_strd_.csv',index_col=0)
df_applema01_strd=pd.read_csv('../PlayerData/2015/standard/applema01_strd_.csv',index_col=0)
df_bachmka01_strd=pd.read_csv('../PlayerData/2015/standard/bachmka01_strd_.csv',index_col=0)
df_balceru01_strd=pd.read_csv('../PlayerData/2015/standard/balceru01_strd_.csv',index_col=0)
df_barzama01_strd=pd.read_csv('../PlayerData/2015/standard/barzama01_strd_.csv',index_col=0)
df_bearet01_strd=pd.read_csv('../PlayerData/2015/standard/bearet01_strd_.csv',index_col=0)
df_beaudje01_strd=pd.read_csv('../PlayerData/2015/standard/beaudje01_strd_.csv',index_col=0)
df_beauvan01_strd=pd.read_csv('../PlayerData/2015/standard/beauvan01_strd_.csv',index_col=0)
df_beckeja01_strd=pd.read_csv('../PlayerData/2015/standard/beckeja01_strd_.csv',index_col=0)
df_bednary01_strd=pd.read_csv('../PlayerData/2015/standard/bednary01_strd_.csv',index_col=0)
df_bernhda01_strd=pd.read_csv('../PlayerData/2015/standard/bernhda01_strd_.csv',index_col=0)
df_bittnpa01_strd=pd.read_csv('../PlayerData/2015/standard/bittnpa01_strd_.csv',index_col=0)
df_blackma01_strd=pd.read_csv('../PlayerData/2015/standard/blackma01_strd_.csv',index_col=0)
df_boesebr01_strd=pd.read_csv('../PlayerData/2015/standard/boesebr01_strd_.csv',index_col=0)
df_boikose01_strd=pd.read_csv('../PlayerData/2015/standard/boikose01_strd_.csv',index_col=0)
df_bokani01_strd=pd.read_csv('../PlayerData/2015/standard/bokani01_strd_.csv',index_col=0)
df_bondrra01_strd=pd.read_csv('../PlayerData/2015/standard/bondrra01_strd_.csv',index_col=0)
df_boothca01_strd=pd.read_csv('../PlayerData/2015/standard/boothca01_strd_.csv',index_col=0)
df_borgewi01_strd=pd.read_csv('../PlayerData/2015/standard/borgewi01_strd_.csv',index_col=0)
df_bouragu01_strd=pd.read_csv('../PlayerData/2015/standard/bouragu01_strd_.csv',index_col=0)
df_bourqsi01_strd=pd.read_csv('../PlayerData/2015/standard/bourqsi01_strd_.csv',index_col=0)
df_braccje01_strd=pd.read_csv('../PlayerData/2015/standard/braccje01_strd_.csv',index_col=0)
df_bradlma02_strd=pd.read_csv('../PlayerData/2015/standard/bradlma02_strd_.csv',index_col=0)
df_brisegu01_strd=pd.read_csv('../PlayerData/2015/standard/brisegu01_strd_.csv',index_col=0)
df_bruceri01_strd=pd.read_csv('../PlayerData/2015/standard/bruceri01_strd_.csv',index_col=0)
df_capobky01_strd=pd.read_csv('../PlayerData/2015/standard/capobky01_strd_.csv',index_col=0)
df_carlobr01_strd=pd.read_csv('../PlayerData/2015/standard/carlobr01_strd_.csv',index_col=0)
df_carlsga01_strd=pd.read_csv('../PlayerData/2015/standard/carlsga01_strd_.csv',index_col=0)
df_carrial01_strd=pd.read_csv('../PlayerData/2015/standard/carrial01_strd_.csv',index_col=0)
df_ceccojo01_strd=pd.read_csv('../PlayerData/2015/standard/ceccojo01_strd_.csv',index_col=0)
df_cernaer01_strd=pd.read_csv('../PlayerData/2015/standard/cernaer01_strd_.csv',index_col=0)
df_chaboth01_strd=pd.read_csv('../PlayerData/2015/standard/chaboth01_strd_.csv',index_col=0)
df_chlapfi01_strd=pd.read_csv('../PlayerData/2015/standard/chlapfi01_strd_.csv',index_col=0)
df_chukaiv01_strd=pd.read_csv('../PlayerData/2015/standard/chukaiv01_strd_.csv',index_col=0)
df_cirelan01_strd=pd.read_csv('../PlayerData/2015/standard/cirelan01_strd_.csv',index_col=0)
df_connoky01_strd=pd.read_csv('../PlayerData/2015/standard/connoky01_strd_.csv',index_col=0)
df_cottoda01_strd=pd.read_csv('../PlayerData/2015/standard/cottoda01_strd_.csv',index_col=0)
df_crousla01_strd=pd.read_csv('../PlayerData/2015/standard/crousla01_strd_.csv',index_col=0)
df_cukstka01_strd=pd.read_csv('../PlayerData/2015/standard/cukstka01_strd_.csv',index_col=0)
df_daccojo01_strd=pd.read_csv('../PlayerData/2015/standard/daccojo01_strd_.csv',index_col=0)
df_dahlsjo01_strd=pd.read_csv('../PlayerData/2015/standard/dahlsjo01_strd_.csv',index_col=0)
df_debruja01_strd=pd.read_csv('../PlayerData/2015/standard/debruja01_strd_.csv',index_col=0)
df_dergaal01_strd=pd.read_csv('../PlayerData/2015/standard/dergaal01_strd_.csv',index_col=0)
df_dermotr01_strd=pd.read_csv('../PlayerData/2015/standard/dermotr01_strd_.csv',index_col=0)
df_desrost01_strd=pd.read_csv('../PlayerData/2015/standard/desrost01_strd_.csv',index_col=0)
df_dovemsa01_strd=pd.read_csv('../PlayerData/2015/standard/dovemsa01_strd_.csv',index_col=0)
df_dundali01_strd=pd.read_csv('../PlayerData/2015/standard/dundali01_strd_.csv',index_col=0)
df_dunnvi01_strd=pd.read_csv('../PlayerData/2015/standard/dunnvi01_strd_.csv',index_col=0)
df_dzierma01_strd=pd.read_csv('../PlayerData/2015/standard/dzierma01_strd_.csv',index_col=0)
df_eicheja01_strd=pd.read_csv('../PlayerData/2015/standard/eicheja01_strd_.csv',index_col=0)
df_eriksjo02_strd=pd.read_csv('../PlayerData/2015/standard/eriksjo02_strd_.csv',index_col=0)
df_estepgi01_strd=pd.read_csv('../PlayerData/2015/standard/estepgi01_strd_.csv',index_col=0)
df_fedotiv01_strd=pd.read_csv('../PlayerData/2015/standard/fedotiv01_strd_.csv',index_col=0)
df_fischch01_strd=pd.read_csv('../PlayerData/2015/standard/fischch01_strd_.csv',index_col=0)
df_foleyer01_strd=pd.read_csv('../PlayerData/2015/standard/foleyer01_strd_.csv',index_col=0)
df_forsbja01_strd=pd.read_csv('../PlayerData/2015/standard/forsbja01_strd_.csv',index_col=0)
df_gabrije01_strd=pd.read_csv('../PlayerData/2015/standard/gabrije01_strd_.csv',index_col=0)
df_gagnega01_strd=pd.read_csv('../PlayerData/2015/standard/gagnega01_strd_.csv',index_col=0)
df_garlaco01_strd=pd.read_csv('../PlayerData/2015/standard/garlaco01_strd_.csv',index_col=0)
df_gatesbr01_strd=pd.read_csv('../PlayerData/2015/standard/gatesbr01_strd_.csv',index_col=0)
df_gaudead01_strd=pd.read_csv('../PlayerData/2015/standard/gaudead01_strd_.csv',index_col=0)
df_gavrivl01_strd=pd.read_csv('../PlayerData/2015/standard/gavrivl01_strd_.csv',index_col=0)
df_gawdigl01_strd=pd.read_csv('../PlayerData/2015/standard/gawdigl01_strd_.csv',index_col=0)
df_gennama01_strd=pd.read_csv('../PlayerData/2015/standard/gennama01_strd_.csv',index_col=0)
df_gilbede01_strd=pd.read_csv('../PlayerData/2015/standard/gilbede01_strd_.csv',index_col=0)
df_greenjo02_strd=pd.read_csv('../PlayerData/2015/standard/greenjo02_strd_.csv',index_col=0)
df_greeraj01_strd=pd.read_csv('../PlayerData/2015/standard/greeraj01_strd_.csv',index_col=0)
df_groppry01_strd=pd.read_csv('../PlayerData/2015/standard/groppry01_strd_.csv',index_col=0)
df_guhlebr01_strd=pd.read_csv('../PlayerData/2015/standard/guhlebr01_strd_.csv',index_col=0)
df_guriade01_strd=pd.read_csv('../PlayerData/2015/standard/guriade01_strd_.csv',index_col=0)
df_hanifno01_strd=pd.read_csv('../PlayerData/2015/standard/hanifno01_strd_.csv',index_col=0)
df_hansspe01_strd=pd.read_csv('../PlayerData/2015/standard/hansspe01_strd_.csv',index_col=0)
df_harkija01_strd=pd.read_csv('../PlayerData/2015/standard/harkija01_strd_.csv',index_col=0)
df_helewad01_strd=pd.read_csv('../PlayerData/2015/standard/helewad01_strd_.csv',index_col=0)
df_hillad01_strd=pd.read_csv('../PlayerData/2015/standard/hillad01_strd_.csv',index_col=0)
df_hintzro01_strd=pd.read_csv('../PlayerData/2015/standard/hintzro01_strd_.csv',index_col=0)
df_hobbsco01_strd=pd.read_csv('../PlayerData/2015/standard/hobbsco01_strd_.csv',index_col=0)
df_holwapa01_strd=pd.read_csv('../PlayerData/2015/standard/holwapa01_strd_.csv',index_col=0)
df_hugheca01_strd=pd.read_csv('../PlayerData/2015/standard/hugheca01_strd_.csv',index_col=0)
df_huskaad01_strd=pd.read_csv('../PlayerData/2015/standard/huskaad01_strd_.csv',index_col=0)
df_imamabo01_strd=pd.read_csv('../PlayerData/2015/standard/imamabo01_strd_.csv',index_col=0)
df_jarosch01_strd=pd.read_csv('../PlayerData/2015/standard/jarosch01_strd_.csv',index_col=0)
df_jaseklu01_strd=pd.read_csv('../PlayerData/2015/standard/jaseklu01_strd_.csv',index_col=0)
df_jonesca01_strd=pd.read_csv('../PlayerData/2015/standard/jonesca01_strd_.csv',index_col=0)
df_josepma01_strd=pd.read_csv('../PlayerData/2015/standard/josepma01_strd_.csv',index_col=0)
df_juulsno01_strd=pd.read_csv('../PlayerData/2015/standard/juulsno01_strd_.csv',index_col=0)
df_kallger01_strd=pd.read_csv('../PlayerData/2015/standard/kallger01_strd_.csv',index_col=0)
df_kapriki01_strd=pd.read_csv('../PlayerData/2015/standard/kapriki01_strd_.csv',index_col=0)
df_karnapa01_strd=pd.read_csv('../PlayerData/2015/standard/karnapa01_strd_.csv',index_col=0)
df_kaseda01_strd=pd.read_csv('../PlayerData/2015/standard/kaseda01_strd_.csv',index_col=0)
df_knottgr01_strd=pd.read_csv('../PlayerData/2015/standard/knottgr01_strd_.csv',index_col=0)
df_koleske01_strd=pd.read_csv('../PlayerData/2015/standard/koleske01_strd_.csv',index_col=0)
df_konectr01_strd=pd.read_csv('../PlayerData/2015/standard/konectr01_strd_.csv',index_col=0)
df_korosni01_strd=pd.read_csv('../PlayerData/2015/standard/korosni01_strd_.csv',index_col=0)
df_kovacro01_strd=pd.read_csv('../PlayerData/2015/standard/kovacro01_strd_.csv',index_col=0)
df_kupskjo01_strd=pd.read_csv('../PlayerData/2015/standard/kupskjo01_strd_.csv',index_col=0)
df_kylinol01_strd=pd.read_csv('../PlayerData/2015/standard/kylinol01_strd_.csv',index_col=0)
df_larssja01_strd=pd.read_csv('../PlayerData/2015/standard/larssja01_strd_.csv',index_col=0)
df_lauzoje01_strd=pd.read_csv('../PlayerData/2015/standard/lauzoje01_strd_.csv',index_col=0)
df_lindgje01_strd=pd.read_csv('../PlayerData/2015/standard/lindgje01_strd_.csv',index_col=0)
df_lookeje01_strd=pd.read_csv('../PlayerData/2015/standard/lookeje01_strd_.csv',index_col=0)
df_lorenst01_strd=pd.read_csv('../PlayerData/2015/standard/lorenst01_strd_.csv',index_col=0)
df_malgide01_strd=pd.read_csv('../PlayerData/2015/standard/malgide01_strd_.csv',index_col=0)
df_mangian01_strd=pd.read_csv('../PlayerData/2015/standard/mangian01_strd_.csv',index_col=0)
df_marinjo01_strd=pd.read_csv('../PlayerData/2015/standard/marinjo01_strd_.csv',index_col=0)
df_marnemi01_strd=pd.read_csv('../PlayerData/2015/standard/marnemi01_strd_.csv',index_col=0)
df_marodco01_strd=pd.read_csv('../PlayerData/2015/standard/marodco01_strd_.csv',index_col=0)
df_marshad01_strd=pd.read_csv('../PlayerData/2015/standard/marshad01_strd_.csv',index_col=0)
df_martech01_strd=pd.read_csv('../PlayerData/2015/standard/martech01_strd_.csv',index_col=0)
df_massija01_strd=pd.read_csv('../PlayerData/2015/standard/massija01_strd_.csv',index_col=0)
df_mcdavco01_strd=pd.read_csv('../PlayerData/2015/standard/mcdavco01_strd_.csv',index_col=0)
df_meierti01_strd=pd.read_csv('../PlayerData/2015/standard/meierti01_strd_.csv',index_col=0)
df_melocni01_strd=pd.read_csv('../PlayerData/2015/standard/melocni01_strd_.csv',index_col=0)
df_merklni01_strd=pd.read_csv('../PlayerData/2015/standard/merklni01_strd_.csv',index_col=0)
df_metcaga01_strd=pd.read_csv('../PlayerData/2015/standard/metcaga01_strd_.csv',index_col=0)
df_mikkoni01_strd=pd.read_csv('../PlayerData/2015/standard/mikkoni01_strd_.csv',index_col=0)
df_mironan01_strd=pd.read_csv('../PlayerData/2015/standard/mironan01_strd_.csv',index_col=0)
df_montesa01_strd=pd.read_csv('../PlayerData/2015/standard/montesa01_strd_.csv',index_col=0)
df_morribr03_strd=pd.read_csv('../PlayerData/2015/standard/morribr03_strd_.csv',index_col=0)
df_moyty01_strd=pd.read_csv('../PlayerData/2015/standard/moyty01_strd_.csv',index_col=0)
df_musilad01_strd=pd.read_csv('../PlayerData/2015/standard/musilad01_strd_.csv',index_col=0)
df_nattiju01_strd=pd.read_csv('../PlayerData/2015/standard/nattiju01_strd_.csv',index_col=0)
df_neillca01_strd=pd.read_csv('../PlayerData/2015/standard/neillca01_strd_.csv',index_col=0)
df_nielsan01_strd=pd.read_csv('../PlayerData/2015/standard/nielsan01_strd_.csv',index_col=0)
df_nikusa01_strd=pd.read_csv('../PlayerData/2015/standard/nikusa01_strd_.csv',index_col=0)
df_novakth01_strd=pd.read_csv('../PlayerData/2015/standard/novakth01_strd_.csv',index_col=0)
df_nutivma01_strd=pd.read_csv('../PlayerData/2015/standard/nutivma01_strd_.csv',index_col=0)
df_oldhakr01_strd=pd.read_csv('../PlayerData/2015/standard/oldhakr01_strd_.csv',index_col=0)
df_olhavgu01_strd=pd.read_csv('../PlayerData/2015/standard/olhavgu01_strd_.csv',index_col=0)
df_olsonta01_strd=pd.read_csv('../PlayerData/2015/standard/olsonta01_strd_.csv',index_col=0)
df_opilklu01_strd=pd.read_csv('../PlayerData/2015/standard/opilklu01_strd_.csv',index_col=0)
df_paigizi01_strd=pd.read_csv('../PlayerData/2015/standard/paigizi01_strd_.csv',index_col=0)
df_parsead01_strd=pd.read_csv('../PlayerData/2015/standard/parsead01_strd_.csv',index_col=0)
df_pavlyni01_strd=pd.read_csv('../PlayerData/2015/standard/pavlyni01_strd_.csv',index_col=0)
df_pearsch01_strd=pd.read_csv('../PlayerData/2015/standard/pearsch01_strd_.csv',index_col=0)
df_pilonry01_strd=pd.read_csv('../PlayerData/2015/standard/pilonry01_strd_.csv',index_col=0)
df_provoiv01_strd=pd.read_csv('../PlayerData/2015/standard/provoiv01_strd_.csv',index_col=0)
df_radkero01_strd=pd.read_csv('../PlayerData/2015/standard/radkero01_strd_.csv',index_col=0)
df_rantami01_strd=pd.read_csv('../PlayerData/2015/standard/rantami01_strd_.csv',index_col=0)
df_reddech01_strd=pd.read_csv('../PlayerData/2015/standard/reddech01_strd_.csv',index_col=0)
df_richaan01_strd=pd.read_csv('../PlayerData/2015/standard/richaan01_strd_.csv',index_col=0)
df_robinmi01_strd=pd.read_csv('../PlayerData/2015/standard/robinmi01_strd_.csv',index_col=0)
df_rosloja01_strd=pd.read_csv('../PlayerData/2015/standard/rosloja01_strd_.csv',index_col=0)
df_royje02_strd=pd.read_csv('../PlayerData/2015/standard/royje02_strd_.csv',index_col=0)
df_royma04_strd=pd.read_csv('../PlayerData/2015/standard/royma04_strd_.csv',index_col=0)
df_royni01_strd=pd.read_csv('../PlayerData/2015/standard/royni01_strd_.csv',index_col=0)
df_ruggist01_strd=pd.read_csv('../PlayerData/2015/standard/ruggist01_strd_.csv',index_col=0)
df_ruoppsa01_strd=pd.read_csv('../PlayerData/2015/standard/ruoppsa01_strd_.csv',index_col=0)
df_ruusuma01_strd=pd.read_csv('../PlayerData/2015/standard/ruusuma01_strd_.csv',index_col=0)
df_saareal01_strd=pd.read_csv('../PlayerData/2015/standard/saareal01_strd_.csv',index_col=0)
df_saarivi01_strd=pd.read_csv('../PlayerData/2015/standard/saarivi01_strd_.csv',index_col=0)
df_sadekja01_strd=pd.read_csv('../PlayerData/2015/standard/sadekja01_strd_.csv',index_col=0)
df_samsoil01_strd=pd.read_csv('../PlayerData/2015/standard/samsoil01_strd_.csv',index_col=0)
df_sandsfe01_strd=pd.read_csv('../PlayerData/2015/standard/sandsfe01_strd_.csv',index_col=0)
df_schemth01_strd=pd.read_csv('../PlayerData/2015/standard/schemth01_strd_.csv',index_col=0)
df_schmama01_strd=pd.read_csv('../PlayerData/2015/standard/schmama01_strd_.csv',index_col=0)
df_seneybr01_strd=pd.read_csv('../PlayerData/2015/standard/seneybr01_strd_.csv',index_col=0)
df_senysza01_strd=pd.read_csv('../PlayerData/2015/standard/senysza01_strd_.csv',index_col=0)
df_sheapa02_strd=pd.read_csv('../PlayerData/2015/standard/sheapa02_strd_.csv',index_col=0)
df_sheary01_strd=pd.read_csv('../PlayerData/2015/standard/sheary01_strd_.csv',index_col=0)
df_siderde01_strd=pd.read_csv('../PlayerData/2015/standard/siderde01_strd_.csv',index_col=0)
df_siegejo01_strd=pd.read_csv('../PlayerData/2015/standard/siegejo01_strd_.csv',index_col=0)
df_simondo01_strd=pd.read_csv('../PlayerData/2015/standard/simondo01_strd_.csv',index_col=0)
df_smallsp01_strd=pd.read_csv('../PlayerData/2015/standard/smallsp01_strd_.csv',index_col=0)
df_smithev01_strd=pd.read_csv('../PlayerData/2015/standard/smithev01_strd_.csv',index_col=0)
df_songan01_strd=pd.read_csv('../PlayerData/2015/standard/songan01_strd_.csv',index_col=0)
df_spacemi01_strd=pd.read_csv('../PlayerData/2015/standard/spacemi01_strd_.csv',index_col=0)
df_speerbl01_strd=pd.read_csv('../PlayerData/2015/standard/speerbl01_strd_.csv',index_col=0)
df_spencma01_strd=pd.read_csv('../PlayerData/2015/standard/spencma01_strd_.csv',index_col=0)
df_spronda01_strd=pd.read_csv('../PlayerData/2015/standard/spronda01_strd_.csv',index_col=0)
df_stenlke01_strd=pd.read_csv('../PlayerData/2015/standard/stenlke01_strd_.csv',index_col=0)
df_stephde01_strd=pd.read_csv('../PlayerData/2015/standard/stephde01_strd_.csv',index_col=0)
df_stephmi01_strd=pd.read_csv('../PlayerData/2015/standard/stephmi01_strd_.csv',index_col=0)
df_stevelu01_strd=pd.read_csv('../PlayerData/2015/standard/stevelu01_strd_.csv',index_col=0)
df_stezkal01_strd=pd.read_csv('../PlayerData/2015/standard/stezkal01_strd_.csv',index_col=0)
df_stromdy01_strd=pd.read_csv('../PlayerData/2015/standard/stromdy01_strd_.csv',index_col=0)
df_svechev01_strd=pd.read_csv('../PlayerData/2015/standard/svechev01_strd_.csv',index_col=0)
df_svobomi01_strd=pd.read_csv('../PlayerData/2015/standard/svobomi01_strd_.csv',index_col=0)
df_tammejo01_strd=pd.read_csv('../PlayerData/2015/standard/tammejo01_strd_.csv',index_col=0)
df_terrytr01_strd=pd.read_csv('../PlayerData/2015/standard/terrytr01_strd_.csv',index_col=0)
df_tiffefr01_strd=pd.read_csv('../PlayerData/2015/standard/tiffefr01_strd_.csv',index_col=0)
df_timasdm01_strd=pd.read_csv('../PlayerData/2015/standard/timasdm01_strd_.csv',index_col=0)
df_tomekma01_strd=pd.read_csv('../PlayerData/2015/standard/tomekma01_strd_.csv',index_col=0)
df_treniya01_strd=pd.read_csv('../PlayerData/2015/standard/treniya01_strd_.csv',index_col=0)
df_tuulojo01_strd=pd.read_csv('../PlayerData/2015/standard/tuulojo01_strd_.csv',index_col=0)
df_vainive01_strd=pd.read_csv('../PlayerData/2015/standard/vainive01_strd_.csv',index_col=0)
df_vandemi01_strd=pd.read_csv('../PlayerData/2015/standard/vandemi01_strd_.csv',index_col=0)
df_vanpojo01_strd=pd.read_csv('../PlayerData/2015/standard/vanpojo01_strd_.csv',index_col=0)
df_vejdelu01_strd=pd.read_csv('../PlayerData/2015/standard/vejdelu01_strd_.csv',index_col=0)
df_vejmeka01_strd=pd.read_csv('../PlayerData/2015/standard/vejmeka01_strd_.csv',index_col=0)
df_velama01_strd=pd.read_csv('../PlayerData/2015/standard/velama01_strd_.csv',index_col=0)
df_vladada01_strd=pd.read_csv('../PlayerData/2015/standard/vladada01_strd_.csv',index_col=0)
df_vorobmi01_strd=pd.read_csv('../PlayerData/2015/standard/vorobmi01_strd_.csv',index_col=0)
df_wagneau01_strd=pd.read_csv('../PlayerData/2015/standard/wagneau01_strd_.csv',index_col=0)
df_warrebr01_strd=pd.read_csv('../PlayerData/2015/standard/warrebr01_strd_.csv',index_col=0)
df_werenza01_strd=pd.read_csv('../PlayerData/2015/standard/werenza01_strd_.csv',index_col=0)
df_whiteco02_strd=pd.read_csv('../PlayerData/2015/standard/whiteco02_strd_.csv',index_col=0)
df_whiteco03_strd=pd.read_csv('../PlayerData/2015/standard/whiteco03_strd_.csv',index_col=0)
df_wilkich01_strd=pd.read_csv('../PlayerData/2015/standard/wilkich01_strd_.csv',index_col=0)
df_willico01_strd=pd.read_csv('../PlayerData/2015/standard/willico01_strd_.csv',index_col=0)
df_wolanch01_strd=pd.read_csv('../PlayerData/2015/standard/wolanch01_strd_.csv',index_col=0)
df_wothepa01_strd=pd.read_csv('../PlayerData/2015/standard/wothepa01_strd_.csv',index_col=0)
df_yande01_strd=pd.read_csv('../PlayerData/2015/standard/yande01_strd_.csv',index_col=0)
df_zachapa01_strd=pd.read_csv('../PlayerData/2015/standard/zachapa01_strd_.csv',index_col=0)
df_zborija01_strd=pd.read_csv('../PlayerData/2015/standard/zborija01_strd_.csv',index_col=0)
df_zborose01_strd=pd.read_csv('../PlayerData/2015/standard/zborose01_strd_.csv',index_col=0)
df_zhukedm01_strd=pd.read_csv('../PlayerData/2015/standard/zhukedm01_strd_.csv',index_col=0)
df_zuhlsry01_strd=pd.read_csv('../PlayerData/2015/standard/zuhlsry01_strd_.csv',index_col=0)

# %%
df_addisje01_strd['name']='addisje01'
df_ahlfi01_strd['name']='ahlfi01'
df_ahose01_strd['name']='ahose01'
df_anderra01_strd['name']='anderra01'
df_applema01_strd['name']='applema01'
df_bachmka01_strd['name']='bachmka01'
df_balceru01_strd['name']='balceru01'
df_barzama01_strd['name']='barzama01'
df_bearet01_strd['name']='bearet01'
df_beaudje01_strd['name']='beaudje01'
df_beauvan01_strd['name']='beauvan01'
df_beckeja01_strd['name']='beckeja01'
df_bednary01_strd['name']='bednary01'
df_bernhda01_strd['name']='bernhda01'
df_bittnpa01_strd['name']='bittnpa01'
df_blackma01_strd['name']='blackma01'
df_boesebr01_strd['name']='boesebr01'
df_boikose01_strd['name']='boikose01'
df_bokani01_strd['name']='bokani01'
df_bondrra01_strd['name']='bondrra01'
df_boothca01_strd['name']='boothca01'
df_borgewi01_strd['name']='borgewi01'
df_bouragu01_strd['name']='bouragu01'
df_bourqsi01_strd['name']='bourqsi01'
df_braccje01_strd['name']='braccje01'
df_bradlma02_strd['name']='bradlma02'
df_brisegu01_strd['name']='brisegu01'
df_bruceri01_strd['name']='bruceri01'
df_capobky01_strd['name']='capobky01'
df_carlobr01_strd['name']='carlobr01'
df_carlsga01_strd['name']='carlsga01'
df_carrial01_strd['name']='carrial01'
df_ceccojo01_strd['name']='ceccojo01'
df_cernaer01_strd['name']='cernaer01'
df_chaboth01_strd['name']='chaboth01'
df_chlapfi01_strd['name']='chlapfi01'
df_chukaiv01_strd['name']='chukaiv01'
df_cirelan01_strd['name']='cirelan01'
df_connoky01_strd['name']='connoky01'
df_cottoda01_strd['name']='cottoda01'
df_crousla01_strd['name']='crousla01'
df_cukstka01_strd['name']='cukstka01'
df_daccojo01_strd['name']='daccojo01'
df_dahlsjo01_strd['name']='dahlsjo01'
df_debruja01_strd['name']='debruja01'
df_dergaal01_strd['name']='dergaal01'
df_dermotr01_strd['name']='dermotr01'
df_desrost01_strd['name']='desrost01'
df_dovemsa01_strd['name']='dovemsa01'
df_dundali01_strd['name']='dundali01'
df_dunnvi01_strd['name']='dunnvi01'
df_dzierma01_strd['name']='dzierma01'
df_eicheja01_strd['name']='eicheja01'
df_eriksjo02_strd['name']='eriksjo02'
df_estepgi01_strd['name']='estepgi01'
df_fedotiv01_strd['name']='fedotiv01'
df_fischch01_strd['name']='fischch01'
df_foleyer01_strd['name']='foleyer01'
df_forsbja01_strd['name']='forsbja01'
df_gabrije01_strd['name']='gabrije01'
df_gagnega01_strd['name']='gagnega01'
df_garlaco01_strd['name']='garlaco01'
df_gatesbr01_strd['name']='gatesbr01'
df_gaudead01_strd['name']='gaudead01'
df_gavrivl01_strd['name']='gavrivl01'
df_gawdigl01_strd['name']='gawdigl01'
df_gennama01_strd['name']='gennama01'
df_gilbede01_strd['name']='gilbede01'
df_greenjo02_strd['name']='greenjo02'
df_greeraj01_strd['name']='greeraj01'
df_groppry01_strd['name']='groppry01'
df_guhlebr01_strd['name']='guhlebr01'
df_guriade01_strd['name']='guriade01'
df_hanifno01_strd['name']='hanifno01'
df_hansspe01_strd['name']='hansspe01'
df_harkija01_strd['name']='harkija01'
df_helewad01_strd['name']='helewad01'
df_hillad01_strd['name']='hillad01'
df_hintzro01_strd['name']='hintzro01'
df_hobbsco01_strd['name']='hobbsco01'
df_holwapa01_strd['name']='holwapa01'
df_hugheca01_strd['name']='hugheca01'
df_huskaad01_strd['name']='huskaad01'
df_imamabo01_strd['name']='imamabo01'
df_jarosch01_strd['name']='jarosch01'
df_jaseklu01_strd['name']='jaseklu01'
df_jonesca01_strd['name']='jonesca01'
df_josepma01_strd['name']='josepma01'
df_juulsno01_strd['name']='juulsno01'
df_kallger01_strd['name']='kallger01'
df_kapriki01_strd['name']='kapriki01'
df_karnapa01_strd['name']='karnapa01'
df_kaseda01_strd['name']='kaseda01'
df_knottgr01_strd['name']='knottgr01'
df_koleske01_strd['name']='koleske01'
df_konectr01_strd['name']='konectr01'
df_korosni01_strd['name']='korosni01'
df_kovacro01_strd['name']='kovacro01'
df_kupskjo01_strd['name']='kupskjo01'
df_kylinol01_strd['name']='kylinol01'
df_larssja01_strd['name']='larssja01'
df_lauzoje01_strd['name']='lauzoje01'
df_lindgje01_strd['name']='lindgje01'
df_lookeje01_strd['name']='lookeje01'
df_lorenst01_strd['name']='lorenst01'
df_malgide01_strd['name']='malgide01'
df_mangian01_strd['name']='mangian01'
df_marinjo01_strd['name']='marinjo01'
df_marnemi01_strd['name']='marnemi01'
df_marodco01_strd['name']='marodco01'
df_marshad01_strd['name']='marshad01'
df_martech01_strd['name']='martech01'
df_massija01_strd['name']='massija01'
df_mcdavco01_strd['name']='mcdavco01'
df_meierti01_strd['name']='meierti01'
df_melocni01_strd['name']='melocni01'
df_merklni01_strd['name']='merklni01'
df_metcaga01_strd['name']='metcaga01'
df_mikkoni01_strd['name']='mikkoni01'
df_mironan01_strd['name']='mironan01'
df_montesa01_strd['name']='montesa01'
df_morribr03_strd['name']='morribr03'
df_moyty01_strd['name']='moyty01'
df_musilad01_strd['name']='musilad01'
df_nattiju01_strd['name']='nattiju01'
df_neillca01_strd['name']='neillca01'
df_nielsan01_strd['name']='nielsan01'
df_nikusa01_strd['name']='nikusa01'
df_novakth01_strd['name']='novakth01'
df_nutivma01_strd['name']='nutivma01'
df_oldhakr01_strd['name']='oldhakr01'
df_olhavgu01_strd['name']='olhavgu01'
df_olsonta01_strd['name']='olsonta01'
df_opilklu01_strd['name']='opilklu01'
df_paigizi01_strd['name']='paigizi01'
df_parsead01_strd['name']='parsead01'
df_pavlyni01_strd['name']='pavlyni01'
df_pearsch01_strd['name']='pearsch01'
df_pilonry01_strd['name']='pilonry01'
df_provoiv01_strd['name']='provoiv01'
df_radkero01_strd['name']='radkero01'
df_rantami01_strd['name']='rantami01'
df_reddech01_strd['name']='reddech01'
df_richaan01_strd['name']='richaan01'
df_robinmi01_strd['name']='robinmi01'
df_rosloja01_strd['name']='rosloja01'
df_royje02_strd['name']='royje02'
df_royma04_strd['name']='royma04'
df_royni01_strd['name']='royni01'
df_ruggist01_strd['name']='ruggist01'
df_ruoppsa01_strd['name']='ruoppsa01'
df_ruusuma01_strd['name']='ruusuma01'
df_saareal01_strd['name']='saareal01'
df_saarivi01_strd['name']='saarivi01'
df_sadekja01_strd['name']='sadekja01'
df_samsoil01_strd['name']='samsoil01'
df_sandsfe01_strd['name']='sandsfe01'
df_schemth01_strd['name']='schemth01'
df_schmama01_strd['name']='schmama01'
df_seneybr01_strd['name']='seneybr01'
df_senysza01_strd['name']='senysza01'
df_sheapa02_strd['name']='sheapa02'
df_sheary01_strd['name']='sheary01'
df_siderde01_strd['name']='siderde01'
df_siegejo01_strd['name']='siegejo01'
df_simondo01_strd['name']='simondo01'
df_smallsp01_strd['name']='smallsp01'
df_smithev01_strd['name']='smithev01'
df_songan01_strd['name']='songan01'
df_spacemi01_strd['name']='spacemi01'
df_speerbl01_strd['name']='speerbl01'
df_spencma01_strd['name']='spencma01'
df_spronda01_strd['name']='spronda01'
df_stenlke01_strd['name']='stenlke01'
df_stephde01_strd['name']='stephde01'
df_stephmi01_strd['name']='stephmi01'
df_stevelu01_strd['name']='stevelu01'
df_stezkal01_strd['name']='stezkal01'
df_stromdy01_strd['name']='stromdy01'
df_svechev01_strd['name']='svechev01'
df_svobomi01_strd['name']='svobomi01'
df_tammejo01_strd['name']='tammejo01'
df_terrytr01_strd['name']='terrytr01'
df_tiffefr01_strd['name']='tiffefr01'
df_timasdm01_strd['name']='timasdm01'
df_tomekma01_strd['name']='tomekma01'
df_treniya01_strd['name']='treniya01'
df_tuulojo01_strd['name']='tuulojo01'
df_vainive01_strd['name']='vainive01'
df_vandemi01_strd['name']='vandemi01'
df_vanpojo01_strd['name']='vanpojo01'
df_vejdelu01_strd['name']='vejdelu01'
df_vejmeka01_strd['name']='vejmeka01'
df_velama01_strd['name']='velama01'
df_vladada01_strd['name']='vladada01'
df_vorobmi01_strd['name']='vorobmi01'
df_wagneau01_strd['name']='wagneau01'
df_warrebr01_strd['name']='warrebr01'
df_werenza01_strd['name']='werenza01'
df_whiteco02_strd['name']='whiteco02'
df_whiteco03_strd['name']='whiteco03'
df_wilkich01_strd['name']='wilkich01'
df_willico01_strd['name']='willico01'
df_wolanch01_strd['name']='wolanch01'
df_wothepa01_strd['name']='wothepa01'
df_yande01_strd['name']='yande01'
df_zachapa01_strd['name']='zachapa01'
df_zborija01_strd['name']='zborija01'
df_zborose01_strd['name']='zborose01'
df_zhukedm01_strd['name']='zhukedm01'
df_zuhlsry01_strd['name']='zuhlsry01'

# %%
strd_frames=[df_addisje01_strd,
df_ahlfi01_strd,
df_ahose01_strd,
df_anderra01_strd,
df_applema01_strd,
df_bachmka01_strd,
df_balceru01_strd,
df_barzama01_strd,
df_bearet01_strd,
df_beaudje01_strd,
df_beauvan01_strd,
df_beckeja01_strd,
df_bednary01_strd,
df_bernhda01_strd,
df_bittnpa01_strd,
df_blackma01_strd,
df_boesebr01_strd,
df_boikose01_strd,
df_bokani01_strd,
df_bondrra01_strd,
df_boothca01_strd,
df_borgewi01_strd,
df_bouragu01_strd,
df_bourqsi01_strd,
df_braccje01_strd,
df_bradlma02_strd,
df_brisegu01_strd,
df_bruceri01_strd,
df_capobky01_strd,
df_carlobr01_strd,
df_carlsga01_strd,
df_carrial01_strd,
df_ceccojo01_strd,
df_cernaer01_strd,
df_chaboth01_strd,
df_chlapfi01_strd,
df_chukaiv01_strd,
df_cirelan01_strd,
df_connoky01_strd,
df_cottoda01_strd,
df_crousla01_strd,
df_cukstka01_strd,
df_daccojo01_strd,
df_dahlsjo01_strd,
df_debruja01_strd,
df_dergaal01_strd,
df_dermotr01_strd,
df_desrost01_strd,
df_dovemsa01_strd,
df_dundali01_strd,
df_dunnvi01_strd,
df_dzierma01_strd,
df_eicheja01_strd,
df_eriksjo02_strd,
df_estepgi01_strd,
df_fedotiv01_strd,
df_fischch01_strd,
df_foleyer01_strd,
df_forsbja01_strd,
df_gabrije01_strd,
df_gagnega01_strd,
df_garlaco01_strd,
df_gatesbr01_strd,
df_gaudead01_strd,
df_gavrivl01_strd,
df_gawdigl01_strd,
df_gennama01_strd,
df_gilbede01_strd,
df_greenjo02_strd,
df_greeraj01_strd,
df_groppry01_strd,
df_guhlebr01_strd,
df_guriade01_strd,
df_hanifno01_strd,
df_hansspe01_strd,
df_harkija01_strd,
df_helewad01_strd,
df_hillad01_strd,
df_hintzro01_strd,
df_hobbsco01_strd,
df_holwapa01_strd,
df_hugheca01_strd,
df_huskaad01_strd,
df_imamabo01_strd,
df_jarosch01_strd,
df_jaseklu01_strd,
df_jonesca01_strd,
df_josepma01_strd,
df_juulsno01_strd,
df_kallger01_strd,
df_kapriki01_strd,
df_karnapa01_strd,
df_kaseda01_strd,
df_knottgr01_strd,
df_koleske01_strd,
df_konectr01_strd,
df_korosni01_strd,
df_kovacro01_strd,
df_kupskjo01_strd,
df_kylinol01_strd,
df_larssja01_strd,
df_lauzoje01_strd,
df_lindgje01_strd,
df_lookeje01_strd,
df_lorenst01_strd,
df_malgide01_strd,
df_mangian01_strd,
df_marinjo01_strd,
df_marnemi01_strd,
df_marodco01_strd,
df_marshad01_strd,
df_martech01_strd,
df_massija01_strd,
df_mcdavco01_strd,
df_meierti01_strd,
df_melocni01_strd,
df_merklni01_strd,
df_metcaga01_strd,
df_mikkoni01_strd,
df_mironan01_strd,
df_montesa01_strd,
df_morribr03_strd,
df_moyty01_strd,
df_musilad01_strd,
df_nattiju01_strd,
df_neillca01_strd,
df_nielsan01_strd,
df_nikusa01_strd,
df_novakth01_strd,
df_nutivma01_strd,
df_oldhakr01_strd,
df_olhavgu01_strd,
df_olsonta01_strd,
df_opilklu01_strd,
df_paigizi01_strd,
df_parsead01_strd,
df_pavlyni01_strd,
df_pearsch01_strd,
df_pilonry01_strd,
df_provoiv01_strd,
df_radkero01_strd,
df_rantami01_strd,
df_reddech01_strd,
df_richaan01_strd,
df_robinmi01_strd,
df_rosloja01_strd,
df_royje02_strd,
df_royma04_strd,
df_royni01_strd,
df_ruggist01_strd,
df_ruoppsa01_strd,
df_ruusuma01_strd,
df_saareal01_strd,
df_saarivi01_strd,
df_sadekja01_strd,
df_samsoil01_strd,
df_sandsfe01_strd,
df_schemth01_strd,
df_schmama01_strd,
df_seneybr01_strd,
df_senysza01_strd,
df_sheapa02_strd,
df_sheary01_strd,
df_siderde01_strd,
df_siegejo01_strd,
df_simondo01_strd,
df_smallsp01_strd,
df_smithev01_strd,
df_songan01_strd,
df_spacemi01_strd,
df_speerbl01_strd,
df_spencma01_strd,
df_spronda01_strd,
df_stenlke01_strd,
df_stephde01_strd,
df_stephmi01_strd,
df_stevelu01_strd,
df_stezkal01_strd,
df_stromdy01_strd,
df_svechev01_strd,
df_svobomi01_strd,
df_tammejo01_strd,
df_terrytr01_strd,
df_tiffefr01_strd,
df_timasdm01_strd,
df_tomekma01_strd,
df_treniya01_strd,
df_tuulojo01_strd,
df_vainive01_strd,
df_vandemi01_strd,
df_vanpojo01_strd,
df_vejdelu01_strd,
df_vejmeka01_strd,
df_velama01_strd,
df_vladada01_strd,
df_vorobmi01_strd,
df_wagneau01_strd,
df_warrebr01_strd,
df_werenza01_strd,
df_whiteco02_strd,
df_whiteco03_strd,
df_wilkich01_strd,
df_willico01_strd,
df_wolanch01_strd,
df_wothepa01_strd,
df_yande01_strd,
df_zachapa01_strd,
df_zborija01_strd,
df_zborose01_strd,
df_zhukedm01_strd,
df_zuhlsry01_strd]

# %%
result_strd = pd.concat(strd_frames)

# %%
result_all = pd.merge(result_strd, result_pos, how ='left', on=['name','season','TOT'])

# %%
result_all
# Out:
#      season  TOT  age_x  games_played  pen_min  plus_minus  goals_ev  \
# 0   2016-17  CAR   19.0          22.0      2.0        -3.0       3.0
# 1   2016-17  NYI   19.0           2.0      6.0        -2.0       0.0
# 2   2016-17  NYI   19.0          18.0      4.0         5.0       2.0
# 3   2016-17  BOS   20.0          23.0     15.0        11.0       2.0
# 4   2016-17  OTT   20.0           1.0      0.0        -2.0       0.0
# 5   2016-17  WPG   20.0          19.0      4.0        -8.0       1.0
# 6   2016-17  ARI   19.0          17.0      8.0        -6.0       1.0
# 7   2015-16  BUF   19.0          81.0     22.0       -16.0      16.0
# 8   2016-17  BUF   20.0           1.0      2.0         1.0       0.0
# 9   2016-17  MIN   20.0           9.0      2.0         2.0       2.0
# 10  2016-17  COL   20.0           5.0      4.0        -2.0       0.0
# 11  2015-16  CAR   19.0          79.0     22.0       -14.0       3.0
# 12  2016-17  CAR   20.0          22.0     14.0        -7.0       0.0
# ...

# %%
import copy
seasonlist=result_all['season']
teamlist=result_all['TOT']
namelist=result_all['name']

currseas=seasonlist[0]
currteam=teamlist[0]
currname=namelist[0]

remlist=[1]
for i in range(1,len(seasonlist)):
    if seasonlist[i]==currseas and currname==namelist[i]:
        remlist.append(0)
    
    else:
        remlist.append(1)
        currname=namelist[i]
        currseas=seasonlist[i]

result_all['uniqueseason']=remlist
result_all=result_all.loc[result_all['uniqueseason'] == 1]
result_all2=copy.deepcopy(result_all)

    
result_all2=result_all2.convert_objects(convert_numeric=True).dropna()

result_all2

result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')
result_all2.to_csv("../draft_year/df_2015.csv")
# Out:
# /Users/takehiromatsuzawa/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:25: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.

# %%
from sklearn import datasets
iris = datasets.load_iris()
