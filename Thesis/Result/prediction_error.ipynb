# %%
import pandas as pd
import numpy as np

# %%
df_sim_3=pd.read_csv('PCA_Folder/similarity_PG_3.csv',index_col=0)

# %%
df_sim_3
# Out:
#             macenma01   staffdr01   rangepa01   collije01   fransco01  \
# name
# macenma01    0.000000  265.252812  194.482313   18.030428  287.169461
# staffdr01  265.252812    0.000000   72.799729  175.634780   38.498566
# rangepa01  194.482313   72.799729    0.000000  123.253468   46.171336
# collije01   18.030428  175.634780  123.253468    0.000000  139.817485
# fransco01  287.169461   38.498566   46.171336  139.817485    0.000000
# scevico01    0.000000   74.540050   96.225306  109.471853   44.029866
# fabbrro01    0.000000    0.000000    0.000000    0.000000    0.000000
# brodzky01  203.789367   34.302943   51.218751  116.273393   37.381635
# richami02    0.000000   60.741079  132.402220  460.941298   86.303479
# jurcoto01   56.503546   77.611327  138.068490   59.334187   99.670197
# molleos01    0.000000  120.545357    0.000000    0.000000  173.038340
# calvema01  101.948051   64.019353   48.735926   85.675509   53.082989
# ...
