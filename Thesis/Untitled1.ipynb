# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20584))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
for x in range(0,totalGoals/2+1):
    oddGoals.append(result2[x][0])
    oddFstAssists.append(result2[x][1])
    oddSndAssists.append(result2[x][2])
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    
# print result2
for x in range(0,totalGoals/2):
    evenGoals.append(resultEven[x][0])
    evenFstAssists.append(resultEven[x][1])
    evenSndAssists.append(resultEven[x][2])



# resultplayers=[elem.find_all("td", attrs={"style":"font-style:cursor:hand;"} ) for elem in result1]
# print soup.find_all("font", attrs={"style":"cursor:hand;"} )
resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )
# resultplayers
# print len(soup.find_all("font", attrs={"style":"cursor:hand;"} ))

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]
# print tds.find("font", attrs={"style":"cursor:hand;"} )
# print tds

# print tds[46]
# print tds[47]
# print tds[46]
# print len(tds)
a = [4,2,3,1,5,6]
# print (7 in a)
# print (6 in a)
# print "font style=" in tds[47]
count=[]
tds2=[]
# print tds[27]
for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
        
# print tds2[1]
# print len(tds2)
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
# print indices

temp=[]
for x in range(0,len(indices)):
#     print x
    if x==0:
#         print x
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
#         print x
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
#         print x
        temp.append(tds2[2][indices[x]:len(tds2[2])])
# print temp
# print len(temp)
temp[0]=temp[0].replace("<td>", "")
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))]
# print "temp"
# print temp    
arrayTemp=[]
# for x in range(1,len(tds2)):
# #     temp=[]
#     indices = [i for i, x in enumerate(tds2[x]) if x == ","]
# #     for x in range(0,len(indices)):
# #         temp.append
indices = []
# for y in range(1,len(tds2)):
#     temp=[]
#     indices = [i for i, x in enumerate(tds2[y]) if x == ","]
#     for x in range(0,len(indices)):
#         if x==0:
# #             print x
#             temp.append(tds2[y][:indices[0]])
#             temp.append(tds2[y][indices[x]:indices[x+1]])
#         elif x!=len(indices)-1:
#             temp.append(tds2[y][indices[x]:indices[x+1]])
#         elif x==len(indices)-1:
#             temp.append(tds2[y][indices[x]:])
#     print temp
#     for x in range(0,len(temp)):
#         temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
#         temp[x]=temp[x][0:(temp[x].index("<"))]
#     print temp 
arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
    for x in range(0,len(indices)):
#     print x
        if x==0:
#             print x
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
#             print x
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
#             print x
            temp.append(tds2[y][indices[x]:len(tds2[2])])
#     print temp
#     print len(temp)
    temp[0]=temp[0].replace("<td>", "")
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
#     print temp
    arrayTemp.append(temp)
    
    
    
# print count
# del count[0]
# print count
print arrayTemp
print len(arrayTemp)

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]

for x in range(0,totalGoals/2+1):
    oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

print oddGoalTeam
for x in range(0,totalGoals/2):
    evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

print evenGoalTeam
oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y]) 
print oddArrayTemp
print evenArrayTemp
# for oddGoalTeam

for y in range(0,len(oddGoalTeam)):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
    
print oddArrayTemp
print len(oddArrayTemp)
    
for y in range(0,len(evenGoalTeam)):
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")
    
print evenArrayTemp 
print len(evenArrayTemp)
print [str(elem.text.strip()) for elem in oddGoals]
print [str(elem.text.strip()) for elem in oddFstAssists]
print [str(elem.text.strip()) for elem in oddSndAssists]
print [str(elem.text.strip()) for elem in evenGoals]
print [str(elem.text.strip()) for elem in evenFstAssists]
print [str(elem.text.strip()) for elem in evenSndAssists]
print [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
print [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
print [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
print [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
print [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
print [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]

oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]

print oddGoalTeam
print evenGoalTeam
elementsOdd = []
for y in range(0,len(oddGoalTeam)):
    elementsOdd.append([])
for y in range(0,len(oddGoalTeam)):
    elementsOdd[y].append(oddGoalsNumber[y])
    
print elementsOdd

elementsEven = []
for y in range(0,len(evenGoalTeam)):
    elementsEven.append([])
for y in range(0,len(evenGoalTeam)):
    elementsEven[y].append(evenGoalsNumber[y])
    
print elementsEven

# for y in range(0,len(oddGoalTeam)):
#     if oddGoalTeam[y]==homeTeam:
# #         oddArrayTemp[2*y].append("W")
#         oddGoalsNumber.append(str(homeTeam))
#     else:
# #         oddArrayTemp[2*y].append("L")
# #         oddArrayTemp[2*y+1].append("W")
#         oddGoalsNumber.append(str(awayTeam))
# print oddGoalsNumber
for y in range(0,len(elementsEven)):
    if evenGoalTeam[y]==homeTeam:
        elementsEven[y].insert(0,str(homeTeam))
    else:
        elementsEven[y].insert(0,str(awayTeam))

print "elementsEven"
print elementsEven

for y in range(0,len(elementsOdd)):
    if oddGoalTeam[y]==homeTeam:
        elementsOdd[y].insert(0,str(homeTeam))
    else:
        elementsOdd[y].insert(0,str(awayTeam))

print "elementsOdd"
print elementsOdd

for y in range(0,len(oddGoalTeam)):
    if oddGoalTeam[y]==homeTeam:
#         oddArrayTemp[2*y].append("W")
        oddGoalsNumber.insert(2*y,str(homeTeam))
        oddFstNumber.insert(2*y,str(homeTeam))
        oddSndNumber.insert(2*y,str(homeTeam))
    else:
#         oddArrayTemp[2*y].append("L")
#         oddArrayTemp[2*y+1].append("W")
        oddGoalsNumber.insert(2*y,str(awayTeam))
        oddFstNumber.insert(2*y,str(awayTeam))
        oddSndNumber.insert(2*y,str(awayTeam))
print oddGoalsNumber
print oddFstNumber
print oddSndNumber


for y in range(0,len(evenGoalTeam)):
    if evenGoalTeam[y]==homeTeam:
#         evenArrayTemp[2*y].append("W")
        evenGoalsNumber.insert(2*y,str(homeTeam))
        evenFstNumber.insert(2*y,str(homeTeam))
        evenSndNumber.insert(2*y,str(homeTeam))
    else:
#         evenArrayTemp[2*y].append("L")
#         evenArrayTemp[2*y+1].append("W")
        evenGoalsNumber.insert(2*y,str(awayTeam))
        evenFstNumber.insert(2*y,str(awayTeam))
        evenSndNumber.insert(2*y,str(awayTeam))
print evenGoalsNumber
print evenFstNumber
print evenSndNumber
# Out:
# [['1', '4', '26', '28', '57', '63'], ['5', '21', '23', '26', '32', '35'], ['1', '6', '24', '36', '65', '84'], ['2', '6', '12', '18', '20', '35'], ['1', '4', '25', '51', '80', '84'], ['19', '25', '26', '32', '35'], ['1', '4', '25', '51', '65', '80'], ['12', '14', '25', '32', '35'], ['4', '26', '28', '57', '63', '80'], ['5', '6', '19', '23', '26', '35']]
# 10
# ['N.J', 'N.J', 'N.J']
# ['N.J', 'BUF']
# [['1', '4', '26', '28', '57', '63'], ['5', '21', '23', '26', '32', '35'], ['1', '4', '25', '51', '80', '84'], ['19', '25', '26', '32', '35'], ['4', '26', '28', '57', '63', '80'], ['5', '6', '19', '23', '26', '35']]
# [['1', '6', '24', '36', '65', '84'], ['2', '6', '12', '18', '20', '35'], ['1', '4', '25', '51', '65', '80'], ['12', '14', '25', '32', '35']]
# [['1', '4', '26', '28', '57', '63', 'L'], ['5', '21', '23', '26', '32', '35', 'W'], ['1', '4', '25', '51', '80', '84', 'L'], ['19', '25', '26', '32', '35', 'W'], ['4', '26', '28', '57', '63', '80', 'L'], ['5', '6', '19', '23', '26', '35', 'W']]
# 6
# [['1', '6', '24', '36', '65', '84', 'L'], ['2', '6', '12', '18', '20', '35', 'W'], ['1', '4', '25', '51', '65', '80', 'W'], ['12', '14', '25', '32', '35', 'L']]
# 4
# ['26 P.ELIAS(6)', '19 T.ZAJAC(6)', '23 M.CAMMALLERI(13)']
# ['23 M.CAMMALLERI(5)', '26 P.ELIAS(10)', '19 T.ZAJAC(7)']
# ['5 A.LARSSON(5)', '32 M.FRASER(1)', '26 P.ELIAS(11)']
# ['20 J.TOOTOO(3)', '25 M.GRIGORENKO(1)']
# ['2 M.ZIDLICKY(15)', '80 C.STEWART(6)']
# ['35 C.SCHNEIDER(1)', '']
# ['26', '19', '23']
# ['23', '26', '19']
# ['5', '32', '26']
# ['20', '25']
# ['2', '80']
# ['35', '']
# ['N.J', 'N.J', 'N.J']
# ['N.J', 'BUF']
# [['26'], ['19'], ['23']]
# [['20'], ['25']]
# elementsEven
# [['N.J', '20'], ['BUF', '25']]
# elementsOdd
# [['N.J', '26'], ['N.J', '19'], ['N.J', '23']]
# ['N.J', '26', 'N.J', '19', 'N.J', '23']
# ['N.J', '23', 'N.J', '26', 'N.J', '19']
# ['N.J', '5', 'N.J', '32', 'N.J', '26']
# ['N.J', '20', 'BUF', '25']
# ['N.J', '2', 'BUF', '80']
# ['N.J', '35', 'BUF', '']

# %%
resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
# print resultTeam
# print resultTeam[0][3]
# print resultTeam[0][4]
# print [elem.text.strip() for elem in Goals]
# print resultTeam[0][3].text.strip().index(" ")
# print resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
# print resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
# print resultTeam[0][4].text.strip()
# print resultTeam[0][3].index(">")
# resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
# resultTeam[0][3]=resultTeam[0][3][(resultTeam[0][3].index(">")+1):len(resultTeam[0][3])]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]
# result2
result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]

for x in range(0,totalGoals/2+1):
    oddGoalTeam.append(resultTeam2[x][4].text.strip())
#     FstAssists.append(result2[x][1])
#     SndAssists.append(result2[x][2])
print oddGoalTeam
for x in range(0,totalGoals/2):
    evenGoalTeam.append(result2TeamEven[x][4].text.strip())
#     FstAssists.append(result2[x][1])
#     SndAssists.append(result2[x][2])
print evenGoalTeam
# print result2
# for x in range(0,totalGoals/2):
#     Goals.append(resultEven[x][0])
#     FstAssists.append(resultEven[x][1])
#     SndAssists.append(resultEven[x][2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ea6cbdbaa872> in <module>()
# ----> 1 resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
#       2 # print resultTeam
#       3 # print resultTeam[0][3]
#       4 # print resultTeam[0][4]
#       5 # print [elem.text.strip() for elem in Goals]
#
# NameError: name 'soup' is not defined

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20585))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
for x in range(0,totalGoals/2+1):
    oddGoals.append(result2[x][0])
    oddFstAssists.append(result2[x][1])
    oddSndAssists.append(result2[x][2])
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    

for x in range(0,totalGoals/2):
    evenGoals.append(resultEven[x][0])
    evenFstAssists.append(resultEven[x][1])
    evenSndAssists.append(resultEven[x][2])



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
        
indices = [i for i, x in enumerate(tds2[2]) if x == ","]

temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[2])])
    temp[0]=temp[0].replace("<td>", "")
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]

for x in range(0,totalGoals/2+1):
    oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

for x in range(0,totalGoals/2):
    evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print oddArrayTemp
print oddGoalTeam
for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
    
for y in range(0,len(evenArrayTemp)/2):
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")
print oddArrayTemp
print 
oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]

goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
    
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])
    
for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd

# for y in range(0,len(oddGoalTeam)):
#     if oddGoalTeam[y]==homeTeam:
#         oddGoalsNumber.insert(2*y,str(homeTeam))
#         oddFstNumber.insert(2*y,str(homeTeam))
#         oddSndNumber.insert(2*y,str(homeTeam))
#     else:
#         oddGoalsNumber.insert(2*y,str(awayTeam))
#         oddFstNumber.insert(2*y,str(awayTeam))
#         oddSndNumber.insert(2*y,str(awayTeam))
# print oddGoalsNumber
# print oddFstNumber
# print oddSndNumber


# for y in range(0,len(evenGoalTeam)):
#     if evenGoalTeam[y]==homeTeam:
# #         evenArrayTemp[2*y].append("W")
#         evenGoalsNumber.insert(2*y,str(homeTeam))
#         evenFstNumber.insert(2*y,str(homeTeam))
#         evenSndNumber.insert(2*y,str(homeTeam))
#     else:
# #         evenArrayTemp[2*y].append("L")
# #         evenArrayTemp[2*y+1].append("W")
#         evenGoalsNumber.insert(2*y,str(awayTeam))
#         evenFstNumber.insert(2*y,str(awayTeam))
#         evenSndNumber.insert(2*y,str(awayTeam))
# print evenGoalsNumber
# print evenFstNumber
# print evenSndNumber

print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# [['2', '5', '22', '41', '44', '68'], ['10', '15', '28', '32', '35', '93']]
# ['OTT', 'PHI']
# [['2', '5', '22', '41', '44', '68', 'W'], ['10', '15', '28', '32', '35', '93', 'L']]
#
# goalEven
# [['PHI', '17']]
# [['PHI', '28']]
# [['PHI', '32']]
# goalOdd
# [['OTT', '68'], ['PHI', '17']]
# [['OTT', '2'], ['PHI', '']]
# [['OTT', ''], ['PHI', '']]
# [['PHI', '17'], ['OTT', '68'], ['PHI', '17']]
# [['PHI', '28'], ['OTT', '2'], ['PHI', '']]
# [['PHI', '32'], ['OTT', ''], ['PHI', '']]

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
goals=[]
fstAssists=[]
sndAssists=[]
Players=[]
# 20001~21227
for gameNum in range(20001,20010):
    print x
    
    soup = BeautifulSoup(get_poll_xml1(gameNum))

    result1= soup.find_all("tr", attrs={"class":"oddColor"} )

    result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

    resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

    resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

    result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

    totalGoals=sum([int(elem.text.strip()) for elem in result3])
    oddGoals=[]
    oddFstAssists=[]
    oddSndAssists=[]

    if totalGoals%2==0:
        ODDGoals=totalGoals/2
        EVENGoals=totalGoals/2
    else:
        ODDGoals=totalGoals/2+1
        EVENGoals=totalGoals/2
        
    for x in range(0,ODDGoals):
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    evenGoals=[]
    evenFstAssists=[]
    evenSndAssists=[]    

    for x in range(0,EVENGoals):
        evenGoals.append(resultEven[x][0])
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])



    resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

    tds=soup.find_all("td" )[1:]
    tds=[str(elem) for elem in tds]

    count=[]
    tds2=[]

    for x in range(0,len(tds)):
        if "font style=" in tds[x]:
            count.append(tds[x].count ("font style="))
            tds2.append(tds[x])

    indices = [i for i, x in enumerate(tds2[2]) if x == ","]

    temp=[]
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[2][:indices[0]])
            temp.append(tds2[2][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[2][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[2][indices[x]:len(tds2[2])])

    temp[0]=temp[0].replace("<td>", "")
    print temp
    print len(temp)
#     print temp[5][(temp[5].index(">")+1):len(temp[5])]
    for x in range(0,len(temp)):
        print x
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))] 
    arrayTemp=[]

    indices = []

    arrayTemp=[]
    for y in range(1,len(tds2)):
        temp=[]
        indices = [i for i, x in enumerate(tds2[y]) if x == ","]
        for x in range(0,len(indices)):
            if x==0:
                temp.append(tds2[y][:indices[0]])
                temp.append(tds2[y][indices[x]:indices[x+1]])
            elif x!=len(indices)-1:
                temp.append(tds2[y][indices[x]:indices[x+1]])
            elif x==len(indices)-1:
                temp.append(tds2[y][indices[x]:len(tds2[2])])
        temp[0]=temp[0].replace("<td>", "")
#         if "," in 
#             temp=temp.remove(",")
        for x in range(0,len(temp)):
            print "x"
            print x
            print temp[x]
            temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
            temp[x]=temp[x][0:(temp[x].index("<"))]
        arrayTemp.append(temp)



    resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
    homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
    awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
    resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
    resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

    result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
    result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
    oddGoalTeam=[]
    evenGoalTeam=[]

    for x in range(0,totalGoals/2+1):
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

    for x in range(0,totalGoals/2):
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

    oddArrayTemp=[]
    evenArrayTemp=[]
    for y in range(0,len(arrayTemp)):
        if y%4==1:
            oddArrayTemp.append(arrayTemp[y]) 
        elif y%4==0:
            oddArrayTemp.append(arrayTemp[y]) 
        elif y%4==2:
            evenArrayTemp.append(arrayTemp[y]) 
        elif y%4==3:
            evenArrayTemp.append(arrayTemp[y]) 
    print "oddArrayTemp"
    print oddArrayTemp
    print len(oddArrayTemp)
    print oddGoalTeam
    
    for y in range(0,len(oddArrayTemp)/2):
        if oddGoalTeam[y]==homeTeam:
            oddArrayTemp[2*y].insert(0,"W")
            oddArrayTemp[2*y].insert(0,homeTeam)
            oddArrayTemp[2*y+1].insert(0,"L")
            oddArrayTemp[2*y+1].insert(0,awayTeam)
        else:
            oddArrayTemp[2*y].insert(0,"L")
            oddArrayTemp[2*y].insert(0,homeTeam)
            oddArrayTemp[2*y+1].insert(0,"W")
            oddArrayTemp[2*y+1].insert(0,awayTeam)

    for y in range(0,len(evenArrayTemp)/2):
        if evenGoalTeam[y]==homeTeam:
            evenArrayTemp[2*y].insert(0,"W")
            evenArrayTemp[2*y].insert(0,homeTeam)
            evenArrayTemp[2*y+1].insert(0,"L")
            evenArrayTemp[2*y+1].insert(0,homeTeam)
        else:
            evenArrayTemp[2*y].insert(0,"L")
            evenArrayTemp[2*y].insert(0,awayTeam)
            evenArrayTemp[2*y+1].insert(0,"W")
            evenArrayTemp[2*y+1].insert(0,awayTeam)

    oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
    oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
    oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
    evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
    evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
    evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
    print evenArrayTemp
    print oddArrayTemp
    goalOdd = []
    fstAssistOdd = []
    sndAssistOdd = []

    for y in range(0,len(oddGoalTeam)):
        goalOdd.append([])
        fstAssistOdd.append([])
        sndAssistOdd.append([])

    for y in range(0,len(oddGoalTeam)):
        goalOdd[y].append(oddGoalsNumber[y])
        fstAssistOdd[y].append(oddFstNumber[y])
        sndAssistOdd[y].append(oddSndNumber[y])

    goalEven = []
    fstAssistEven = []
    sndAssistEven = []

    for y in range(0,len(evenGoalTeam)):
        goalEven.append([])
        fstAssistEven.append([])
        sndAssistEven.append([])

    for y in range(0,len(evenGoalTeam)):
        goalEven[y].append(evenGoalsNumber[y])
        fstAssistEven[y].append(evenFstNumber[y])
        sndAssistEven[y].append(evenSndNumber[y])


    for y in range(0,len(goalEven)):
        if evenGoalTeam[y]==homeTeam:
            goalEven[y].insert(0,str(homeTeam))
            fstAssistEven[y].insert(0,str(homeTeam))
            sndAssistEven[y].insert(0,str(homeTeam))
        else:
            goalEven[y].insert(0,str(awayTeam))
            fstAssistEven[y].insert(0,str(awayTeam))
            sndAssistEven[y].insert(0,str(awayTeam))

    print "goalEven"
    print goalEven
    print fstAssistEven
    print sndAssistEven
    for y in range(0,len(goalOdd)):
        if oddGoalTeam[y]==homeTeam:
            goalOdd[y].insert(0,str(homeTeam))
            fstAssistOdd[y].insert(0,str(homeTeam))
            sndAssistOdd[y].insert(0,str(homeTeam))
        else:
            goalOdd[y].insert(0,str(awayTeam))
            fstAssistOdd[y].insert(0,str(awayTeam))
            sndAssistOdd[y].insert(0,str(awayTeam))

    print "goalOdd"
    print goalOdd
    print fstAssistOdd
    print sndAssistOdd


    print goalEven+goalOdd
    print fstAssistEven+fstAssistOdd
    print sndAssistEven+sndAssistOdd
    
    goals.append(goalEven+goalOdd)
    fstAssists.append(fstAssistEven+fstAssistOdd)
    sndAssists.append(sndAssistEven+sndAssistOdd)
    Players.append(oddArrayTemp+evenArrayTemp)
    
print goals
print fstAssists
print sndAssists
print Players
# Out:
# 5
# ['\n<font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>', ', <font style="cursor:hand;" title="Defense - STEPHANE ROBIDAS">12</font>', ', <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# 6
# 0
# 1
# 2
# 3
# 4
# 5
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - PIERRE-ALEXANDRE PARENTEAU">15</font>
# x
# 1
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>
# x
# 3
# , <font style="cursor:hand;" title="Center - DAVID DESHARNAIS">51</font>
# x
# 4
# , <font style="cursor:hand;" title="Left Wing - MAX PACIORETTY">67</font>
# x
# 5
# , <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</f
# x
# 0
#
# <font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>
# x
# 1
# , <font style="cursor:hand;" title="Defense - STEPHANE ROBIDAS">12</font>
# x
# 2
# , <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>
# x
# 3
# , <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>
# x
# 4
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 5
# , <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>
# x
# 3
# , <font style="cursor:hand;" title="Defense - NATHAN BEAULIEU">28</font>
# x
# 4
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 5
# , <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>
# x
# 2
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 3
# , <font style="cursor:hand;" title="Defense - ROMAN POLAK">46</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>
# x
# 5
# , <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - DALE WEISE">22</font>
# x
# 1
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>
# x
# 3
# , <font style="cursor:hand;" title="Defense - ANDREI MARKOV">79</font>
# x
# 4
# , <font style="cursor:hand;" title="Center - LARS ELLER">81</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>
# x
# 1
# , <font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>
# x
# 5
# , <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>
# x
# 5
# , <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>
# x
# 5
# , <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - PIERRE-ALEXANDRE PARENTEAU">15</font>
# x
# 1
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - DAVID DESHARNAIS">51</font>
# x
# 3
# , <font style="cursor:hand;" title="Left Wing - MAX PACIORETTY">67</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>
# x
# 5
# , <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</f
# x
# 0
#
# <font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>
# x
# 5
# , <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - RENE BOURQUE">17</font>
# x
# 1
# , <font style="cursor:hand;" title="Left Wing - JIRI SEKAC">26</font>
# x
# 2
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 3
# , <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</font>
# x
# 5
# , <font style="cursor:hand;" title="Center - LARS ELLER">81</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Center - MIKE SANTORELLI">25</font>
# x
# 1
# , <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>
# x
# 2
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 3
# , <font style="cursor:hand;" title="Center - LEO KOMAROV">47</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>
# x
# 5
# , <font style="cursor:hand;" title="Right Wing - DAVID CLARKSON">71</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - TOM GILBERT">77</font>
# x
# 5
# , <font style="cursor:hand;" title="Defense - ANDREI MARKOV">79</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>
# x
# 2
# , <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>
# x
# 3
# , <font style="cursor:hand;" title="Defense - ROMAN POLAK">46</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>
# x
# 5
# , <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>
# </td>
# oddArrayTemp
# [['15', '31', '43', '51', '67', '74'], ['3', '12', '19', '43', '45', '67'], ['22', '31', '43', '79', '81'], ['3', '21', '42', '45', '50', '81'], ['15', '31', '51', '67', '74', '76'], ['21', '42', '44', '45', '51', '81'], ['11', '14', '27', '31', '77', '79'], ['19', '43', '45', '46', '50', '67']]
# 8
# ['MTL', 'TOR', 'MTL', 'MTL']
# [[u'TOR', 'L', '11', '14', '27', '28', '31', '43'], [u'TOR', 'W', '19', '43', '45', '46', '50', '67'], [u'MTL', 'W', '11', '14', '27', '31', '74', '76'], [u'MTL', 'L', '21', '42', '44', '45', '51', '81'], [u'TOR', 'L', '17', '26', '31', '74', '76', '81'], [u'TOR', 'W', '25', '44', '45', '47', '51', '71']]
# [[u'MTL', 'W', '15', '31', '43', '51', '67', '74'], [u'TOR', 'L', '3', '12', '19', '43', '45', '67'], [u'MTL', 'L', '22', '31', '43', '79', '81'], [u'TOR', 'W', '3', '21', '42', '45', '50', '81'], [u'MTL', 'W', '15', '31', '51', '67', '74', '76'], [u'TOR', 'L', '21', '42', '44', '45', '51', '81'], [u'MTL', 'W', '11', '14', '27', '31', '77', '79'], [u'TOR', 'L', '19', '43', '45', '46', '50', '67']]
# goalEven
# [['TOR', '43'], ['MTL', '14'], ['TOR', '44']]
# [['TOR', '67'], ['MTL', '74'], ['TOR', '47']]
# [['TOR', '19'], ['MTL', ''], ['TOR', '25']]
# goalOdd
# [['MTL', '67'], ['TOR', '42'], ['MTL', '76'], ['MTL', '14']]
# [['MTL', '15'], ['TOR', '50'], ['MTL', '51'], ['MTL', '27']]
# [['MTL', '74'], ['TOR', '3'], ['MTL', '15'], ['MTL', '']]
# [['TOR', '43'], ['MTL', '14'], ['TOR', '44'], ['MTL', '67'], ['TOR', '42'], ['MTL', '76'], ['MTL', '14']]
# [['TOR', '67'], ['MTL', '74'], ['TOR', '47'], ['MTL', '15'], ['TOR', '50'], ['MTL', '51'], ['MTL', '27']]
# [['TOR', '19'], ['MTL', ''], ['TOR', '25'], ['MTL', '74'], ['TOR', '3'], ['MTL', '15'], ['MTL', '']]
# 2
# ['\n<font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>', ', <font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>', ', <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Center - PATRICE BERGERON">37</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>\n</td>']
# 6
# 0
# 1
# 2
# 3
# 4
# 5
# x
# 0
#
# <font style="cursor:hand;" title="Defense - BRAYDON COBURN">5</font>
# x
# 1
# , <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>
# x
# 1
# , <font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>
# x
# 3
# , <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>
# x
# 4
# , <font style="cursor:hand;" title="Center - PATRICE BERGERON">37</font>
# x
# 5
# , <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Defense - BRAYDON COBURN">5</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>
# x
# 2
# , <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>
# x
# 5
# , <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>
# x
# 1
# , <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - ZDENO CHARA">33</font>
# x
# 3
# , <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>
# x
# 4
# , <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>
# x
# 5
# , <font style="cursor:hand;" title="Center - BRAD MARCHAND">63</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>
# x
# 1
# , <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>
# x
# 2
# , <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>
# x
# 3
# , <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>
# x
# 4
# , <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>
# x
# 5
# , <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>
# </td>
# x
# 0
#
# <font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>
# x
# 1
# , <font style="cursor:hand;" title="Center - CHRIS KELLY">23</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>
# x
# 3
# , <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>
# x
# 4
# , <font style="cursor:hand;" title="Defense - TOREY KRUG">47</font>
# x
# 5
# , <font style="cursor:hand;" title="Defense - ADAM MCQUAID">54</font>
# </td>
# oddArrayTemp
# [['5', '12', '18', '35', '47'], ['18', '21', '27', '34', '37', '40'], ['10', '15', '22', '28', '35', '93'], ['21', '23', '34', '40', '47', '54']]
# 4
# ['BOS', 'BOS']
# [[u'PHI', 'W', '5', '14', '24', '35', '47', '93'], [u'PHI', 'L', '18', '27', '33', '34', '40', '63']]
# [[u'PHI', 'L', '5', '12', '18', '35', '47'], [u'BOS', 'W', '18', '21', '27', '34', '37', '40'], [u'PHI', 'L', '10', '15', '22', '28', '35', '93'], [u'BOS', 'W', '21', '23', '34', '40', '47', '54']]
# goalEven
# [['PHI', '14']]
# [['PHI', '93']]
# [['PHI', '24']]
# goalOdd
# [['BOS', '18'], ['BOS', '23']]
# [['BOS', '34'], ['BOS', '54']]
# [['BOS', '37'], ['BOS', '34']]
# [['PHI', '14'], ['BOS', '18'], ['BOS', '23']]
# [['PHI', '93'], ['BOS', '34'], ['BOS', '54']]
# [['PHI', '24'], ['BOS', '37'], ['BOS', '34']]
# 0
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# 5
# 0
# 1
# 2
# 3
# 4
# x
# 0
#
# <font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>
# x
# 1
# , <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>
# x
# 2
# , <font style="cursor:hand;" title="Center - NICK BONINO">13</font>
# x
# 3
# , <font style="cursor:hand;" title="Left Wing - ALEXANDRE BURROWS">14</font>
# x
# 4
# , <font style="cursor:hand;" title="Left Wing - CHRIS HIGGINS">20</font>
# x
# 5
# ,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-2e0c539091d5> in <module>()
#     118             print x
#     119             print temp[x]
# --> 120             temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
#     121             temp[x]=temp[x][0:(temp[x].index("<"))]
#     122         arrayTemp.append(temp)
#
# ValueError: substring not found

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
goals=[]
fstAssists=[]
sndAssists=[]
Players=[]
# 20001~21227
for gameNum in range(20001,20010):
    print gameNum
    
    soup = BeautifulSoup(get_poll_xml1(gameNum))

    result1= soup.find_all("tr", attrs={"class":"oddColor"} )

    result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

    resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

    resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

    result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

    totalGoals=sum([int(elem.text.strip()) for elem in result3])
    oddGoals=[]
    oddFstAssists=[]
    oddSndAssists=[]

    if totalGoals%2==0:
        ODDGoals=totalGoals/2
        EVENGoals=totalGoals/2
    else:
        ODDGoals=totalGoals/2+1
        EVENGoals=totalGoals/2
        
    for x in range(0,ODDGoals):
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    evenGoals=[]
    evenFstAssists=[]
    evenSndAssists=[]    

    for x in range(0,EVENGoals):
        evenGoals.append(resultEven[x][0])
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])



    resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

    tds=soup.find_all("td" )[1:]
    tds=[str(elem) for elem in tds]

    count=[]
    tds2=[]

    for x in range(0,len(tds)):
        if "font style=" in tds[x]:
            count.append(tds[x].count ("font style="))
            tds2.append(tds[x])

    indices = [i for i, x in enumerate(tds2[2]) if x == ","]

    temp=[]
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[2][:indices[0]])
            temp.append(tds2[2][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[2][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[2][indices[x]:len(tds2[2])])

    temp[0]=temp[0].replace("<td>", "")
    print temp
    print len(temp)
#     print temp[5][(temp[5].index(">")+1):len(temp[5])]
    for x in range(0,len(temp)):
        print x
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))] 
    arrayTemp=[]

    indices = []

    arrayTemp=[]
    for y in range(1,len(tds2)):
        temp=[]
        indices = [i for i, x in enumerate(tds2[y]) if x == ","]
        for x in range(0,len(indices)):
            if x==0:
                temp.append(tds2[y][:indices[0]])
                temp.append(tds2[y][indices[x]:indices[x+1]])
            elif x!=len(indices)-1:
                temp.append(tds2[y][indices[x]:indices[x+1]])
            elif x==len(indices)-1:
                temp.append(tds2[y][indices[x]:len(tds2[2])])
        temp[0]=temp[0].replace("<td>", "")
        print temp
        
        if "," in temp:
            temp.remove(",")
        print temp
        for x in range(0,len(temp)):
#             print "x"
#             print x
#             print temp[x]
            temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
            temp[x]=temp[x][0:(temp[x].index("<"))]
        arrayTemp.append(temp)



    resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
    homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
    awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
    resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
    resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

    result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
    result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
    oddGoalTeam=[]
    evenGoalTeam=[]

    for x in range(0,totalGoals/2+1):
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

    for x in range(0,totalGoals/2):
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

    oddArrayTemp=[]
    evenArrayTemp=[]
    for y in range(0,len(arrayTemp)):
        if y%4==1:
            oddArrayTemp.append(arrayTemp[y]) 
        elif y%4==0:
            oddArrayTemp.append(arrayTemp[y]) 
        elif y%4==2:
            evenArrayTemp.append(arrayTemp[y]) 
        elif y%4==3:
            evenArrayTemp.append(arrayTemp[y]) 
    print "oddArrayTemp"
    print oddArrayTemp
    print len(oddArrayTemp)
    print oddGoalTeam
    
    for y in range(0,len(oddArrayTemp)/2):
        if oddGoalTeam[y]==homeTeam:
            oddArrayTemp[2*y].insert(0,"W")
            oddArrayTemp[2*y].insert(0,homeTeam)
            oddArrayTemp[2*y+1].insert(0,"L")
            oddArrayTemp[2*y+1].insert(0,awayTeam)
        else:
            oddArrayTemp[2*y].insert(0,"L")
            oddArrayTemp[2*y].insert(0,homeTeam)
            oddArrayTemp[2*y+1].insert(0,"W")
            oddArrayTemp[2*y+1].insert(0,awayTeam)

    for y in range(0,len(evenArrayTemp)/2):
        if evenGoalTeam[y]==homeTeam:
            evenArrayTemp[2*y].insert(0,"W")
            evenArrayTemp[2*y].insert(0,homeTeam)
            evenArrayTemp[2*y+1].insert(0,"L")
            evenArrayTemp[2*y+1].insert(0,homeTeam)
        else:
            evenArrayTemp[2*y].insert(0,"L")
            evenArrayTemp[2*y].insert(0,awayTeam)
            evenArrayTemp[2*y+1].insert(0,"W")
            evenArrayTemp[2*y+1].insert(0,awayTeam)

    oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
    oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
    oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
    evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
    evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
    evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
    print evenArrayTemp
    print oddArrayTemp
    goalOdd = []
    fstAssistOdd = []
    sndAssistOdd = []

    for y in range(0,len(oddGoalTeam)):
        goalOdd.append([])
        fstAssistOdd.append([])
        sndAssistOdd.append([])

    for y in range(0,len(oddGoalTeam)):
        goalOdd[y].append(oddGoalsNumber[y])
        fstAssistOdd[y].append(oddFstNumber[y])
        sndAssistOdd[y].append(oddSndNumber[y])

    goalEven = []
    fstAssistEven = []
    sndAssistEven = []

    for y in range(0,len(evenGoalTeam)):
        goalEven.append([])
        fstAssistEven.append([])
        sndAssistEven.append([])

    for y in range(0,len(evenGoalTeam)):
        goalEven[y].append(evenGoalsNumber[y])
        fstAssistEven[y].append(evenFstNumber[y])
        sndAssistEven[y].append(evenSndNumber[y])


    for y in range(0,len(goalEven)):
        if evenGoalTeam[y]==homeTeam:
            goalEven[y].insert(0,str(homeTeam))
            fstAssistEven[y].insert(0,str(homeTeam))
            sndAssistEven[y].insert(0,str(homeTeam))
        else:
            goalEven[y].insert(0,str(awayTeam))
            fstAssistEven[y].insert(0,str(awayTeam))
            sndAssistEven[y].insert(0,str(awayTeam))

    print "goalEven"
    print goalEven
    print fstAssistEven
    print sndAssistEven
    for y in range(0,len(goalOdd)):
        if oddGoalTeam[y]==homeTeam:
            goalOdd[y].insert(0,str(homeTeam))
            fstAssistOdd[y].insert(0,str(homeTeam))
            sndAssistOdd[y].insert(0,str(homeTeam))
        else:
            goalOdd[y].insert(0,str(awayTeam))
            fstAssistOdd[y].insert(0,str(awayTeam))
            sndAssistOdd[y].insert(0,str(awayTeam))

    print "goalOdd"
    print goalOdd
    print fstAssistOdd
    print sndAssistOdd


    print goalEven+goalOdd
    print fstAssistEven+fstAssistOdd
    print sndAssistEven+sndAssistOdd
    
    goals.append(goalEven+goalOdd)
    fstAssists.append(fstAssistEven+fstAssistOdd)
    sndAssists.append(sndAssistEven+sndAssistOdd)
    Players.append(oddArrayTemp+evenArrayTemp)
    
print goals
print fstAssists
print sndAssists
print Players
# Out:
# 20001
# ['\n<font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>', ', <font style="cursor:hand;" title="Defense - STEPHANE ROBIDAS">12</font>', ', <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# 6
# 0
# 1
# 2
# 3
# 4
# 5
# ['\n<font style="cursor:hand;" title="Right Wing - PIERRE-ALEXANDRE PARENTEAU">15</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>', ', <font style="cursor:hand;" title="Center - DAVID DESHARNAIS">51</font>', ', <font style="cursor:hand;" title="Left Wing - MAX PACIORETTY">67</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</f']
# ['\n<font style="cursor:hand;" title="Right Wing - PIERRE-ALEXANDRE PARENTEAU">15</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>', ', <font style="cursor:hand;" title="Center - DAVID DESHARNAIS">51</font>', ', <font style="cursor:hand;" title="Left Wing - MAX PACIORETTY">67</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</f']
# ['\n<font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>', ', <font style="cursor:hand;" title="Defense - STEPHANE ROBIDAS">12</font>', ', <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>', ', <font style="cursor:hand;" title="Defense - STEPHANE ROBIDAS">12</font>', ', <font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>', ', <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>', ', <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>', ', <font style="cursor:hand;" title="Defense - NATHAN BEAULIEU">28</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>', ', <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>', ', <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>', ', <font style="cursor:hand;" title="Defense - NATHAN BEAULIEU">28</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - ROMAN POLAK">46</font>', ', <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - ROMAN POLAK">46</font>', ', <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - DALE WEISE">22</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>', ', <font style="cursor:hand;" title="Defense - ANDREI MARKOV">79</font>', ', <font style="cursor:hand;" title="Center - LARS ELLER">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - DALE WEISE">22</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEAVER">43</font>', ', <font style="cursor:hand;" title="Defense - ANDREI MARKOV">79</font>', ', <font style="cursor:hand;" title="Center - LARS ELLER">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>', ', <font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>', ', <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>', ', <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - DION PHANEUF">3</font>', ', <font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>', ', <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>', ', <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>', ', <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>', ', <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>', ', <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>', ', <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>', ', <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>', ', <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>', ', <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>', ', <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>', ', <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>', ', <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>', ', <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>', ', <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - PIERRE-ALEXANDRE PARENTEAU">15</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Center - DAVID DESHARNAIS">51</font>', ', <font style="cursor:hand;" title="Left Wing - MAX PACIORETTY">67</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>', ', <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</f']
# ['\n<font style="cursor:hand;" title="Right Wing - PIERRE-ALEXANDRE PARENTEAU">15</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Center - DAVID DESHARNAIS">51</font>', ', <font style="cursor:hand;" title="Left Wing - MAX PACIORETTY">67</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>', ', <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</f']
# ['\n<font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>', ', <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>', ', <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>', ', <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - JAMES VAN RIEMSDYK">21</font>', ', <font style="cursor:hand;" title="Center - TYLER BOZAK">42</font>', ', <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>', ', <font style="cursor:hand;" title="Center - PHIL KESSEL">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - RENE BOURQUE">17</font>', ', <font style="cursor:hand;" title="Left Wing - JIRI SEKAC">26</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>', ', <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</font>', ', <font style="cursor:hand;" title="Center - LARS ELLER">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - RENE BOURQUE">17</font>', ', <font style="cursor:hand;" title="Left Wing - JIRI SEKAC">26</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - ALEXEI EMELIN">74</font>', ', <font style="cursor:hand;" title="Defense - P.K. SUBBAN">76</font>', ', <font style="cursor:hand;" title="Center - LARS ELLER">81</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Center - MIKE SANTORELLI">25</font>', ', <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Center - LEO KOMAROV">47</font>', ', <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>', ', <font style="cursor:hand;" title="Right Wing - DAVID CLARKSON">71</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Center - MIKE SANTORELLI">25</font>', ', <font style="cursor:hand;" title="Defense - MORGAN RIELLY">44</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Center - LEO KOMAROV">47</font>', ', <font style="cursor:hand;" title="Defense - JAKE GARDINER">51</font>', ', <font style="cursor:hand;" title="Right Wing - DAVID CLARKSON">71</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>', ', <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>', ', <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - TOM GILBERT">77</font>', ', <font style="cursor:hand;" title="Defense - ANDREI MARKOV">79</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - BRENDAN GALLAGHER">11</font>', ', <font style="cursor:hand;" title="Center - TOMAS PLEKANEC">14</font>', ', <font style="cursor:hand;" title="Center - ALEX GALCHENYUK">27</font>', ', <font style="cursor:hand;" title="Goalie - CAREY PRICE">31</font>', ', <font style="cursor:hand;" title="Defense - TOM GILBERT">77</font>', ', <font style="cursor:hand;" title="Defense - ANDREI MARKOV">79</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - ROMAN POLAK">46</font>', ', <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - JOFFREY LUPUL">19</font>', ', <font style="cursor:hand;" title="Center - NAZEM KADRI">43</font>', ', <font style="cursor:hand;" title="Goalie - JONATHAN BERNIER">45</font>', ', <font style="cursor:hand;" title="Defense - ROMAN POLAK">46</font>', ', <font style="cursor:hand;" title="Defense - STUART PERCY">50</font>', ', <font style="cursor:hand;" title="Right Wing - BRANDON KOZUN">67</font>\n</td>']
# oddArrayTemp
# [['15', '31', '43', '51', '67', '74'], ['3', '12', '19', '43', '45', '67'], ['22', '31', '43', '79', '81'], ['3', '21', '42', '45', '50', '81'], ['15', '31', '51', '67', '74', '76'], ['21', '42', '44', '45', '51', '81'], ['11', '14', '27', '31', '77', '79'], ['19', '43', '45', '46', '50', '67']]
# 8
# ['MTL', 'TOR', 'MTL', 'MTL']
# [[u'TOR', 'L', '11', '14', '27', '28', '31', '43'], [u'TOR', 'W', '19', '43', '45', '46', '50', '67'], [u'MTL', 'W', '11', '14', '27', '31', '74', '76'], [u'MTL', 'L', '21', '42', '44', '45', '51', '81'], [u'TOR', 'L', '17', '26', '31', '74', '76', '81'], [u'TOR', 'W', '25', '44', '45', '47', '51', '71']]
# [[u'MTL', 'W', '15', '31', '43', '51', '67', '74'], [u'TOR', 'L', '3', '12', '19', '43', '45', '67'], [u'MTL', 'L', '22', '31', '43', '79', '81'], [u'TOR', 'W', '3', '21', '42', '45', '50', '81'], [u'MTL', 'W', '15', '31', '51', '67', '74', '76'], [u'TOR', 'L', '21', '42', '44', '45', '51', '81'], [u'MTL', 'W', '11', '14', '27', '31', '77', '79'], [u'TOR', 'L', '19', '43', '45', '46', '50', '67']]
# goalEven
# [['TOR', '43'], ['MTL', '14'], ['TOR', '44']]
# [['TOR', '67'], ['MTL', '74'], ['TOR', '47']]
# [['TOR', '19'], ['MTL', ''], ['TOR', '25']]
# goalOdd
# [['MTL', '67'], ['TOR', '42'], ['MTL', '76'], ['MTL', '14']]
# [['MTL', '15'], ['TOR', '50'], ['MTL', '51'], ['MTL', '27']]
# [['MTL', '74'], ['TOR', '3'], ['MTL', '15'], ['MTL', '']]
# [['TOR', '43'], ['MTL', '14'], ['TOR', '44'], ['MTL', '67'], ['TOR', '42'], ['MTL', '76'], ['MTL', '14']]
# [['TOR', '67'], ['MTL', '74'], ['TOR', '47'], ['MTL', '15'], ['TOR', '50'], ['MTL', '51'], ['MTL', '27']]
# [['TOR', '19'], ['MTL', ''], ['TOR', '25'], ['MTL', '74'], ['TOR', '3'], ['MTL', '15'], ['MTL', '']]
# 20002
# ['\n<font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>', ', <font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>', ', <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Center - PATRICE BERGERON">37</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>\n</td>']
# 6
# 0
# 1
# 2
# 3
# 4
# 5
# ['\n<font style="cursor:hand;" title="Defense - BRAYDON COBURN">5</font>', ', <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - BRAYDON COBURN">5</font>', ', <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>', ', <font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>', ', <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Center - PATRICE BERGERON">37</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>', ', <font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>', ', <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Center - PATRICE BERGERON">37</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - BRAYDON COBURN">5</font>', ', <font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>', ', <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - BRAYDON COBURN">5</font>', ', <font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>', ', <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>', ', <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>', ', <font style="cursor:hand;" title="Defense - ZDENO CHARA">33</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>', ', <font style="cursor:hand;" title="Center - BRAD MARCHAND">63</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Right Wing - REILLY SMITH">18</font>', ', <font style="cursor:hand;" title="Defense - DOUGIE HAMILTON">27</font>', ', <font style="cursor:hand;" title="Defense - ZDENO CHARA">33</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>', ', <font style="cursor:hand;" title="Center - BRAD MARCHAND">63</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>', ', <font style="cursor:hand;" title="Center - CHRIS KELLY">23</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>', ', <font style="cursor:hand;" title="Defense - TOREY KRUG">47</font>', ', <font style="cursor:hand;" title="Defense - ADAM MCQUAID">54</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - LOUI ERIKSSON">21</font>', ', <font style="cursor:hand;" title="Center - CHRIS KELLY">23</font>', ', <font style="cursor:hand;" title="Center - CARL SODERBERG">34</font>', ', <font style="cursor:hand;" title="Goalie - TUUKKA RASK">40</font>', ', <font style="cursor:hand;" title="Defense - TOREY KRUG">47</font>', ', <font style="cursor:hand;" title="Defense - ADAM MCQUAID">54</font>\n</td>']
# oddArrayTemp
# [['5', '12', '18', '35', '47'], ['18', '21', '27', '34', '37', '40'], ['10', '15', '22', '28', '35', '93'], ['21', '23', '34', '40', '47', '54']]
# 4
# ['BOS', 'BOS']
# [[u'PHI', 'W', '5', '14', '24', '35', '47', '93'], [u'PHI', 'L', '18', '27', '33', '34', '40', '63']]
# [[u'PHI', 'L', '5', '12', '18', '35', '47'], [u'BOS', 'W', '18', '21', '27', '34', '37', '40'], [u'PHI', 'L', '10', '15', '22', '28', '35', '93'], [u'BOS', 'W', '21', '23', '34', '40', '47', '54']]
# goalEven
# [['PHI', '14']]
# [['PHI', '93']]
# [['PHI', '24']]
# goalOdd
# [['BOS', '18'], ['BOS', '23']]
# [['BOS', '34'], ['BOS', '54']]
# [['BOS', '37'], ['BOS', '34']]
# [['PHI', '14'], ['BOS', '18'], ['BOS', '23']]
# [['PHI', '93'], ['BOS', '34'], ['BOS', '54']]
# [['PHI', '24'], ['BOS', '37'], ['BOS', '34']]
# 20003
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# 5
# 0
# 1
# 2
# 3
# 4
# ['\n<font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>', ', <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Center - NICK BONINO">13</font>', ', <font style="cursor:hand;" title="Left Wing - ALEXANDRE BURROWS">14</font>', ', <font style="cursor:hand;" title="Left Wing - CHRIS HIGGINS">20</font>', ',']
# ['\n<font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>', ', <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Center - NICK BONINO">13</font>', ', <font style="cursor:hand;" title="Left Wing - ALEXANDRE BURROWS">14</font>', ', <font style="cursor:hand;" title="Left Wing - CHRIS HIGGINS">20</font>']
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Defense - ALEXANDER EDLER">23</font>', ', <font style="cursor:hand;" title="Center - SHAWN MATTHIAS">27</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>', ', <font style="cursor:hand;" title="Right Wing - JANNIK HANSEN">36</font>', ',']
# ['\n<font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Defense - ALEXANDER EDLER">23</font>', ', <font style="cursor:hand;" title="Center - SHAWN MATTHIAS">27</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>', ', <font style="cursor:hand;" title="Right Wing - JANNIK HANSEN">36</font>']
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Defense - KRIS RUSSELL">4</font>', ', <font style="cursor:hand;" title="Center - JOE COLBORNE">8</font>', ', <font style="cursor:hand;" title="Left Wing - JOHNNY GAUDREAU">13</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>', ', <font ']
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Defense - KRIS RUSSELL">4</font>', ', <font style="cursor:hand;" title="Center - JOE COLBORNE">8</font>', ', <font style="cursor:hand;" title="Left Wing - JOHNNY GAUDREAU">13</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>', ', <font ']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-717c496af3ca> in <module>()
#     121 #             print x
#     122 #             print temp[x]
# --> 123             temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
#     124             temp[x]=temp[x][0:(temp[x].index("<"))]
#     125         arrayTemp.append(temp)
#
# ValueError: substring not found

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20003))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])

if totalGoals%2==0:
    ODDGoals=totalGoals/2
    EVENGoals=totalGoals/2
else:
    ODDGoals=totalGoals/2+1
    EVENGoals=totalGoals/2
        
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
for x in range(0,ODDGoals):
    oddGoals.append(result2[x][0])
    oddFstAssists.append(result2[x][1])
    oddSndAssists.append(result2[x][2])
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    

for x in range(0,EVENGoals):
    evenGoals.append(resultEven[x][0])
    evenFstAssists.append(resultEven[x][1])
    evenSndAssists.append(resultEven[x][2])



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
print tds2[2]
   
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
print tds2[2]
temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
print temp

print temp
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
    print tds2[y]
    print indices
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[y])])
    temp[0]=temp[0].replace("<td>", "")
    print y
    print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]

for x in range(0,ODDGoals):
    oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

for x in range(0,EVENGoals):
    evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print oddArrayTemp
print oddGoalTeam
for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
    
for y in range(0,len(evenArrayTemp)/2):
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")
print oddArrayTemp
print 
oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]

goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
    
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])
    
for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd



print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>, <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>, <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>, <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>
# </td>
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>, <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>, <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>, <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>
# </td>
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>, <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>, <font style="cursor:hand;" title="Center - NICK BONINO">13</font>, <font style="cursor:hand;" title="Left Wing - ALEXANDRE BURROWS">14</font>, <font style="cursor:hand;" title="Left Wing - CHRIS HIGGINS">20</font>, <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>
# </td>
# [70, 143, 210, 286, 358]
# 1
# ['\n<font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>', ', <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Center - NICK BONINO">13</font>', ', <font style="cursor:hand;" title="Left Wing - ALEXANDRE BURROWS">14</font>', ', <font style="cursor:hand;" title="Left Wing - CHRIS HIGGINS">20</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>, <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>, <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>, <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>
# </td>
# [70, 141, 211, 281]
# 2
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>, <font style="cursor:hand;" title="Defense - ALEXANDER EDLER">23</font>, <font style="cursor:hand;" title="Center - SHAWN MATTHIAS">27</font>, <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>, <font style="cursor:hand;" title="Right Wing - JANNIK HANSEN">36</font>, <font style="cursor:hand;" title="Right Wing - DEREK DORSETT">51</font>
# </td>
# [76, 148, 218, 285, 358]
# 3
# ['\n<font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Defense - ALEXANDER EDLER">23</font>', ', <font style="cursor:hand;" title="Center - SHAWN MATTHIAS">27</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>', ', <font style="cursor:hand;" title="Right Wing - JANNIK HANSEN">36</font>', ', <font style="cursor:hand;" title="Right Wing - DEREK DORSETT">51</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Defense - KRIS RUSSELL">4</font>, <font style="cursor:hand;" title="Center - JOE COLBORNE">8</font>, <font style="cursor:hand;" title="Left Wing - JOHNNY GAUDREAU">13</font>, <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>, <font style="cursor:hand;" title="Left Wing - PAUL BYRON">32</font>
# </td>
# [70, 138, 205, 279, 351]
# 4
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Defense - KRIS RUSSELL">4</font>', ', <font style="cursor:hand;" title="Center - JOE COLBORNE">8</font>', ', <font style="cursor:hand;" title="Left Wing - JOHNNY GAUDREAU">13</font>', ', <font style="cursor:hand;" title="Defense - DERYK ENGELLAND">29</font>', ', <font style="cursor:hand;" title="Left Wing - PAUL BYRON">32</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - KEVIN BIEKSA">3</font>, <font style="cursor:hand;" title="Right Wing - LINDEN VEY">7</font>, <font style="cursor:hand;" title="Right Wing - ZACK KASSIAN">9</font>, <font style="cursor:hand;" title="Right Wing - BRAD RICHARDSON">15</font>, <font style="cursor:hand;" title="Defense - RYAN STANTON">18</font>, <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>
# </td>
# [71, 140, 211, 286, 355]
# 5
# ['\n<font style="cursor:hand;" title="Defense - KEVIN BIEKSA">3</font>', ', <font style="cursor:hand;" title="Right Wing - LINDEN VEY">7</font>', ', <font style="cursor:hand;" title="Right Wing - ZACK KASSIAN">9</font>', ', <font style="cursor:hand;" title="Right Wing - BRAD RICHARDSON">15</font>', ', <font style="cursor:hand;" title="Defense - RYAN STANTON">18</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Defense - DENNIS WIDEMAN">6</font>, <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>, <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>, <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>, <font style="cursor:hand;" title="Left Wing - MASON RAYMOND">21</font>
# </td>
# [70, 140, 211, 281, 351]
# 6
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Defense - DENNIS WIDEMAN">6</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Defense - LADISLAV SMID">15</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Left Wing - MASON RAYMOND">21</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - KEVIN BIEKSA">3</font>, <font style="cursor:hand;" title="Right Wing - RADIM VRBATA">17</font>, <font style="cursor:hand;" title="Defense - RYAN STANTON">18</font>, <font style="cursor:hand;" title="Left Wing - DANIEL SEDIN">22</font>, <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>, <font style="cursor:hand;" title="Center - HENRIK SEDIN">33</font>
# </td>
# [71, 143, 212, 283, 350]
# 7
# ['\n<font style="cursor:hand;" title="Defense - KEVIN BIEKSA">3</font>', ', <font style="cursor:hand;" title="Right Wing - RADIM VRBATA">17</font>', ', <font style="cursor:hand;" title="Defense - RYAN STANTON">18</font>', ', <font style="cursor:hand;" title="Left Wing - DANIEL SEDIN">22</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>', ', <font style="cursor:hand;" title="Center - HENRIK SEDIN">33</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Defense - MARK GIORDANO">5</font>, <font style="cursor:hand;" title="Defense - TJ BRODIE">7</font>, <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>, <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>, <font style="cursor:hand;" title="Left Wing - MASON RAYMOND">21</font>
# </td>
# [70, 139, 204, 275, 345]
# 8
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Defense - MARK GIORDANO">5</font>', ', <font style="cursor:hand;" title="Defense - TJ BRODIE">7</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Left Wing - LANCE BOUMA">17</font>', ', <font style="cursor:hand;" title="Left Wing - MASON RAYMOND">21</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>, <font style="cursor:hand;" title="Defense - ALEXANDER EDLER">23</font>, <font style="cursor:hand;" title="Center - SHAWN MATTHIAS">27</font>, <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>, <font style="cursor:hand;" title="Right Wing - JANNIK HANSEN">36</font>, <font style="cursor:hand;" title="Right Wing - DEREK DORSETT">51</font>
# </td>
# [76, 148, 218, 285, 358]
# 9
# ['\n<font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Defense - ALEXANDER EDLER">23</font>', ', <font style="cursor:hand;" title="Center - SHAWN MATTHIAS">27</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>', ', <font style="cursor:hand;" title="Right Wing - JANNIK HANSEN">36</font>', ', <font style="cursor:hand;" title="Right Wing - DEREK DORSETT">51</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>, <font style="cursor:hand;" title="Defense - MARK GIORDANO">5</font>, <font style="cursor:hand;" title="Defense - TJ BRODIE">7</font>, <font style="cursor:hand;" title="Left Wing - CURTIS GLENCROSS">20</font>, <font style="cursor:hand;" title="Center - SEAN MONAHAN">23</font>, <font style="cursor:hand;" title="Right Wing - JIRI HUDLER">24</font>
# </td>
# [70, 139, 204, 279, 347]
# 10
# ['\n<font style="cursor:hand;" title="Goalie - JONAS HILLER">1</font>', ', <font style="cursor:hand;" title="Defense - MARK GIORDANO">5</font>', ', <font style="cursor:hand;" title="Defense - TJ BRODIE">7</font>', ', <font style="cursor:hand;" title="Left Wing - CURTIS GLENCROSS">20</font>', ', <font style="cursor:hand;" title="Center - SEAN MONAHAN">23</font>', ', <font style="cursor:hand;" title="Right Wing - JIRI HUDLER">24</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>, <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>, <font style="cursor:hand;" title="Right Wing - BRAD RICHARDSON">15</font>, <font style="cursor:hand;" title="Right Wing - RADIM VRBATA">17</font>, <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>, <font style="cursor:hand;" title="Center - HENRIK SEDIN">33</font>
# </td>
# [70, 143, 218, 290, 357]
# 11
# ['\n<font style="cursor:hand;" title="Defense - DAN HAMHUIS">2</font>', ', <font style="cursor:hand;" title="Defense - CHRISTOPHER TANEV">8</font>', ', <font style="cursor:hand;" title="Right Wing - BRAD RICHARDSON">15</font>', ', <font style="cursor:hand;" title="Right Wing - RADIM VRBATA">17</font>', ', <font style="cursor:hand;" title="Goalie - RYAN MILLER">30</font>', ', <font style="cursor:hand;" title="Center - HENRIK SEDIN">33</font>\n</td>']
# <td>
# <font style="cursor:hand;" title="Defense - KRIS RUSSELL">4</font>, <font style="cursor:hand;" title="Defense - MARK GIORDANO">5</font>, <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>, <font style="cursor:hand;" title="Left Wing - CURTIS GLENCROSS">20</font>, <font style="cursor:hand;" title="Right Wing - JIRI HUDLER">24</font>, <font style="cursor:hand;" title="Left Wing - PAUL BYRON">32</font>
# </td>
# [71, 140, 211, 286, 357]
# 12
# ['\n<font style="cursor:hand;" title="Defense - KRIS RUSSELL">4</font>', ', <font style="cursor:hand;" title="Defense - MARK GIORDANO">5</font>', ', <font style="cursor:hand;" title="Center - MIKAEL BACKLUND">11</font>', ', <font style="cursor:hand;" title="Left Wing - CURTIS GLENCROSS">20</font>', ', <font style="cursor:hand;" title="Right Wing - JIRI HUDLER">24</font>', ', <font style="cursor:hand;" title="Left Wing - PAUL BYRON">32</font>\n</td>']
# [['2', '8', '13', '14', '20', '30'], ['1', '11', '15', '17', '29'], ['3', '7', '9', '15', '18', '30'], ['1', '6', '11', '15', '17', '21'], ['8', '23', '27', '30', '36', '51'], ['1', '5', '7', '20', '23', '24']]
# ['VAN', 'VAN', 'CGY']
# [['2', '8', '13', '14', '20', '30', 'W'], ['1', '11', '15', '17', '29', 'L'], ['3', '7', '9', '15', '18', '30', 'W'], ['1', '6', '11', '15', '17', '21', 'L'], ['8', '23', '27', '30', '36', '51', 'L'], ['1', '5', '7', '20', '23', '24', 'W']]
#
# goalEven
# [['CGY', '32'], ['VAN', '17'], ['VAN', '33']]
# [['CGY', '8'], ['VAN', '33'], ['VAN', '8']]
# [['CGY', ''], ['VAN', '22'], ['VAN', '15']]
# goalOdd
# [['VAN', '14'], ['VAN', '9'], ['CGY', '24']]
# [['VAN', '2'], ['VAN', '7'], ['CGY', '23']]
# [['VAN', '8'], ['VAN', '15'], ['CGY', '5']]
# [['CGY', '32'], ['VAN', '17'], ['VAN', '33'], ['VAN', '14'], ['VAN', '9'], ['CGY', '24']]
# [['CGY', '8'], ['VAN', '33'], ['VAN', '8'], ['VAN', '2'], ['VAN', '7'], ['CGY', '23']]
# [['CGY', ''], ['VAN', '22'], ['VAN', '15'], ['VAN', '8'], ['VAN', '15'], ['CGY', '5']]

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
for numYear in range(20021,20040):
    print numYear
    soup = BeautifulSoup(get_poll_xml1(numYear))
    # soup

    result1= soup.find_all("tr", attrs={"class":"oddColor"} )

    result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

    resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

    resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

    result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

    totalGoals=sum([int(elem.text.strip()) for elem in result3])

    if totalGoals%2==0:
        ODDGoals=totalGoals/2
        EVENGoals=totalGoals/2
    else:
        ODDGoals=totalGoals/2+1
        EVENGoals=totalGoals/2

    oddGoals=[]
    oddFstAssists=[]
    oddSndAssists=[]
    for x in range(0,ODDGoals):
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    evenGoals=[]
    evenFstAssists=[]
    evenSndAssists=[]    

    for x in range(0,EVENGoals):
        if len(resultEven[x])==3:
            evenGoals.append(resultEven[x][0])
            evenFstAssists.append(resultEven[x][1])
            print "len(resultEven[x])"
            print len(resultEven[x])
            evenSndAssists.append(resultEven[x][2])
        elif len(resultEven[x])==2:
            evenGoals.append(resultEven[x][0])
            evenFstAssists.append("NA")
            evenFstAssists.append("NA")



    resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

    tds=soup.find_all("td" )[1:]
    tds=[str(elem) for elem in tds]

    count=[]
    tds2=[]

    for x in range(0,len(tds)):
        if "font style=" in tds[x]:
            count.append(tds[x].count ("font style="))
            tds2.append(tds[x])
    # print tds2[2]

    indices = [i for i, x in enumerate(tds2[2]) if x == ","]
    # print tds2[2]
    temp=[]
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[2][:indices[0]])
            temp.append(tds2[2][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[2][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[2][indices[x]:len(tds2[2])])

    temp[0]=temp[0].replace("<td>", "")
    # print temp

    # print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))] 
    arrayTemp=[]

    indices = []

    arrayTemp=[]
    for y in range(1,len(tds2)):
        temp=[]
        indices = [i for i, x in enumerate(tds2[y]) if x == ","]
    #     print tds2[y]
    #     print indices
        for x in range(0,len(indices)):
            if x==0:
                temp.append(tds2[y][:indices[0]])
                temp.append(tds2[y][indices[x]:indices[x+1]])
            elif x!=len(indices)-1:
                temp.append(tds2[y][indices[x]:indices[x+1]])
            elif x==len(indices)-1:
                temp.append(tds2[y][indices[x]:len(tds2[y])])
        temp[0]=temp[0].replace("<td>", "")
    #     print y
    #     print temp
        for x in range(0,len(temp)):
            temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
            temp[x]=temp[x][0:(temp[x].index("<"))]
        arrayTemp.append(temp)



    resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
    homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
    awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
    resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
    resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

    result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
    result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
    oddGoalTeam=[]
    evenGoalTeam=[]

    for x in range(0,ODDGoals):
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

    for x in range(0,EVENGoals):
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

    oddArrayTemp=[]
    evenArrayTemp=[]
    for y in range(0,len(arrayTemp)):
        if y%4==1:
            oddArrayTemp.append(arrayTemp[y]) 
        elif y%4==0:
            oddArrayTemp.append(arrayTemp[y]) 
        elif y%4==2:
            evenArrayTemp.append(arrayTemp[y]) 
        elif y%4==3:
            evenArrayTemp.append(arrayTemp[y])
    print oddArrayTemp
    print oddGoalTeam
    for y in range(0,len(oddArrayTemp)/2):
        if oddGoalTeam[y]==homeTeam:
            oddArrayTemp[2*y].append("W")
            oddArrayTemp[2*y+1].append("L")
        else:
            oddArrayTemp[2*y].append("L")
            oddArrayTemp[2*y+1].append("W")

    for y in range(0,len(evenArrayTemp)/2):
        if evenGoalTeam[y]==homeTeam:
            evenArrayTemp[2*y].append("W")
            evenArrayTemp[2*y+1].append("L")
        else:
            evenArrayTemp[2*y].append("L")
            evenArrayTemp[2*y+1].append("W")
    print oddArrayTemp
    print 
    oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
    oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
    oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
    evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
    evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
    evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]

    goalOdd = []
    fstAssistOdd = []
    sndAssistOdd = []

    for y in range(0,len(oddGoalTeam)):
        goalOdd.append([])
        fstAssistOdd.append([])
        sndAssistOdd.append([])

    for y in range(0,len(oddGoalTeam)):
        goalOdd[y].append(oddGoalsNumber[y])
        fstAssistOdd[y].append(oddFstNumber[y])
        sndAssistOdd[y].append(oddSndNumber[y])

    goalEven = []
    fstAssistEven = []
    sndAssistEven = []

    for y in range(0,len(evenGoalTeam)):
        goalEven.append([])
        fstAssistEven.append([])
        sndAssistEven.append([])

    for y in range(0,len(evenGoalTeam)):
        goalEven[y].append(evenGoalsNumber[y])
        fstAssistEven[y].append(evenFstNumber[y])
        sndAssistEven[y].append(evenSndNumber[y])


    for y in range(0,len(goalEven)):
        if evenGoalTeam[y]==homeTeam:
            goalEven[y].insert(0,str(homeTeam))
            fstAssistEven[y].insert(0,str(homeTeam))
            sndAssistEven[y].insert(0,str(homeTeam))
        else:
            goalEven[y].insert(0,str(awayTeam))
            fstAssistEven[y].insert(0,str(awayTeam))
            sndAssistEven[y].insert(0,str(awayTeam))

    print "goalEven"
    print goalEven
    print fstAssistEven
    print sndAssistEven
    for y in range(0,len(goalOdd)):
        if oddGoalTeam[y]==homeTeam:
            goalOdd[y].insert(0,str(homeTeam))
            fstAssistOdd[y].insert(0,str(homeTeam))
            sndAssistOdd[y].insert(0,str(homeTeam))
        else:
            goalOdd[y].insert(0,str(awayTeam))
            fstAssistOdd[y].insert(0,str(awayTeam))
            sndAssistOdd[y].insert(0,str(awayTeam))

    print "goalOdd"
    print goalOdd
    print fstAssistOdd
    print sndAssistOdd



    print goalEven+goalOdd
    print fstAssistEven+fstAssistOdd
    print sndAssistEven+sndAssistOdd
# Out:
# 20021
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['4', '5', '7', '27', '40'], ['18', '24', '30', '51', '77', '91'], ['2', '7', '16', '40', '61', '65'], ['6', '18', '24', '30', '77', '91']]
# ['T.B', 'OTT', 'OTT']
# [['4', '5', '7', '27', '40', 'L'], ['18', '24', '30', '51', '77', '91', 'W'], ['2', '7', '16', '40', '61', '65', 'W'], ['6', '18', '24', '30', '77', '91', 'L']]
#
# goalEven
# [['OTT', '65'], ['T.B', '14']]
# [['OTT', '90'], ['T.B', '11']]
# [['OTT', '6'], ['T.B', '']]
# goalOdd
# [['T.B', '77'], ['OTT', '61'], ['OTT', '93']]
# [['T.B', '91'], ['OTT', '7'], ['OTT', '']]
# [['T.B', '51'], ['OTT', ''], ['OTT', '']]
# [['OTT', '65'], ['T.B', '14'], ['T.B', '77'], ['OTT', '61'], ['OTT', '93']]
# [['OTT', '90'], ['T.B', '11'], ['T.B', '91'], ['OTT', '7'], ['OTT', '']]
# [['OTT', '6'], ['T.B', ''], ['T.B', '51'], ['OTT', ''], ['OTT', '']]
# 20022
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['7', '11', '15', '20', '22', '35'], ['1', '5', '17', '22', '51', '82'], ['2', '19', '23', '28', '35', '68'], ['1', '7', '17', '33', '63'], ['6', '14', '17', '28', '29', '35'], ['1', '7', '17', '24', '33', '82']]
# ['N.J', 'N.J', 'N.J']
# [['7', '11', '15', '20', '22', '35', 'W'], ['1', '5', '17', '22', '51', '82', 'L'], ['2', '19', '23', '28', '35', '68', 'W'], ['1', '7', '17', '33', '63', 'L'], ['6', '14', '17', '28', '29', '35', 'W'], ['1', '7', '17', '24', '33', '82', 'L']]
#
# goalEven
# [['N.J', '9'], ['N.J', '28'], ['FLA', '17']]
# [['N.J', '22'], ['N.J', 'unassisted'], ['FLA', '19']]
# [['N.J', '26'], ['N.J', ''], ['FLA', '51']]
# goalOdd
# [['N.J', '15'], ['N.J', '23'], ['N.J', '29']]
# [['N.J', '22'], ['N.J', '2'], ['N.J', '17']]
# [['N.J', '7'], ['N.J', '28'], ['N.J', '14']]
# [['N.J', '9'], ['N.J', '28'], ['FLA', '17'], ['N.J', '15'], ['N.J', '23'], ['N.J', '29']]
# [['N.J', '22'], ['N.J', 'unassisted'], ['FLA', '19'], ['N.J', '22'], ['N.J', '2'], ['N.J', '17']]
# [['N.J', '26'], ['N.J', ''], ['FLA', '51'], ['N.J', '7'], ['N.J', '28'], ['N.J', '14']]
# 20023
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['6', '20', '24', '31', '44'], ['18', '21', '29', '30', '55', '91'], ['4', '14', '16', '27', '31', '49'], ['2', '14', '21', '30', '89', '91'], ['6', '18', '31', '39', '44'], ['21', '29', '30', '51', '55', '91'], ['4', '19', '20', '27', '28', '31'], ['8', '21', '30', '37', '89', '91']]
# ['NYI', 'NYI', 'NYI', 'CAR']
# [['6', '20', '24', '31', '44', 'L'], ['18', '21', '29', '30', '55', '91', 'W'], ['4', '14', '16', '27', '31', '49', 'L'], ['2', '14', '21', '30', '89', '91', 'W'], ['6', '18', '31', '39', '44', 'L'], ['21', '29', '30', '51', '55', '91', 'W'], ['4', '19', '20', '27', '28', '31', 'W'], ['8', '21', '30', '37', '89', '91', 'L']]
#
# goalEven
# [['CAR', '19'], ['CAR', '19'], ['NYI', '12']]
# [['CAR', '26'], ['CAR', '12'], ['NYI', '51']]
# [['CAR', '28'], ['CAR', '28'], ['NYI', '86']]
# goalOdd
# [['NYI', '91'], ['NYI', '89'], ['NYI', '29'], ['CAR', '19']]
# [['NYI', '29'], ['NYI', '91'], ['NYI', '55'], ['CAR', 'unassisted']]
# [['NYI', '55'], ['NYI', '21'], ['NYI', '21'], ['CAR', '']]
# [['CAR', '19'], ['CAR', '19'], ['NYI', '12'], ['NYI', '91'], ['NYI', '89'], ['NYI', '29'], ['CAR', '19']]
# [['CAR', '26'], ['CAR', '12'], ['NYI', '51'], ['NYI', '29'], ['NYI', '91'], ['NYI', '55'], ['CAR', 'unassisted']]
# [['CAR', '28'], ['CAR', '28'], ['NYI', '86'], ['NYI', '55'], ['NYI', '21'], ['NYI', '21'], ['CAR', '']]
# 20024
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['8', '20', '22', '28', '31', '77'], ['12', '15', '22', '28', '29', '93'], ['8', '20', '31', '43', '79'], ['17', '28', '29', '32', '40', '93'], ['14', '15', '27', '31', '76', '79'], ['10', '15', '17', '22', '29', '40']]
# ['PHI', 'PHI', 'MTL', 'MTL']
# [['8', '20', '22', '28', '31', '77', 'L'], ['12', '15', '22', '28', '29', '93', 'W'], ['8', '20', '31', '43', '79', 'L'], ['17', '28', '29', '32', '40', '93', 'W'], ['14', '15', '27', '31', '76', '79', 'W'], ['10', '15', '17', '22', '29', '40', 'L']]
#
# goalEven
# [['PHI', '17'], ['MTL', '79'], ['MTL', '27']]
# [['PHI', '10'], ['MTL', '11'], ['MTL', '14']]
# [['PHI', '15'], ['MTL', '76'], ['MTL', '79']]
# goalOdd
# [['PHI', '12'], ['PHI', '17'], ['MTL', '14'], ['MTL', '15']]
# [['PHI', '28'], ['PHI', '40'], ['MTL', '15'], ['MTL', '']]
# [['PHI', '93'], ['PHI', '32'], ['MTL', '79'], ['MTL', '']]
# [['PHI', '17'], ['MTL', '79'], ['MTL', '27'], ['PHI', '12'], ['PHI', '17'], ['MTL', '14'], ['MTL', '15']]
# [['PHI', '10'], ['MTL', '11'], ['MTL', '14'], ['PHI', '28'], ['PHI', '40'], ['MTL', '15'], ['MTL', '']]
# [['PHI', '15'], ['MTL', '76'], ['MTL', '79'], ['PHI', '93'], ['PHI', '32'], ['MTL', '79'], ['MTL', '']]
# 20025
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['16', '17', '20', '33', '36', '44'], ['42', '43', '47', '51', '56', '72'], ['10', '12', '18', '33', '44', '63'], ['7', '13', '19', '58', '71', '72'], ['5', '15', '18', '28', '33', '36'], ['39', '40', '47', '51', '56', '72'], ['5', '10', '12', '16', '27', '36'], ['13', '21', '42', '43', '51', '72']]
# ['CBJ', 'NYR', 'CBJ', 'CBJ']
# [['16', '17', '20', '33', '36', '44', 'L'], ['42', '43', '47', '51', '56', '72', 'W'], ['10', '12', '18', '33', '44', '63', 'W'], ['7', '13', '19', '58', '71', '72', 'L'], ['5', '15', '18', '28', '33', '36', 'L'], ['39', '40', '47', '51', '56', '72', 'W'], ['5', '10', '12', '16', '27', '36', 'L'], ['13', '21', '42', '43', '51', '72', 'W']]
#
# goalEven
# [['CBJ', '71'], ['CBJ', '13'], ['NYR', '61']]
# [['CBJ', '19'], ['CBJ', '71'], ['NYR', '63']]
# [['CBJ', '58'], ['CBJ', '19'], ['NYR', '']]
# goalOdd
# [['CBJ', '42'], ['NYR', '12'], ['CBJ', '56'], ['CBJ', '13']]
# [['CBJ', '43'], ['NYR', '63'], ['CBJ', '47'], ['CBJ', '43']]
# [['CBJ', '56'], ['NYR', '18'], ['CBJ', '39'], ['CBJ', '']]
# [['CBJ', '71'], ['CBJ', '13'], ['NYR', '61'], ['CBJ', '42'], ['NYR', '12'], ['CBJ', '56'], ['CBJ', '13']]
# [['CBJ', '19'], ['CBJ', '71'], ['NYR', '63'], ['CBJ', '43'], ['NYR', '63'], ['CBJ', '47'], ['CBJ', '43']]
# [['CBJ', '58'], ['CBJ', '19'], ['NYR', ''], ['CBJ', '56'], ['NYR', '18'], ['CBJ', '39'], ['CBJ', '']]
# 20026
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['1', '4', '22', '23', '29', '32'], ['1', '10', '19', '20', '22', '26'], ['1', '5', '7', '8', '32'], ['1', '22', '26', '27', '42', '91'], ['1', '5', '7', '11', '20', '23'], ['1', '17', '19', '27', '74']]
# ['STL', 'STL', 'CGY']
# [['1', '4', '22', '23', '29', '32', 'L'], ['1', '10', '19', '20', '22', '26', 'W'], ['1', '5', '7', '8', '32', 'L'], ['1', '22', '26', '27', '42', '91', 'W'], ['1', '5', '7', '11', '20', '23', 'W'], ['1', '17', '19', '27', '74', 'L']]
#
# goalEven
# [['STL', '42'], ['STL', '91']]
# [['STL', '22'], ['STL', '17']]
# [['STL', '26'], ['STL', '22']]
# goalOdd
# [['STL', '10'], ['STL', '27'], ['CGY', '20']]
# [['STL', '26'], ['STL', '22'], ['CGY', '5']]
# [['STL', '20'], ['STL', '26'], ['CGY', '7']]
# [['STL', '42'], ['STL', '91'], ['STL', '10'], ['STL', '27'], ['CGY', '20']]
# [['STL', '22'], ['STL', '17'], ['STL', '26'], ['STL', '22'], ['CGY', '5']]
# [['STL', '26'], ['STL', '22'], ['STL', '20'], ['STL', '26'], ['CGY', '7']]
# 20027
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['6', '16', '20', '21', '24', '29'], ['4', '14', '18', '35', '57', '63'], ['6', '14', '22', '29', '33', '91'], ['6', '24', '28', '35', '41', '59'], ['6', '14', '33', '83', '90', '91'], ['6', '24', '28', '35', '41', '59']]
# ['DAL', 'NSH', 'NSH']
# [['6', '16', '20', '21', '24', '29', 'W'], ['4', '14', '18', '35', '57', '63', 'L'], ['6', '14', '22', '29', '33', '91', 'L'], ['6', '24', '28', '35', '41', '59', 'W'], ['6', '14', '33', '83', '90', '91', 'L'], ['6', '24', '28', '35', '41', '59', 'W']]
#
# goalEven
# [['NSH', '6'], ['NSH', '24']]
# [['NSH', '9'], ['NSH', '28']]
# [['NSH', '21'], ['NSH', '']]
# goalOdd
# [['DAL', '21'], ['NSH', '28'], ['NSH', '59']]
# [['DAL', '6'], ['NSH', '41'], ['NSH', '24']]
# [['DAL', '16'], ['NSH', '24'], ['NSH', '6']]
# [['NSH', '6'], ['NSH', '24'], ['DAL', '21'], ['NSH', '28'], ['NSH', '59']]
# [['NSH', '9'], ['NSH', '28'], ['DAL', '6'], ['NSH', '41'], ['NSH', '24']]
# [['NSH', '21'], ['NSH', ''], ['DAL', '16'], ['NSH', '24'], ['NSH', '6']]
# 20028
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['1', '21', '26', '41', '61', '63'], ['4', '20', '27', '50', '65', '88'], ['1', '21', '26', '28', '41', '61'], ['2', '7', '20', '50', '65', '81'], ['1', '23', '41', '61', '80', '82'], ['5', '20', '27', '50', '65', '88'], ['1', '4', '8', '17', '61'], ['2', '10', '19', '50', '65', '88']]
# ['CHI', 'BUF', 'CHI', 'CHI']
# [['1', '21', '26', '41', '61', '63', 'L'], ['4', '20', '27', '50', '65', '88', 'W'], ['1', '21', '26', '28', '41', '61', 'W'], ['2', '7', '20', '50', '65', '81', 'L'], ['1', '23', '41', '61', '80', '82', 'L'], ['5', '20', '27', '50', '65', '88', 'W'], ['1', '4', '8', '17', '61', 'L'], ['2', '10', '19', '50', '65', '88', 'W']]
#
# goalEven
# [['CHI', '2'], ['BUF', '63'], ['CHI', '81'], ['CHI', '13']]
# [['CHI', 'unassisted'], ['BUF', '21'], ['CHI', '19'], ['CHI', '20']]
# [['CHI', ''], ['BUF', ''], ['CHI', '7'], ['CHI', '']]
# goalOdd
# [['CHI', '65'], ['BUF', '28'], ['CHI', '88'], ['CHI', '10']]
# [['CHI', '4'], ['BUF', '41'], ['CHI', '65'], ['CHI', '19']]
# [['CHI', '20'], ['BUF', '21'], ['CHI', '20'], ['CHI', '88']]
# [['CHI', '2'], ['BUF', '63'], ['CHI', '81'], ['CHI', '13'], ['CHI', '65'], ['BUF', '28'], ['CHI', '88'], ['CHI', '10']]
# [['CHI', 'unassisted'], ['BUF', '21'], ['CHI', '19'], ['CHI', '20'], ['CHI', '4'], ['BUF', '41'], ['CHI', '65'], ['CHI', '19']]
# [['CHI', ''], ['BUF', ''], ['CHI', '7'], ['CHI', ''], ['CHI', '20'], ['BUF', '21'], ['CHI', '20'], ['CHI', '88']]
# 20029
# len(resultEven[x])
# 3
# [['3', '20', '22', '25', '35', '56'], ['1', '17', '44', '45', '90', '92'], ['6', '11', '21', '24', '35', '46'], ['4', '11', '17', '40', '48', '90']]
# ['MIN', 'MIN']
# [['3', '20', '22', '25', '35', '56', 'W'], ['1', '17', '44', '45', '90', '92', 'L'], ['6', '11', '21', '24', '35', '46', 'W'], ['4', '11', '17', '40', '48', '90', 'L']]
#
# goalEven
# [['MIN', '16']]
# [['MIN', '26']]
# [['MIN', '55']]
# goalOdd
# [['MIN', '3'], ['MIN', '11']]
# [['MIN', '25'], ['MIN', '24']]
# [['MIN', '20'], ['MIN', '46']]
# [['MIN', '16'], ['MIN', '3'], ['MIN', '11']]
# [['MIN', '26'], ['MIN', '25'], ['MIN', '24']]
# [['MIN', '55'], ['MIN', '20'], ['MIN', '46']]
# 20030
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['2', '27', '32', '70', '73', '77'], ['3', '9', '18', '26', '28', '40'], ['2', '8', '11', '28', '32'], ['3', '19', '23', '40', '50', '89'], ['2', '28', '32', '44'], ['3', '19', '23', '40', '50']]
# ['L.A', 'ARI', 'ARI']
# [['2', '27', '32', '70', '73', '77', 'W'], ['3', '9', '18', '26', '28', '40', 'L'], ['2', '8', '11', '28', '32', 'L'], ['3', '19', '23', '40', '50', '89', 'W'], ['2', '28', '32', '44', 'L'], ['3', '19', '23', '40', '50', 'W']]
#
# goalEven
# [['L.A', '77'], ['ARI', '89']]
# [['L.A', '73'], ['ARI', '3']]
# [['L.A', ''], ['ARI', '26']]
# goalOdd
# [['L.A', '70'], ['ARI', '50'], ['ARI', '23']]
# [['L.A', 'unassisted'], ['ARI', '3'], ['ARI', '50']]
# [['L.A', ''], ['ARI', ''], ['ARI', '3']]
# [['L.A', '77'], ['ARI', '89'], ['L.A', '70'], ['ARI', '50'], ['ARI', '23']]
# [['L.A', '73'], ['ARI', '3'], ['L.A', 'unassisted'], ['ARI', '3'], ['ARI', '50']]
# [['L.A', ''], ['ARI', '26'], ['L.A', ''], ['ARI', ''], ['ARI', '3']]
# 20031
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['10', '16', '29', '35', '57', '59'], ['2', '5', '15', '30', '36'], ['2', '16', '21', '26', '35', '57'], ['8', '17', '22', '23', '30', '33'], ['2', '16', '21', '26', '35', '57'], ['2', '8', '13', '14', '20', '30'], ['5', '6', '35', '86', '93'], ['7', '17', '22', '23', '30', '33']]
# ['EDM', 'VAN', 'VAN', 'VAN', 'VAN']
# [['10', '16', '29', '35', '57', '59', 'W'], ['2', '5', '15', '30', '36', 'L'], ['2', '16', '21', '26', '35', '57', 'L'], ['8', '17', '22', '23', '30', '33', 'W'], ['2', '16', '21', '26', '35', '57', 'L'], ['2', '8', '13', '14', '20', '30', 'W'], ['5', '6', '35', '86', '93', 'L'], ['7', '17', '22', '23', '30', '33', 'W']]
#
# goalEven
# [['EDM', '26'], ['EDM', '10'], ['EDM', '6'], ['VAN', '7']]
# [['EDM', '16'], ['EDM', '67'], ['EDM', '26'], ['VAN', '22']]
# [['EDM', '57'], ['EDM', ''], ['EDM', '5'], ['VAN', '17']]
# goalOdd
# [['EDM', '59'], ['VAN', '33'], ['VAN', '13'], ['VAN', '17'], ['VAN', '20']]
# [['EDM', '16'], ['VAN', '22'], ['VAN', '2'], ['VAN', '22'], ['VAN', '']]
# [['EDM', '57'], ['VAN', '23'], ['VAN', '14'], ['VAN', '33'], ['VAN', '']]
# [['EDM', '26'], ['EDM', '10'], ['EDM', '6'], ['VAN', '7'], ['EDM', '59'], ['VAN', '33'], ['VAN', '13'], ['VAN', '17'], ['VAN', '20']]
# [['EDM', '16'], ['EDM', '67'], ['EDM', '26'], ['VAN', '22'], ['EDM', '16'], ['VAN', '22'], ['VAN', '2'], ['VAN', '22'], ['VAN', '']]
# [['EDM', '57'], ['EDM', ''], ['EDM', '5'], ['VAN', '17'], ['EDM', '57'], ['VAN', '23'], ['VAN', '14'], ['VAN', '33'], ['VAN', '']]
# 20032
# len(resultEven[x])
# 3
# [['5', '8', '26', '31', '33', '55'], ['12', '32', '39', '44', '61', '83'], ['16', '18', '31', '39', '44', '67'], ['12', '32', '41', '50', '83', '88']]
# ['S.J', 'S.J']
# [['5', '8', '26', '31', '33', '55', 'L'], ['12', '32', '39', '44', '61', '83', 'W'], ['16', '18', '31', '39', '44', '67', 'L'], ['12', '32', '41', '50', '83', '88', 'W']]
#
# goalEven
# [['S.J', '48']]
# [['S.J', '19']]
# [['S.J', '8']]
# goalOdd
# [['S.J', '44'], ['S.J', '12']]
# [['S.J', '39'], ['S.J', '83']]
# [['S.J', '12'], ['S.J', '88']]
# [['S.J', '48'], ['S.J', '44'], ['S.J', '12']]
# [['S.J', '19'], ['S.J', '39'], ['S.J', '83']]
# [['S.J', '8'], ['S.J', '12'], ['S.J', '88']]
# 20033
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['3', '4', '21', '34', '42', '81'], ['5', '16', '27', '30', '62'], ['3', '4', '21', '34', '42', '81'], ['5', '27', '28', '30', '62'], ['21', '34', '46', '50', '67'], ['10', '12', '16', '20', '27', '30'], ['19', '34', '42', '46', '50', '81'], ['5', '10', '13', '27', '30', '62'], ['4', '21', '42', '45', '50', '81'], ['5', '12', '16', '20', '27', '33']]
# ['TOR', 'TOR', 'TOR', 'TOR', 'NYR']
# [['3', '4', '21', '34', '42', '81', 'W'], ['5', '16', '27', '30', '62', 'L'], ['3', '4', '21', '34', '42', '81', 'W'], ['5', '27', '28', '30', '62', 'L'], ['21', '34', '46', '50', '67', 'W'], ['10', '12', '16', '20', '27', '30', 'L'], ['19', '34', '42', '46', '50', '81', 'W'], ['5', '10', '13', '27', '30', '62', 'L'], ['4', '21', '42', '45', '50', '81', 'L'], ['5', '12', '16', '20', '27', '33', 'W']]
#
# goalEven
# [['NYR', '61'], ['TOR', '43'], ['NYR', '12'], ['TOR', '71']]
# [['NYR', '26'], ['TOR', '21'], ['NYR', 'unassisted'], ['TOR', '50']]
# [['NYR', '18'], ['TOR', '26'], ['NYR', ''], ['TOR', '47']]
# goalOdd
# [['TOR', '4'], ['TOR', '81'], ['TOR', '21'], ['TOR', '42'], ['NYR', '16']]
# [['TOR', '42'], ['TOR', '3'], ['TOR', '47'], ['TOR', '81'], ['NYR', '20']]
# [['TOR', '81'], ['TOR', '4'], ['TOR', ''], ['TOR', '12'], ['NYR', '12']]
# [['NYR', '61'], ['TOR', '43'], ['NYR', '12'], ['TOR', '71'], ['TOR', '4'], ['TOR', '81'], ['TOR', '21'], ['TOR', '42'], ['NYR', '16']]
# [['NYR', '26'], ['TOR', '21'], ['NYR', 'unassisted'], ['TOR', '50'], ['TOR', '42'], ['TOR', '3'], ['TOR', '47'], ['TOR', '81'], ['NYR', '20']]
# [['NYR', '18'], ['TOR', '26'], ['NYR', ''], ['TOR', '47'], ['TOR', '81'], ['TOR', '4'], ['TOR', ''], ['TOR', '12'], ['NYR', '12']]
# 20034
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# [['5', '8', '16', '18', '26', '34'], ['8', '27', '31', '71', '73', '77'], ['5', '8', '17', '22', '34', '85'], ['2', '27', '31', '70', '73', '77'], ['16', '18', '31', '39', '44', '67'], ['2', '11', '13', '27', '31', '71']]
# ['L.A', 'L.A', 'WPG']
# [['5', '8', '16', '18', '26', '34', 'L'], ['8', '27', '31', '71', '73', '77', 'W'], ['5', '8', '17', '22', '34', '85', 'L'], ['2', '27', '31', '70', '73', '77', 'W'], ['16', '18', '31', '39', '44', '67', 'W'], ['2', '11', '13', '27', '31', '71', 'L']]
#
# goalEven
# [['L.A', '11'], ['L.A', '77']]
# [['L.A', '12'], ['L.A', '73']]
# [['L.A', '8'], ['L.A', '70']]
# goalOdd
# [['L.A', '73'], ['L.A', '70'], ['WPG', '18']]
# [['L.A', '8'], ['L.A', 'unassisted'], ['WPG', '67']]
# [['L.A', '77'], ['L.A', ''], ['WPG', '39']]
# [['L.A', '11'], ['L.A', '77'], ['L.A', '73'], ['L.A', '70'], ['WPG', '18']]
# [['L.A', '12'], ['L.A', '73'], ['L.A', '8'], ['L.A', 'unassisted'], ['WPG', '67']]
# [['L.A', '8'], ['L.A', '70'], ['L.A', '77'], ['L.A', ''], ['WPG', '39']]
# 20035
# len(resultEven[x])
# 3
# [['4', '8', '9', '11', '12', '20'], ['20', '38', '43', '44', '51', '72'], ['6', '8', '20', '29', '40', '48'], ['18', '37', '43', '44', '63', '72']]
# ['COL', 'COL']
# [['4', '8', '9', '11', '12', '20', 'W'], ['20', '38', '43', '44', '51', '72', 'L'], ['6', '8', '20', '29', '40', '48', 'W'], ['18', '37', '43', '44', '63', '72', 'L']]
#
# goalEven
# [['BOS', '21']]
# [['BOS', '34']]
# [['BOS', '18']]
# goalOdd
# [['COL', '11'], ['COL', '48']]
# [['COL', '4'], ['COL', '8']]
# [['COL', '9'], ['COL', '29']]
# [['BOS', '21'], ['COL', '11'], ['COL', '48']]
# [['BOS', '34'], ['COL', '4'], ['COL', '8']]
# [['BOS', '18'], ['COL', '9'], ['COL', '29']]
# 20036
# len(resultEven[x])
# 3
# len(resultEven[x])
# 3
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-129-9526a287aa88> in <module>()
#     116             elif x==len(indices)-1:
#     117                 temp.append(tds2[y][indices[x]:len(tds2[y])])
# --> 118         temp[0]=temp[0].replace("<td>", "")
#     119     #     print y
#     120     #     print temp
#
# IndexError: list index out of range

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20006))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])

if totalGoals%2==0:
    ODDGoals=totalGoals/2
    EVENGoals=totalGoals/2
else:
    ODDGoals=totalGoals/2+1
    EVENGoals=totalGoals/2
        
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
oddarrayFailure=[]
for x in range(0,ODDGoals):
    if len(result2[x])==3:
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    else:
        oddarrayFailure.append(x)
        
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    
evenarrayFailure=[]
for x in range(0,EVENGoals):
    print "Test"
    print 
    if len(resultEven[x])==3:
        evenGoals.append(resultEven[x][0])
#         print resultEven[x][1]
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])
    else:
        evenarrayFailure.append(x)
#     else:
#         evenGoals.append(resultEven[x][0])
# #         print resultEven[x][1]
#         evenFstAssists.append(resultEven[x][1])
#         evenSndAssists.append()



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
print tds2[2]
   
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
print tds2[2]
temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
print temp

print temp
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
#     print tds2[y]
#     print indices
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[y])])
    print y
    print temp
    if temp!=[]:
        temp[0]=temp[0].replace("<td>", "")
#     print y
#     print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]
print "EVENGoals"
print ODDGoals
print EVENGoals
print arrayTemp
print "evenarrayFailure"
print evenarrayFailure
# oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
print indicesloc

print arrayTemp

for x in range(0,ODDGoals):
    if x  not in oddarrayFailure:
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

for x in range(0,EVENGoals):
    if x not in evenarrayFailure:
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

indicesloc = [i for i, x in enumerate(arrayTemp) if x == []]
# print arrayTemp.index([])
print indicesloc 
# indicesloc=[]
indicesloc= [ elem/2  for elem in indicesloc if elem%2==0]
print "result2TeamEven[indicesloc[0]]"
print indicesloc
print result2TeamEven[0]
print result2TeamEven[1]


for x in range(0,len(indicesloc)):
    print x
    if indicesloc[x]%2==0:
        evenGoalTeam.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
    else:
        oddGoalTeam.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        
oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print "oddArrayTemp"   
# print arrayTemp.index([])


for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
print evenArrayTemp
print evenGoalTeam
print evenarrayFailure
print len(evenArrayTemp)
print arrayTemp
print len(evenArrayTemp)/2
print len(evenGoalTeam)
print evenGoalTeam
evenArrayTemp=filter(lambda a: a != [], evenArrayTemp)
# evenArrayTemp.remove([])
print evenArrayTemp
for y in range(0,len(evenArrayTemp)/2):
#     print y
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")

print 
for x in range(0,len(indicesloc)):
#     print x
    if indicesloc[x]%2==0:
#         evenGoalTeam.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
        evenGoals.append(result2[EVENGoals][0])
        evenFstAssists.append(result2[EVENGoals][1])
        evenSndAssists.append(result2[EVENoals][2])
    else:
#         oddGoalTeam.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        oddGoals.append(result2[ODDGoals][0])
        oddFstAssists.append(result2[ODDGoals][1])
        oddSndAssists.append(result2[ODDGoals][2])
        
# oddGoals.append(result2[ODDGoals][0])
# oddFstAssists.append(result2[ODDGoals][1])
# oddSndAssists.append(result2[ODDGoals][2])

oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
print "evenGoalsNumber"
print oddGoals
# for x in range(0,len(indicesloc)):
#     print x
#     if indicesloc[x]%2==0:
#         evenGoalsNumber.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
#     else:
#         oddGoalsNumber.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        
goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
print oddGoalsNumber
print oddFstNumber
print oddSndNumber
print oddGoalTeam
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])
    
for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd



print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# Test
#
# Test
#
# Test
#
# Test
#
# Test
#
# <td>
# <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>, <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>, <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>, <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>, <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>, <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>
# </td>
# <td>
# <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>, <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>, <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>, <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>, <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>, <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>
# </td>
# ['\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 1
# ['<td>\n<font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - DAMON SEVERSON">28</font>', ', <font style="cursor:hand;" title="Left Wing - RYANE CLOWE">29</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 2
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 3
# ['<td>\n<font style="cursor:hand;" title="Defense - JON MERRILL">7</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - ERIC GELINAS">22</font>', ', <font style="cursor:hand;" title="Left Wing - RYANE CLOWE">29</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 4
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 5
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - TRAVIS ZAJAC">19</font>', ', <font style="cursor:hand;" title="Left Wing - MIKE CAMMALLERI">23</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAROMIR JAGR">68</font>\n</td>']
# 6
# ['<td>\n<font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 7
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Right Wing - STEPHEN GIONTA">11</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 8
# ['<td>\n<font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 9
# ['<td>\n<font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Defense - JON MERRILL">7</font>', ', <font style="cursor:hand;" title="Center - TRAVIS ZAJAC">19</font>', ', <font style="cursor:hand;" title="Left Wing - MIKE CAMMALLERI">23</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAROMIR JAGR">68</font>\n</td>']
# 10
# ['<td>\n<font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>\n</td>']
# 11
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - DAINIUS ZUBRUS">8</font>', ', <font style="cursor:hand;" title="Right Wing - STEPHEN GIONTA">11</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 12
# ['<td>\n<font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 13
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - DAINIUS ZUBRUS">8</font>', ', <font style="cursor:hand;" title="Right Wing - MARTIN HAVLAT">9</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Left Wing - PATRIK ELIAS">26</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 14
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 15
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Left Wing - RYANE CLOWE">29</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 16
# ['<td>\n<font style="cursor:hand;" title="Defense - NICKLAS GROSSMANN">8</font>', ', <font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>', ', <font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 17
# ['<td>\n<font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Center - DAINIUS ZUBRUS">8</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - DAMON SEVERSON">28</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 18
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 19
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Left Wing - MIKE CAMMALLERI">23</font>', ', <font style="cursor:hand;" title="Left Wing - PATRIK ELIAS">26</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAROMIR JAGR">68</font>\n</td>']
# 20
# ['<td>\n<font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# EVENGoals
# 5
# 5
# [['6', '14', '17', '28', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '19', '23', '24', '35', '68'], ['10', '15', '22', '28', '35', '93'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['6', '7', '19', '23', '35', '68'], ['14', '15', '17', '24', '35', '47'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '9', '24', '26', '35'], ['12', '15', '22', '28', '35', '93'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['6', '8', '14', '17', '28', '35'], ['12', '22', '28', '32', '35', '93'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
# evenarrayFailure
# []
# [5]
# [['6', '14', '17', '28', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '19', '23', '24', '35', '68'], ['10', '15', '22', '28', '35', '93'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['6', '7', '19', '23', '35', '68'], ['14', '15', '17', '24', '35', '47'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '9', '24', '26', '35'], ['12', '15', '22', '28', '35', '93'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['6', '8', '14', '17', '28', '35'], ['12', '22', '28', '32', '35', '93'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
# []
# result2TeamEven[indicesloc[0]]
# []
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">2:10</td>, <td align="center">EV</td>, <td align="center">N.J</td>]
# [<td align="center">4</td>, <td align="center">2</td>, <td align="center">15:44</td>, <td align="center">PP</td>, <td align="center">PHI</td>]
# oddArrayTemp
# [['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
# ['N.J', 'PHI', 'PHI', 'PHI', 'N.J']
# []
# 10
# [['6', '14', '17', '28', '29', '35', 'W'], ['12', '15', '18', '22', '35', '40', 'L'], ['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '19', '23', '24', '35', '68', 'W'], ['10', '15', '22', '28', '35', '93', 'L'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['6', '7', '19', '23', '35', '68', 'L'], ['14', '15', '17', '24', '35', '47', 'W'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '9', '24', '26', '35', 'W'], ['12', '15', '22', '28', '35', '93', 'L'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['6', '8', '14', '17', '28', '35', 'W'], ['12', '22', '28', '32', '35', '93', 'L'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
# 5
# 5
# ['N.J', 'PHI', 'PHI', 'PHI', 'N.J']
# [['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
#
# evenGoalsNumber
# [<td align="left">17 M.RYDER(1)</td>, <td align="left">23 M.CAMMALLERI(1)</td>, <td align="left">17 W.SIMMONDS(1)</td>, <td align="left">26 P.ELIAS(1)</td>, <td align="left">8 D.ZUBRUS(1)</td>]
# ['17', '23', '17', '26', '8']
# ['29', '68', '24', '2', '14']
# ['6', '2', '47', '9', '17']
# ['N.J', 'N.J', 'PHI', 'N.J', 'N.J']
# goalEven
# [['N.J', '14'], ['PHI', '28'], ['PHI', '17'], ['PHI', '40'], ['N.J', '23']]
# [['N.J', '17'], ['PHI', '32'], ['PHI', '40'], ['PHI', '17'], ['N.J', '68']]
# [['N.J', ''], ['PHI', '93'], ['PHI', '28'], ['PHI', '32'], ['N.J', '']]
# goalOdd
# [['N.J', '17'], ['N.J', '23'], ['PHI', '17'], ['N.J', '26'], ['N.J', '8']]
# [['N.J', '29'], ['N.J', '68'], ['PHI', '24'], ['N.J', '2'], ['N.J', '14']]
# [['N.J', '6'], ['N.J', '2'], ['PHI', '47'], ['N.J', '9'], ['N.J', '17']]
# [['N.J', '14'], ['PHI', '28'], ['PHI', '17'], ['PHI', '40'], ['N.J', '23'], ['N.J', '17'], ['N.J', '23'], ['PHI', '17'], ['N.J', '26'], ['N.J', '8']]
# [['N.J', '17'], ['PHI', '32'], ['PHI', '40'], ['PHI', '17'], ['N.J', '68'], ['N.J', '29'], ['N.J', '68'], ['PHI', '24'], ['N.J', '2'], ['N.J', '14']]
# [['N.J', ''], ['PHI', '93'], ['PHI', '28'], ['PHI', '32'], ['N.J', ''], ['N.J', '6'], ['N.J', '2'], ['PHI', '47'], ['N.J', '9'], ['N.J', '17']]

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20036))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])

if totalGoals%2==0:
    ODDGoals=totalGoals/2
    EVENGoals=totalGoals/2
else:
    ODDGoals=totalGoals/2+1
    EVENGoals=totalGoals/2
        
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
oddarrayFailure=[]
for x in range(0,ODDGoals):
    if len(result2[x])==3:
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    else:
        oddarrayFailure.append(x)
        
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    
evenarrayFailure=[]
for x in range(0,EVENGoals):
    print "Test"
    print 
    if len(resultEven[x])==3:
        evenGoals.append(resultEven[x][0])
#         print resultEven[x][1]
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])
    else:
        evenarrayFailure.append(x)
#     else:
#         evenGoals.append(resultEven[x][0])
# #         print resultEven[x][1]
#         evenFstAssists.append(resultEven[x][1])
#         evenSndAssists.append()



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
print tds2[2]
   
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
print tds2[2]
temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
print temp

print temp
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
#     print tds2[y]
#     print indices
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[y])])
    print y
    print temp
    if temp!=[]:
        temp[0]=temp[0].replace("<td>", "")
#     print y
#     print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]
print "EVENGoals"
print ODDGoals
print EVENGoals
print arrayTemp
print "evenarrayFailure"
print evenarrayFailure
# oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
print indicesloc

print arrayTemp

for x in range(0,ODDGoals):
    if x  not in oddarrayFailure:
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))

for x in range(0,EVENGoals):
    if x not in evenarrayFailure:
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

indicesloc = [i for i, x in enumerate(arrayTemp) if x == []]
# print arrayTemp.index([])
print indicesloc 
# indicesloc=[]
indicesloc= [ elem/2  for elem in indicesloc if elem%2==0]
print "result2TeamEven[indicesloc[0]]"
print indicesloc
print result2TeamEven[0]
print result2TeamEven[1]
print result2TeamEven[2]



for x in range(0,len(indicesloc)):
    print indicesloc[x]
    if indicesloc[x]%2==1:
        evenGoalTeam.append((str(result2TeamEven[indicesloc[x]/2][4].text.strip())))
    else:
        oddGoalTeam.append((str(resultTeam2[indicesloc[x]/2][4].text.strip())))
        
oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print "oddArrayTemp"   
# print arrayTemp.index([])


for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
print evenArrayTemp
print evenGoalTeam
print evenarrayFailure
print len(evenArrayTemp)
print arrayTemp
print len(evenArrayTemp)/2
print len(evenGoalTeam)
print evenGoalTeam
evenArrayTemp=filter(lambda a: a != [], evenArrayTemp)
# evenArrayTemp.remove([])
print evenArrayTemp
for y in range(0,len(evenArrayTemp)/2):
#     print y
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")

print oddGoals
print oddFstAssists
print oddSndAssists
print result2[ODDGoals]
for x in range(0,len(indicesloc)):
#     print x
    if indicesloc[x]%2==1 and len(evenGoals)==indicesloc[x]:
#         evenGoalTeam.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
        evenGoals.append(result2[EVENGoals][0])
        evenFstAssists.append(result2[EVENGoals][1])
        evenSndAssists.append(result2[EVENGoals][2])
    else:
#         oddGoalTeam.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        oddGoals.append(result2[ODDGoals][0])
        oddFstAssists.append(result2[ODDGoals][1])
        oddSndAssists.append(result2[ODDGoals][2])
        
# oddGoals.append(result2[ODDGoals][0])
# oddFstAssists.append(result2[ODDGoals][1])
# oddSndAssists.append(result2[ODDGoals][2])

oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
print "evenGoalsNumber"
print oddGoals
# for x in range(0,len(indicesloc)):
#     print x
#     if indicesloc[x]%2==0:
#         evenGoalsNumber.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
#     else:
#         oddGoalsNumber.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        
goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
print oddGoalsNumber
print oddFstNumber
print oddSndNumber
print oddGoalTeam
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])
    
for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd



print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# Test
#
# Test
#
# Test
#
# <td>
# <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>, <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>, <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>, <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>, <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>
# </td>
# <td>
# <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>, <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>, <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>, <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>, <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>
# </td>
# ['\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 1
# ['<td>\n<font style="cursor:hand;" title="Right Wing - COREY PERRY">10</font>', ', <font style="cursor:hand;" title="Center - RYAN GETZLAF">15</font>', ', <font style="cursor:hand;" title="Center - RYAN KESLER">17</font>', ', <font style="cursor:hand;" title="Left Wing - PATRICK MAROON">19</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Defense - SAMI VATANEN">45</font>\n</td>']
# 2
# ['<td>\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 3
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Right Wing - DEVANTE SMITH-PELLY">12</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Right Wing - JAKOB SILFVERBERG">33</font>', ', <font style="cursor:hand;" title="Center - WILLIAM KARLSSON">38</font>', ', <font style="cursor:hand;" title="Defense - HAMPUS LINDHOLM">47</font>\n</td>']
# 4
# ['<td>\n<font style="cursor:hand;" title="Defense - JOSH GORGES">4</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Right Wing - DREW STAFFORD">21</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - TYLER MYERS">57</font>\n</td>']
# 5
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Defense - BEN LOVEJOY">6</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Center - RYAN GETZLAF">15</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Left Wing - MATT BELESKEY">39</font>\n</td>']
# 6
# ['<td>\n<font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDREJ MESZAROS">41</font>', ', <font style="cursor:hand;" title="Left Wing - NICOLAS DESLAURIERS">44</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 7
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Defense - BEN LOVEJOY">6</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Right Wing - JAKOB SILFVERBERG">33</font>', ', <font style="cursor:hand;" title="Center - WILLIAM KARLSSON">38</font>\n</td>']
# 8
# ['<td>\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY HODGSON">19</font>', ', <font style="cursor:hand;" title="Center - ZEMGUS GIRGENSONS">28</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - RASMUS RISTOLAINEN">55</font>', ', <font style="cursor:hand;" title="Right Wing - CHRIS STEWART">80</font>\n</td>']
# 9
# ['<td>\n<font style="cursor:hand;" title="Defense - CLAYTON STONER">3</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Right Wing - TIM JACKMAN">18</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Center - NATE THOMPSON">44</font>', ', <font style="cursor:hand;" title="Defense - SAMI VATANEN">45</font>\n</td>']
# 10
# ['<td>\n<font style="cursor:hand;" title="Defense - JOSH GORGES">4</font>', ', <font style="cursor:hand;" title="Right Wing - DREW STAFFORD">21</font>', ', <font style="cursor:hand;" title="Left Wing - MATT MOULSON">26</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - TYLER MYERS">57</font>', ', <font style="cursor:hand;" title="Center - TYLER ENNIS">63</font>\n</td>']
# 11
# []
# 12
# []
# EVENGoals
# 3
# 3
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63'], [], []]
# evenarrayFailure
# [2]
# []
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63'], [], []]
# [10, 11]
# result2TeamEven[indicesloc[0]]
# [5]
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">8:15</td>, <td align="center">EV</td>, <td align="center">ANA</td>]
# [<td align="center">4</td>, <td align="center">3</td>, <td align="center">3:14</td>, <td align="center">EV</td>, <td align="center">ANA</td>]
# [<td align="center">6</td>, <td align="center">3</td>, <td align="center">12:25</td>, <td align="center">EV-PS</td>, <td align="center">ANA</td>]
# 5
# oddArrayTemp
# [['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], [], []]
# ['ANA', 'ANA', 'ANA']
# [2]
# 6
# [['10', '15', '17', '19', '31', '45', 'W'], ['6', '8', '34', '61', '65', 'L'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39', 'W'], ['8', '34', '41', '44', '61', '65', 'L'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45', 'L'], ['4', '21', '26', '34', '57', '63', 'W'], [], []]
# 3
# 3
# ['ANA', 'ANA', 'ANA']
# [['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80']]
# [<td align="left">10 C.PERRY(4)</td>, <td align="left">39 M.BELESKEY(2)</td>, <td align="left">63 T.ENNIS(2)</td>]
# [<td align="left">19 P.MAROON(3)</td>, <td align="left">6 B.LOVEJOY(1)</td>, <td align="left">26 M.MOULSON(1)</td>]
# [<td align="left">45 S.VATANEN(3)</td>, <td align="left">15 R.GETZLAF(3)</td>, <td align="left">21 D.STAFFORD(3)</td>]
# [<td align="left">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="right" width="15">19</td>
# <td> </td>
# <td> </td>
# <td>P.MAROON</td>
# </tr>
# </table>
# </td>, <td align="left">Tripping</td>]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-181-3ac61d51ca28> in <module>()
#     242         oddGoals.append(result2[ODDGoals][0])
#     243         oddFstAssists.append(result2[ODDGoals][1])
# --> 244         oddSndAssists.append(result2[ODDGoals][2])
#     245
#     246 # oddGoals.append(result2[ODDGoals][0])
#
# IndexError: list index out of range

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20006))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])

if totalGoals%2==0:
    ODDGoals=totalGoals/2
    EVENGoals=totalGoals/2
else:
    ODDGoals=totalGoals/2+1
    EVENGoals=totalGoals/2
        
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
oddarrayFailure=[]
for x in range(0,ODDGoals):
    if len(result2[x])==3:
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    else:
        oddarrayFailure.append(x)
        
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    
evenarrayFailure=[]
for x in range(0,EVENGoals):
#     print "Test"
#     print 
    if len(resultEven[x])==3:
        evenGoals.append(resultEven[x][0])
#         print resultEven[x][1]
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])
    else:
        evenarrayFailure.append(x)
#     else:
#         evenGoals.append(resultEven[x][0])
# #         print resultEven[x][1]
#         evenFstAssists.append(resultEven[x][1])
#         evenSndAssists.append()



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
print tds2[2]
   
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
print tds2[2]
temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
print temp

print temp
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
#     print tds2[y]
#     print indices
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[y])])
    print y
    print temp
    if temp!=[]:
        temp[0]=temp[0].replace("<td>", "")
#     print y
#     print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]
print "EVENGoals"
print ODDGoals
print EVENGoals
print arrayTemp
print "evenarrayFailure"
print evenarrayFailure
# oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
print indicesloc

print arrayTemp

for x in range(0,ODDGoals):
    if x  not in oddarrayFailure:
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))
print evenarrayFailure
for x in range(0,EVENGoals):
    print x
    if x not in evenarrayFailure:
        print x
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

indicesloc = [i for i, x in enumerate(arrayTemp) if x == []]
# print arrayTemp.index([])
print indicesloc 
# indicesloc=[]
indicesloc= [ elem/2  for elem in indicesloc if elem%2==0]
print "result2TeamEven[indicesloc[0]]"
print indicesloc
print result2TeamEven[0]
print result2TeamEven[1]
print result2TeamEven[2]
print result2TeamEven[3]
print result2TeamEven[4]
print result2TeamEven[5]
print "result2TeamEven[indicesloc[0]/2]"
# print result2TeamEven[indicesloc[0]/2]

# print result2TeamEven

print result2TeamEven[indicesloc[0]]
for x in range(0,len(indicesloc)):
    print x
    if indicesloc[x]%2==1 and indicesloc[x]!=totalGoals-1:
        evenGoalTeam.append((str(result2TeamEven[indicesloc[x]/2][4].text.strip())))
    elif indicesloc[x]%2==0 and indicesloc[x]!=totalGoals-1:
        oddGoalTeam.append((str(resultTeam2[indicesloc[x]/2][4].text.strip())))
        
oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print "oddArrayTemp"   
# print arrayTemp.index([])


for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
print evenArrayTemp
print evenGoalTeam
print evenarrayFailure
print len(evenArrayTemp)
print arrayTemp
print len(evenArrayTemp)/2
print len(evenGoalTeam)
print evenGoalTeam
evenArrayTemp=filter(lambda a: a != [], evenArrayTemp)
# evenArrayTemp.remove([])
print evenArrayTemp
for y in range(0,len(evenArrayTemp)/2):
#     print y
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")

print 
print result2[1]
print result2[2]
print result2[3]
print indicesloc
for x in range(0,len(indicesloc)):
#     print x
    if indicesloc[x]%2==1 and indicesloc[x]!=totalGoals-1:
#         evenGoalTeam.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
        evenGoals.append(result2[EVENGoals][0])
        evenFstAssists.append(result2[EVENGoals][1])
        evenSndAssists.append(result2[EVENGoals][2])
    elif indicesloc[x]%2==0 and indicesloc[x]!=totalGoals-1:
#         oddGoalTeam.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        oddGoals.append(result2[ODDGoals][0])
        oddFstAssists.append(result2[ODDGoals][1])
        oddSndAssists.append(result2[ODDGoals][2])
        
# oddGoals.append(result2[ODDGoals][0])
# oddFstAssists.append(result2[ODDGoals][1])
# oddSndAssists.append(result2[ODDGoals][2])

oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
print "evenGoalsNumber"
print oddGoals
# for x in range(0,len(indicesloc)):
#     print x
#     if indicesloc[x]%2==0:
#         evenGoalsNumber.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
#     else:
#         oddGoalsNumber.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        
goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
print oddGoalsNumber
print oddFstNumber
print oddSndNumber
print oddGoalTeam
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])

print evenGoalsNumber
print evenFstNumber
print evenSndNumber
print evenGoalTeam
print evenarrayFailure

for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd



print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# <td>
# <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>, <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>, <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>, <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>, <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>, <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>
# </td>
# <td>
# <font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>, <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>, <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>, <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>, <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>, <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>
# </td>
# ['\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 1
# ['<td>\n<font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - DAMON SEVERSON">28</font>', ', <font style="cursor:hand;" title="Left Wing - RYANE CLOWE">29</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 2
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 3
# ['<td>\n<font style="cursor:hand;" title="Defense - JON MERRILL">7</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - ERIC GELINAS">22</font>', ', <font style="cursor:hand;" title="Left Wing - RYANE CLOWE">29</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 4
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Center - R.J. UMBERGER">18</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 5
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - TRAVIS ZAJAC">19</font>', ', <font style="cursor:hand;" title="Left Wing - MIKE CAMMALLERI">23</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAROMIR JAGR">68</font>\n</td>']
# 6
# ['<td>\n<font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 7
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Right Wing - STEPHEN GIONTA">11</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 8
# ['<td>\n<font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 9
# ['<td>\n<font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Defense - JON MERRILL">7</font>', ', <font style="cursor:hand;" title="Center - TRAVIS ZAJAC">19</font>', ', <font style="cursor:hand;" title="Left Wing - MIKE CAMMALLERI">23</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAROMIR JAGR">68</font>\n</td>']
# 10
# ['<td>\n<font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Defense - ANDREW MACDONALD">47</font>\n</td>']
# 11
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - DAINIUS ZUBRUS">8</font>', ', <font style="cursor:hand;" title="Right Wing - STEPHEN GIONTA">11</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 12
# ['<td>\n<font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 13
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - DAINIUS ZUBRUS">8</font>', ', <font style="cursor:hand;" title="Right Wing - MARTIN HAVLAT">9</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Left Wing - PATRIK ELIAS">26</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 14
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 15
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - BRYCE SALVADOR">24</font>', ', <font style="cursor:hand;" title="Left Wing - RYANE CLOWE">29</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 16
# ['<td>\n<font style="cursor:hand;" title="Defense - NICKLAS GROSSMANN">8</font>', ', <font style="cursor:hand;" title="Center - BRAYDEN SCHENN">10</font>', ', <font style="cursor:hand;" title="Right Wing - WAYNE SIMMONDS">17</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Center - VINCENT LECAVALIER">40</font>\n</td>']
# 17
# ['<td>\n<font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Center - DAINIUS ZUBRUS">8</font>', ', <font style="cursor:hand;" title="Center - ADAM HENRIQUE">14</font>', ', <font style="cursor:hand;" title="Right Wing - MICHAEL RYDER">17</font>', ', <font style="cursor:hand;" title="Defense - DAMON SEVERSON">28</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>\n</td>']
# 18
# ['<td>\n<font style="cursor:hand;" title="Left Wing - MICHAEL RAFFL">12</font>', ', <font style="cursor:hand;" title="Defense - LUKE SCHENN">22</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Goalie - STEVE MASON">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# 19
# ['<td>\n<font style="cursor:hand;" title="Defense - MAREK ZIDLICKY">2</font>', ', <font style="cursor:hand;" title="Defense - ANDY GREENE">6</font>', ', <font style="cursor:hand;" title="Left Wing - MIKE CAMMALLERI">23</font>', ', <font style="cursor:hand;" title="Left Wing - PATRIK ELIAS">26</font>', ', <font style="cursor:hand;" title="Goalie - CORY SCHNEIDER">35</font>', ', <font style="cursor:hand;" title="Right Wing - JAROMIR JAGR">68</font>\n</td>']
# 20
# ['<td>\n<font style="cursor:hand;" title="Center - SEAN COUTURIER">14</font>', ', <font style="cursor:hand;" title="Defense - MICHAEL DEL ZOTTO">15</font>', ', <font style="cursor:hand;" title="Right Wing - MATT READ">24</font>', ', <font style="cursor:hand;" title="Right Wing - CLAUDE GIROUX">28</font>', ', <font style="cursor:hand;" title="Defense - MARK STREIT">32</font>', ', <font style="cursor:hand;" title="Right Wing - JAKUB VORACEK">93</font>\n</td>']
# EVENGoals
# 5
# 5
# [['6', '14', '17', '28', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '19', '23', '24', '35', '68'], ['10', '15', '22', '28', '35', '93'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['6', '7', '19', '23', '35', '68'], ['14', '15', '17', '24', '35', '47'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '9', '24', '26', '35'], ['12', '15', '22', '28', '35', '93'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['6', '8', '14', '17', '28', '35'], ['12', '22', '28', '32', '35', '93'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
# evenarrayFailure
# []
# []
# [['6', '14', '17', '28', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['7', '14', '17', '22', '29', '35'], ['12', '15', '18', '22', '35', '40'], ['2', '19', '23', '24', '35', '68'], ['10', '15', '22', '28', '35', '93'], ['2', '11', '14', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['6', '7', '19', '23', '35', '68'], ['14', '15', '17', '24', '35', '47'], ['2', '8', '11', '24', '35'], ['17', '28', '32', '35', '40', '93'], ['2', '8', '9', '24', '26', '35'], ['12', '15', '22', '28', '35', '93'], ['2', '14', '17', '24', '29', '35'], ['8', '10', '17', '32', '35', '40'], ['6', '8', '14', '17', '28', '35'], ['12', '22', '28', '32', '35', '93'], ['2', '6', '23', '26', '35', '68'], ['14', '15', '24', '28', '32', '93']]
# []
# 0
# 0
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 4
# []
# result2TeamEven[indicesloc[0]]
# []
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">2:10</td>, <td align="center">EV</td>, <td align="center">N.J</td>]
# [<td align="center">4</td>, <td align="center">2</td>, <td align="center">15:44</td>, <td align="center">PP</td>, <td align="center">PHI</td>]
# [<td align="center">6</td>, <td align="center">2</td>, <td align="center">19:59</td>, <td align="center">PP</td>, <td align="center">PHI</td>]
# [<td align="center">8</td>, <td align="center">3</td>, <td align="center">4:31</td>, <td align="center">EV</td>, <td align="center">PHI</td>]
# [<td align="center">10</td>, <td align="center">3</td>, <td align="center">19:00</td>, <td align="center">EV-EN</td>, <td align="center">N.J</td>]
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">7:29</td>, <td align="center">2</td>]
# result2TeamEven[indicesloc[0]/2]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-206-fa9fbea4dd61> in <module>()
#     185 # print result2TeamEven
#     186
# --> 187 print result2TeamEven[indicesloc[0]]
#     188 for x in range(0,len(indicesloc)):
#     189     print x
#
# IndexError: list index out of range

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20036))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])

if totalGoals%2==0:
    ODDGoals=totalGoals/2
    EVENGoals=totalGoals/2
else:
    ODDGoals=totalGoals/2+1
    EVENGoals=totalGoals/2
        
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
oddarrayFailure=[]
for x in range(0,ODDGoals):
    if len(result2[x])==3:
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    else:
        oddarrayFailure.append(x)
        
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    
evenarrayFailure=[]
for x in range(0,EVENGoals):
#     print "Test"
#     print 
    if len(resultEven[x])==3:
        evenGoals.append(resultEven[x][0])
#         print resultEven[x][1]
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])
    else:
        evenarrayFailure.append(x)
#     else:
#         evenGoals.append(resultEven[x][0])
# #         print resultEven[x][1]
#         evenFstAssists.append(resultEven[x][1])
#         evenSndAssists.append()



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
print tds2[2]
   
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
print tds2[2]
temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
print temp

print temp
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
#     print tds2[y]
#     print indices
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[y])])
    print y
    print temp
    if temp!=[]:
        temp[0]=temp[0].replace("<td>", "")
#     print y
#     print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]
print "EVENGoals"
print ODDGoals
print EVENGoals
print arrayTemp
print "evenarrayFailure"
print evenarrayFailure
# oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
print indicesloc

print arrayTemp

for x in range(0,ODDGoals):
    if x  not in oddarrayFailure:
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))
print evenarrayFailure
for x in range(0,EVENGoals):
    print x
    if x not in evenarrayFailure:
        print x
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

indicesloc = [i for i, x in enumerate(arrayTemp) if x == []]
# print arrayTemp.index([])
print indicesloc 
# indicesloc=[]
indicesloc= [ elem/2  for elem in indicesloc if elem%2==0]
print "result2TeamEven[indicesloc[0]]"
print indicesloc
print result2TeamEven[0]
print result2TeamEven[1]
print result2TeamEven[2]
print result2TeamEven[3]
print result2TeamEven[4]
print result2TeamEven[5]
print "result2TeamEven[indicesloc[0]/2]"
print result2TeamEven[indicesloc[0]/2]
print indicesloc
print totalGoals
# print result2TeamEven

print result2TeamEven[indicesloc[0]]
for x in range(0,len(indicesloc)):
    print x
    if indicesloc[x]%2==1 and indicesloc[x]!=totalGoals/2:
        evenGoalTeam.append((str(result2TeamEven[indicesloc[x]/2][4].text.strip())))
    elif indicesloc[x]%2==0 and indicesloc[x]!=totalGoals/2:
        oddGoalTeam.append((str(resultTeam2[indicesloc[x]/2][4].text.strip())))
        
oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print "oddArrayTemp"   
# print arrayTemp.index([])

print oddArrayTemp
print oddGoalTeam
for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
print evenArrayTemp
print evenGoalTeam
print evenarrayFailure
print len(evenArrayTemp)
print arrayTemp
print len(evenArrayTemp)/2
print len(evenGoalTeam)
print evenGoalTeam
evenArrayTemp=filter(lambda a: a != [], evenArrayTemp)
# evenArrayTemp.remove([])
print evenArrayTemp
for y in range(0,len(evenArrayTemp)/2):
#     print y
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")

print 
print result2[1]
print result2[2]
print result2[3]
print indicesloc
for x in range(0,len(indicesloc)):
#     print x
    if indicesloc[x]%2==1 and indicesloc[x]!=totalGoals-1:
#         evenGoalTeam.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
        evenGoals.append(result2[EVENGoals][0])
        evenFstAssists.append(result2[EVENGoals][1])
        evenSndAssists.append(result2[EVENGoals][2])
    elif indicesloc[x]%2==0 and indicesloc[x]!=totalGoals-1:
#         oddGoalTeam.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        oddGoals.append(result2[ODDGoals][0])
        oddFstAssists.append(result2[ODDGoals][1])
        oddSndAssists.append(result2[ODDGoals][2])
        
# oddGoals.append(result2[ODDGoals][0])
# oddFstAssists.append(result2[ODDGoals][1])
# oddSndAssists.append(result2[ODDGoals][2])

oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
print "evenGoalsNumber"
print oddGoals
# for x in range(0,len(indicesloc)):
#     print x
#     if indicesloc[x]%2==0:
#         evenGoalsNumber.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
#     else:
#         oddGoalsNumber.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        
goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
print oddGoalsNumber
print oddFstNumber
print oddSndNumber
print oddGoalTeam
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])

print evenGoalsNumber
print evenFstNumber
print evenSndNumber
print evenGoalTeam
print evenarrayFailure

for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd



print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# <td>
# <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>, <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>, <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>, <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>, <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>
# </td>
# <td>
# <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>, <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>, <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>, <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>, <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>
# </td>
# ['\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 1
# ['<td>\n<font style="cursor:hand;" title="Right Wing - COREY PERRY">10</font>', ', <font style="cursor:hand;" title="Center - RYAN GETZLAF">15</font>', ', <font style="cursor:hand;" title="Center - RYAN KESLER">17</font>', ', <font style="cursor:hand;" title="Left Wing - PATRICK MAROON">19</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Defense - SAMI VATANEN">45</font>\n</td>']
# 2
# ['<td>\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 3
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Right Wing - DEVANTE SMITH-PELLY">12</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Right Wing - JAKOB SILFVERBERG">33</font>', ', <font style="cursor:hand;" title="Center - WILLIAM KARLSSON">38</font>', ', <font style="cursor:hand;" title="Defense - HAMPUS LINDHOLM">47</font>\n</td>']
# 4
# ['<td>\n<font style="cursor:hand;" title="Defense - JOSH GORGES">4</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Right Wing - DREW STAFFORD">21</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - TYLER MYERS">57</font>\n</td>']
# 5
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Defense - BEN LOVEJOY">6</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Center - RYAN GETZLAF">15</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Left Wing - MATT BELESKEY">39</font>\n</td>']
# 6
# ['<td>\n<font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDREJ MESZAROS">41</font>', ', <font style="cursor:hand;" title="Left Wing - NICOLAS DESLAURIERS">44</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 7
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Defense - BEN LOVEJOY">6</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Right Wing - JAKOB SILFVERBERG">33</font>', ', <font style="cursor:hand;" title="Center - WILLIAM KARLSSON">38</font>\n</td>']
# 8
# ['<td>\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY HODGSON">19</font>', ', <font style="cursor:hand;" title="Center - ZEMGUS GIRGENSONS">28</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - RASMUS RISTOLAINEN">55</font>', ', <font style="cursor:hand;" title="Right Wing - CHRIS STEWART">80</font>\n</td>']
# 9
# ['<td>\n<font style="cursor:hand;" title="Defense - CLAYTON STONER">3</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Right Wing - TIM JACKMAN">18</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Center - NATE THOMPSON">44</font>', ', <font style="cursor:hand;" title="Defense - SAMI VATANEN">45</font>\n</td>']
# 10
# ['<td>\n<font style="cursor:hand;" title="Defense - JOSH GORGES">4</font>', ', <font style="cursor:hand;" title="Right Wing - DREW STAFFORD">21</font>', ', <font style="cursor:hand;" title="Left Wing - MATT MOULSON">26</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - TYLER MYERS">57</font>', ', <font style="cursor:hand;" title="Center - TYLER ENNIS">63</font>\n</td>']
# 11
# []
# 12
# []
# EVENGoals
# 3
# 3
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63'], [], []]
# evenarrayFailure
# [2]
# [5]
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63'], [], []]
# [2]
# 0
# 0
# 1
# 1
# 2
# [10, 11]
# result2TeamEven[indicesloc[0]]
# [5]
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">8:15</td>, <td align="center">EV</td>, <td align="center">ANA</td>]
# [<td align="center">4</td>, <td align="center">3</td>, <td align="center">3:14</td>, <td align="center">EV</td>, <td align="center">ANA</td>]
# [<td align="center">6</td>, <td align="center">3</td>, <td align="center">12:25</td>, <td align="center">EV-PS</td>, <td align="center">ANA</td>]
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">0:12</td>, <td align="center">2</td>]
# [<td align="center">4</td>, <td align="center">2</td>, <td align="center">20:00</td>, <td align="center">2</td>]
# [<td align="center">2</td>, <td align="center">1</td>, <td align="center">3:38</td>, <td align="center">2</td>]
# result2TeamEven[indicesloc[0]/2]
# [<td align="center">6</td>, <td align="center">3</td>, <td align="center">12:25</td>, <td align="center">EV-PS</td>, <td align="center">ANA</td>]
# [5]
# 6
# [<td align="center">2</td>, <td align="center">1</td>, <td align="center">3:38</td>, <td align="center">2</td>]
# 0
# oddArrayTemp
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63']]
# ['ANA', 'ANA', 'BUF']
# [['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], [], []]
# ['ANA', 'ANA', 'ANA']
# [2]
# 6
# [['10', '15', '17', '19', '31', '45', 'W'], ['6', '8', '34', '61', '65', 'L'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39', 'W'], ['8', '34', '41', '44', '61', '65', 'L'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45', 'L'], ['4', '21', '26', '34', '57', '63', 'W'], [], []]
# 3
# 3
# ['ANA', 'ANA', 'ANA']
# [['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80']]
#
# [<td align="left">39 M.BELESKEY(2)</td>, <td align="left">6 B.LOVEJOY(1)</td>, <td align="left">15 R.GETZLAF(3)</td>]
# [<td align="left">63 T.ENNIS(2)</td>, <td align="left">26 M.MOULSON(1)</td>, <td align="left">21 D.STAFFORD(3)</td>]
# [<td align="left">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="right" width="15">19</td>
# <td> </td>
# <td> </td>
# <td>P.MAROON</td>
# </tr>
# </table>
# </td>, <td align="left">Tripping</td>]
# [5]
# evenGoalsNumber
# [<td align="left">10 C.PERRY(4)</td>, <td align="left">39 M.BELESKEY(2)</td>, <td align="left">63 T.ENNIS(2)</td>]
# ['10', '39', '63']
# ['19', '6', '26']
# ['45', '15', '21']
# ['ANA', 'ANA', 'BUF']
# ['38', '38']
# ['47', '4']
# ['33', '33']
# ['ANA', 'ANA', 'ANA']
# [2]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-212-497b55424a2f> in <module>()
#     307
#     308 for y in range(0,len(evenGoalTeam)):
# --> 309     goalEven[y].append(evenGoalsNumber[y])
#     310     fstAssistEven[y].append(evenFstNumber[y])
#     311     sndAssistEven[y].append(evenSndNumber[y])
#
# IndexError: list index out of range

# %%
import json
import unicodedata
import numpy as np
import networkx as nx
import requests
from pattern import web
import matplotlib.pyplot as plt

# set some nicer defaults for matplotlib
from matplotlib import rcParams

def get_poll_xml1(poll_id):
    url = "http://www.nhl.com/scores/htmlreports/20142015/GS0%i.HTM" % int(poll_id)
    return requests.get(url).text

from bs4 import BeautifulSoup
soup = BeautifulSoup(get_poll_xml1(20036))
# soup

result1= soup.find_all("tr", attrs={"class":"oddColor"} )

result2=[elem.find_all("td", attrs={"align":"left"} ) for elem in result1]

resultEven= soup.find_all("tr", attrs={"class":"evenColor"} )

resultEven=[elem.find_all("td", attrs={"align":"left"} ) for elem in resultEven]

result3= soup.find_all("td", attrs={"align":"center", "style":"font-size: 40px;font-weight:bold"} )

totalGoals=sum([int(elem.text.strip()) for elem in result3])

if totalGoals%2==0:
    ODDGoals=totalGoals/2
    EVENGoals=totalGoals/2
else:
    ODDGoals=totalGoals/2+1
    EVENGoals=totalGoals/2
        
oddGoals=[]
oddFstAssists=[]
oddSndAssists=[]
oddarrayFailure=[]
for x in range(0,ODDGoals):
    if len(result2[x])==3:
        oddGoals.append(result2[x][0])
        oddFstAssists.append(result2[x][1])
        oddSndAssists.append(result2[x][2])
    else:
        oddarrayFailure.append(x)
        
evenGoals=[]
evenFstAssists=[]
evenSndAssists=[]    
evenarrayFailure=[]
for x in range(0,EVENGoals):
#     print "Test"
#     print 
    if len(resultEven[x])==3:
        evenGoals.append(resultEven[x][0])
#         print resultEven[x][1]
        evenFstAssists.append(resultEven[x][1])
        evenSndAssists.append(resultEven[x][2])
    else:
        evenarrayFailure.append(x)
#     else:
#         evenGoals.append(resultEven[x][0])
# #         print resultEven[x][1]
#         evenFstAssists.append(resultEven[x][1])
#         evenSndAssists.append()



resultplayers=soup.find_all("font", attrs={"style":"cursor:hand;"} )

tds=soup.find_all("td" )[1:]
tds=[str(elem) for elem in tds]

count=[]
tds2=[]

for x in range(0,len(tds)):
    if "font style=" in tds[x]:
        count.append(tds[x].count ("font style="))
        tds2.append(tds[x])
print tds2[2]
   
indices = [i for i, x in enumerate(tds2[2]) if x == ","]
print tds2[2]
temp=[]
for x in range(0,len(indices)):
    if x==0:
        temp.append(tds2[2][:indices[0]])
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x!=len(indices)-1:
        temp.append(tds2[2][indices[x]:indices[x+1]])
    elif x==len(indices)-1:
        temp.append(tds2[2][indices[x]:len(tds2[2])])

temp[0]=temp[0].replace("<td>", "")
print temp

print temp
for x in range(0,len(temp)):
    temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
    temp[x]=temp[x][0:(temp[x].index("<"))] 
arrayTemp=[]

indices = []

arrayTemp=[]
for y in range(1,len(tds2)):
    temp=[]
    indices = [i for i, x in enumerate(tds2[y]) if x == ","]
#     print tds2[y]
#     print indices
    for x in range(0,len(indices)):
        if x==0:
            temp.append(tds2[y][:indices[0]])
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x!=len(indices)-1:
            temp.append(tds2[y][indices[x]:indices[x+1]])
        elif x==len(indices)-1:
            temp.append(tds2[y][indices[x]:len(tds2[y])])
    print y
    print temp
    if temp!=[]:
        temp[0]=temp[0].replace("<td>", "")
#     print y
#     print temp
    for x in range(0,len(temp)):
        temp[x]=temp[x][(temp[x].index(">")+1):len(temp[x])]
        temp[x]=temp[x][0:(temp[x].index("<"))]
    arrayTemp.append(temp)
    
    

resultTeam=[elem.find_all("td", attrs={"align":"left","class":"heading + bborder"} ) for elem in soup]
homeTeam=resultTeam[0][3].text.strip()[:resultTeam[0][3].text.strip().index(" ")]
awayTeam=resultTeam[0][4].text.strip()[:resultTeam[0][4].text.strip().index(" ")]
resultTeam1= soup.find_all("tr", attrs={"class":"oddColor"} )
resultTeam2=[elem.find_all("td", attrs={"align":"center"} ) for elem in resultTeam1]

result1TeamEven= soup.find_all("tr", attrs={"class":"evenColor"} )
result2TeamEven=[elem.find_all("td", attrs={"align":"center"} ) for elem in result1TeamEven]
oddGoalTeam=[]
evenGoalTeam=[]
print "EVENGoals"
print ODDGoals
print EVENGoals
print arrayTemp
print "evenarrayFailure"
print evenarrayFailure
# oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
print indicesloc

print arrayTemp

for x in range(0,ODDGoals):
    if x  not in oddarrayFailure:
        oddGoalTeam.append(str(resultTeam2[x][4].text.strip()))
print evenarrayFailure
for x in range(0,EVENGoals):
    print x
    if x not in evenarrayFailure:
        print x
        evenGoalTeam.append(str(result2TeamEven[x][4].text.strip()))

indicesloc = [i for i, x in enumerate(arrayTemp) if x == []]
# print arrayTemp.index([])
print indicesloc 
# indicesloc=[]
indicesloc= [ elem/2  for elem in indicesloc if elem%2==0]
print "result2TeamEven[indicesloc[0]]"
print indicesloc
print result2TeamEven[0]
print result2TeamEven[1]
print result2TeamEven[2]
print result2TeamEven[3]
print result2TeamEven[4]
print result2TeamEven[5]
print "result2TeamEven[indicesloc[0]/2]"
# print result2TeamEven[indicesloc[0]/2]

# print result2TeamEven

print result2TeamEven[indicesloc[0]]
for x in range(0,len(indicesloc)):
    print x
    if indicesloc[x]%2==1 and indicesloc[x]!=totalGoals-1:
        evenGoalTeam.append((str(result2TeamEven[indicesloc[x]/2][4].text.strip())))
    elif indicesloc[x]%2==0 and indicesloc[x]!=totalGoals-1:
        oddGoalTeam.append((str(resultTeam2[indicesloc[x]/2][4].text.strip())))
        
oddArrayTemp=[]
evenArrayTemp=[]
for y in range(0,len(arrayTemp)):
    if y%4==1:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==0:
        oddArrayTemp.append(arrayTemp[y]) 
    elif y%4==2:
        evenArrayTemp.append(arrayTemp[y]) 
    elif y%4==3:
        evenArrayTemp.append(arrayTemp[y])
print "oddArrayTemp"   
# print arrayTemp.index([])


for y in range(0,len(oddArrayTemp)/2):
    if oddGoalTeam[y]==homeTeam:
        oddArrayTemp[2*y].append("W")
        oddArrayTemp[2*y+1].append("L")
    else:
        oddArrayTemp[2*y].append("L")
        oddArrayTemp[2*y+1].append("W")
print evenArrayTemp
print evenGoalTeam
print evenarrayFailure
print len(evenArrayTemp)
print arrayTemp
print len(evenArrayTemp)/2
print len(evenGoalTeam)
print evenGoalTeam
evenArrayTemp=filter(lambda a: a != [], evenArrayTemp)
# evenArrayTemp.remove([])
print evenArrayTemp
for y in range(0,len(evenArrayTemp)/2):
#     print y
    if evenGoalTeam[y]==homeTeam:
        evenArrayTemp[2*y].append("W")
        evenArrayTemp[2*y+1].append("L")
    else:
        evenArrayTemp[2*y].append("L")
        evenArrayTemp[2*y+1].append("W")

print 
print result2[1]
print result2[2]
print result2[3]
print indicesloc
for x in range(0,len(indicesloc)):
#     print x
    if indicesloc[x]%2==1 and indicesloc[x]!=totalGoals-1:
#         evenGoalTeam.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
        evenGoals.append(result2[EVENGoals][0])
        evenFstAssists.append(result2[EVENGoals][1])
        evenSndAssists.append(result2[EVENGoals][2])
    elif indicesloc[x]%2==0 and indicesloc[x]!=totalGoals-1:
#         oddGoalTeam.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        oddGoals.append(result2[ODDGoals][0])
        oddFstAssists.append(result2[ODDGoals][1])
        oddSndAssists.append(result2[ODDGoals][2])
        
# oddGoals.append(result2[ODDGoals][0])
# oddFstAssists.append(result2[ODDGoals][1])
# oddSndAssists.append(result2[ODDGoals][2])

oddGoalsNumber= [str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddGoals]
oddFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddFstAssists]
oddSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in oddSndAssists]
evenGoalsNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenGoals]
evenFstNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenFstAssists]
evenSndNumber=[str(elem.text.strip())[0:str(elem.text.strip()).index(" ")] if " " in str(elem.text.strip()) else str(elem.text.strip()) for elem in evenSndAssists ]
print "evenGoalsNumber"
print oddGoals
# for x in range(0,len(indicesloc)):
#     print x
#     if indicesloc[x]%2==0:
#         evenGoalsNumber.append((str(result2TeamEven[indicesloc[x]][4].text.strip())))
#     else:
#         oddGoalsNumber.append((str(resultTeam2[indicesloc[x]][4].text.strip())))
        
goalOdd = []
fstAssistOdd = []
sndAssistOdd = []

for y in range(0,len(oddGoalTeam)):
    goalOdd.append([])
    fstAssistOdd.append([])
    sndAssistOdd.append([])
print oddGoalsNumber
print oddFstNumber
print oddSndNumber
print oddGoalTeam
for y in range(0,len(oddGoalTeam)):
    goalOdd[y].append(oddGoalsNumber[y])
    fstAssistOdd[y].append(oddFstNumber[y])
    sndAssistOdd[y].append(oddSndNumber[y])
    
goalEven = []
fstAssistEven = []
sndAssistEven = []

for y in range(0,len(evenGoalTeam)):
    goalEven.append([])
    fstAssistEven.append([])
    sndAssistEven.append([])

print evenGoalsNumber
print evenFstNumber
print evenSndNumber
print evenGoalTeam
print evenarrayFailure

for y in range(0,len(evenGoalTeam)):
    goalEven[y].append(evenGoalsNumber[y])
    fstAssistEven[y].append(evenFstNumber[y])
    sndAssistEven[y].append(evenSndNumber[y])


for y in range(0,len(goalEven)):
    if evenGoalTeam[y]==homeTeam:
        goalEven[y].insert(0,str(homeTeam))
        fstAssistEven[y].insert(0,str(homeTeam))
        sndAssistEven[y].insert(0,str(homeTeam))
    else:
        goalEven[y].insert(0,str(awayTeam))
        fstAssistEven[y].insert(0,str(awayTeam))
        sndAssistEven[y].insert(0,str(awayTeam))

print "goalEven"
print goalEven
print fstAssistEven
print sndAssistEven
for y in range(0,len(goalOdd)):
    if oddGoalTeam[y]==homeTeam:
        goalOdd[y].insert(0,str(homeTeam))
        fstAssistOdd[y].insert(0,str(homeTeam))
        sndAssistOdd[y].insert(0,str(homeTeam))
    else:
        goalOdd[y].insert(0,str(awayTeam))
        fstAssistOdd[y].insert(0,str(awayTeam))
        sndAssistOdd[y].insert(0,str(awayTeam))

print "goalOdd"
print goalOdd
print fstAssistOdd
print sndAssistOdd



print goalEven+goalOdd
print fstAssistEven+fstAssistOdd
print sndAssistEven+sndAssistOdd
# Out:
# <td>
# <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>, <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>, <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>, <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>, <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>
# </td>
# <td>
# <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>, <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>, <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>, <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>, <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>
# </td>
# ['\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# ['\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 1
# ['<td>\n<font style="cursor:hand;" title="Right Wing - COREY PERRY">10</font>', ', <font style="cursor:hand;" title="Center - RYAN GETZLAF">15</font>', ', <font style="cursor:hand;" title="Center - RYAN KESLER">17</font>', ', <font style="cursor:hand;" title="Left Wing - PATRICK MAROON">19</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Defense - SAMI VATANEN">45</font>\n</td>']
# 2
# ['<td>\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 3
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Right Wing - DEVANTE SMITH-PELLY">12</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Right Wing - JAKOB SILFVERBERG">33</font>', ', <font style="cursor:hand;" title="Center - WILLIAM KARLSSON">38</font>', ', <font style="cursor:hand;" title="Defense - HAMPUS LINDHOLM">47</font>\n</td>']
# 4
# ['<td>\n<font style="cursor:hand;" title="Defense - JOSH GORGES">4</font>', ', <font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Right Wing - DREW STAFFORD">21</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - TYLER MYERS">57</font>\n</td>']
# 5
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Defense - BEN LOVEJOY">6</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Center - RYAN GETZLAF">15</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Left Wing - MATT BELESKEY">39</font>\n</td>']
# 6
# ['<td>\n<font style="cursor:hand;" title="Center - CODY MCCORMICK">8</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - ANDREJ MESZAROS">41</font>', ', <font style="cursor:hand;" title="Left Wing - NICOLAS DESLAURIERS">44</font>', ', <font style="cursor:hand;" title="Defense - ANDRE BENOIT">61</font>', ', <font style="cursor:hand;" title="Center - BRIAN FLYNN">65</font>\n</td>']
# 7
# ['<td>\n<font style="cursor:hand;" title="Defense - CAM FOWLER">4</font>', ', <font style="cursor:hand;" title="Defense - BEN LOVEJOY">6</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Right Wing - JAKOB SILFVERBERG">33</font>', ', <font style="cursor:hand;" title="Center - WILLIAM KARLSSON">38</font>\n</td>']
# 8
# ['<td>\n<font style="cursor:hand;" title="Defense - MIKE WEBER">6</font>', ', <font style="cursor:hand;" title="Center - CODY HODGSON">19</font>', ', <font style="cursor:hand;" title="Center - ZEMGUS GIRGENSONS">28</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - RASMUS RISTOLAINEN">55</font>', ', <font style="cursor:hand;" title="Right Wing - CHRIS STEWART">80</font>\n</td>']
# 9
# ['<td>\n<font style="cursor:hand;" title="Defense - CLAYTON STONER">3</font>', ', <font style="cursor:hand;" title="Center - ANDREW COGLIANO">7</font>', ', <font style="cursor:hand;" title="Right Wing - TIM JACKMAN">18</font>', ', <font style="cursor:hand;" title="Goalie - FREDERIK ANDERSEN">31</font>', ', <font style="cursor:hand;" title="Center - NATE THOMPSON">44</font>', ', <font style="cursor:hand;" title="Defense - SAMI VATANEN">45</font>\n</td>']
# 10
# ['<td>\n<font style="cursor:hand;" title="Defense - JOSH GORGES">4</font>', ', <font style="cursor:hand;" title="Right Wing - DREW STAFFORD">21</font>', ', <font style="cursor:hand;" title="Left Wing - MATT MOULSON">26</font>', ', <font style="cursor:hand;" title="Goalie - MICHAL NEUVIRTH">34</font>', ', <font style="cursor:hand;" title="Defense - TYLER MYERS">57</font>', ', <font style="cursor:hand;" title="Center - TYLER ENNIS">63</font>\n</td>']
# 11
# []
# 12
# []
# EVENGoals
# 3
# 3
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63'], [], []]
# evenarrayFailure
# [2]
# [5]
# [['10', '15', '17', '19', '31', '45'], ['6', '8', '34', '61', '65'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39'], ['8', '34', '41', '44', '61', '65'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45'], ['4', '21', '26', '34', '57', '63'], [], []]
# [2]
# 0
# 0
# 1
# 1
# 2
# [10, 11]
# result2TeamEven[indicesloc[0]]
# [5]
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">8:15</td>, <td align="center">EV</td>, <td align="center">ANA</td>]
# [<td align="center">4</td>, <td align="center">3</td>, <td align="center">3:14</td>, <td align="center">EV</td>, <td align="center">ANA</td>]
# [<td align="center">6</td>, <td align="center">3</td>, <td align="center">12:25</td>, <td align="center">EV-PS</td>, <td align="center">ANA</td>]
# [<td align="center">2</td>, <td align="center">2</td>, <td align="center">0:12</td>, <td align="center">2</td>]
# [<td align="center">4</td>, <td align="center">2</td>, <td align="center">20:00</td>, <td align="center">2</td>]
# [<td align="center">2</td>, <td align="center">1</td>, <td align="center">3:38</td>, <td align="center">2</td>]
# result2TeamEven[indicesloc[0]/2]
# [<td align="center">2</td>, <td align="center">1</td>, <td align="center">3:38</td>, <td align="center">2</td>]
# 0
# oddArrayTemp
# [['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], [], []]
# ['ANA', 'ANA']
# [2]
# 6
# [['10', '15', '17', '19', '31', '45', 'W'], ['6', '8', '34', '61', '65', 'L'], ['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '15', '31', '39', 'W'], ['8', '34', '41', '44', '61', '65', 'L'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80'], ['3', '7', '18', '31', '44', '45', 'L'], ['4', '21', '26', '34', '57', '63', 'W'], [], []]
# 3
# 2
# ['ANA', 'ANA']
# [['4', '12', '31', '33', '38', '47'], ['4', '6', '8', '21', '34', '57'], ['4', '6', '7', '31', '33', '38'], ['6', '19', '28', '34', '55', '80']]
#
# [<td align="left">39 M.BELESKEY(2)</td>, <td align="left">6 B.LOVEJOY(1)</td>, <td align="left">15 R.GETZLAF(3)</td>]
# [<td align="left">63 T.ENNIS(2)</td>, <td align="left">26 M.MOULSON(1)</td>, <td align="left">21 D.STAFFORD(3)</td>]
# [<td align="left">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="right" width="15">19</td>
# <td> </td>
# <td> </td>
# <td>P.MAROON</td>
# </tr>
# </table>
# </td>, <td align="left">Tripping</td>]
# [5]
# evenGoalsNumber
# [<td align="left">10 C.PERRY(4)</td>, <td align="left">39 M.BELESKEY(2)</td>, <td align="left">63 T.ENNIS(2)</td>]
# ['10', '39', '63']
# ['19', '6', '26']
# ['45', '15', '21']
# ['ANA', 'ANA', 'BUF']
# ['38', '38']
# ['47', '4']
# ['33', '33']
# ['ANA', 'ANA']
# [2]
# goalEven
# [['ANA', '38'], ['ANA', '38']]
# [['ANA', '47'], ['ANA', '4']]
# [['ANA', '33'], ['ANA', '33']]
# goalOdd
# [['ANA', '10'], ['ANA', '39'], ['BUF', '63']]
# [['ANA', '19'], ['ANA', '6'], ['BUF', '26']]
# [['ANA', '45'], ['ANA', '15'], ['BUF', '21']]
# [['ANA', '38'], ['ANA', '38'], ['ANA', '10'], ['ANA', '39'], ['BUF', '63']]
# [['ANA', '47'], ['ANA', '4'], ['ANA', '19'], ['ANA', '6'], ['BUF', '26']]
# [['ANA', '33'], ['ANA', '33'], ['ANA', '45'], ['ANA', '15'], ['BUF', '21']]
