# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
csv_list=[]
for i in range(1996,1997):
    filename="./PlayerData/"+str(i)+"/posession"
    filename2=[]
    for elem in os.listdir(filename):
        filename2.append(filename+'/'+elem)
    csv_list.append(os.listdir(filename))
    print os.listdir(filename)
# Out:
# ['adamscr01_pos_.csv', 'aitkejo01_pos_.csv', 'allench01_pos_.csv', 'ashamar01_pos_.csv', 'babenyu01_pos_.csv', 'beginst01_pos_.csv', 'belaner01_pos_.csv', 'bennja01_pos_.csv', 'berenbu01_pos_.csv', 'bouleje01_pos_.csv', 'boumejo01_pos_.csv', 'bourqra01_pos_.csv', 'bradlma01_pos_.csv', 'brierda01_pos_.csv', 'brigltr01_pos_.csv', 'brodema01_pos_.csv', 'bulisja01_pos_.csv', 'charazd01_pos_.csv', 'chrisry01_pos_.csv', 'cierniv01_pos_.csv', 'cisarma01_pos_.csv', 'clarkbr01_pos_.csv', 'corsoda01_pos_.csv', 'cullema01_pos_.csv', 'dackean01_pos_.csv', 'dagenpi01_pos_.csv', 'delisxa01_pos_.csv', 'descoma01_pos_.csv', 'deverbo01_pos_.csv', 'dumonjp01_pos_.csv', 'dwyergo01_pos_.csv', 'eschero01_pos_.csv', 'fochtda01_pos_.csv', 'garnety01_pos_.csv', 'garonma01_pos_.csv', 'getzlry01_pos_.csv', 'goldmer01_pos_.csv', 'goneada01_pos_.csv', 'greenjo01_pos_.csv', 'gretzwa01_pos_.csv', 'hajtch01_pos_.csv', 'higgima01_pos_.csv', 'hinotda01_pos_.csv', 'holdejo01_pos_.csv', 'hossama01_pos_.csv', 'howego01
# ...

# %%
df_adamscr01_pos=pd.read_csv('./PlayerData/1996/posession/adamscr01_pos_.csv',index_col=0)
df_aitkejo01_pos=pd.read_csv('./PlayerData/1996/posession/aitkejo01_pos_.csv',index_col=0)
df_allench01_pos=pd.read_csv('./PlayerData/1996/posession/allench01_pos_.csv',index_col=0)
df_ashamar01_pos=pd.read_csv('./PlayerData/1996/posession/ashamar01_pos_.csv',index_col=0)
df_babenyu01_pos=pd.read_csv('./PlayerData/1996/posession/babenyu01_pos_.csv',index_col=0)
df_beginst01_pos=pd.read_csv('./PlayerData/1996/posession/beginst01_pos_.csv',index_col=0)
df_belaner01_pos=pd.read_csv('./PlayerData/1996/posession/belaner01_pos_.csv',index_col=0)
df_berenbu01_pos=pd.read_csv('./PlayerData/1996/posession/berenbu01_pos_.csv',index_col=0)
df_bouleje01_pos=pd.read_csv('./PlayerData/1996/posession/bouleje01_pos_.csv',index_col=0)
df_boumejo01_pos=pd.read_csv('./PlayerData/1996/posession/boumejo01_pos_.csv',index_col=0)
df_bradlma01_pos=pd.read_csv('./PlayerData/1996/posession/bradlma01_pos_.csv',index_col=0)
df_brierda01_pos=pd.read_csv('./PlayerData/1996/posession/brierda01_pos_.csv',index_col=0)
df_brigltr01_pos=pd.read_csv('./PlayerData/1996/posession/brigltr01_pos_.csv',index_col=0)
df_bulisja01_pos=pd.read_csv('./PlayerData/1996/posession/bulisja01_pos_.csv',index_col=0)
df_charazd01_pos=pd.read_csv('./PlayerData/1996/posession/charazd01_pos_.csv',index_col=0)
df_chrisry01_pos=pd.read_csv('./PlayerData/1996/posession/chrisry01_pos_.csv',index_col=0)
df_cierniv01_pos=pd.read_csv('./PlayerData/1996/posession/cierniv01_pos_.csv',index_col=0)
df_cisarma01_pos=pd.read_csv('./PlayerData/1996/posession/cisarma01_pos_.csv',index_col=0)
df_clarkbr01_pos=pd.read_csv('./PlayerData/1996/posession/clarkbr01_pos_.csv',index_col=0)
df_corsoda01_pos=pd.read_csv('./PlayerData/1996/posession/corsoda01_pos_.csv',index_col=0)

df_cullema01_pos=pd.read_csv('./PlayerData/1996/posession/cullema01_pos_.csv',index_col=0)
df_dackean01_pos=pd.read_csv('./PlayerData/1996/posession/dackean01_pos_.csv',index_col=0)
df_dagenpi01_pos=pd.read_csv('./PlayerData/1996/posession/dagenpi01_pos_.csv',index_col=0)
df_delisxa01_pos=pd.read_csv('./PlayerData/1996/posession/delisxa01_pos_.csv',index_col=0)

df_descoma01_pos=pd.read_csv('./PlayerData/1996/posession/descoma01_pos_.csv',index_col=0)
df_deverbo01_pos=pd.read_csv('./PlayerData/1996/posession/deverbo01_pos_.csv',index_col=0)
df_dumonjp01_pos=pd.read_csv('./PlayerData/1996/posession/dumonjp01_pos_.csv',index_col=0)
df_dwyergo01_pos=pd.read_csv('./PlayerData/1996/posession/dwyergo01_pos_.csv',index_col=0)
df_eschero01_pos=pd.read_csv('./PlayerData/1996/posession/eschero01_pos_.csv',index_col=0)

df_fochtda01_pos=pd.read_csv('./PlayerData/1996/posession/fochtda01_pos_.csv',index_col=0)
df_garnety01_pos=pd.read_csv('./PlayerData/1996/posession/garnety01_pos_.csv',index_col=0)
df_garonma01_pos=pd.read_csv('./PlayerData/1996/posession/garonma01_pos_.csv',index_col=0)
df_goldmer01_pos=pd.read_csv('./PlayerData/1996/posession/goldmer01_pos_.csv',index_col=0)
df_goneada01_pos=pd.read_csv('./PlayerData/1996/posession/goneada01_pos_.csv',index_col=0)
df_greenjo01_pos=pd.read_csv('./PlayerData/1996/posession/greenjo01_pos_.csv',index_col=0)

df_hajtch01_pos=pd.read_csv('./PlayerData/1996/posession/hajtch01_pos_.csv',index_col=0)
df_higgima01_pos=pd.read_csv('./PlayerData/1996/posession/higgima01_pos_.csv',index_col=0)
df_hinotda01_pos=pd.read_csv('./PlayerData/1996/posession/hinotda01_pos_.csv',index_col=0)
df_holdejo01_pos=pd.read_csv('./PlayerData/1996/posession/holdejo01_pos_.csv',index_col=0)
df_jackmri01_pos=pd.read_csv('./PlayerData/1996/posession/jackmri01_pos_.csv',index_col=0)

df_kaberto01_pos=pd.read_csv('./PlayerData/1996/posession/kaberto01_pos_.csv',index_col=0)
df_kanebo01_pos=pd.read_csv('./PlayerData/1996/posession/kanebo01_pos_.csv',index_col=0)
df_komarze01_pos=pd.read_csv('./PlayerData/1996/posession/komarze01_pos_.csv',index_col=0)
df_korolev01_pos=pd.read_csv('./PlayerData/1996/posession/korolev01_pos_.csv',index_col=0)
df_kubinpa01_pos=pd.read_csv('./PlayerData/1996/posession/kubinpa01_pos_.csv',index_col=0)

df_kuznigr01_pos=pd.read_csv('./PlayerData/1996/posession/kuznigr01_pos_.csv',index_col=0)
df_kvashol01_pos=pd.read_csv('./PlayerData/1996/posession/kvashol01_pos_.csv',index_col=0)
df_kwiatjo01_pos=pd.read_csv('./PlayerData/1996/posession/kwiatjo01_pos_.csv',index_col=0)
df_lacouda01_pos=pd.read_csv('./PlayerData/1996/posession/lacouda01_pos_.csv',index_col=0)
df_larocma01_pos=pd.read_csv('./PlayerData/1996/posession/larocma01_pos_.csv',index_col=0)


df_larocmi02_pos=pd.read_csv('./PlayerData/1996/posession/larocmi02_pos_.csv',index_col=0)
df_letowtr01_pos=pd.read_csv('./PlayerData/1996/posession/letowtr01_pos_.csv',index_col=0)
df_lintnri01_pos=pd.read_csv('./PlayerData/1996/posession/lintnri01_pos_.csv',index_col=0)
df_lowre01_pos=pd.read_csv('./PlayerData/1996/posession/lowre01_pos_.csv',index_col=0)
df_lydmato01_pos=pd.read_csv('./PlayerData/1996/posession/lydmato01_pos_.csv',index_col=0)

df_macdocr01_pos=pd.read_csv('./PlayerData/1996/posession/macdocr01_pos_.csv',index_col=0)
df_melocer01_pos=pd.read_csv('./PlayerData/1996/posession/melocer01_pos_.csv',index_col=0)
df_mitchwi01_pos=pd.read_csv('./PlayerData/1996/posession/mitchwi01_pos_.csv',index_col=0)
df_morride01_pos=pd.read_csv('./PlayerData/1996/posession/morride01_pos_.csv',index_col=0)
df_niemian01_pos=pd.read_csv('./PlayerData/1996/posession/niemian01_pos_.csv',index_col=0)

df_nilsoma01_pos=pd.read_csv('./PlayerData/1996/posession/nilsoma01_pos_.csv',index_col=0)
df_nurmika01_pos=pd.read_csv('./PlayerData/1996/posession/nurmika01_pos_.csv',index_col=0)
df_pahlssa01_pos=pd.read_csv('./PlayerData/1996/posession/pahlssa01_pos_.csv',index_col=0)
df_parkesc01_pos=pd.read_csv('./PlayerData/1996/posession/parkesc01_pos_.csv',index_col=0)
df_parrima01_pos=pd.read_csv('./PlayerData/1996/posession/parrima01_pos_.csv',index_col=0)

df_paulje01_pos=pd.read_csv('./PlayerData/1996/posession/paulje01_pos_.csv',index_col=0)
df_petroro02_pos=pd.read_csv('./PlayerData/1996/posession/petroro02_pos_.csv',index_col=0)
df_phillch02_pos=pd.read_csv('./PlayerData/1996/posession/phillch02_pos_.csv',index_col=0)
df_pisanfe01_pos=pd.read_csv('./PlayerData/1996/posession/pisanfe01_pos_.csv',index_col=0)
df_podkoan01_pos=pd.read_csv('./PlayerData/1996/posession/podkoan01_pos_.csv',index_col=0)

df_posmyma01_pos=pd.read_csv('./PlayerData/1996/posession/posmyma01_pos_.csv',index_col=0)
df_potito01_pos=pd.read_csv('./PlayerData/1996/posession/potito01_pos_.csv',index_col=0)
df_rasmuer01_pos=pd.read_csv('./PlayerData/1996/posession/rasmuer01_pos_.csv',index_col=0)
df_ratchpe01_pos=pd.read_csv('./PlayerData/1996/posession/ratchpe01_pos_.csv',index_col=0)
df_reasoma01_pos=pd.read_csv('./PlayerData/1996/posession/reasoma01_pos_.csv',index_col=0)

df_royerre01_pos=pd.read_csv('./PlayerData/1996/posession/royerre01_pos_.csv',index_col=0)
df_rozsimi01_pos=pd.read_csv('./PlayerData/1996/posession/rozsimi01_pos_.csv',index_col=0)
df_saleiru01_pos=pd.read_csv('./PlayerData/1996/posession/saleiru01_pos_.csv',index_col=0)
df_salosa01_pos=pd.read_csv('./PlayerData/1996/posession/salosa01_pos_.csv',index_col=0)
df_saricco01_pos=pd.read_csv('./PlayerData/1996/posession/saricco01_pos_.csv',index_col=0)

df_shafrko01_pos=pd.read_csv('./PlayerData/1996/posession/shafrko01_pos_.csv',index_col=0)
df_simjo01_pos=pd.read_csv('./PlayerData/1996/posession/simjo01_pos_.csv',index_col=0)
df_skrbepa01_pos=pd.read_csv('./PlayerData/1996/posession/skrbepa01_pos_.csv',index_col=0)
df_sturmma01_pos=pd.read_csv('./PlayerData/1996/posession/sturmma01_pos_.csv',index_col=0)
df_sundiro01_pos=pd.read_csv('./PlayerData/1996/posession/sundiro01_pos_.csv',index_col=0)

df_svejkja01_pos=pd.read_csv('./PlayerData/1996/posession/svejkja01_pos_.csv',index_col=0)
df_tetarjo01_pos=pd.read_csv('./PlayerData/1996/posession/tetarjo01_pos_.csv',index_col=0)
df_tezikal01_pos=pd.read_csv('./PlayerData/1996/posession/tezikal01_pos_.csv',index_col=0)
df_vaiclu01_pos=pd.read_csv('./PlayerData/1996/posession/vaiclu01_pos_.csv',index_col=0)
df_valiqst01_pos=pd.read_csv('./PlayerData/1996/posession/valiqst01_pos_.csv',index_col=0)

df_volchal01_pos=pd.read_csv('./PlayerData/1996/posession/volchal01_pos_.csv',index_col=0)
df_wallije01_pos=pd.read_csv('./PlayerData/1996/posession/wallije01_pos_.csv',index_col=0)
df_wardla01_pos=pd.read_csv('./PlayerData/1996/posession/wardla01_pos_.csv',index_col=0)
df_whiteco01_pos=pd.read_csv('./PlayerData/1996/posession/whiteco01_pos_.csv',index_col=0)
df_whitftr01_pos=pd.read_csv('./PlayerData/1996/posession/whitftr01_pos_.csv',index_col=0)

df_willsbr01_pos=pd.read_csv('./PlayerData/1996/posession/willsbr01_pos_.csv',index_col=0)
df_yakusdm01_pos=pd.read_csv('./PlayerData/1996/posession/yakusdm01_pos_.csv',index_col=0)
df_zubruda01_pos=pd.read_csv('./PlayerData/1996/posession/zubruda01_pos_.csv',index_col=0)
df_zyuzian01_pos=pd.read_csv('./PlayerData/1996/posession/zyuzian01_pos_.csv',index_col=0)

# %%
df_adamscr01_pos['name']='adamscr01'
df_aitkejo01_pos['name']='aitkejo01'
df_allench01_pos['name']='allench01'
df_ashamar01_pos['name']='ashamar01'
df_babenyu01_pos['name']='babenyu01'

df_beginst01_pos['name']='beginst01'
df_belaner01_pos['name']='belaner01'
df_berenbu01_pos['name']='berenbu01'
df_bouleje01_pos['name']='bouleje01'
df_boumejo01_pos['name']='boumejo01'
df_bradlma01_pos['name']='bradlma01'
df_brierda01_pos['name']='brierda01'
df_brigltr01_pos['name']='brigltr01'
df_bulisja01_pos['name']='bulisja01'
df_charazd01_pos['name']='charazd01'
df_chrisry01_pos['name']='chrisry01'
df_cierniv01_pos['name']='cierniv01'
df_cisarma01_pos['name']='cisarma01'
df_clarkbr01_pos['name']='clarkbr01'
df_corsoda01_pos['name']='corsoda01'

df_cullema01_pos['name']='cullema01'
df_dackean01_pos['name']='dackean01'
df_dagenpi01_pos['name']='dagenpi01'
df_delisxa01_pos['name']='delisxa01'

df_descoma01_pos['name']='descoma01'
df_deverbo01_pos['name']='deverbo01'
df_dumonjp01_pos['name']='dumonjp01'
df_dwyergo01_pos['name']='dwyergo01'
df_eschero01_pos['name']='eschero01'

df_fochtda01_pos['name']='fochtda01'
df_garnety01_pos['name']='garnety01'
df_garonma01_pos['name']='garonma01'
df_goldmer01_pos['name']='goldmer01'
df_goneada01_pos['name']='goneada01'
df_greenjo01_pos['name']='greenjo01'

df_hajtch01_pos['name']='hajtch01'
df_higgima01_pos['name']='higgima01'
df_hinotda01_pos['name']='hinotda01'
df_holdejo01_pos['name']='holdejo01'
df_jackmri01_pos['name']='jackmri01'

df_kaberto01_pos['name']='kaberto01'
df_kanebo01_pos['name']='kanebo01'
df_komarze01_pos['name']='komarze01'
df_korolev01_pos['name']='korolev01'
df_kubinpa01_pos['name']='kubinpa01'

df_kuznigr01_pos['name']='kuznigr01'
df_kvashol01_pos['name']='kvashol01'
df_kwiatjo01_pos['name']='kwiatjo01'
df_lacouda01_pos['name']='lacouda01'
df_larocma01_pos['name']='larocma01'


df_larocmi02_pos['name']='larocmi02'
df_letowtr01_pos['name']='letowtr01'
df_lintnri01_pos['name']='lintnri01'
df_lowre01_pos['name']='lowre01'
df_lydmato01_pos['name']='lydmato01'

df_macdocr01_pos['name']='macdocr01'
df_melocer01_pos['name']='melocer01'
df_mitchwi01_pos['name']='mitchwi01'
df_morride01_pos['name']='morride01'
df_niemian01_pos['name']='niemian01'

df_nilsoma01_pos['name']='nilsoma01'
df_nurmika01_pos['name']='nurmika01'
df_pahlssa01_pos['name']='pahlssa01'
df_parkesc01_pos['name']='parkesc01'
df_parrima01_pos['name']='parrima01'

df_paulje01_pos['name']='paulje01'
df_petroro02_pos['name']='petroro02'
df_phillch02_pos['name']='phillch02'
df_pisanfe01_pos['name']='pisanfe01'
df_podkoan01_pos['name']='podkoan01'

df_posmyma01_pos['name']='posmyma01'
df_potito01_pos['name']='potito01'
df_rasmuer01_pos['name']='rasmuer01'
df_ratchpe01_pos['name']='ratchpe01'
df_reasoma01_pos['name']='reasoma01'

df_royerre01_pos['name']='royerre01'
df_rozsimi01_pos['name']='rozsimi01'
df_saleiru01_pos['name']='saleiru01'
df_salosa01_pos['name']='salosa01'
df_saricco01_pos['name']='saricco01'

df_shafrko01_pos['name']='shafrko01'
df_simjo01_pos['name']='simjo01'
df_skrbepa01_pos['name']='skrbepa01'
df_sturmma01_pos['name']='sturmma01'
df_sundiro01_pos['name']='sundiro01'

df_svejkja01_pos['name']='svejkja01'
df_tetarjo01_pos['name']='tetarjo01'
df_tezikal01_pos['name']='tezikal01'
df_vaiclu01_pos['name']='vaiclu01'
df_valiqst01_pos['name']='valiqst01'

df_volchal01_pos['name']='volchal01'
df_wallije01_pos['name']='wallije01'
df_wardla01_pos['name']='wardla01'
df_whiteco01_pos['name']='whiteco01'
df_whitftr01_pos['name']='whitftr01'

df_willsbr01_pos['name']='willsbr01'
df_yakusdm01_pos['name']='yakusdm01'
df_zubruda01_pos['name']='zubruda01'
df_zyuzian01_pos['name']='zyuzian01'

# %%
pos_frames = [df_adamscr01_pos,
df_aitkejo01_pos,
df_allench01_pos,
df_ashamar01_pos,
df_babenyu01_pos,

df_beginst01_pos,
df_belaner01_pos,
df_berenbu01_pos,
df_bouleje01_pos,
df_boumejo01_pos,
df_bradlma01_pos,
df_brierda01_pos,
df_brigltr01_pos,
df_bulisja01_pos,
df_charazd01_pos,
df_chrisry01_pos,
df_cierniv01_pos,
df_cisarma01_pos,
df_clarkbr01_pos,
df_corsoda01_pos,

df_cullema01_pos,
df_dackean01_pos,
df_dagenpi01_pos,
df_delisxa01_pos,

df_descoma01_pos,
df_deverbo01_pos,
df_dumonjp01_pos,
df_dwyergo01_pos,
df_eschero01_pos,

df_fochtda01_pos,
df_garnety01_pos,
df_garonma01_pos,
df_goldmer01_pos,
df_goneada01_pos,
df_greenjo01_pos,

df_hajtch01_pos,
df_higgima01_pos,
df_hinotda01_pos,
df_holdejo01_pos,
df_jackmri01_pos,

df_kaberto01_pos,
df_kanebo01_pos,
df_komarze01_pos,
df_korolev01_pos,
df_kubinpa01_pos,

df_kuznigr01_pos,
df_kvashol01_pos,
df_kwiatjo01_pos,
df_lacouda01_pos,
df_larocma01_pos,


df_larocmi02_pos,
df_letowtr01_pos,
df_lintnri01_pos,
df_lowre01_pos,
df_lydmato01_pos,

df_macdocr01_pos,
df_melocer01_pos,
df_mitchwi01_pos,
df_morride01_pos,
df_niemian01_pos,

df_nilsoma01_pos,
df_nurmika01_pos,
df_pahlssa01_pos,
df_parkesc01_pos,
df_parrima01_pos,

df_paulje01_pos,
df_petroro02_pos,
df_phillch02_pos,
df_pisanfe01_pos,
df_podkoan01_pos,


df_posmyma01_pos,
df_potito01_pos,
df_rasmuer01_pos,
df_ratchpe01_pos,
df_reasoma01_pos,

df_royerre01_pos,
df_rozsimi01_pos,
df_saleiru01_pos,
df_salosa01_pos,
df_saricco01_pos,

df_shafrko01_pos,
df_simjo01_pos,
df_skrbepa01_pos,
df_sturmma01_pos,
df_sundiro01_pos,

df_svejkja01_pos,
df_tetarjo01_pos,
df_tezikal01_pos,
df_vaiclu01_pos,
df_valiqst01_pos,

df_volchal01_pos,
df_wallije01_pos,
df_wardla01_pos,
df_whiteco01_pos,
df_whitftr01_pos,

df_willsbr01_pos,
df_yakusdm01_pos,
df_zubruda01_pos,
df_zyuzian01_pos]

# %%
result_pos = pd.concat(pos_frames)

# %%
result_pos
# Out:
#      season  TOT  age  corsi_for  corsi_against  corsi_pct corsi_rel_pct  \
# 1   2007-08  TOT   30        446            550       44.8          -9.2
# 2   2007-08  CAR   30        273            280       49.4          -5.3
# 3   2007-08  CHI   30        173            270       39.1           -13
# 4   2008-09  TOT   31        306            274       52.8          -3.2
# 5   2008-09  CHI   31        239            240       49.9          -5.7
# 6   2008-09  PIT   31         67             34       66.3           9.5
# 7   2009-10  PIT   32        511            604       45.8          -9.2
# 8   2010-11  PIT   33        565            647       46.6          -7.8
# 9   2011-12  PIT   34        530            545       49.3          -6.6
# 10  2012-13  PIT   35        277            381       42.1          -8.8
# 11  2013-14  PIT   36        489            714       40.6           -10
# 12  2014-15  PIT   37        363            396       47.8          -6.3
# ...

# %%
len(pos_frames)
# Out:
# 99

# %%
#df_adamscr01_strd

# %%
df_adamscr01_strd=pd.read_csv('./PlayerData/1996/standard/adamscr01_strd_.csv',index_col=0)
df_aitkejo01_strd=pd.read_csv('./PlayerData/1996/standard/aitkejo01_strd_.csv',index_col=0)
df_allench01_strd=pd.read_csv('./PlayerData/1996/standard/allench01_strd_.csv',index_col=0)
df_ashamar01_strd=pd.read_csv('./PlayerData/1996/standard/ashamar01_strd_.csv',index_col=0)
df_babenyu01_strd=pd.read_csv('./PlayerData/1996/standard/babenyu01_strd_.csv',index_col=0)
df_beginst01_strd=pd.read_csv('./PlayerData/1996/standard/beginst01_strd_.csv',index_col=0)
df_belaner01_strd=pd.read_csv('./PlayerData/1996/standard/belaner01_strd_.csv',index_col=0)
df_berenbu01_strd=pd.read_csv('./PlayerData/1996/standard/berenbu01_strd_.csv',index_col=0)
df_bouleje01_strd=pd.read_csv('./PlayerData/1996/standard/bouleje01_strd_.csv',index_col=0)
df_boumejo01_strd=pd.read_csv('./PlayerData/1996/standard/boumejo01_strd_.csv',index_col=0)
df_bradlma01_strd=pd.read_csv('./PlayerData/1996/standard/bradlma01_strd_.csv',index_col=0)
df_brierda01_strd=pd.read_csv('./PlayerData/1996/standard/brierda01_strd_.csv',index_col=0)
df_brigltr01_strd=pd.read_csv('./PlayerData/1996/standard/brigltr01_strd_.csv',index_col=0)
df_bulisja01_strd=pd.read_csv('./PlayerData/1996/standard/bulisja01_strd_.csv',index_col=0)
df_charazd01_strd=pd.read_csv('./PlayerData/1996/standard/charazd01_strd_.csv',index_col=0)
df_chrisry01_strd=pd.read_csv('./PlayerData/1996/standard/chrisry01_strd_.csv',index_col=0)
df_cierniv01_strd=pd.read_csv('./PlayerData/1996/standard/cierniv01_strd_.csv',index_col=0)
df_cisarma01_strd=pd.read_csv('./PlayerData/1996/standard/cisarma01_strd_.csv',index_col=0)
df_clarkbr01_strd=pd.read_csv('./PlayerData/1996/standard/clarkbr01_strd_.csv',index_col=0)
df_corsoda01_strd=pd.read_csv('./PlayerData/1996/standard/corsoda01_strd_.csv',index_col=0)

df_cullema01_strd=pd.read_csv('./PlayerData/1996/standard/cullema01_strd_.csv',index_col=0)
df_dackean01_strd=pd.read_csv('./PlayerData/1996/standard/dackean01_strd_.csv',index_col=0)
df_dagenpi01_strd=pd.read_csv('./PlayerData/1996/standard/dagenpi01_strd_.csv',index_col=0)
df_delisxa01_strd=pd.read_csv('./PlayerData/1996/standard/delisxa01_strd_.csv',index_col=0)

df_descoma01_strd=pd.read_csv('./PlayerData/1996/standard/descoma01_strd_.csv',index_col=0)
df_deverbo01_strd=pd.read_csv('./PlayerData/1996/standard/deverbo01_strd_.csv',index_col=0)
df_dumonjp01_strd=pd.read_csv('./PlayerData/1996/standard/dumonjp01_strd_.csv',index_col=0)
df_dwyergo01_strd=pd.read_csv('./PlayerData/1996/standard/dwyergo01_strd_.csv',index_col=0)
df_eschero01_strd=pd.read_csv('./PlayerData/1996/standard/eschero01_strd_.csv',index_col=0)

df_fochtda01_strd=pd.read_csv('./PlayerData/1996/standard/fochtda01_strd_.csv',index_col=0)
df_garnety01_strd=pd.read_csv('./PlayerData/1996/standard/garnety01_strd_.csv',index_col=0)
df_garonma01_strd=pd.read_csv('./PlayerData/1996/standard/garonma01_strd_.csv',index_col=0)
df_goldmer01_strd=pd.read_csv('./PlayerData/1996/standard/goldmer01_strd_.csv',index_col=0)
df_goneada01_strd=pd.read_csv('./PlayerData/1996/standard/goneada01_strd_.csv',index_col=0)
df_greenjo01_strd=pd.read_csv('./PlayerData/1996/standard/greenjo01_strd_.csv',index_col=0)

df_hajtch01_strd=pd.read_csv('./PlayerData/1996/standard/hajtch01_strd_.csv',index_col=0)
df_higgima01_strd=pd.read_csv('./PlayerData/1996/standard/higgima01_strd_.csv',index_col=0)
df_hinotda01_strd=pd.read_csv('./PlayerData/1996/standard/hinotda01_strd_.csv',index_col=0)
df_holdejo01_strd=pd.read_csv('./PlayerData/1996/standard/holdejo01_strd_.csv',index_col=0)
df_jackmri01_strd=pd.read_csv('./PlayerData/1996/standard/jackmri01_strd_.csv',index_col=0)

df_kaberto01_strd=pd.read_csv('./PlayerData/1996/standard/kaberto01_strd_.csv',index_col=0)
df_kanebo01_strd=pd.read_csv('./PlayerData/1996/standard/kanebo01_strd_.csv',index_col=0)
df_komarze01_strd=pd.read_csv('./PlayerData/1996/standard/komarze01_strd_.csv',index_col=0)
df_korolev01_strd=pd.read_csv('./PlayerData/1996/standard/korolev01_strd_.csv',index_col=0)
df_kubinpa01_strd=pd.read_csv('./PlayerData/1996/standard/kubinpa01_strd_.csv',index_col=0)

df_kuznigr01_strd=pd.read_csv('./PlayerData/1996/standard/kuznigr01_strd_.csv',index_col=0)
df_kvashol01_strd=pd.read_csv('./PlayerData/1996/standard/kvashol01_strd_.csv',index_col=0)
df_kwiatjo01_strd=pd.read_csv('./PlayerData/1996/standard/kwiatjo01_strd_.csv',index_col=0)
df_lacouda01_strd=pd.read_csv('./PlayerData/1996/standard/lacouda01_strd_.csv',index_col=0)
df_larocma01_strd=pd.read_csv('./PlayerData/1996/standard/larocma01_strd_.csv',index_col=0)


df_larocmi02_strd=pd.read_csv('./PlayerData/1996/standard/larocmi02_strd_.csv',index_col=0)
df_letowtr01_strd=pd.read_csv('./PlayerData/1996/standard/letowtr01_strd_.csv',index_col=0)
df_lintnri01_strd=pd.read_csv('./PlayerData/1996/standard/lintnri01_strd_.csv',index_col=0)
df_lowre01_strd=pd.read_csv('./PlayerData/1996/standard/lowre01_strd_.csv',index_col=0)
df_lydmato01_strd=pd.read_csv('./PlayerData/1996/standard/lydmato01_strd_.csv',index_col=0)

df_macdocr01_strd=pd.read_csv('./PlayerData/1996/standard/macdocr01_strd_.csv',index_col=0)
df_melocer01_strd=pd.read_csv('./PlayerData/1996/standard/melocer01_strd_.csv',index_col=0)
df_mitchwi01_strd=pd.read_csv('./PlayerData/1996/standard/mitchwi01_strd_.csv',index_col=0)
df_morride01_strd=pd.read_csv('./PlayerData/1996/standard/morride01_strd_.csv',index_col=0)
df_niemian01_strd=pd.read_csv('./PlayerData/1996/standard/niemian01_strd_.csv',index_col=0)

df_nilsoma01_strd=pd.read_csv('./PlayerData/1996/standard/nilsoma01_strd_.csv',index_col=0)
df_nurmika01_strd=pd.read_csv('./PlayerData/1996/standard/nurmika01_strd_.csv',index_col=0)
df_pahlssa01_strd=pd.read_csv('./PlayerData/1996/standard/pahlssa01_strd_.csv',index_col=0)
df_parkesc01_strd=pd.read_csv('./PlayerData/1996/standard/parkesc01_strd_.csv',index_col=0)
df_parrima01_strd=pd.read_csv('./PlayerData/1996/standard/parrima01_strd_.csv',index_col=0)

df_paulje01_strd=pd.read_csv('./PlayerData/1996/standard/paulje01_strd_.csv',index_col=0)
df_petroro02_strd=pd.read_csv('./PlayerData/1996/standard/petroro02_strd_.csv',index_col=0)
df_phillch02_strd=pd.read_csv('./PlayerData/1996/standard/phillch02_strd_.csv',index_col=0)
df_pisanfe01_strd=pd.read_csv('./PlayerData/1996/standard/pisanfe01_strd_.csv',index_col=0)
df_podkoan01_strd=pd.read_csv('./PlayerData/1996/standard/podkoan01_strd_.csv',index_col=0)

df_strdmyma01_strd=pd.read_csv('./PlayerData/1996/standard/posmyma01_strd_.csv',index_col=0)
df_potito01_strd=pd.read_csv('./PlayerData/1996/standard/potito01_strd_.csv',index_col=0)
df_rasmuer01_strd=pd.read_csv('./PlayerData/1996/standard/rasmuer01_strd_.csv',index_col=0)
df_ratchpe01_strd=pd.read_csv('./PlayerData/1996/standard/ratchpe01_strd_.csv',index_col=0)
df_reasoma01_strd=pd.read_csv('./PlayerData/1996/standard/reasoma01_strd_.csv',index_col=0)

df_royerre01_strd=pd.read_csv('./PlayerData/1996/standard/royerre01_strd_.csv',index_col=0)
df_rozsimi01_strd=pd.read_csv('./PlayerData/1996/standard/rozsimi01_strd_.csv',index_col=0)
df_saleiru01_strd=pd.read_csv('./PlayerData/1996/standard/saleiru01_strd_.csv',index_col=0)
df_salosa01_strd=pd.read_csv('./PlayerData/1996/standard/salosa01_strd_.csv',index_col=0)
df_saricco01_strd=pd.read_csv('./PlayerData/1996/standard/saricco01_strd_.csv',index_col=0)

df_shafrko01_strd=pd.read_csv('./PlayerData/1996/standard/shafrko01_strd_.csv',index_col=0)
df_simjo01_strd=pd.read_csv('./PlayerData/1996/standard/simjo01_strd_.csv',index_col=0)
df_skrbepa01_strd=pd.read_csv('./PlayerData/1996/standard/skrbepa01_strd_.csv',index_col=0)
df_sturmma01_strd=pd.read_csv('./PlayerData/1996/standard/sturmma01_strd_.csv',index_col=0)
df_sundiro01_strd=pd.read_csv('./PlayerData/1996/standard/sundiro01_strd_.csv',index_col=0)

df_svejkja01_strd=pd.read_csv('./PlayerData/1996/standard/svejkja01_strd_.csv',index_col=0)
df_tetarjo01_strd=pd.read_csv('./PlayerData/1996/standard/tetarjo01_strd_.csv',index_col=0)
df_tezikal01_strd=pd.read_csv('./PlayerData/1996/standard/tezikal01_strd_.csv',index_col=0)
df_vaiclu01_strd=pd.read_csv('./PlayerData/1996/standard/vaiclu01_strd_.csv',index_col=0)
df_valiqst01_strd=pd.read_csv('./PlayerData/1996/standard/valiqst01_strd_.csv',index_col=0)

df_volchal01_strd=pd.read_csv('./PlayerData/1996/standard/volchal01_strd_.csv',index_col=0)
df_wallije01_strd=pd.read_csv('./PlayerData/1996/standard/wallije01_strd_.csv',index_col=0)
df_wardla01_strd=pd.read_csv('./PlayerData/1996/standard/wardla01_strd_.csv',index_col=0)
df_whiteco01_strd=pd.read_csv('./PlayerData/1996/standard/whiteco01_strd_.csv',index_col=0)
df_whitftr01_strd=pd.read_csv('./PlayerData/1996/standard/whitftr01_strd_.csv',index_col=0)

df_willsbr01_strd=pd.read_csv('./PlayerData/1996/standard/willsbr01_strd_.csv',index_col=0)
df_yakusdm01_strd=pd.read_csv('./PlayerData/1996/standard/yakusdm01_strd_.csv',index_col=0)
df_zubruda01_strd=pd.read_csv('./PlayerData/1996/standard/zubruda01_strd_.csv',index_col=0)
df_zyuzian01_strd=pd.read_csv('./PlayerData/1996/standard/zyuzian01_strd_.csv',index_col=0)

# %%
df_adamscr01_strd['name']='adamscr01'
df_aitkejo01_strd['name']='aitkejo01'
df_allench01_strd['name']='allench01'
df_ashamar01_strd['name']='ashamar01'
df_babenyu01_strd['name']='babenyu01'

df_beginst01_strd['name']='beginst01'
df_belaner01_strd['name']='belaner01'
df_berenbu01_strd['name']='berenbu01'
df_bouleje01_strd['name']='bouleje01'
df_boumejo01_strd['name']='boumejo01'
df_bradlma01_strd['name']='bradlma01'
df_brierda01_strd['name']='brierda01'
df_brigltr01_strd['name']='brigltr01'
df_bulisja01_strd['name']='bulisja01'
df_charazd01_strd['name']='charazd01'
df_chrisry01_strd['name']='chrisry01'
df_cierniv01_strd['name']='cierniv01'
df_cisarma01_strd['name']='cisarma01'
df_clarkbr01_strd['name']='clarkbr01'
df_corsoda01_strd['name']='corsoda01'

df_cullema01_strd['name']='cullema01'
df_dackean01_strd['name']='dackean01'
df_dagenpi01_strd['name']='dagenpi01'
df_delisxa01_strd['name']='delisxa01'

df_descoma01_strd['name']='descoma01'
df_deverbo01_strd['name']='deverbo01'
df_dumonjp01_strd['name']='dumonjp01'
df_dwyergo01_strd['name']='dwyergo01'
df_eschero01_strd['name']='eschero01'

df_fochtda01_strd['name']='fochtda01'
df_garnety01_strd['name']='garnety01'
df_garonma01_strd['name']='garonma01'
df_goldmer01_strd['name']='goldmer01'
df_goneada01_strd['name']='goneada01'
df_greenjo01_strd['name']='greenjo01'

df_hajtch01_strd['name']='hajtch01'
df_higgima01_strd['name']='higgima01'
df_hinotda01_strd['name']='hinotda01'
df_holdejo01_strd['name']='holdejo01'
df_jackmri01_strd['name']='jackmri01'

df_kaberto01_strd['name']='kaberto01'
df_kanebo01_strd['name']='kanebo01'
df_komarze01_strd['name']='komarze01'
df_korolev01_strd['name']='korolev01'
df_kubinpa01_strd['name']='kubinpa01'

df_kuznigr01_strd['name']='kuznigr01'
df_kvashol01_strd['name']='kvashol01'
df_kwiatjo01_strd['name']='kwiatjo01'
df_lacouda01_strd['name']='lacouda01'
df_larocma01_strd['name']='larocma01'


df_larocmi02_strd['name']='larocmi02'
df_letowtr01_strd['name']='letowtr01'
df_lintnri01_strd['name']='lintnri01'
df_lowre01_strd['name']='lowre01'
df_lydmato01_strd['name']='lydmato01'

df_macdocr01_strd['name']='macdocr01'
df_melocer01_strd['name']='melocer01'
df_mitchwi01_strd['name']='mitchwi01'
df_morride01_strd['name']='morride01'
df_niemian01_strd['name']='niemian01'

df_nilsoma01_strd['name']='nilsoma01'
df_nurmika01_strd['name']='nurmika01'
df_pahlssa01_strd['name']='pahlssa01'
df_parkesc01_strd['name']='parkesc01'
df_parrima01_strd['name']='parrima01'

df_paulje01_strd['name']='paulje01'
df_petroro02_strd['name']='petroro02'
df_phillch02_strd['name']='phillch02'
df_pisanfe01_strd['name']='pisanfe01'
df_podkoan01_strd['name']='podkoan01'

df_strdmyma01_strd['name']='strdmyma01'
df_potito01_strd['name']='potito01'
df_rasmuer01_strd['name']='rasmuer01'
df_ratchpe01_strd['name']='ratchpe01'
df_reasoma01_strd['name']='reasoma01'

df_royerre01_strd['name']='royerre01'
df_rozsimi01_strd['name']='rozsimi01'
df_saleiru01_strd['name']='saleiru01'
df_salosa01_strd['name']='salosa01'
df_saricco01_strd['name']='saricco01'

df_shafrko01_strd['name']='shafrko01'
df_simjo01_strd['name']='simjo01'
df_skrbepa01_strd['name']='skrbepa01'
df_sturmma01_strd['name']='sturmma01'
df_sundiro01_strd['name']='sundiro01'

df_svejkja01_strd['name']='svejkja01'
df_tetarjo01_strd['name']='tetarjo01'
df_tezikal01_strd['name']='tezikal01'
df_vaiclu01_strd['name']='vaiclu01'
df_valiqst01_strd['name']='valiqst01'

df_volchal01_strd['name']='volchal01'
df_wallije01_strd['name']='wallije01'
df_wardla01_strd['name']='wardla01'
df_whiteco01_strd['name']='whiteco01'
df_whitftr01_strd['name']='whitftr01'

df_willsbr01_strd['name']='willsbr01'
df_yakusdm01_strd['name']='yakusdm01'
df_zubruda01_strd['name']='zubruda01'
df_zyuzian01_strd['name']='zyuzian01'

# %%
strd_frames = [df_adamscr01_strd,
df_aitkejo01_strd,
df_allench01_strd,
df_ashamar01_strd,
df_babenyu01_strd,

df_beginst01_strd,
df_belaner01_strd,
df_berenbu01_strd,
df_bouleje01_strd,
df_boumejo01_strd,
df_bradlma01_strd,
df_brierda01_strd,
df_brigltr01_strd,
df_bulisja01_strd,
df_charazd01_strd,
df_chrisry01_strd,
df_cierniv01_strd,
df_cisarma01_strd,
df_clarkbr01_strd,
df_corsoda01_strd,

df_cullema01_strd,
df_dackean01_strd,
df_dagenpi01_strd,
df_delisxa01_strd,

df_descoma01_strd,
df_deverbo01_strd,
df_dumonjp01_strd,
df_dwyergo01_strd,
df_eschero01_strd,

df_fochtda01_strd,
df_garnety01_strd,
df_garonma01_strd,
df_goldmer01_strd,
df_goneada01_strd,
df_greenjo01_strd,

df_hajtch01_strd,
df_higgima01_strd,
df_hinotda01_strd,
df_holdejo01_strd,
df_jackmri01_strd,

df_kaberto01_strd,
df_kanebo01_strd,
df_komarze01_strd,
df_korolev01_strd,
df_kubinpa01_strd,

df_kuznigr01_strd,
df_kvashol01_strd,
df_kwiatjo01_strd,
df_lacouda01_strd,
df_larocma01_strd,


df_larocmi02_strd,
df_letowtr01_strd,
df_lintnri01_strd,
df_lowre01_strd,
df_lydmato01_strd,

df_macdocr01_strd,
df_melocer01_strd,
df_mitchwi01_strd,
df_morride01_strd,
df_niemian01_strd,

df_nilsoma01_strd,
df_nurmika01_strd,
df_pahlssa01_strd,
df_parkesc01_strd,
df_parrima01_strd,

df_paulje01_strd,
df_petroro02_strd,
df_phillch02_strd,
df_pisanfe01_strd,
df_podkoan01_strd,


df_strdmyma01_strd,
df_potito01_strd,
df_rasmuer01_strd,
df_ratchpe01_strd,
df_reasoma01_strd,

df_royerre01_strd,
df_rozsimi01_strd,
df_saleiru01_strd,
df_salosa01_strd,
df_saricco01_strd,

df_shafrko01_strd,
df_simjo01_strd,
df_skrbepa01_strd,
df_sturmma01_strd,
df_sundiro01_strd,

df_svejkja01_strd,
df_tetarjo01_strd,
df_tezikal01_strd,
df_vaiclu01_strd,
df_valiqst01_strd,

df_volchal01_strd,
df_wallije01_strd,
df_wardla01_strd,
df_whiteco01_strd,
df_whitftr01_strd,

df_willsbr01_strd,
df_yakusdm01_strd,
df_zubruda01_strd,
df_zyuzian01_strd]

# %%
result_strd = pd.concat(strd_frames)

# %%
result_strd.to_csv("result_strd_1996.csv")
result_pos.to_csv("result_pos_1996.csv")

# %%
result_strd=result_strd.reset_index()

# %%
result_pos=result_pos.reset_index()

# %%
del result_strd['index']

# %%
del result_pos['index']

# %%
del result_strd['shots_attempted.1']

# %%
result_all = pd.merge(result_strd, result_pos, how ='left', on=['name','season','TOT'])

# %%
#result_all['name_y']

# %%
result_all.head(15)
# Out:
#      season  TOT  age_x  games_played  pen_min plus_minus  goals_ev  goals_pp  \
# 0   2000-01  CAR     23            44       20         -7         1         0
# 1   2001-02  CAR     24            33       38          2         0         0
# 2   2002-03  CAR     25            81       71        -11         5         1
# 3   2003-04  CAR     26            80       69         -5         6         0
# 4   2005-06  CAR     28            67       51          1         8         1
# 5   2006-07  CAR     29            82       54         -9         6         0
# 6   2007-08  TOT     30            75       58        -16         3         0
# 7   2007-08  CAR     30            40       34         -8         2         0
# 8   2007-08  CHI     30            35       24         -8         1         0
# 9   2008-09  TOT     31            45       22         -3         1         1
# 10  2008-09  CHI     31            36       22         -3         1         1
# ...

# %%
#result_all[result_all['name']=='adamscr01']

# %%
#result_all.head(10)

# %%
#result_all2=pd.read_csv('./df_result_pos_strd/df_result_1996.csv',index_col=0)

# %%
import copy
seasonlist=result_all['season']
teamlist=result_all['TOT']
namelist=result_all['name']

currseas=seasonlist[0]
currteam=teamlist[0]
currname=namelist[0]

remlist=[1]
for i in range(1,len(seasonlist)):
    if seasonlist[i]==currseas and currname==namelist[i]:
        remlist.append(0)
    
    else:
        remlist.append(1)
        currname=namelist[i]
        currseas=seasonlist[i]

result_all['uniqueseason']=remlist
result_all=result_all.loc[result_all['uniqueseason'] == 1]
result_all2=copy.deepcopy(result_all)

    
result_all2=result_all2.convert_objects(convert_numeric=True).dropna()

result_all2

result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')
result_all2.to_csv("df_1996.csv")

# %%
#from sklearn import datasets
#iris = datasets.load_iris()

# %%
#iris.data

# %%
#iris.target

# %%
# from sklearn import neighbors
# from sklearn import cluster, datasets

# %%
# knn = neighbors.KNeighborsClassifier()

# %%
# knn.fit(iris.data, iris.target)

# %%
# knn.predict([[5.1, 3, 4, 3]])

# %%
# k_means = cluster.KMeans(n_clusters=3)

# %%
# k_means.fit(iris.data)

# %%
# print(k_means.labels_[::10])

# %%
# print(iris.target[::10])

# %%
# import copy

# %%
result_all.head(12)
# Out:
#      season TOT_x  age_x  games_played  pen_min plus_minus  goals_ev  \
# 0   2007-08   PIT     32            75       58        -16         3
# 1   2007-08   PIT     32            75       58        -16         3
# 2   2007-08   PIT     32            75       58        -16         3
# 3   2007-08   PIT     33            40       34         -8         2
# 4   2007-08   PIT     33            40       34         -8         2
# 5   2007-08   PIT     33            40       34         -8         2
# 6   2007-08   PIT     34            35       24         -8         1
# 7   2007-08   PIT     34            35       24         -8         1
# 8   2007-08   PIT     34            35       24         -8         1
# 9   2008-09   PIT     35            45       22         -3         1
# 10  2008-09   PIT     35            45       22         -3         1
# 11  2008-09   PIT     35            45       22         -3         1
#
# ...

# %%
import copy
seasonlist=result_all['season']
teamlist=result_all['TOT']
namelist=result_all['name']

currseas=seasonlist[0]
currteam=teamlist[0]
currname=namelist[0]

remlist=[1]
for i in range(1,len(seasonlist)):
    if seasonlist[i]==currseas and currname==namelist[i]:
        remlist.append(0)
    
    else:
        remlist.append(1)
        currname=namelist[i]
        currseas=seasonlist[i]

result_all['uniqueseason']=remlist
result_all=result_all.loc[result_all['uniqueseason'] == 1]
result_all2=copy.deepcopy(result_all)

    
result_all2=result_all2.convert_objects(convert_numeric=True).dropna()

result_all2

result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')
result_all2.to_csv("df_1996.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-49ee4dc2480b> in <module>()
#       1 import copy
#       2 seasonlist=result_all['season']
# ----> 3 teamlist=result_all['TOT']
#       4 namelist=result_all['name']
#       5
#
# /Users/takehiro/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/takehiro/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1802         # get column
#    1803         if self.columns.is_unique:
# -> 1804             return self._get_item_cache(key)
#    1805
#    1806         # duplicate columns & possible reduce dimensionaility
#
# ...

# %%
# Out:
#      age  games_played  pen_min  plus_minus  goals_ev  goals_pp  goals_sh  \
# 0     30            75       58         -16         3         0         1
# 3     31            45       22          -3         1         1         0
# 6     32            82       72          -5         0         0         0
# 7     33            80       76          -5         2         0         2
# 8     34            82       34          -6         5         0         0
# 10    36            82       46         -16         5         0         0
# 11    37            70       44          -1         1         0         0
# 12    29            77       84          -6         6         0         0
# 13    30            78      155           0         8         0         0
# 14    31            72      126          -2        10         0         0
# 15    32            44       46           0         5         0         0
# 16    33            64       76          -5         5         0         0
# ...

# %%
del result_all2['name']

# %%
#result_all2.to_csv("df_1996_numeric.csv")

# %%
#result_all2=pd.read_csv('df_1996_numeric.csv',index_col=0)

# %%
result_all2['time_on_ice_avg'] = result_all2['time_on_ice_avg'].str.replace(':', '.')

# %%
result_all2.to_csv("df_1996.csv")

# %%
result_all2
# Out:
#      age  games_played  pen_min  plus_minus  goals_ev  goals_pp  goals_sh  \
# 0     30            75       58         -16         3         0         1
# 3     31            45       22          -3         1         1         0
# 6     32            82       72          -5         0         0         0
# 7     33            80       76          -5         2         0         2
# 8     34            82       34          -6         5         0         0
# 10    36            82       46         -16         5         0         0
# 11    37            70       44          -1         1         0         0
# 12    29            77       84          -6         6         0         0
# 13    30            78      155           0         8         0         0
# 14    31            72      126          -2        10         0         0
# 15    32            44       46           0         5         0         0
# 16    33            64       76          -5         5         0         0
# ...

# %%
data_1996=result_all2.as_matrix()

# %%
# k_means = cluster.KMeans(n_clusters=5)

# %%
k_means = cluster.KMeans(n_clusters=5)
k_means.fit(data_1996)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=5, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
print(k_means.labels_[::10])
# Out:
# [1 1 4 1 0 4 3 2 0 4 0 4 2 1 4 4 4 2 4 1]

# %%
from sklearn.neighbors import KNeighborsClassifier
import pylab as pl

# %%
test_idx = np.random.uniform(0, 1, len(result_all2)) <= 0.7
train = result_all2[test_idx==True]
test = result_all2[test_idx==False]

# %%
print len(test)
print len(train)
# Out:
# 74
# 124

# %%
list(result_all2.columns)
# Out:
# ['age',
#  'games_played',
#  'pen_min',
#  'plus_minus',
#  'goals_ev',
#  'goals_pp',
#  'goals_sh',
#  'goals_gw',
#  'assists_ev',
#  'assists_pp',
#  'assists_sh',
#  'shot_pct',
#  'shots_attempted',
#  'shot_pct.1',
#  'shots_attempted.1',
#  'time_on_ice_avg',
#  'hits',
#  'blocks',
#  'takeaways',
#  'giveaways',
#  'corsi_for',
#  'corsi_against',
#  'corsi_pct',
#  'corsi_rel_pct',
#  'fenwick_for',
#  'fenwick_against',
#  'fenwick_pct',
#  'fenwick_rel_pct',
#  'on_ice_shot_pct',
#  'on_ice_sv_pct',
#  'pdo',
#  'zs_offense_pct',
#  'zs_defense_pct',
#  'uniqueseason']

# %%
features = ['age',
 'games_played',
 'pen_min',
 'plus_minus',
 'assists_ev',
 'shot_pct',
 'shots_attempted',
 'time_on_ice_avg',
 'hits',
 'blocks',
 'takeaways',
 'giveaways',
 'corsi_for',
 'corsi_against',
 'corsi_pct',
 'corsi_rel_pct',
 'fenwick_for',
 'fenwick_against',
 'fenwick_pct',
 'fenwick_rel_pct',
 'on_ice_shot_pct',
 'on_ice_sv_pct',
 'pdo',
 'zs_offense_pct',
 'zs_defense_pct',
 ]

# %%
results = {}
for i in range(50):
    test_idx = np.random.uniform(0, 1, len(result_all2)) <= 0.7
    train = result_all2[test_idx==True]
    test = result_all2[test_idx==False]
    
    for n in range(1, 15, 1):
        clf = KNeighborsClassifier(n_neighbors=n)
        clf.fit(train[features], train['goals_ev'])
        preds = clf.predict(test[features])
        accuracy = np.where(preds==test['goals_ev'], 1, 0).sum() / float(len(test))
        #print "Neighbors: %d, Accuracy: %3f" % (n, accuracy)
        
        if n in results:
            results[n].append(accuracy)
        else:
            results[n]=[accuracy]

# %%
print sum(results[1])/len(results[1])
# Out:
# 0.19206527324

# %%
for i in range(1,15):
    print str(i)+": "+str(sum(results[i])/len(results[i]))
# Out:
# 1: 0.19206527324
# 2: 0.224222628889
# 3: 0.217833185442
# 4: 0.199025233598
# 5: 0.202071770989
# 6: 0.202710854527
# 7: 0.204023024358
# 8: 0.201391271621
# 9: 0.208156122581
# 10: 0.211188227385
# 11: 0.209433450995
# 12: 0.204635042965
# 13: 0.203392221857
# 14: 0.202948570376

# %%
k_means = cluster.KMeans(n_clusters=6)
k_means.fit(data_1996)
# Out:
# KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=6, n_init=10,
#     n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#     verbose=0)

# %%
print(k_means.labels_[::10])
# Out:
# [3 1 0 1 4 2 3 5 2 0 4 2 5 1 2 0 0 5 0 3]

# %%
len(features)
# Out:
# 25

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components=25)

# %%
pca.fit(iris.data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a67586b5e172> in <module>()
# ----> 1 pca.fit(iris.data)
#
# NameError: name 'iris' is not defined

# %%
data_1996
# Out:
# array([[30.0, 75.0, 58.0, ..., 51.0, 49.0, 1],
#        [31.0, 45.0, 22.0, ..., 56.5, 43.5, 1],
#        [32.0, 82.0, 72.0, ..., 42.4, 57.6, 1],
#        ...,
#        [36.0, 74.0, 42.0, ..., 38.7, 61.3, 1],
#        [37.0, 50.0, 20.0, ..., 47.1, 52.9, 1],
#        [30.0, 32.0, 38.0, ..., 45.8, 54.2, 1]], dtype=object)

# %%
data_1996[0]
# Out:
# array([30.0, 75.0, 58.0, -16.0, 3.0, 0.0, 1.0, 1.0, 7.0, 0.0, 0.0, 6.3,
#        110, 6.3, 110, '10.48', 117, 43, 22, 9, 446.0, 550.0, 44.8, -9.2,
#        340.0, 408.0, 45.5, -8.7, 4.7, 89.5, 94.2, 51.0, 49.0, 1], dtype=object)

# %%
converted_data_1996=[[float(y) for y in x] for x in data_1996.T]

# %%
corr_data_1996=np.corrcoef(converted_data_1996)

# %%
corr_data_1996
# Out:
# array([[ 1.        , -0.15706472, -0.29950715, ..., -0.0835584 ,
#          0.0835584 ,         nan],
#        [-0.15706472,  1.        ,  0.55727294, ...,  0.11286674,
#         -0.11286674,         nan],
#        [-0.29950715,  0.55727294,  1.        , ...,  0.12446712,
#         -0.12446712,         nan],
#        ...,
#        [-0.0835584 ,  0.11286674,  0.12446712, ...,  1.        ,
#         -1.        ,         nan],
#        [ 0.0835584 , -0.11286674, -0.12446712, ..., -1.        ,
#          1.        ,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan]])

# %%
len(np.corrcoef(converted_data_1996))
# Out:
# 198

# %%
np.corrcoef(converted_data_1996)[0]
# Out:
# array([ 1.        , -0.15706472, -0.29950715,  0.05855314, -0.16829189,
#        -0.16596988, -0.08472011, -0.14110036, -0.14609185, -0.1590806 ,
#         0.00625499, -0.20603366, -0.12856185, -0.20603366, -0.12856185,
#         0.0826508 , -0.06359139,  0.00552884, -0.21989686, -0.08262709,
#        -0.06811877, -0.05904383,  0.00688633,  0.07996869, -0.08087478,
#        -0.06902351,  0.01412665,  0.05764185,  0.12325484, -0.03471748,
#         0.04590346, -0.0835584 ,  0.0835584 ,         nan])

# %% [markdown]
# ##Variance

# %%
df_var_1996=pd.DataFrame(np.corrcoef(converted_data_1996), columns=result_all2.columns)

# %%
df_var_1996['name']=result_all2.columns

# %%
df_var_1996=df_var_1996.set_index('name')

# %%
df_var_1996.to_csv("df_var.csv")

# %%
df_var_1996
# Out:
#                         age  games_played   pen_min  plus_minus  goals_ev  \
# name
# age                1.000000     -0.157065 -0.299507    0.058553 -0.168292
# games_played      -0.157065      1.000000  0.557273    0.092614  0.464988
# pen_min           -0.299507      0.557273  1.000000    0.183602  0.231884
# plus_minus         0.058553      0.092614  0.183602    1.000000  0.144976
# goals_ev          -0.168292      0.464988  0.231884    0.144976  1.000000
# goals_pp          -0.165970      0.296418  0.202333    0.191130  0.439163
# goals_sh          -0.084720      0.184067 -0.006490   -0.023529  0.210279
# goals_gw          -0.141100      0.378309  0.164789    0.181969  0.676294
# assists_ev        -0.146092      0.683473  0.365334    0.348112  0.569251
# assists_pp        -0.159081      0.380848  0.166603    0.073358  0.315725
# assists_sh         0.006255      0.293050  0.190254    0.215117  0.126607
# shot_pct          -0.206034      0.126906  0.033710    0.069370  0.565259
# ...

# %%
data_1996.T
# Out:
# array([[30.0, 31.0, 32.0, ..., 36.0, 37.0, 30.0],
#        [75.0, 45.0, 82.0, ..., 74.0, 50.0, 32.0],
#        [58.0, 22.0, 72.0, ..., 42.0, 20.0, 38.0],
#        ...,
#        [51.0, 56.5, 42.4, ..., 38.7, 47.1, 45.8],
#        [49.0, 43.5, 57.6, ..., 61.3, 52.9, 54.2],
#        [1, 1, 1, ..., 1, 1, 1]], dtype=object)

# %%
converted_data_1996=[[float(y) for y in x] for x in data_1996.T]

# %%
np.cov(converted_data_1996)
# Out:
# array([[   6.13303082,   -9.12798031,  -20.60036917, ...,   -1.72130441,
#            1.72130441,    0.        ],
#        [  -9.12798031,  550.70235348,  363.20904476, ...,   22.03202584,
#          -22.03202584,    0.        ],
#        [ -20.60036917,  363.20904476,  771.3659437 , ...,   28.75509922,
#          -28.75509922,    0.        ],
#        ...,
#        [  -1.72130441,   22.03202584,   28.75509922, ...,   69.19265344,
#          -69.19265344,    0.        ],
#        [   1.72130441,  -22.03202584,  -28.75509922, ...,  -69.19265344,
#           69.19265344,    0.        ],
#        [   0.        ,    0.        ,    0.        , ...,    0.        ,
#            0.        ,    0.        ]])

# %%
pd.DataFrame(np.cov(converted_data_1996), columns=result_all2.columns)
# Out:
#           age  games_played      pen_min   plus_minus    goals_ev    goals_pp  \
# 0    6.133031     -9.127980   -20.600369     1.450469   -1.882505   -1.061324
# 1   -9.127980    550.702353   363.209045    21.739732   49.287340   17.961544
# 2  -20.600369    363.209045   771.365944    51.006922   29.089525   14.510383
# 3    1.450469     21.739732    51.006922   100.055607    6.550146    4.936625
# 4   -1.882505     49.287340    29.089525     6.550146   20.401913    5.122033
# 5   -1.061324     17.961544    14.510383     4.936625    5.122033    6.667487
# 6   -0.132672      2.731426    -0.113982    -0.148823    0.600600    0.128288
# 7   -0.469620     11.931241     6.150900     2.446239    4.105368    1.660052
# 8   -2.328770    103.238733    65.310568    22.413167   16.550172    7.970569
# 9   -2.036251     46.194124    23.916013     3.792647    7.370917    9.201097
# 10   0.013024      5.781880     4.442547     1.809106    0.480798    0.185459
# ...

# %%
# X = pca.transform(iris.data)
# pl.scatter(X[:, 0], X[:, 1], c=iris.target)
# pl.show()

# %%
pca.fit(data_1996)
# Out:
# PCA(copy=True, n_components=25, whiten=False)

# %%
X = pca.transform(data_1996)

# %%
X
# Out:
# array([[  4.30147026e+02,  -6.53515991e+01,  -1.86633902e+01, ...,
#          -1.65640128e+00,   8.90021306e-01,   7.54891395e-02],
#        [  7.98914580e+02,   7.13842539e+01,   9.42434036e+00, ...,
#           2.21201311e+00,  -9.90707257e-01,   1.51757447e+00],
#        [  3.30316296e+02,  -4.78128475e+01,  -3.38180045e+01, ...,
#          -5.23610639e-01,   2.73865345e-01,  -3.04103677e-01],
#        ...,
#        [  1.89309468e+01,  -1.33245980e+02,   1.86525045e+01, ...,
#          -5.02324609e-01,  -1.92119288e-01,   1.60553033e-01],
#        [  5.54317212e+02,   1.35475382e+01,   4.44359758e+01, ...,
#           1.99805389e+00,  -4.43643298e-01,   7.83054866e-01],
#        [  7.97566854e+02,   1.16910752e+00,   3.40432625e-01, ...,
#          -1.83365764e+00,   7.21266086e-01,  -4.49408853e-01]])
