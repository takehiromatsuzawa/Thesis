# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
df_age_18 = pd.DataFrame()
df_age_19 = pd.DataFrame()

df_age_20 = pd.DataFrame()
df_age_21 = pd.DataFrame()
df_age_22 = pd.DataFrame()
df_age_23 = pd.DataFrame()
df_age_24 = pd.DataFrame()
df_age_25 = pd.DataFrame()
df_age_26 = pd.DataFrame()
df_age_27 = pd.DataFrame()
df_age_28 = pd.DataFrame()
df_age_29 = pd.DataFrame()

df_age_30 = pd.DataFrame()
df_age_31 = pd.DataFrame()
df_age_32 = pd.DataFrame()
df_age_33 = pd.DataFrame()
df_age_34 = pd.DataFrame()
df_age_35 = pd.DataFrame()
df_age_36 = pd.DataFrame()
df_age_37 = pd.DataFrame()
df_age_38 = pd.DataFrame()
df_age_39 = pd.DataFrame()
df_age_40 = pd.DataFrame()

# %%
df_age_29
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_1996=pd.read_csv('df_1996.csv',index_col=0)
df_1996=pd.read_csv('df_1997.csv',index_col=0)
df_1998=pd.read_csv('df_1998.csv',index_col=0)
df_1999=pd.read_csv('df_1999.csv',index_col=0)

df_1996=pd.read_csv('df_1996.csv',index_col=0)
df_1997=pd.read_csv('df_1997.csv',index_col=0)
df_1998=pd.read_csv('df_1998.csv',index_col=0)
df_1999=pd.read_csv('df_1999.csv',index_col=0)

df_2000=pd.read_csv('df_2000.csv',index_col=0)
df_2001=pd.read_csv('df_2001.csv',index_col=0)
df_2002=pd.read_csv('df_2002.csv',index_col=0)
df_2003=pd.read_csv('df_2003.csv',index_col=0)

df_2004=pd.read_csv('df_2004.csv',index_col=0)
df_2005=pd.read_csv('df_2005.csv',index_col=0)

df_2006=pd.read_csv('df_2006.csv',index_col=0)
df_2007=pd.read_csv('df_2007.csv',index_col=0)
df_2008=pd.read_csv('df_2008.csv',index_col=0)
df_2009=pd.read_csv('df_2009.csv',index_col=0)
df_2010=pd.read_csv('df_2010.csv',index_col=0)
df_2011=pd.read_csv('df_2011.csv',index_col=0)

df_2012=pd.read_csv('df_2012.csv',index_col=0)
df_2013=pd.read_csv('df_2013.csv',index_col=0)
df_2014=pd.read_csv('df_2014.csv',index_col=0)
df_2015=pd.read_csv('df_2015.csv',index_col=0)

# df_2006=pd.read_csv('df_2012.csv',index_col=0)
# df_2007=pd.read_csv('df_2013.csv',index_col=0)
# df_2008=pd.read_csv('df_2014.csv',index_col=0)
# df_2009=pd.read_csv('df_2015.csv',index_col=0)

# %%
df_1996
# Out:
#       season  TOT  age_x  games_played  pen_min  plus_minus  goals_ev  \
# 6    2007-08  TOT     30            75       58         -16         3
# 9    2008-09  TOT     31            45       22          -3         1
# 12   2009-10  PIT     32            82       72          -5         0
# 13   2010-11  PIT     33            80       76          -5         2
# 14   2011-12  PIT     34            82       34          -6         5
# 15   2012-13  PIT     35            48       28          -1         2
# 16   2013-14  PIT     36            82       46         -16         5
# 17   2014-15  PIT     37            70       44          -1         1
# 64   2007-08  BOS     39            77      114          14         7
# 101  2010-11  ANA     33            12        6          -3         0
# 102  2011-12  EDM     34             7        7          -6         0
#
#      goals_pp  goals_sh  goals_gw      ...       fenwick_for  fenwick_against  \
# ...

# %%
df_age_18=df_age_18.append(df_1996[df_1996.age==18])
df_age_19=df_age_19.append(df_1996[df_1996.age==19])

df_age_20=df_age_20.append(df_1996[df_1996.age==20])
df_age_21=df_age_21.append(df_1996[df_1996.age==21])
df_age_22=df_age_22.append(df_1996[df_1996.age==22])
df_age_23=df_age_23.append(df_1996[df_1996.age==23])
df_age_24=df_age_24.append(df_1996[df_1996.age==24])
df_age_25=df_age_25.append(df_1996[df_1996.age==25])
df_age_26=df_age_26.append(df_1996[df_1996.age==26])
df_age_27=df_age_27.append(df_1996[df_1996.age==27])
df_age_28=df_age_28.append(df_1996[df_1996.age==28])
df_age_29=df_age_29.append(df_1996[df_1996.age==29])

df_age_30=df_age_30.append(df_1996[df_1996.age==30])
df_age_31=df_age_31.append(df_1996[df_1996.age==31])
df_age_32=df_age_32.append(df_1996[df_1996.age==32])
df_age_33=df_age_33.append(df_1996[df_1996.age==33])
df_age_34=df_age_34.append(df_1996[df_1996.age==34])
df_age_35=df_age_35.append(df_1996[df_1996.age==35])
df_age_36=df_age_36.append(df_1996[df_1996.age==36])
df_age_37=df_age_37.append(df_1996[df_1996.age==37])
df_age_38=df_age_38.append(df_1996[df_1996.age==38])
df_age_39=df_age_39.append(df_1996[df_1996.age==39])
df_age_40=df_age_40.append(df_1996[df_1996.age==40])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-eba8ca5ae180> in <module>()
# ----> 1 df_age_18=df_age_18.append(df_1996[df_1996.age==18])
#       2 df_age_19=df_age_19.append(df_1996[df_1996.age==19])
#       3
#       4 df_age_20=df_age_20.append(df_1996[df_1996.age==20])
#       5 df_age_21=df_age_21.append(df_1996[df_1996.age==21])
#
# /Users/takehiro/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2148                 return self[name]
#    2149             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 2150                                  (type(self).__name__, name))
#    2151
#    2152     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
df_age_18=df_age_18.append(df_1997[df_1997.age==18])
df_age_19=df_age_19.append(df_1997[df_1997.age==19])

df_age_20=df_age_20.append(df_1997[df_1997.age==20])
df_age_21=df_age_21.append(df_1997[df_1997.age==21])
df_age_22=df_age_22.append(df_1997[df_1997.age==22])
df_age_23=df_age_23.append(df_1997[df_1997.age==23])
df_age_24=df_age_24.append(df_1997[df_1997.age==24])
df_age_25=df_age_25.append(df_1997[df_1997.age==25])
df_age_26=df_age_26.append(df_1997[df_1997.age==26])
df_age_27=df_age_27.append(df_1997[df_1997.age==27])
df_age_28=df_age_28.append(df_1997[df_1997.age==28])
df_age_29=df_age_29.append(df_1997[df_1997.age==29])

df_age_30=df_age_30.append(df_1997[df_1997.age==30])
df_age_31=df_age_31.append(df_1997[df_1997.age==31])
df_age_32=df_age_32.append(df_1997[df_1997.age==32])
df_age_33=df_age_33.append(df_1997[df_1997.age==33])
df_age_34=df_age_34.append(df_1997[df_1997.age==34])
df_age_35=df_age_35.append(df_1997[df_1997.age==35])
df_age_36=df_age_36.append(df_1997[df_1997.age==36])
df_age_37=df_age_37.append(df_1997[df_1997.age==37])
df_age_38=df_age_38.append(df_1997[df_1997.age==38])
df_age_39=df_age_39.append(df_1997[df_1997.age==39])
df_age_40=df_age_40.append(df_1997[df_1997.age==40])

# %%
df_age_18=df_age_18.append(df_1998[df_1998.age==18])
df_age_19=df_age_19.append(df_1998[df_1998.age==19])

df_age_20=df_age_20.append(df_1998[df_1998.age==20])
df_age_21=df_age_21.append(df_1998[df_1998.age==21])
df_age_22=df_age_22.append(df_1998[df_1998.age==22])
df_age_23=df_age_23.append(df_1998[df_1998.age==23])
df_age_24=df_age_24.append(df_1998[df_1998.age==24])
df_age_25=df_age_25.append(df_1998[df_1998.age==25])
df_age_26=df_age_26.append(df_1998[df_1998.age==26])
df_age_27=df_age_27.append(df_1998[df_1998.age==27])
df_age_28=df_age_28.append(df_1998[df_1998.age==28])
df_age_29=df_age_29.append(df_1998[df_1998.age==29])

df_age_30=df_age_30.append(df_1998[df_1998.age==30])
df_age_31=df_age_31.append(df_1998[df_1998.age==31])
df_age_32=df_age_32.append(df_1998[df_1998.age==32])
df_age_33=df_age_33.append(df_1998[df_1998.age==33])
df_age_34=df_age_34.append(df_1998[df_1998.age==34])
df_age_35=df_age_35.append(df_1998[df_1998.age==35])
df_age_36=df_age_36.append(df_1998[df_1998.age==36])
df_age_37=df_age_37.append(df_1998[df_1998.age==37])
df_age_38=df_age_38.append(df_1998[df_1998.age==38])
df_age_39=df_age_39.append(df_1998[df_1998.age==39])
df_age_40=df_age_40.append(df_1998[df_1998.age==40])

# %%
df_age_18=df_age_18.append(df_1999[df_1999.age==18])
df_age_19=df_age_19.append(df_1999[df_1999.age==19])

df_age_20=df_age_20.append(df_1999[df_1999.age==20])
df_age_21=df_age_21.append(df_1999[df_1999.age==21])
df_age_22=df_age_22.append(df_1999[df_1999.age==22])
df_age_23=df_age_23.append(df_1999[df_1999.age==23])
df_age_24=df_age_24.append(df_1999[df_1999.age==24])
df_age_25=df_age_25.append(df_1999[df_1999.age==25])
df_age_26=df_age_26.append(df_1999[df_1999.age==26])
df_age_27=df_age_27.append(df_1999[df_1999.age==27])
df_age_28=df_age_28.append(df_1999[df_1999.age==28])
df_age_29=df_age_29.append(df_1999[df_1999.age==29])

df_age_30=df_age_30.append(df_1999[df_1999.age==30])
df_age_31=df_age_31.append(df_1999[df_1999.age==31])
df_age_32=df_age_32.append(df_1999[df_1999.age==32])
df_age_33=df_age_33.append(df_1999[df_1999.age==33])
df_age_34=df_age_34.append(df_1999[df_1999.age==34])
df_age_35=df_age_35.append(df_1999[df_1999.age==35])
df_age_36=df_age_36.append(df_1999[df_1999.age==36])
df_age_37=df_age_37.append(df_1999[df_1999.age==37])
df_age_38=df_age_38.append(df_1999[df_1999.age==38])
df_age_39=df_age_39.append(df_1999[df_1999.age==39])
df_age_40=df_age_40.append(df_1999[df_1999.age==40])

# %%
df_age_18=df_age_18.append(df_2000[df_2000.age==18])
df_age_19=df_age_19.append(df_2000[df_2000.age==19])

df_age_20=df_age_20.append(df_2000[df_2000.age==20])
df_age_21=df_age_21.append(df_2000[df_2000.age==21])
df_age_22=df_age_22.append(df_2000[df_2000.age==22])
df_age_23=df_age_23.append(df_2000[df_2000.age==23])
df_age_24=df_age_24.append(df_2000[df_2000.age==24])
df_age_25=df_age_25.append(df_2000[df_2000.age==25])
df_age_26=df_age_26.append(df_2000[df_2000.age==26])
df_age_27=df_age_27.append(df_2000[df_2000.age==27])
df_age_28=df_age_28.append(df_2000[df_2000.age==28])
df_age_29=df_age_29.append(df_2000[df_2000.age==29])

df_age_30=df_age_30.append(df_2000[df_2000.age==30])
df_age_31=df_age_31.append(df_2000[df_2000.age==31])
df_age_32=df_age_32.append(df_2000[df_2000.age==32])
df_age_33=df_age_33.append(df_2000[df_2000.age==33])
df_age_34=df_age_34.append(df_2000[df_2000.age==34])
df_age_35=df_age_35.append(df_2000[df_2000.age==35])
df_age_36=df_age_36.append(df_2000[df_2000.age==36])
df_age_37=df_age_37.append(df_2000[df_2000.age==37])
df_age_38=df_age_38.append(df_2000[df_2000.age==38])
df_age_39=df_age_39.append(df_2000[df_2000.age==39])
df_age_40=df_age_40.append(df_2000[df_2000.age==40])

# %%
df_age_18=df_age_18.append(df_2001[df_2001.age==18])
df_age_19=df_age_19.append(df_2001[df_2001.age==19])

df_age_20=df_age_20.append(df_2001[df_2001.age==20])
df_age_21=df_age_21.append(df_2001[df_2001.age==21])
df_age_22=df_age_22.append(df_2001[df_2001.age==22])
df_age_23=df_age_23.append(df_2001[df_2001.age==23])
df_age_24=df_age_24.append(df_2001[df_2001.age==24])
df_age_25=df_age_25.append(df_2001[df_2001.age==25])
df_age_26=df_age_26.append(df_2001[df_2001.age==26])
df_age_27=df_age_27.append(df_2001[df_2001.age==27])
df_age_28=df_age_28.append(df_2001[df_2001.age==28])
df_age_29=df_age_29.append(df_2001[df_2001.age==29])

df_age_30=df_age_30.append(df_2001[df_2001.age==30])
df_age_31=df_age_31.append(df_2001[df_2001.age==31])
df_age_32=df_age_32.append(df_2001[df_2001.age==32])
df_age_33=df_age_33.append(df_2001[df_2001.age==33])
df_age_34=df_age_34.append(df_2001[df_2001.age==34])
df_age_35=df_age_35.append(df_2001[df_2001.age==35])
df_age_36=df_age_36.append(df_2001[df_2001.age==36])
df_age_37=df_age_37.append(df_2001[df_2001.age==37])
df_age_38=df_age_38.append(df_2001[df_2001.age==38])
df_age_39=df_age_39.append(df_2001[df_2001.age==39])
df_age_40=df_age_40.append(df_2001[df_2001.age==40])

# %%
df_age_18=df_age_18.append(df_2002[df_2002.age==18])
df_age_19=df_age_19.append(df_2002[df_2002.age==19])

df_age_20=df_age_20.append(df_2002[df_2002.age==20])
df_age_21=df_age_21.append(df_2002[df_2002.age==21])
df_age_22=df_age_22.append(df_2002[df_2002.age==22])
df_age_23=df_age_23.append(df_2002[df_2002.age==23])
df_age_24=df_age_24.append(df_2002[df_2002.age==24])
df_age_25=df_age_25.append(df_2002[df_2002.age==25])
df_age_26=df_age_26.append(df_2002[df_2002.age==26])
df_age_27=df_age_27.append(df_2002[df_2002.age==27])
df_age_28=df_age_28.append(df_2002[df_2002.age==28])
df_age_29=df_age_29.append(df_2002[df_2002.age==29])

df_age_30=df_age_30.append(df_2002[df_2002.age==30])
df_age_31=df_age_31.append(df_2002[df_2002.age==31])
df_age_32=df_age_32.append(df_2002[df_2002.age==32])
df_age_33=df_age_33.append(df_2002[df_2002.age==33])
df_age_34=df_age_34.append(df_2002[df_2002.age==34])
df_age_35=df_age_35.append(df_2002[df_2002.age==35])
df_age_36=df_age_36.append(df_2002[df_2002.age==36])
df_age_37=df_age_37.append(df_2002[df_2002.age==37])
df_age_38=df_age_38.append(df_2002[df_2002.age==38])
df_age_39=df_age_39.append(df_2002[df_2002.age==39])
df_age_40=df_age_40.append(df_2002[df_2002.age==40])

# %%
df_age_18=df_age_18.append(df_2003[df_2003.age==18])
df_age_19=df_age_19.append(df_2003[df_2003.age==19])

df_age_20=df_age_20.append(df_2003[df_2003.age==20])
df_age_21=df_age_21.append(df_2003[df_2003.age==21])
df_age_22=df_age_22.append(df_2003[df_2003.age==22])
df_age_23=df_age_23.append(df_2003[df_2003.age==23])
df_age_24=df_age_24.append(df_2003[df_2003.age==24])
df_age_25=df_age_25.append(df_2003[df_2003.age==25])
df_age_26=df_age_26.append(df_2003[df_2003.age==26])
df_age_27=df_age_27.append(df_2003[df_2003.age==27])
df_age_28=df_age_28.append(df_2003[df_2003.age==28])
df_age_29=df_age_29.append(df_2003[df_2003.age==29])

df_age_30=df_age_30.append(df_2003[df_2003.age==30])
df_age_31=df_age_31.append(df_2003[df_2003.age==31])
df_age_32=df_age_32.append(df_2003[df_2003.age==32])
df_age_33=df_age_33.append(df_2003[df_2003.age==33])
df_age_34=df_age_34.append(df_2003[df_2003.age==34])
df_age_35=df_age_35.append(df_2003[df_2003.age==35])
df_age_36=df_age_36.append(df_2003[df_2003.age==36])
df_age_37=df_age_37.append(df_2003[df_2003.age==37])
df_age_38=df_age_38.append(df_2003[df_2003.age==38])
df_age_39=df_age_39.append(df_2003[df_2003.age==39])
df_age_40=df_age_40.append(df_2003[df_2003.age==40])

# %%
df_age_18=df_age_18.append(df_2004[df_2004.age==18])
df_age_19=df_age_19.append(df_2004[df_2004.age==19])

df_age_20=df_age_20.append(df_2004[df_2004.age==20])
df_age_21=df_age_21.append(df_2004[df_2004.age==21])
df_age_22=df_age_22.append(df_2004[df_2004.age==22])
df_age_23=df_age_23.append(df_2004[df_2004.age==23])
df_age_24=df_age_24.append(df_2004[df_2004.age==24])
df_age_25=df_age_25.append(df_2004[df_2004.age==25])
df_age_26=df_age_26.append(df_2004[df_2004.age==26])
df_age_27=df_age_27.append(df_2004[df_2004.age==27])
df_age_28=df_age_28.append(df_2004[df_2004.age==28])
df_age_29=df_age_29.append(df_2004[df_2004.age==29])

df_age_30=df_age_30.append(df_2004[df_2004.age==30])
df_age_31=df_age_31.append(df_2004[df_2004.age==31])
df_age_32=df_age_32.append(df_2004[df_2004.age==32])
df_age_33=df_age_33.append(df_2004[df_2004.age==33])
df_age_34=df_age_34.append(df_2004[df_2004.age==34])
df_age_35=df_age_35.append(df_2004[df_2004.age==35])
df_age_36=df_age_36.append(df_2004[df_2004.age==36])
df_age_37=df_age_37.append(df_2004[df_2004.age==37])
df_age_38=df_age_38.append(df_2004[df_2004.age==38])
df_age_39=df_age_39.append(df_2004[df_2004.age==39])
df_age_40=df_age_40.append(df_2004[df_2004.age==40])

# %%
df_age_18=df_age_18.append(df_2005[df_2005.age==18])
df_age_19=df_age_19.append(df_2005[df_2005.age==19])

df_age_20=df_age_20.append(df_2005[df_2005.age==20])
df_age_21=df_age_21.append(df_2005[df_2005.age==21])
df_age_22=df_age_22.append(df_2005[df_2005.age==22])
df_age_23=df_age_23.append(df_2005[df_2005.age==23])
df_age_24=df_age_24.append(df_2005[df_2005.age==24])
df_age_25=df_age_25.append(df_2005[df_2005.age==25])
df_age_26=df_age_26.append(df_2005[df_2005.age==26])
df_age_27=df_age_27.append(df_2005[df_2005.age==27])
df_age_28=df_age_28.append(df_2005[df_2005.age==28])
df_age_29=df_age_29.append(df_2005[df_2005.age==29])

df_age_30=df_age_30.append(df_2005[df_2005.age==30])
df_age_31=df_age_31.append(df_2005[df_2005.age==31])
df_age_32=df_age_32.append(df_2005[df_2005.age==32])
df_age_33=df_age_33.append(df_2005[df_2005.age==33])
df_age_34=df_age_34.append(df_2005[df_2005.age==34])
df_age_35=df_age_35.append(df_2005[df_2005.age==35])
df_age_36=df_age_36.append(df_2005[df_2005.age==36])
df_age_37=df_age_37.append(df_2005[df_2005.age==37])
df_age_38=df_age_38.append(df_2005[df_2005.age==38])
df_age_39=df_age_39.append(df_2005[df_2005.age==39])
df_age_40=df_age_40.append(df_2005[df_2005.age==40])

# %%
df_2006
# Out:
#       season  TOT  age_x  games_played  pen_min  plus_minus  goals_ev  \
# 0    2008-09  NYR     20             1        0           0         0
# 1    2009-10  NYR     21            82       32          -2        11
# 2    2010-11  NYR     22            82       20           3        15
# 3    2011-12  NYR     23            79       34          12        11
# 4    2012-13  CBJ     24            35       12          -6        10
# 5    2013-14  CBJ     25            81       20          -2        17
# 6    2014-15  CBJ     26            52        8          -6         7
# 7    2015-16  CHI     27            77       12           8        12
# 8    2016-17  CHI     28            22       16          11         8
# 9    2007-08  WSH     20            82       24          13        11
# 10   2008-09  WSH     21            82       46          16         8
# 11   2009-10  WSH     22            82       50          37        22
# ...

# %%
df_age_18=df_age_18.append(df_2006[df_2006.age_x==18])
df_age_19=df_age_19.append(df_2006[df_2006.age_x==19])

df_age_20=df_age_20.append(df_2006[df_2006.age_x==20])
df_age_21=df_age_21.append(df_2006[df_2006.age_x==21])
df_age_22=df_age_22.append(df_2006[df_2006.age_x==22])
df_age_23=df_age_23.append(df_2006[df_2006.age_x==23])
df_age_24=df_age_24.append(df_2006[df_2006.age_x==24])
df_age_25=df_age_25.append(df_2006[df_2006.age_x==25])
df_age_26=df_age_26.append(df_2006[df_2006.age_x==26])
df_age_27=df_age_27.append(df_2006[df_2006.age_x==27])
df_age_28=df_age_28.append(df_2006[df_2006.age_x==28])
df_age_29=df_age_29.append(df_2006[df_2006.age_x==29])

df_age_30=df_age_30.append(df_2006[df_2006.age_x==30])
df_age_31=df_age_31.append(df_2006[df_2006.age_x==31])
df_age_32=df_age_32.append(df_2006[df_2006.age_x==32])
df_age_33=df_age_33.append(df_2006[df_2006.age_x==33])
df_age_34=df_age_34.append(df_2006[df_2006.age_x==34])
df_age_35=df_age_35.append(df_2006[df_2006.age_x==35])
df_age_36=df_age_36.append(df_2006[df_2006.age_x==36])
df_age_37=df_age_37.append(df_2006[df_2006.age_x==37])
df_age_38=df_age_38.append(df_2006[df_2006.age_x==38])
df_age_39=df_age_39.append(df_2006[df_2006.age_x==39])
df_age_40=df_age_40.append(df_2006[df_2006.age_x==40])

# %%
df_age_18=df_age_18.append(df_2007[df_2007.age_x==18])
df_age_19=df_age_19.append(df_2007[df_2007.age_x==19])

df_age_20=df_age_20.append(df_2007[df_2007.age_x==20])
df_age_21=df_age_21.append(df_2007[df_2007.age_x==21])
df_age_22=df_age_22.append(df_2007[df_2007.age_x==22])
df_age_23=df_age_23.append(df_2007[df_2007.age_x==23])
df_age_24=df_age_24.append(df_2007[df_2007.age_x==24])
df_age_25=df_age_25.append(df_2007[df_2007.age_x==25])
df_age_26=df_age_26.append(df_2007[df_2007.age_x==26])
df_age_27=df_age_27.append(df_2007[df_2007.age_x==27])
df_age_28=df_age_28.append(df_2007[df_2007.age_x==28])
df_age_29=df_age_29.append(df_2007[df_2007.age_x==29])

df_age_30=df_age_30.append(df_2007[df_2007.age_x==30])
df_age_31=df_age_31.append(df_2007[df_2007.age_x==31])
df_age_32=df_age_32.append(df_2007[df_2007.age_x==32])
df_age_33=df_age_33.append(df_2007[df_2007.age_x==33])
df_age_34=df_age_34.append(df_2007[df_2007.age_x==34])
df_age_35=df_age_35.append(df_2007[df_2007.age_x==35])
df_age_36=df_age_36.append(df_2007[df_2007.age_x==36])
df_age_37=df_age_37.append(df_2007[df_2007.age_x==37])
df_age_38=df_age_38.append(df_2007[df_2007.age_x==38])
df_age_39=df_age_39.append(df_2007[df_2007.age_x==39])
df_age_40=df_age_40.append(df_2007[df_2007.age_x==40])

# %%
df_age_18=df_age_18.append(df_2008[df_2008.age_x==18])
df_age_19=df_age_19.append(df_2008[df_2008.age_x==19])

df_age_20=df_age_20.append(df_2008[df_2008.age_x==20])
df_age_21=df_age_21.append(df_2008[df_2008.age_x==21])
df_age_22=df_age_22.append(df_2008[df_2008.age_x==22])
df_age_23=df_age_23.append(df_2008[df_2008.age_x==23])
df_age_24=df_age_24.append(df_2008[df_2008.age_x==24])
df_age_25=df_age_25.append(df_2008[df_2008.age_x==25])
df_age_26=df_age_26.append(df_2008[df_2008.age_x==26])
df_age_27=df_age_27.append(df_2008[df_2008.age_x==27])
df_age_28=df_age_28.append(df_2008[df_2008.age_x==28])
df_age_29=df_age_29.append(df_2008[df_2008.age_x==29])

df_age_30=df_age_30.append(df_2008[df_2008.age_x==30])
df_age_31=df_age_31.append(df_2008[df_2008.age_x==31])
df_age_32=df_age_32.append(df_2008[df_2008.age_x==32])
df_age_33=df_age_33.append(df_2008[df_2008.age_x==33])
df_age_34=df_age_34.append(df_2008[df_2008.age_x==34])
df_age_35=df_age_35.append(df_2008[df_2008.age_x==35])
df_age_36=df_age_36.append(df_2008[df_2008.age_x==36])
df_age_37=df_age_37.append(df_2008[df_2008.age_x==37])
df_age_38=df_age_38.append(df_2008[df_2008.age_x==38])
df_age_39=df_age_39.append(df_2008[df_2008.age_x==39])
df_age_40=df_age_40.append(df_2008[df_2008.age_x==40])

# %%
df_age_18=df_age_18.append(df_2009[df_2009.age_x==18])
df_age_19=df_age_19.append(df_2009[df_2009.age_x==19])

df_age_20=df_age_20.append(df_2009[df_2009.age_x==20])
df_age_21=df_age_21.append(df_2009[df_2009.age_x==21])
df_age_22=df_age_22.append(df_2009[df_2009.age_x==22])
df_age_23=df_age_23.append(df_2009[df_2009.age_x==23])
df_age_24=df_age_24.append(df_2009[df_2009.age_x==24])
df_age_25=df_age_25.append(df_2009[df_2009.age_x==25])
df_age_26=df_age_26.append(df_2009[df_2009.age_x==26])
df_age_27=df_age_27.append(df_2009[df_2009.age_x==27])
df_age_28=df_age_28.append(df_2009[df_2009.age_x==28])
df_age_29=df_age_29.append(df_2009[df_2009.age_x==29])

df_age_30=df_age_30.append(df_2009[df_2009.age_x==30])
df_age_31=df_age_31.append(df_2009[df_2009.age_x==31])
df_age_32=df_age_32.append(df_2009[df_2009.age_x==32])
df_age_33=df_age_33.append(df_2009[df_2009.age_x==33])
df_age_34=df_age_34.append(df_2009[df_2009.age_x==34])
df_age_35=df_age_35.append(df_2009[df_2009.age_x==35])
df_age_36=df_age_36.append(df_2009[df_2009.age_x==36])
df_age_37=df_age_37.append(df_2009[df_2009.age_x==37])
df_age_38=df_age_38.append(df_2009[df_2009.age_x==38])
df_age_39=df_age_39.append(df_2009[df_2009.age_x==39])
df_age_40=df_age_40.append(df_2009[df_2009.age_x==40])

# %%
df_age_18=df_age_18.append(df_2010[df_2010.age_x==18])
df_age_19=df_age_19.append(df_2010[df_2010.age_x==19])

df_age_20=df_age_20.append(df_2010[df_2010.age_x==20])
df_age_21=df_age_21.append(df_2010[df_2010.age_x==21])
df_age_22=df_age_22.append(df_2010[df_2010.age_x==22])
df_age_23=df_age_23.append(df_2010[df_2010.age_x==23])
df_age_24=df_age_24.append(df_2010[df_2010.age_x==24])
df_age_25=df_age_25.append(df_2010[df_2010.age_x==25])
df_age_26=df_age_26.append(df_2010[df_2010.age_x==26])
df_age_27=df_age_27.append(df_2010[df_2010.age_x==27])
df_age_28=df_age_28.append(df_2010[df_2010.age_x==28])
df_age_29=df_age_29.append(df_2010[df_2010.age_x==29])

df_age_30=df_age_30.append(df_2010[df_2010.age_x==30])
df_age_31=df_age_31.append(df_2010[df_2010.age_x==31])
df_age_32=df_age_32.append(df_2010[df_2010.age_x==32])
df_age_33=df_age_33.append(df_2010[df_2010.age_x==33])
df_age_34=df_age_34.append(df_2010[df_2010.age_x==34])
df_age_35=df_age_35.append(df_2010[df_2010.age_x==35])
df_age_36=df_age_36.append(df_2010[df_2010.age_x==36])
df_age_37=df_age_37.append(df_2010[df_2010.age_x==37])
df_age_38=df_age_38.append(df_2010[df_2010.age_x==38])
df_age_39=df_age_39.append(df_2010[df_2010.age_x==39])
df_age_40=df_age_40.append(df_2010[df_2010.age_x==40])

# %%
df_age_18=df_age_18.append(df_2011[df_2011.age_x==18])
df_age_19=df_age_19.append(df_2011[df_2011.age_x==19])

df_age_20=df_age_20.append(df_2011[df_2011.age_x==20])
df_age_21=df_age_21.append(df_2011[df_2011.age_x==21])
df_age_22=df_age_22.append(df_2011[df_2011.age_x==22])
df_age_23=df_age_23.append(df_2011[df_2011.age_x==23])
df_age_24=df_age_24.append(df_2011[df_2011.age_x==24])
df_age_25=df_age_25.append(df_2011[df_2011.age_x==25])
df_age_26=df_age_26.append(df_2011[df_2011.age_x==26])
df_age_27=df_age_27.append(df_2011[df_2011.age_x==27])
df_age_28=df_age_28.append(df_2011[df_2011.age_x==28])
df_age_29=df_age_29.append(df_2011[df_2011.age_x==29])

df_age_30=df_age_30.append(df_2011[df_2011.age_x==30])
df_age_31=df_age_31.append(df_2011[df_2011.age_x==31])
df_age_32=df_age_32.append(df_2011[df_2011.age_x==32])
df_age_33=df_age_33.append(df_2011[df_2011.age_x==33])
df_age_34=df_age_34.append(df_2011[df_2011.age_x==34])
df_age_35=df_age_35.append(df_2011[df_2011.age_x==35])
df_age_36=df_age_36.append(df_2011[df_2011.age_x==36])
df_age_37=df_age_37.append(df_2011[df_2011.age_x==37])
df_age_38=df_age_38.append(df_2011[df_2011.age_x==38])
df_age_39=df_age_39.append(df_2011[df_2011.age_x==39])
df_age_40=df_age_40.append(df_2011[df_2011.age_x==40])

# %%
df_age_18=df_age_18.append(df_2012[df_2012.age_x==18])
df_age_19=df_age_19.append(df_2012[df_2012.age_x==19])

df_age_20=df_age_20.append(df_2012[df_2012.age_x==20])
df_age_21=df_age_21.append(df_2012[df_2012.age_x==21])
df_age_22=df_age_22.append(df_2012[df_2012.age_x==22])
df_age_23=df_age_23.append(df_2012[df_2012.age_x==23])
df_age_24=df_age_24.append(df_2012[df_2012.age_x==24])
df_age_25=df_age_25.append(df_2012[df_2012.age_x==25])
df_age_26=df_age_26.append(df_2012[df_2012.age_x==26])
df_age_27=df_age_27.append(df_2012[df_2012.age_x==27])
df_age_28=df_age_28.append(df_2012[df_2012.age_x==28])
df_age_29=df_age_29.append(df_2012[df_2012.age_x==29])

df_age_30=df_age_30.append(df_2012[df_2012.age_x==30])
df_age_31=df_age_31.append(df_2012[df_2012.age_x==31])
df_age_32=df_age_32.append(df_2012[df_2012.age_x==32])
df_age_33=df_age_33.append(df_2012[df_2012.age_x==33])
df_age_34=df_age_34.append(df_2012[df_2012.age_x==34])
df_age_35=df_age_35.append(df_2012[df_2012.age_x==35])
df_age_36=df_age_36.append(df_2012[df_2012.age_x==36])
df_age_37=df_age_37.append(df_2012[df_2012.age_x==37])
df_age_38=df_age_38.append(df_2012[df_2012.age_x==38])
df_age_39=df_age_39.append(df_2012[df_2012.age_x==39])
df_age_40=df_age_40.append(df_2012[df_2012.age_x==40])

# %%
df_age_18=df_age_18.append(df_2013[df_2013.age==18])
df_age_19=df_age_19.append(df_2013[df_2013.age==19])

df_age_20=df_age_20.append(df_2013[df_2013.age==20])
df_age_21=df_age_21.append(df_2013[df_2013.age==21])
df_age_22=df_age_22.append(df_2013[df_2013.age==22])
df_age_23=df_age_23.append(df_2013[df_2013.age==23])
df_age_24=df_age_24.append(df_2013[df_2013.age==24])
df_age_25=df_age_25.append(df_2013[df_2013.age==25])
df_age_26=df_age_26.append(df_2013[df_2013.age==26])
df_age_27=df_age_27.append(df_2013[df_2013.age==27])
df_age_28=df_age_28.append(df_2013[df_2013.age==28])
df_age_29=df_age_29.append(df_2013[df_2013.age==29])

df_age_30=df_age_30.append(df_2013[df_2013.age==30])
df_age_31=df_age_31.append(df_2013[df_2013.age==31])
df_age_32=df_age_32.append(df_2013[df_2013.age==32])
df_age_33=df_age_33.append(df_2013[df_2013.age==33])
df_age_34=df_age_34.append(df_2013[df_2013.age==34])
df_age_35=df_age_35.append(df_2013[df_2013.age==35])
df_age_36=df_age_36.append(df_2013[df_2013.age==36])
df_age_37=df_age_37.append(df_2013[df_2013.age==37])
df_age_38=df_age_38.append(df_2013[df_2013.age==38])
df_age_39=df_age_39.append(df_2013[df_2013.age==39])
df_age_40=df_age_40.append(df_2013[df_2013.age==40])

# %%
df_age_18=df_age_18.append(df_2014[df_2014.age==18])
df_age_19=df_age_19.append(df_2014[df_2014.age==19])

df_age_20=df_age_20.append(df_2014[df_2014.age==20])
df_age_21=df_age_21.append(df_2014[df_2014.age==21])
df_age_22=df_age_22.append(df_2014[df_2014.age==22])
df_age_23=df_age_23.append(df_2014[df_2014.age==23])
df_age_24=df_age_24.append(df_2014[df_2014.age==24])
df_age_25=df_age_25.append(df_2014[df_2014.age==25])
df_age_26=df_age_26.append(df_2014[df_2014.age==26])
df_age_27=df_age_27.append(df_2014[df_2014.age==27])
df_age_28=df_age_28.append(df_2014[df_2014.age==28])
df_age_29=df_age_29.append(df_2014[df_2014.age==29])

df_age_30=df_age_30.append(df_2014[df_2014.age==30])
df_age_31=df_age_31.append(df_2014[df_2014.age==31])
df_age_32=df_age_32.append(df_2014[df_2014.age==32])
df_age_33=df_age_33.append(df_2014[df_2014.age==33])
df_age_34=df_age_34.append(df_2014[df_2014.age==34])
df_age_35=df_age_35.append(df_2014[df_2014.age==35])
df_age_36=df_age_36.append(df_2014[df_2014.age==36])
df_age_37=df_age_37.append(df_2014[df_2014.age==37])
df_age_38=df_age_38.append(df_2014[df_2014.age==38])
df_age_39=df_age_39.append(df_2014[df_2014.age==39])
df_age_40=df_age_40.append(df_2014[df_2014.age==40])

# %%
df_age_18=df_age_18.append(df_2015[df_2015.age==18])
df_age_19=df_age_19.append(df_2015[df_2015.age==19])

df_age_20=df_age_20.append(df_2015[df_2015.age==20])
df_age_21=df_age_21.append(df_2015[df_2015.age==21])
df_age_22=df_age_22.append(df_2015[df_2015.age==22])
df_age_23=df_age_23.append(df_2015[df_2015.age==23])
df_age_24=df_age_24.append(df_2015[df_2015.age==24])
df_age_25=df_age_25.append(df_2015[df_2015.age==25])
df_age_26=df_age_26.append(df_2015[df_2015.age==26])
df_age_27=df_age_27.append(df_2015[df_2015.age==27])
df_age_28=df_age_28.append(df_2015[df_2015.age==28])
df_age_29=df_age_29.append(df_2015[df_2015.age==29])

df_age_30=df_age_30.append(df_2015[df_2015.age==30])
df_age_31=df_age_31.append(df_2015[df_2015.age==31])
df_age_32=df_age_32.append(df_2015[df_2015.age==32])
df_age_33=df_age_33.append(df_2015[df_2015.age==33])
df_age_34=df_age_34.append(df_2015[df_2015.age==34])
df_age_35=df_age_35.append(df_2015[df_2015.age==35])
df_age_36=df_age_36.append(df_2015[df_2015.age==36])
df_age_37=df_age_37.append(df_2015[df_2015.age==37])
df_age_38=df_age_38.append(df_2015[df_2015.age==38])
df_age_39=df_age_39.append(df_2015[df_2015.age==39])
df_age_40=df_age_40.append(df_2015[df_2015.age==40])

# %%
df_age_18.to_csv('AgeData/df_age_18.csv')
df_age_19.to_csv('AgeData/df_age_19.csv')

df_age_20.to_csv('AgeData/df_age_20.csv')
df_age_21.to_csv('AgeData/df_age_21.csv')
df_age_22.to_csv('AgeData/df_age_22.csv')
df_age_23.to_csv('AgeData/df_age_23.csv')
df_age_24.to_csv('AgeData/df_age_24.csv')
df_age_25.to_csv('AgeData/df_age_25.csv')
df_age_26.to_csv('AgeData/df_age_26.csv')
df_age_27.to_csv('AgeData/df_age_27.csv')
df_age_28.to_csv('AgeData/df_age_28.csv')
df_age_29.to_csv('AgeData/df_age_29.csv')

df_age_30.to_csv('AgeData/df_age_30.csv')
df_age_31.to_csv('AgeData/df_age_31.csv')
df_age_32.to_csv('AgeData/df_age_32.csv')
df_age_33.to_csv('AgeData/df_age_33.csv')
df_age_34.to_csv('AgeData/df_age_34.csv')
df_age_35.to_csv('AgeData/df_age_35.csv')
df_age_36.to_csv('AgeData/df_age_36.csv')
df_age_37.to_csv('AgeData/df_age_37.csv')
df_age_38.to_csv('AgeData/df_age_38.csv')
df_age_39.to_csv('AgeData/df_age_39.csv')

df_age_40.to_csv('AgeData/df_age_40.csv')

# %%
df_age_30
# Out:
#      TOT  age  age_x  age_y  assists_ev  assists_pp  assists_sh  blocks  \
# 90   VAN  NaN     30     30           3           0           0       6
# 187  TOR  NaN     30     30           4           2           0      14
# 199  NYI  NaN     30     30           3           0           0      14
# 209  LAK  NaN     30     30           4           0           0       8
# 240  PHI  NaN     30     30           5           0           0      29
# 397  NYR  NaN     30     30          11           0           0      33
# 196  STL  NaN     30     30           1           0           0      25
#
#      corsi_against  corsi_for       ...         season  shot_pct  shot_pct.1  \
# 90             100        115       ...        2016-17       4.2         4.2
# 187            281        277       ...        2016-17      11.5        11.5
# 199            209        182       ...        2016-17       6.7         6.7
# 209            197        229       ...        2016-17       5.9         5.9
# ...
