# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
df_similar=pd.read_csv('PCA_Folder/similarity.csv',index_col=0)

# %%
df_player_1996=pd.read_csv('df_1996.csv',index_col=0)
df_player_1997=pd.read_csv('df_1997.csv',index_col=0)
df_player_1998=pd.read_csv('df_1998.csv',index_col=0)
df_player_1999=pd.read_csv('df_1999.csv',index_col=0)
df_player_2000=pd.read_csv('df_2000.csv',index_col=0)
df_player_2001=pd.read_csv('df_2001.csv',index_col=0)
df_player_2002=pd.read_csv('df_2002.csv',index_col=0)
df_player_2003=pd.read_csv('df_2003.csv',index_col=0)
df_player_2004=pd.read_csv('df_2004.csv',index_col=0)
df_player_2005=pd.read_csv('df_2005.csv',index_col=0)
df_player_2006=pd.read_csv('df_2006.csv',index_col=0)
df_player_2007=pd.read_csv('df_2007.csv',index_col=0)
df_player_2008=pd.read_csv('df_2008.csv',index_col=0)
df_player_2009=pd.read_csv('df_2009.csv',index_col=0)

df_player_2010=pd.read_csv('df_2010.csv',index_col=0)
df_player_2011=pd.read_csv('df_2011.csv',index_col=0)
df_player_2012=pd.read_csv('df_2012.csv',index_col=0)
df_player_2013=pd.read_csv('df_2013.csv',index_col=0)
df_player_2014=pd.read_csv('df_2014.csv',index_col=0)
df_player_2015=pd.read_csv('df_2015.csv',index_col=0)

# %%
df_player_year=pd.read_csv('player_year.csv',index_col=0)

# %%
df_player_year.head()
# Out:
#         name  year
# 0  adamscr01  1996
# 1  ashamar01  1996
# 2  beginst01  1996
# 3  belaner01  1996
# 4  bouleje01  1996

# %%
dict_player_year = dict(zip(df_player_year.name, df_player_year.year))

# %%
# Out:
# 2007

# %%
df_similar.columns[:2]
# Out:
# Index([u'macenma01', u'staffdr01'], dtype='object')

# %%
min(df_similar['macenma01'][df_similar['macenma01']!=0])
# Out:
# 19.6687233205

# %%
def sorted(s, num):
    tmp = s.order(ascending=False)[:num]
    tmp.index = range(num)
    return tmp

# %%
#df_similar['macenma01'][df_similar['macenma01']!=0]
newdf_similar=df_similar.sort('macenma01', ascending=True)
simplayers=newdf_similar['macenma01'][newdf_similar['macenma01']!=0][:10]

# %%
simplayers.index
# Out:
# Index([u'lauriol01', u'omarrry01', u'olvecpe01', u'robakco01', u'gillico01',
#        u'johnsst03', u'pitlity01', u'summech01', u'shoredr01', u'oleksja01'],
#       dtype='object', name=u'name')

# %%
simplayers
# Out:
# name
# lauriol01    19.668723
# omarrry01    36.303722
# olvecpe01    51.986218
# robakco01    55.547616
# gillico01    56.372262
# johnsst03    56.471197
# pitlity01    58.090721
# summech01    58.131942
# shoredr01    58.511342
# oleksja01    61.114358
# Name: macenma01, dtype: float64

# %%
newdf_similar['lauriol01']
# Out:
# name
# macenma01      19.668723
# sundsjo01       0.000000
# hudleji01    1426.007755
# adamscr01       0.000000
# blancni01      98.217431
# friesal01       4.202205
# ristora01       0.000000
# monahse01       0.000000
# kapanni01       0.000000
# pastrda01       0.000000
# edmunjo01       0.000000
# kondrma01      20.135937
# bodietr01     770.982005
# coppan01        0.000000
# bourdlu01       0.000000
# mackina01       0.000000
# sjostfr01    1158.490678
# scheima01       0.000000
# parkesc01       0.000000
# mccarst01       0.000000
# lacouda01       0.000000
# goldoni01       0.000000
# wymanja01     523.723057
# comrimi01       0.000000
# bjorkol01       0.000000
# laakste01       0.000000
# leivojo01       0.000000
# gocma01       952.977534
# pointbr01       0.000000
# wilsoto01       0.000000
#                 ...
# seabrbr01    1556.158919
# whiteia01    1898.030216
# edleral01    1566.905502
# eberljo01    1339.265085
# alzneka01    1491.098453
# kulikdm01    1354.798664
# yandlke01    1628.368001
# mcbaija02    1368.521793
# leddyni01     719.192788
# kanepa01     1390.233981
# ryanbo01     1104.733961
# hamontr01    1607.037104
# schulju01    1285.197858
# greenmi03    1264.197858
# staaler01    1464.427354
# vlasima01    2069.250518
# johnsja02    1612.495247
# webersh01    1650.319724
# barrity01    2091.152524
# staalma01    1174.779535
# broditj01    1566.127792
# coburbr01    1644.870497
# kesseph01    2160.670862
# letankr01    1160.857915
# josiro01     1757.239309
# gardija01    1645.848450
# ekmanol01    2272.924048
# phanedi01    1652.743434
# klingjo01    2456.560328
# karlser01    2197.367944
# Name: lauriol01, dtype: float64

# %%
newdf_similar=df_similar.sort('staffdr01', ascending=True)
newdf_similar['staffdr01'][newdf_similar['staffdr01']!=0][:10]
# Out:
# name
# kanebo01       1.272131
# whitftr01      8.440595
# lacouda01     53.211739
# brouwtr01     81.308313
# callary01     88.281765
# lessafr01     91.792517
# bourdma01    104.305576
# laddan01     115.868858
# spalini01    119.882901
# jaskidm01    122.977461
# Name: staffdr01, dtype: float64

# %%
newdf_similar['staffdr01'][newdf_similar['staffdr01']!=0][:10].index[0]
# Out:
# 'macenma01'

# %%
a[0]
# Out:
# 0.23221580423839394

# %%
lists_of_lists = [[1, 2, 3], [4, 5, 6], [4, 5, 6]]
[sum(x) for x in zip(*lists_of_lists)]
# Out:
# [9, 12, 15]

# %%
a=(100/newdf_similar['macenma01'][newdf_similar['macenma01']!=0][:10])/sum(100/newdf_similar['macenma01'][newdf_similar['macenma01']!=0][:10])

# %%
df_similar.sort(cur_play, ascending=True)
# Out:
#             macenma01    staffdr01    rangepa01    collije01    fransco01  \
# name
# rakelri01    0.000000   529.561855     0.000000     0.000000   417.279473
# datsypa01    0.000000   879.906773     0.000000     0.000000     0.000000
# brentti01    0.000000   487.672734     0.000000   928.808521   579.395114
# ryanmi01     0.000000   724.697409     0.000000     0.000000   899.573677
# pelecma01    0.000000  1976.888044     0.000000   216.411132  2232.718308
# horvabo01    0.000000     0.000000     0.000000     0.000000     0.000000
# oystrna01    0.000000   676.084334     0.000000   943.253601   816.366001
# widemch01    0.000000   563.711381     0.000000  1205.508669  1019.416935
# reinhma01    0.000000  1088.791692     0.000000     0.000000  1187.097440
# gaudrjo01    0.000000  1035.712155     0.000000     0.000000   949.375208
# riellmo01    0.000000  1118.347798     0.000000     0.000000  1214.723541
# malonry01    0.000000   305.008175     0.000000     0.000000   445.030974
# gauthfr01    0.000000     0.000000     0.000000     0.000000     0.000000
# lindbpe02    0.000000   938.211979     0.000000     0.000000  1034.469139
# borerca01    0.000000   914.330189     0.000000     0.000000  1010.614693
# lehtomi02    0.000000  1135.484624     0.000000     0.000000  1230.972222
# strakpe01    0.000000  1104.024367     0.000000     0.000000  1200.309077
# dadonev01    0.000000   907.676320     0.000000     0.000000  1004.506105
# dibenju01    0.000000  1041.652964     0.000000     0.000000  1141.901068
# negrijo01    0.000000     0.000000     0.000000     0.000000     0.000000
# koekksl01    0.000000     0.000000     0.000000     0.000000     0.000000
# galchal01    0.000000  1099.632127     0.000000     0.000000  1197.887920
# blandjo01    0.000000     0.000000     0.000000     0.000000     0.000000
# leipsbr01    0.000000     0.000000     0.000000     0.000000     0.000000
# marshke01    0.000000   992.903533     0.000000     0.000000  1093.700711
# hollobu01    0.000000  1010.078124     0.000000     0.000000  2083.106221
# kalindm01    0.000000   150.525793     0.000000     0.000000   573.544499
# pescebr01    0.000000     0.000000     0.000000     0.000000     0.000000
# lehtejo01    0.000000   349.915123     0.000000     0.000000   357.998616
# nurseda01    0.000000     0.000000     0.000000     0.000000     0.000000
# ...               ...          ...          ...          ...          ...
# klingca01  306.190909  1635.134093  2180.215325   113.320396  1718.684896
# mcfarjo01  304.285388  1635.452952  2180.966516   116.555166  1719.391923
# ouellxa01  308.914487   943.073578  2181.321563   114.552129  1007.327451
# kucheni01  312.098901   887.386297  2181.796657   113.969468   877.326190
# ellismo01  309.202461  1637.396664  2182.266336   114.935250  1720.816560
# millejt01  308.606891   819.546863  2182.876315   115.883030   827.133064
# agostke01  310.473188  1639.001193  2183.057005   116.166292  1722.347855
# arvidvi01  313.466969   628.593110  2184.866311   117.113127   643.884767
# murrary01  311.564589  1045.287991  2185.899570   119.370310  1055.204022
# danauph01  310.680179   644.644822  2186.463533   120.833505   717.581359
# ritchbr01  314.480499   937.391455  2187.987380   120.792704  1001.699236
# paquece01  318.580557   653.653340  2190.518311   122.850419   729.357647
# hertlto01  316.673790   887.991128  2191.682233   125.156305   874.519850
# murphco02  320.547473   970.212453  2194.397884   127.695967   983.003237
# sissoco01  320.829190   831.740685  2194.836393   128.144067   896.299969
# oneilwe01  322.108834   969.886429  2194.902296   127.894856  1033.984435
# cousini01  321.297875   780.282414  2195.738174   129.136448   844.047725
# bulmebr01  319.474798  1650.543077  2195.997527   130.833286  1734.434875
# cecico01   323.626358   900.489415  2196.562683   129.055047   919.478185
# raskvi01   327.519475   870.302970  2196.802478   129.699050   871.888580
# salommi01  322.735956   640.145804  2197.158344   130.640190   721.773516
# shuggju01  323.373514  1652.459074  2197.416253   130.344659  1735.977616
# nugenry01  324.642695   700.161062  2199.373152   132.460017   720.787297
# huttobe01  327.533395   898.315368  2200.820078   133.610723   911.577095
# brownco02  328.503553   945.860346  2203.139388   136.097985  1009.587791
# kulakbr01  331.033725   937.504119  2204.518037   137.585505  1001.047554
# girgeze01  334.613692   681.954973  2205.588562   138.447302   714.576034
# granlma01  335.563950   691.042487  2206.645253   139.588374   773.370834
# lockeco01  338.566916  1278.192057  2211.703676   117.228746  1397.915012
# armiajo01  338.137342   739.601784  2212.452286   145.295810   806.483535
#
#              scevico01    fabbrro01    brodzky01    richami02    jurcoto01  \
# name
# rakelri01     0.000000  1103.411724     0.000000   242.250781   477.258184
# datsypa01     0.000000     0.000000   764.887287  1412.059041     0.000000
# brentti01   264.594132     0.000000   561.333361  1458.296645     0.000000
# ryanmi01      0.000000     0.000000  1513.304316  1587.317156     0.000000
# pelecma01  1222.885320     0.000000  1708.523706     0.000000   561.135010
# horvabo01     0.000000   419.218834     0.000000     0.000000   658.473322
# oystrna01   171.632432     0.000000   923.185714  1661.837322     0.000000
# widemch01   253.642941     0.000000   837.231713     0.000000     0.000000
# reinhma01     0.000000  1224.824657     0.000000  1627.449980   524.432227
# gaudrjo01     0.000000     0.000000     0.000000   549.111542   912.684587
# riellmo01     0.000000  1028.632988     0.000000  1657.337329  1125.710874
# malonry01     0.000000     0.000000   232.206646   446.396802     0.000000
# gauthfr01     0.000000  1322.644343     0.000000     0.000000     0.000000
# lindbpe02     0.000000     0.000000     0.000000  1482.141282   345.350890
# borerca01     0.000000     0.000000     0.000000  1462.029760   762.331080
# lehtomi02     0.000000     0.000000     0.000000  1674.514017   982.655761
# strakpe01     0.000000     0.000000     0.000000  1643.746296   951.838673
# dadonev01     0.000000  1373.634432     0.000000  1451.348736   323.543380
# dibenju01     0.000000     0.000000     0.000000  1582.295035   892.856598
# negrijo01     0.000000     0.000000     0.000000     0.000000     0.000000
# koekksl01     0.000000     0.000000     0.000000     0.000000   505.769602
# galchal01     0.000000   567.702552     0.000000  1639.452539   816.223619
# blandjo01     0.000000     0.000000     0.000000     0.000000   213.232966
# leipsbr01     0.000000     0.000000     0.000000     0.000000   533.787037
# marshke01     0.000000     0.000000     0.000000  1535.715496   844.629428
# hollobu01     0.000000     0.000000  2085.260848     0.000000     0.000000
# kalindm01     0.000000     0.000000  1114.178359   263.367360     0.000000
# pescebr01     0.000000     0.000000     0.000000     0.000000  1109.894153
# lehtejo01     0.000000     0.000000   602.535864   236.339875     0.000000
# nurseda01     0.000000   722.219423     0.000000     0.000000   650.926687
# ...                ...          ...          ...          ...          ...
# klingca01     0.000000     0.000000  1274.304971     0.000000   395.041734
# mcfarjo01     0.000000     0.000000  1274.013528     0.000000   505.298861
# ouellxa01     0.000000  1360.233836  1276.976279  1571.756553   303.966080
# kucheni01     0.000000   351.639898  1276.843680   400.161686   535.317608
# ellismo01     0.000000     0.000000  1276.775560     0.000000   506.763252
# millejt01     0.000000   897.990970  1276.414959   312.599046   362.778112
# agostke01     0.000000     0.000000  1278.507262     0.000000   365.121483
# arvidvi01     0.000000     0.000000  1279.816695   566.314293   240.973623
# murrary01     0.000000   246.362453  1280.305682   918.750228   457.087050
# danauph01     0.000000     0.000000  1279.969113   755.024798   241.801648
# ritchbr01     0.000000     0.000000  1282.400795  1547.217768   273.888538
# paquece01     0.000000  1399.296542  1285.397776   779.028319   212.896959
# hertlto01     0.000000   555.546215  1285.331832   463.495118   530.230112
# murphco02     0.000000   643.548723  1289.259171   680.820946   573.405342
# sissoco01     0.000000  1216.173898  1289.574309  1254.736909   379.114130
# oneilwe01     0.000000     0.000000  1290.232501  1633.297844   516.772823
# cousini01     0.000000     0.000000  1290.165274  1112.311080   278.955833
# bulmebr01     0.000000     0.000000  1289.152414     0.000000   394.364914
# cecico01      0.000000   187.107426  1291.111872   518.157733   596.089359
# raskvi01      0.000000     0.000000  1293.170398   382.586670   519.418031
# salommi01     0.000000     0.000000  1291.732147   730.070014   253.182725
# shuggju01     0.000000     0.000000  1291.653039     0.000000   521.894960
# nugenry01     0.000000   828.243936  1293.007009   319.381336   472.017041
# huttobe01     0.000000     0.000000  1295.621323   497.467390   560.299314
# brownco02     0.000000     0.000000  1296.772940  1557.841899   492.479707
# kulakbr01     0.000000     0.000000  1299.561239  1533.749337   483.884809
# girgeze01     0.000000   227.319439  1301.658095   387.080632   366.282115
# granlma01     0.000000  1348.403881  1302.784504   840.987830   218.535487
# lockeco01  1194.448411     0.000000  1055.739510     0.000000   536.420564
# armiajo01     0.000000     0.000000  1306.538868   981.348408   289.633503
#
#               ...         smithbr05    schulju01    bouwmja01  byersda01  \
# name          ...
# rakelri01     ...       1357.625557     0.000000     0.000000   0.000000
# datsypa01     ...          0.000000     0.000000   367.207754   0.000000
# brentti01     ...        565.080374  1127.694722  1004.430604   0.000000
# ryanmi01      ...        523.994445     0.000000  1621.884803   0.000000
# pelecma01     ...       1537.946316    19.798631  2383.749474   0.000000
# horvabo01     ...          0.000000     0.000000     0.000000   0.000000
# oystrna01     ...        153.078032  1137.977639  1236.098506   0.000000
# widemch01     ...        128.775118  1402.508817  1278.142030   0.000000
# reinhma01     ...        252.148403     0.000000     0.000000   0.000000
# gaudrjo01     ...       1883.096026     0.000000     0.000000   0.000000
# riellmo01     ...        276.720153     0.000000     0.000000   0.000000
# malonry01     ...          0.000000     0.000000   464.960332   0.000000
# gauthfr01     ...          0.000000     0.000000     0.000000   0.000000
# lindbpe02     ...         99.954492     0.000000     0.000000   0.000000
# borerca01     ...         75.594904     0.000000     0.000000   0.000000
# lehtomi02     ...        292.022379     0.000000     0.000000   0.000000
# strakpe01     ...        261.962389     0.000000     0.000000   0.000000
# dadonev01     ...         76.917268     0.000000     0.000000   0.000000
# dibenju01     ...        210.050691     0.000000     0.000000   0.000000
# negrijo01     ...          0.000000     0.000000     0.000000   0.000000
# koekksl01     ...          0.000000     0.000000     0.000000   0.000000
# galchal01     ...        261.300277     0.000000     0.000000   0.000000
# blandjo01     ...          0.000000     0.000000     0.000000   0.000000
# leipsbr01     ...          0.000000     0.000000     0.000000   0.000000
# marshke01     ...        164.650886     0.000000     0.000000   0.000000
# hollobu01     ...         51.004689     0.000000  2658.176970   0.000000
# kalindm01     ...        925.788550     0.000000   941.850109   0.000000
# pescebr01     ...          0.000000     0.000000     0.000000   0.000000
# lehtejo01     ...       1506.722542     0.000000   761.024859   0.000000
# nurseda01     ...          0.000000     0.000000     0.000000   0.000000
# ...           ...               ...          ...          ...        ...
# klingca01     ...        784.802759  2358.333956     0.000000   6.006517
# mcfarjo01     ...        786.941730  2356.833486     0.000000  18.484456
# ouellxa01     ...        345.907093  2360.949683     0.000000   7.396075
# kucheni01     ...        879.290342  2362.668766     0.000000  17.987204
# ellismo01     ...        786.411316  2361.136760     0.000000   6.472454
# millejt01     ...        820.105464  2360.632911     0.000000  10.122389
# agostke01     ...        786.998137  2362.528609     0.000000   7.956325
# arvidvi01     ...        582.267819  2364.856657     0.000000  12.814110
# murrary01     ...       1041.929895  2363.945888     0.000000  10.501903
# danauph01     ...        517.541674  2363.190660     0.000000  15.809256
# ritchbr01     ...        342.546646  2366.578472     0.000000  11.661380
# paquece01     ...        512.749110  2370.217188     0.000000  16.024947
# hertlto01     ...        877.256363  2369.026646     0.000000  17.178232
# murphco02     ...        968.868591  2372.936348     0.000000  18.182275
# sissoco01     ...        337.097691  2373.234855     0.000000  18.622223
# oneilwe01     ...        371.832136  2374.263871     0.000000  19.012057
# cousini01     ...        387.952947  2373.749982     0.000000  19.753220
# bulmebr01     ...        801.665400  2372.045588     0.000000  25.054219
# cecico01      ...        898.107401  2375.587736     0.000000  20.483927
# raskvi01      ...        868.703144  2378.483378     0.000000  27.763949
# salommi01     ...        531.317377  2375.230583     0.000000  21.211964
# shuggju01     ...        801.772409  2375.638128     0.000000  21.059156
# nugenry01     ...        700.957393  2376.922390     0.000000  23.776703
# huttobe01     ...        897.343093  2379.732343     0.000000  24.417787
# brownco02     ...        348.867972  2380.762910     0.000000  27.296988
# kulakbr01     ...        339.299994  2383.388703     0.000000  28.250200
# girgeze01     ...        680.461335  2386.310608     0.000000  32.028857
# granlma01     ...        497.027618  2387.331068     0.000000  32.949397
# lockeco01     ...        822.688674   851.806267  2355.215165  35.424431
# armiajo01     ...        440.128330  2390.486202     0.000000  36.027937
#
#              goligal01    potito01    carsobr01   jokinol01    radulal01  \
# name
# rakelri01  1590.670755    0.000000     0.000000    0.000000   444.991592
# datsypa01  1150.292122  345.945256     0.000000  185.762352  1950.567770
# brentti01   698.987671    0.000000   928.872807    0.000000     0.000000
# ryanmi01   1108.492201    0.000000   408.569070    0.000000     0.000000
# pelecma01  2159.740958    0.000000     0.000000    0.000000  1685.692183
# horvabo01     0.000000    0.000000     0.000000    0.000000  1782.802985
# oystrna01   916.709739    0.000000   125.937978    0.000000     0.000000
# widemch01   780.627646    0.000000   155.873479    0.000000     0.000000
# reinhma01    20.888725    0.000000     0.000000    0.000000  1666.483930
# gaudrjo01  2113.459300    0.000000     0.000000    0.000000   307.764856
# riellmo01    40.156975    0.000000     0.000000    0.000000  1090.639254
# malonry01   644.763607  148.791357     0.000000  385.397656  1567.596975
# gauthfr01     0.000000    0.000000     0.000000    0.000000     0.000000
# lindbpe02   142.991509    0.000000     0.000000    0.000000  1289.010453
# borerca01   169.480756    0.000000     0.000000    0.000000     0.000000
# lehtomi02    57.085963    0.000000     0.000000    0.000000     0.000000
# strakpe01    25.776702    0.000000     0.000000    0.000000     0.000000
# dadonev01   172.982037    0.000000     0.000000    0.000000   998.830246
# dibenju01    43.938696    0.000000     0.000000    0.000000     0.000000
# negrijo01     0.000000    0.000000     0.000000    0.000000     0.000000
# koekksl01     0.000000    0.000000     0.000000    0.000000  1629.890135
# galchal01    23.287406    0.000000     0.000000    0.000000   243.349847
# blandjo01     0.000000    0.000000     0.000000    0.000000  1010.222184
# leipsbr01     0.000000    0.000000     0.000000    0.000000  1657.821250
# marshke01    89.159583    0.000000     0.000000    0.000000     0.000000
# hollobu01  1425.658434    0.000000   167.219497    0.000000     0.000000
# kalindm01   428.089432    0.000000   808.979345    0.000000     0.000000
# pescebr01     0.000000    0.000000     0.000000    0.000000   182.586749
# lehtejo01   337.416959    0.000000  1390.858269    0.000000     0.000000
# nurseda01     0.000000    0.000000     0.000000    0.000000  1774.197905
# ...                ...         ...          ...         ...          ...
# klingca01   965.470506    0.000000    42.761848    0.000000  1738.235964
# mcfarjo01   966.721580    0.000000    43.446805    0.000000     0.000000
# ouellxa01   359.557170    0.000000    45.304578    0.000000  1313.992443
# kucheni01  1025.777701    0.000000    51.425738    0.000000     0.000000
# ellismo01   967.410248    0.000000    45.702936    0.000000     0.000000
# millejt01   964.639237    0.000000    45.722462    0.000000   610.680512
# agostke01   968.480005    0.000000    46.773407    0.000000  1644.705128
# arvidvi01   728.659476    0.000000    50.726588    0.000000  1700.162180
# murrary01  1185.936199    0.000000    47.958642    0.000000  1492.693095
# danauph01   662.272337    0.000000    48.302780    0.000000  1766.013127
# ritchbr01   370.459530    0.000000    50.855447    0.000000  1165.492880
# paquece01   657.312633    0.000000    55.311375    0.000000   689.675800
# hertlto01  1024.422981    0.000000    53.679860    0.000000   124.556446
# murphco02  1112.223904    0.000000    56.787879    0.000000   346.656295
# sissoco01   481.008947    0.000000    57.112960    0.000000     0.000000
# oneilwe01   351.581444    0.000000    58.295254    0.000000     0.000000
# cousini01   533.847490    0.000000    57.756647    0.000000  1644.115304
# bulmebr01   981.690671    0.000000    57.987437    0.000000  1718.072956
# cecico01   1040.326690    0.000000    60.017462    0.000000   403.271334
# raskvi01   1014.586841    0.000000    65.390735    0.000000    96.774891
# salommi01   674.956165    0.000000    59.180060    0.000000  1780.098897
# shuggju01   982.685429    0.000000    59.806800    0.000000     0.000000
# nugenry01   844.995693    0.000000    61.548611    0.000000   318.824634
# huttobe01  1040.996666    0.000000    63.748012    0.000000     0.000000
# brownco02   371.956349    0.000000    65.378120    0.000000     0.000000
# kulakbr01   381.635593    0.000000    67.239218    0.000000     0.000000
# girgeze01   824.597302    0.000000    71.193217    0.000000   575.523125
# granlma01   637.178900    0.000000    72.088657    0.000000   876.943287
# lockeco01  1106.329289    0.000000    74.792037    0.000000     0.000000
# armiajo01   584.725112    0.000000    74.702544    0.000000     0.000000
#
#              hertlto01
# name
# rakelri01   281.573335
# datsypa01     0.000000
# brentti01     0.000000
# ryanmi01      0.000000
# pelecma01  1803.629450
# horvabo01  1005.014812
# oystrna01     0.000000
# widemch01     0.000000
# reinhma01   846.858235
# gaudrjo01   194.097605
# riellmo01   869.613493
# malonry01     0.000000
# gauthfr01   782.929746
# lindbpe02  1126.112950
# borerca01  1753.523320
# lehtomi02  1974.103446
# strakpe01  1943.537249
# dadonev01   711.152321
# dibenju01  1885.344607
# negrijo01     0.000000
# koekksl01  1747.912040
# galchal01   615.370832
# blandjo01  1130.435736
# leipsbr01  1775.971348
# marshke01  1837.076656
# hollobu01     0.000000
# kalindm01     0.000000
# pescebr01   248.391407
# lehtejo01     0.000000
# nurseda01  1115.254975
# ...                ...
# klingca01   660.557814
# mcfarjo01    14.939910
# ouellxa01   516.891238
# kucheni01    67.328128
# ellismo01    12.781679
# millejt01   177.606627
# agostke01   628.830725
# arvidvi01   513.665900
# murrary01   383.260074
# danauph01   562.980585
# ritchbr01   604.747522
# paquece01   342.389704
# hertlto01     0.000000
# murphco02   136.306637
# sissoco01   428.812907
# oneilwe01   688.306329
# cousini01   608.992741
# bulmebr01   652.673502
# cecico01    150.184726
# raskvi01     58.383063
# salommi01   563.440113
# shuggju01     8.117677
# nugenry01   275.223888
# huttobe01   148.417269
# brownco02   660.954607
# kulakbr01   653.294620
# girgeze01   253.524419
# granlma01   373.474346
# lockeco01    23.302906
# armiajo01   457.115082
#
# [1305 rows x 1305 columns]

# %%
len(df_similar)
# Out:
# 1305

# %%
df_similar.columns[0]
# Out:
# 'macenma01'

# %%
result_lists=[]
for j in range(0,len(df_similar)):
    cur_play=df_similar.columns[j]
    newdf_similar=df_similar.sort(cur_play, ascending=True)

    names=newdf_similar[cur_play][newdf_similar[cur_play]!=0][:10].index
    all_value=(100/newdf_similar[cur_play][newdf_similar[cur_play]!=0][:10])/sum(100/newdf_similar[cur_play][newdf_similar[cur_play]!=0][:10])
    lists_of_lists=[]
    
    for i in range(0,10):
        if names[i] in dict_player_year:
            if dict_player_year[names[i]]==1996:
                result = map(lambda x: x * all_value[i], list(df_player_1996[df_player_1996['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==1997:
                result = map(lambda x: x * all_value[i], list(df_player_1997[df_player_1997['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==1998:
                result = map(lambda x: x * all_value[i], list(df_player_1998[df_player_1998['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==1999:
                result = map(lambda x: x * all_value[i], list(df_player_1999[df_player_1999['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2000:
                result = map(lambda x: x * all_value[i], list(df_player_2000[df_player_2000['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2001:
                result = map(lambda x: x * all_value[i], list(df_player_2001[df_player_2001['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2002:
                result = map(lambda x: x * all_value[i], list(df_player_2002[df_player_2002['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2003:
                result = map(lambda x: x * all_value[i], list(df_player_2003[df_player_2003['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2004:
                result = map(lambda x: x * all_value[i], list(df_player_2004[df_player_2004['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2005:
                result = map(lambda x: x * all_value[i], list(df_player_2005[df_player_2005['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2006:
                result = map(lambda x: x * all_value[i], list(df_player_2006[df_player_2006['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2007:
                result = map(lambda x: x * all_value[i], list(df_player_2007[df_player_2007['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2008:
                result = map(lambda x: x * all_value[i], list(df_player_2008[df_player_2008['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2009:
                result = map(lambda x: x * all_value[i], list(df_player_2009[df_player_2009['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2010:
                result = map(lambda x: x * all_value[i], list(df_player_2010[df_player_2010['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2011:
                result = map(lambda x: x * all_value[i], list(df_player_2011[df_player_2011['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2012:
                result = map(lambda x: x * all_value[i], list(df_player_2012[df_player_2012['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2013:
                result = map(lambda x: x * all_value[i], list(df_player_2013[df_player_2013['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2014:
                result = map(lambda x: x * all_value[i], list(df_player_2014[df_player_2014['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2015:
                result = map(lambda x: x * all_value[i], list(df_player_2015[df_player_2015['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)
        else:
            print names[i]
            
    summList=[sum(x) for x in zip(*lists_of_lists)]   
    summList.insert(0,cur_play)
    #print summList
    result_lists.append(summList)
# Out:
# severda01
# mcginbr01
# kosmasc01
# reinhgr01
# koekksl01
# pelecad01
# laughsc01
# kosmasc01
# stephch02
# severda01
# lindbpe02
# mattest02
# hudonch01
# severda01
# severda01
# murrary01
# loovvi01
# veseyji02
# woodsbr01
# gostish01
# gustaer02
# provoiv01
# samuehe01
# paquece01
# veseyji02
# cecico01
# faksara01
# lindees01
# hinosvi01
# stephch02
# connoky01
# gustaer02
# mcginbr01
# hinosvi01
# brownco02
# sissoco01
# hudonch01
# riellmo01
# grigomi01
# slavija01
# tiernch01
# athanan01
# carrico01
# woodsbr01
# gauncbr01
# forsbfi01
# mattest02
# ahose01
# beauvan01
# zachapa01
# mathemi01
# griffse01
# khairju01
# sundqos01
# pelecad01
# lindees01
# stephch02
# hinosvi01
# carritr01
# mathemi01
# lindees01
# leipsbr01
# gustaer02
# samuehe01
# provoiv01
# slavija01
# wilsoto01
# gauncbr01
# tiernch01
# riellmo01
# hudonch01
# carritr01
# sundqos01
# khairju01
# athanan01
# gauncbr01
# woodsbr01
# carrico01
# mathemi01
# gostish01
# shorede01
# samuehe01
# speerbl01
# gostish01
# bertsch02
# mccabja01
# teravte01
# werenza01
# konectr01
# zachapa01
# mcginbr01
# sundqos01
# khairju01
# simondo01
# sielopa01
# smithco01
# mattest02
# martijo01
# pelecad01
# troubja01
# hanifno01
# maattol01
# lindhha01
# hudonch01
# carritr01
# provoiv01
# carritr01
# faksara01
# mcginbr01
# mcginbr01
# sundqos01
# mattest02
# sielopa01
# zachapa01
# konectr01
# beauvan01
# ahose01
# ahose01
# konectr01
# zachapa01
# teravte01
# wilsoto01
# slavija01
# gauncbr01
# tiernch01
# hanifno01
# pelecad01
# smithco01
# sielopa01
# woodsbr01
# loovvi01
# speerbl01
# speerbl01
# malgide01
# hanifno01
# provoiv01
# forsbfi01
# mathemi01
# mcginbr01
# sundqos01
# khairju01
# digiuph01
# tiernch01
# wilsoto01
# gauncbr01
# carrico01
# slavija01
# huttobe01
# hudonch01
# carritr01
# yakupna01
# sissoco01
# carlobr01
# samuehe01
# provoiv01
# gustaer02
# leierta01
# carritr01
# dumbama01
# galchal01
# mcdavco01
# loovvi01
# samuehe01
# mcdavco01
# zachapa01
# teravte01
# beauvan01
# ahose01
# mcdavco01
# lindhha01
# huttobe01
# hinosvi01
# hinosvi01
# lindees01
# stephch02
# mathemi01
# mathemi01
# lindees01
# leipsbr01
# mcdavco01
# mcginbr01
# murrary01
# hertlto01
# shorede01
# lindees01
# stephch02
# hinosvi01
# kosmasc01
# sundqos01
# samuehe01
# lindbpe02
# griffse01
# dumbama01
# forsbfi01
# galchal01
# faksara01
# mattest02
# gauncbr01
# athanan01
# carrico01
# slavija01
# wilsoto01
# gauncbr01
# carrico01
# smithco01
# sielopa01
# laughsc01
# poulide01
# pelecad01
# anderjo05
# pelecad01
# galchal01
# forsbfi01
# dumbama01
# yakupna01
# sielopa01
# smithco01
# mathemi01
# forsbfi01
# leipsbr01
# hudonch01
# simondo01
# pearsta01
# samuehe01
# koekksl01
# gauncbr01
# paquece01
# cecico01
# mattest02
# mcginbr01
# loovvi01
# veseyji02
# anderjo05
# skjeibr01
# reinhgr01
# laughsc01
# lindees01
# stephch02
# hinosvi01
# mathemi01
# speerbl01
# paquece01
# hinosvi01
# leierta01
# woodsbr01
# paquece01
# cecico01
# sissoco01
# gustaer02
# laughsc01
# speerbl01
# malgide01
# provoiv01
# parayco01
# mcdavco01
# dumbama01
# galchal01
# forsbfi01
# laughsc01
# parayco01
# pelecad01
# reinhgr01
# anderjo05
# skjeibr01
# griffse01
# gostish01
# hudonch01
# carritr01
# severda01
# mathemi01
# maattol01
# teravte01
# pearsta01
# khairju01
# woodsbr01
# parayco01
# hanifno01
# grigomi01
# smithco01
# sielopa01
# hanifno01
# simondo01
# carritr01
# leierta01
# yakupna01
# ahose01
# beauvan01
# konectr01
# zachapa01
# werenza01
# faksara01
# smithco01
# sielopa01
# beauvan01
# ahose01
# konectr01
# zachapa01
# werenza01
# dumbama01
# forsbfi01
# rantami01
# lindbpe02
# carritr01
# hudonch01
# mattest02
# simondo01
# malgide01
# provoiv01
# sielopa01
# smithco01
# sielopa01
# severda01
# carritr01
# khairju01
# murrary01
# pelecad01
# koekksl01
# pelecad01
# milleco02
# anderjo05
# veseyji02
# carlobr01
# connoky01
# paquece01
# provoiv01
# teravte01
# reinhgr01
# martijo01
# griffse01
# simondo01
# laughsc01
# severda01
# mathemi01
# maattol01
# pelecad01
# samuehe01
# carlobr01
# mccabja01
# hudonch01
# carritr01
# hudonch01
# malgide01
# provoiv01
# speerbl01
# veseyji02
# hanifno01
# mathemi01
# hudonch01
# riellmo01
# grigomi01
# tiernch01
# loovvi01
# woodsbr01
# mcginbr01
# gostish01
# kosmasc01
# kulakbr01
# huttobe01
# girgeze01
# brownco02
# cecico01
# samuehe01
# smithco01
# sielopa01
# mcginbr01
# sundqos01
# khairju01
# lindbpe02
# gustaer02
# veseyji02
# paquece01
# leierta01
# woodsbr01
# gostish01
# speerbl01
# woodsbr01
# loovvi01
# leipsbr01
# koekksl01
# hinosvi01
# lindees01
# gustaer02
# lindees01
# hinosvi01
# stephch02
# carrico01
# athanan01
# gauncbr01
# mathemi01
# paquece01
# rantami01
# malgide01
# provoiv01
# carlobr01
# loovvi01
# digiuph01
# blandjo01
# murrary01
# koekksl01
# leipsbr01
# digiuph01
# faksara01
# zachapa01
# konectr01
# beauvan01
# ahose01
# werenza01
# faksara01
# lindhha01
# khairju01
# simondo01
# mccabja01
# loovvi01
# severda01
# maattol01
# girgeze01
# kulakbr01
# huttobe01
# cecico01
# digiuph01
# mcginbr01
# mattest02
# mccabja01
# mathemi01
# carritr01
# hinosvi01
# brownco02
# blandjo01
# lindees01
# mathemi01
# griffse01
# brownco02
# samuehe01
# pelecad01
# mattest02
# troubja01
# parayco01
# leipsbr01
# kosmasc01
# paquece01
# cecico01
# khairju01
# shorede01
# wilsoto01
# tiernch01
# anderjo05
# slavija01
# gauncbr01
# provoiv01
# slavija01
# tiernch01
# riellmo01
# provoiv01
# malgide01
# lindees01
# paquece01
# cecico01
# sissoco01
# koekksl01
# leipsbr01
# rantami01
# faksara01
# blandjo01
# kosmasc01
# blandjo01
# loovvi01
# woodsbr01
# galchal01
# poulide01
# teravte01
# mcdavco01
# digiuph01
# leierta01
# bertsch02
# hanifno01
# simondo01
# sielopa01
# werenza01
# konectr01
# zachapa01
# beauvan01
# ahose01
# rantami01
# gustaer02
# mccabja01
# anderjo05
# kosmasc01
# veseyji02
# sielopa01
# carritr01
# konectr01
# zachapa01
# werenza01
# beauvan01
# ahose01
# poulide01
# galchal01
# forsbfi01
# dumbama01
# mattest02
# malgide01
# griffse01
# severda01
# slavija01
# maattol01
# mcdavco01
# kosmasc01
# carritr01
# hinosvi01
# sielopa01
# khairju01
# shorede01
# anderjo05
# tiernch01
# wilsoto01
# dumbama01
# slavija01
# athanan01
# gauncbr01
# woodsbr01
# carrico01
# faksara01
# woodsbr01
# loovvi01
# mathemi01
# lindees01
# lindbpe02
# blandjo01
# mcginbr01
# lindbpe02
# samuehe01
# sissoco01
# cecico01
# huttobe01
# brownco02
# grigomi01
# riellmo01
# tiernch01
# anderjo05
# slavija01
# mattest02
# dumbama01
# galchal01
# shorede01
# forsbfi01
# anderjo05
# grigomi01
# riellmo01
# gustaer02
# severda01
# maattol01
# samuehe01
# provoiv01
# carlobr01
# connoky01
# martijo01
# speerbl01
# hanifno01
# mattest02
# severda01
# maattol01
# hudonch01
# simondo01
# lindbpe02
# werenza01
# teravte01
# konectr01
# zachapa01
# lindbpe02
# leipsbr01
# veseyji02
# paquece01
# leierta01
# samuehe01
# hinosvi01
# blandjo01
# faksara01
# beauvan01
# konectr01
# zachapa01
# teravte01
# faksara01
# pelecad01
# werenza01
# sielopa01
# carritr01
# anderjo05
# dumbama01
# grigomi01
# lindhha01
# rantami01
# faksara01
# werenza01
# sielopa01
# smithco01
# poulide01
# anderjo05
# werenza01
# zachapa01
# konectr01
# rantami01
# beauvan01
# grigomi01
# laughsc01
# maattol01
# koekksl01
# samuehe01
# provoiv01
# carlobr01
# connoky01
# malgide01
# gauncbr01
# athanan01
# carrico01
# slavija01
# wilsoto01
# leierta01
# shorede01
# rantami01
# werenza01
# zachapa01
# konectr01
# beauvan01
# mccabja01
# zachapa01
# werenza01
# konectr01
# digiuph01
# beauvan01
# reinhgr01
# bertsch02
# galchal01
# mathemi01
# koekksl01
# leipsbr01
# tiernch01
# riellmo01
# anderjo05
# slavija01
# wilsoto01
# grigomi01
# shorede01
# faksara01
# kosmasc01
# teravte01
# konectr01
# zachapa01
# hudonch01
# skjeibr01
# lindhha01
# troubja01
# kosmasc01
# pearsta01
# mccabja01
# bertsch02
# samuehe01
# mattest02
# connoky01
# kosmasc01
# lindbpe02
# khairju01
# sundqos01
# mcginbr01
# pelecad01
# carritr01
# hudonch01
# lindbpe02
# kosmasc01
# galchal01
# dumbama01
# forsbfi01
# mathemi01
# severda01
# mathemi01
# forsbfi01
# koekksl01
# loovvi01
# woodsbr01
# griffse01
# teravte01
# samuehe01
# mcginbr01
# woodsbr01
# maattol01
# galchal01
# mcginbr01
# digiuph01
# sundqos01
# pearsta01
# riellmo01
# grigomi01
# slavija01
# tiernch01
# wilsoto01
# poulide01
# sielopa01
# leipsbr01
# troubja01
# rantami01
# werenza01
# severda01
# maattol01
# mathemi01
# samuehe01
# simondo01
# kulakbr01
# simondo01
# loovvi01
# gostish01
# woodsbr01
# milleco02
# griffse01
# paquece01
# cecico01
# sissoco01
# huttobe01
# mcdavco01
# connoky01
# anderjo05
# mattest02
# paquece01
# mcginbr01
# mattest02
# sielopa01
# simondo01
# paquece01
# veseyji02
# lindees01
# stephch02
# provoiv01
# kulakbr01
# sielopa01
# simondo01
# severda01
# digiuph01
# speerbl01
# hanifno01
# carritr01
# hudonch01
# forsbfi01
# dumbama01
# galchal01
# maattol01
# hanifno01
# speerbl01
# sissoco01
# provoiv01
# sundqos01
# milleco02
# khairju01
# mcginbr01
# kulakbr01
# hanifno01
# hanifno01
# koekksl01
# lindbpe02
# severda01
# loovvi01
# lindees01
# stephch02
# girgeze01
# mcdavco01
# yakupna01
# shorede01
# athanan01
# gauncbr01
# carrico01
# kosmasc01
# sundqos01
# khairju01
# wilsoto01
# gauncbr01
# shorede01
# athanan01
# carrico01
# slavija01
# kosmasc01
# mathemi01
# troubja01
# lindhha01
# hinosvi01
# konectr01
# teravte01
# beauvan01
# khairju01
# sundqos01
# woodsbr01
# malgide01
# provoiv01
# galchal01
# dumbama01
# shorede01
# forsbfi01
# maattol01
# digiuph01
# mathemi01
# severda01
# maattol01
# griffse01

# %%
df_player_similar = pd.DataFrame(result_lists,columns=['name','goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh'])

# %%
df_player_similar.to_csv('df_player_similar.csv')

# %%
[sum(x) for x in zip(*lists_of_lists)]
# Out:
# [1.1293008249627543,
#  0.10684928444073283,
#  0.0,
#  1.7660933559949372,
#  0.086762786298438838,
#  0.022567454788318998]

# %%
df_player_2009[df_player_2009['name']=='lauriol01']
# Out:
#       season  TOT  age  games_played  pen_min  plus_minus  goals_ev  goals_pp  \
# 279  2012-13  PHI   23            15       34           0         2         0
# 280  2014-15  PHI   25             1       10          -1         0         0
#
#      goals_sh  goals_gw      ...       fenwick_for  fenwick_against  \
# 279         0         2      ...               132              145
# 280         0         0      ...                 6                6
#
#      fenwick_pct  fenwick_rel_pct  on_ice_shot_pct  on_ice_sv_pct  pdo  \
# 279         47.7              3.0             12.1           88.1  100
# 280         50.0             24.1              0.0           80.0   80
#
#      zs_offense_pct  zs_defense_pct  uniqueseason
# 279            42.0            58.0             1
# 280            42.9            57.1             1
#
# [2 rows x 37 columns]

# %%
df_player_2009[df_player_2009['name']=='lauriol01']

# %%
newdf_similar['macenma01'][newdf_similar['macenma01']!=0][:10][0]*df_player_2009[df_player_2009['name']=='lauriol01'][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)
# Out:
# goals_ev      19.668723
# goals_pp       0.000000
# goals_sh       0.000000
# assists_ev     9.834362
# assists_pp     0.000000
# assists_sh     0.000000
# dtype: float64
