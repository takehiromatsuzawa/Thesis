# %%
import pandas as pd
import numpy as np
import os
from sklearn import neighbors
from sklearn import cluster, datasets

# %%
df_similar=pd.read_csv('PCA_Folder/similarity_PG_4.csv',index_col=0)

# %%
df_player_1996=pd.read_csv('df_1996.csv',index_col=0)
df_player_1997=pd.read_csv('df_1997.csv',index_col=0)
df_player_1998=pd.read_csv('df_1998.csv',index_col=0)
df_player_1999=pd.read_csv('df_1999.csv',index_col=0)
df_player_2000=pd.read_csv('df_2000.csv',index_col=0)
df_player_2001=pd.read_csv('df_2001.csv',index_col=0)
df_player_2002=pd.read_csv('df_2002.csv',index_col=0)
df_player_2003=pd.read_csv('df_2003.csv',index_col=0)
df_player_2004=pd.read_csv('df_2004.csv',index_col=0)
df_player_2005=pd.read_csv('df_2005.csv',index_col=0)
df_player_2006=pd.read_csv('df_2006.csv',index_col=0)
df_player_2007=pd.read_csv('df_2007.csv',index_col=0)
df_player_2008=pd.read_csv('df_2008.csv',index_col=0)
df_player_2009=pd.read_csv('df_2009.csv',index_col=0)

df_player_2010=pd.read_csv('df_2010.csv',index_col=0)
df_player_2011=pd.read_csv('df_2011.csv',index_col=0)
df_player_2012=pd.read_csv('df_2012.csv',index_col=0)
df_player_2013=pd.read_csv('df_2013.csv',index_col=0)
df_player_2014=pd.read_csv('df_2014.csv',index_col=0)
df_player_2015=pd.read_csv('df_2015.csv',index_col=0)

# %%
df_player_1996['goals_ev']=df_player_1996['goals_ev']/df_player_1996['games_played']
df_player_1996['goals_pp']=df_player_1996['goals_pp']/df_player_1996['games_played']
df_player_1996['goals_sh']=df_player_1996['goals_sh']/df_player_1996['games_played']
df_player_1996['assists_ev']=df_player_1996['assists_ev']/df_player_1996['games_played']
df_player_1996['assists_pp']=df_player_1996['assists_pp']/df_player_1996['games_played']
df_player_1996['assists_sh']=df_player_1996['assists_sh']/df_player_1996['games_played']

df_player_1997['goals_ev']=df_player_1997['goals_ev']/df_player_1997['games_played']
df_player_1997['goals_pp']=df_player_1997['goals_pp']/df_player_1997['games_played']
df_player_1997['goals_sh']=df_player_1997['goals_sh']/df_player_1997['games_played']
df_player_1997['assists_ev']=df_player_1997['assists_ev']/df_player_1997['games_played']
df_player_1997['assists_pp']=df_player_1997['assists_pp']/df_player_1997['games_played']
df_player_1997['assists_sh']=df_player_1997['assists_sh']/df_player_1997['games_played']

df_player_1998['goals_ev']=df_player_1998['goals_ev']/df_player_1998['games_played']
df_player_1998['goals_pp']=df_player_1998['goals_pp']/df_player_1998['games_played']
df_player_1998['goals_sh']=df_player_1998['goals_sh']/df_player_1998['games_played']
df_player_1998['assists_ev']=df_player_1998['assists_ev']/df_player_1998['games_played']
df_player_1998['assists_pp']=df_player_1998['assists_pp']/df_player_1998['games_played']
df_player_1998['assists_sh']=df_player_1998['assists_sh']/df_player_1998['games_played']

df_player_1999['goals_ev']=df_player_1999['goals_ev']/df_player_1999['games_played']
df_player_1999['goals_pp']=df_player_1999['goals_pp']/df_player_1999['games_played']
df_player_1999['goals_sh']=df_player_1999['goals_sh']/df_player_1999['games_played']
df_player_1999['assists_ev']=df_player_1999['assists_ev']/df_player_1999['games_played']
df_player_1999['assists_pp']=df_player_1999['assists_pp']/df_player_1999['games_played']
df_player_1999['assists_sh']=df_player_1999['assists_sh']/df_player_1999['games_played']

df_player_2000['goals_ev']=df_player_2000['goals_ev']/df_player_2000['games_played']
df_player_2000['goals_pp']=df_player_2000['goals_pp']/df_player_2000['games_played']
df_player_2000['goals_sh']=df_player_2000['goals_sh']/df_player_2000['games_played']
df_player_2000['assists_ev']=df_player_2000['assists_ev']/df_player_2000['games_played']
df_player_2000['assists_pp']=df_player_2000['assists_pp']/df_player_2000['games_played']
df_player_2000['assists_sh']=df_player_2000['assists_sh']/df_player_2000['games_played']

df_player_2001['goals_ev']=df_player_2001['goals_ev']/df_player_2001['games_played']
df_player_2001['goals_pp']=df_player_2001['goals_pp']/df_player_2001['games_played']
df_player_2001['goals_sh']=df_player_2001['goals_sh']/df_player_2001['games_played']
df_player_2001['assists_ev']=df_player_2001['assists_ev']/df_player_2001['games_played']
df_player_2001['assists_pp']=df_player_2001['assists_pp']/df_player_2001['games_played']
df_player_2001['assists_sh']=df_player_2001['assists_sh']/df_player_2001['games_played']

df_player_2002['goals_ev']=df_player_2002['goals_ev']/df_player_2002['games_played']
df_player_2002['goals_pp']=df_player_2002['goals_pp']/df_player_2002['games_played']
df_player_2002['goals_sh']=df_player_2002['goals_sh']/df_player_2002['games_played']
df_player_2002['assists_ev']=df_player_2002['assists_ev']/df_player_2002['games_played']
df_player_2002['assists_pp']=df_player_2002['assists_pp']/df_player_2002['games_played']
df_player_2002['assists_sh']=df_player_2002['assists_sh']/df_player_2002['games_played']

df_player_2003['goals_ev']=df_player_2003['goals_ev']/df_player_2003['games_played']
df_player_2003['goals_pp']=df_player_2003['goals_pp']/df_player_2003['games_played']
df_player_2003['goals_sh']=df_player_2003['goals_sh']/df_player_2003['games_played']
df_player_2003['assists_ev']=df_player_2003['assists_ev']/df_player_2003['games_played']
df_player_2003['assists_pp']=df_player_2003['assists_pp']/df_player_2003['games_played']
df_player_2003['assists_sh']=df_player_2003['assists_sh']/df_player_2003['games_played']

df_player_2004['goals_ev']=df_player_2004['goals_ev']/df_player_2004['games_played']
df_player_2004['goals_pp']=df_player_2004['goals_pp']/df_player_2004['games_played']
df_player_2004['goals_sh']=df_player_2004['goals_sh']/df_player_2004['games_played']
df_player_2004['assists_ev']=df_player_2004['assists_ev']/df_player_2004['games_played']
df_player_2004['assists_pp']=df_player_2004['assists_pp']/df_player_2004['games_played']
df_player_2004['assists_sh']=df_player_2004['assists_sh']/df_player_2004['games_played']

df_player_2005['goals_ev']=df_player_2005['goals_ev']/df_player_2005['games_played']
df_player_2005['goals_pp']=df_player_2005['goals_pp']/df_player_2005['games_played']
df_player_2005['goals_sh']=df_player_2005['goals_sh']/df_player_2005['games_played']
df_player_2005['assists_ev']=df_player_2005['assists_ev']/df_player_2005['games_played']
df_player_2005['assists_pp']=df_player_2005['assists_pp']/df_player_2005['games_played']
df_player_2005['assists_sh']=df_player_2005['assists_sh']/df_player_2005['games_played']

df_player_2006['goals_ev']=df_player_2006['goals_ev']/df_player_2006['games_played']
df_player_2006['goals_pp']=df_player_2006['goals_pp']/df_player_2006['games_played']
df_player_2006['goals_sh']=df_player_2006['goals_sh']/df_player_2006['games_played']
df_player_2006['assists_ev']=df_player_2006['assists_ev']/df_player_2006['games_played']
df_player_2006['assists_pp']=df_player_2006['assists_pp']/df_player_2006['games_played']
df_player_2006['assists_sh']=df_player_2006['assists_sh']/df_player_2006['games_played']

df_player_2007['goals_ev']=df_player_2007['goals_ev']/df_player_2007['games_played']
df_player_2007['goals_pp']=df_player_2007['goals_pp']/df_player_2007['games_played']
df_player_2007['goals_sh']=df_player_2007['goals_sh']/df_player_2007['games_played']
df_player_2007['assists_ev']=df_player_2007['assists_ev']/df_player_2007['games_played']
df_player_2007['assists_pp']=df_player_2007['assists_pp']/df_player_2007['games_played']
df_player_2007['assists_sh']=df_player_2007['assists_sh']/df_player_2007['games_played']

df_player_2008['goals_ev']=df_player_2008['goals_ev']/df_player_2008['games_played']
df_player_2008['goals_pp']=df_player_2008['goals_pp']/df_player_2008['games_played']
df_player_2008['goals_sh']=df_player_2008['goals_sh']/df_player_2008['games_played']
df_player_2008['assists_ev']=df_player_2008['assists_ev']/df_player_2008['games_played']
df_player_2008['assists_pp']=df_player_2008['assists_pp']/df_player_2008['games_played']
df_player_2008['assists_sh']=df_player_2008['assists_sh']/df_player_2008['games_played']

df_player_2009['goals_ev']=df_player_2009['goals_ev']/df_player_2009['games_played']
df_player_2009['goals_pp']=df_player_2009['goals_pp']/df_player_2009['games_played']
df_player_2009['goals_sh']=df_player_2009['goals_sh']/df_player_2009['games_played']
df_player_2009['assists_ev']=df_player_2009['assists_ev']/df_player_2009['games_played']
df_player_2009['assists_pp']=df_player_2009['assists_pp']/df_player_2009['games_played']
df_player_2009['assists_sh']=df_player_2009['assists_sh']/df_player_2009['games_played']

df_player_2010['goals_ev']=df_player_2010['goals_ev']/df_player_2010['games_played']
df_player_2010['goals_pp']=df_player_2010['goals_pp']/df_player_2010['games_played']
df_player_2010['goals_sh']=df_player_2010['goals_sh']/df_player_2010['games_played']
df_player_2010['assists_ev']=df_player_2010['assists_ev']/df_player_2010['games_played']
df_player_2010['assists_pp']=df_player_2010['assists_pp']/df_player_2010['games_played']
df_player_2010['assists_sh']=df_player_2010['assists_sh']/df_player_2010['games_played']

df_player_2011['goals_ev']=df_player_2011['goals_ev']/df_player_2011['games_played']
df_player_2011['goals_pp']=df_player_2011['goals_pp']/df_player_2011['games_played']
df_player_2011['goals_sh']=df_player_2011['goals_sh']/df_player_2011['games_played']
df_player_2011['assists_ev']=df_player_2011['assists_ev']/df_player_2011['games_played']
df_player_2011['assists_pp']=df_player_2011['assists_pp']/df_player_2011['games_played']
df_player_2011['assists_sh']=df_player_2011['assists_sh']/df_player_2011['games_played']

df_player_2012['goals_ev']=df_player_2012['goals_ev']/df_player_2012['games_played']
df_player_2012['goals_pp']=df_player_2012['goals_pp']/df_player_2012['games_played']
df_player_2012['goals_sh']=df_player_2012['goals_sh']/df_player_2012['games_played']
df_player_2012['assists_ev']=df_player_2012['assists_ev']/df_player_2012['games_played']
df_player_2012['assists_pp']=df_player_2012['assists_pp']/df_player_2012['games_played']
df_player_2012['assists_sh']=df_player_2012['assists_sh']/df_player_2012['games_played']

df_player_2013['goals_ev']=df_player_2013['goals_ev']/df_player_2013['games_played']
df_player_2013['goals_pp']=df_player_2013['goals_pp']/df_player_2013['games_played']
df_player_2013['goals_sh']=df_player_2013['goals_sh']/df_player_2013['games_played']
df_player_2013['assists_ev']=df_player_2013['assists_ev']/df_player_2013['games_played']
df_player_2013['assists_pp']=df_player_2013['assists_pp']/df_player_2013['games_played']
df_player_2013['assists_sh']=df_player_2013['assists_sh']/df_player_2013['games_played']

df_player_2014['goals_ev']=df_player_2014['goals_ev']/df_player_2014['games_played']
df_player_2014['goals_pp']=df_player_2014['goals_pp']/df_player_2014['games_played']
df_player_2014['goals_sh']=df_player_2014['goals_sh']/df_player_2014['games_played']
df_player_2014['assists_ev']=df_player_2014['assists_ev']/df_player_2014['games_played']
df_player_2014['assists_pp']=df_player_2014['assists_pp']/df_player_2014['games_played']
df_player_2014['assists_sh']=df_player_2014['assists_sh']/df_player_2014['games_played']

df_player_2015['goals_ev']=df_player_2015['goals_ev']/df_player_2015['games_played']
df_player_2015['goals_pp']=df_player_2015['goals_pp']/df_player_2015['games_played']
df_player_2015['goals_sh']=df_player_2015['goals_sh']/df_player_2015['games_played']
df_player_2015['assists_ev']=df_player_2015['assists_ev']/df_player_2015['games_played']
df_player_2015['assists_pp']=df_player_2015['assists_pp']/df_player_2015['games_played']
df_player_2015['assists_sh']=df_player_2015['assists_sh']/df_player_2015['games_played']

# %%
df_player_1996['goals_ev']=df_player_1996['goals_ev']/df_player_1996['games_played']
df_player_1996['goals_pp']=df_player_1996['goals_pp']/df_player_1996['games_played']
df_player_1996['goals_sh']=df_player_1996['goals_sh']/df_player_1996['games_played']
df_player_1996['assists_ev']=df_player_1996['assists_ev']/df_player_1996['games_played']
df_player_1996['assists_pp']=df_player_1996['assists_pp']/df_player_1996['games_played']
df_player_1996['assists_sh']=df_player_1996['assists_sh']/df_player_1996['games_played']

df_player_1997['goals_ev']=df_player_1997['goals_ev']/df_player_1997['games_played']
df_player_1997['goals_pp']=df_player_1997['goals_pp']/df_player_1997['games_played']
df_player_1997['goals_sh']=df_player_1997['goals_sh']/df_player_1997['games_played']
df_player_1997['assists_ev']=df_player_1997['assists_ev']/df_player_1997['games_played']
df_player_1997['assists_pp']=df_player_1997['assists_pp']/df_player_1997['games_played']
df_player_1997['assists_sh']=df_player_1997['assists_sh']/df_player_1997['games_played']

df_player_1998['goals_ev']=df_player_1998['goals_ev']/df_player_1998['games_played']
df_player_1998['goals_pp']=df_player_1998['goals_pp']/df_player_1998['games_played']
df_player_1998['goals_sh']=df_player_1998['goals_sh']/df_player_1998['games_played']
df_player_1998['assists_ev']=df_player_1998['assists_ev']/df_player_1998['games_played']
df_player_1998['assists_pp']=df_player_1998['assists_pp']/df_player_1998['games_played']
df_player_1998['assists_sh']=df_player_1998['assists_sh']/df_player_1998['games_played']

df_player_1999['goals_ev']=df_player_1999['goals_ev']/df_player_1999['games_played']
df_player_1999['goals_pp']=df_player_1999['goals_pp']/df_player_1999['games_played']
df_player_1999['goals_sh']=df_player_1999['goals_sh']/df_player_1999['games_played']
df_player_1999['assists_ev']=df_player_1999['assists_ev']/df_player_1999['games_played']
df_player_1999['assists_pp']=df_player_1999['assists_pp']/df_player_1999['games_played']
df_player_1999['assists_sh']=df_player_1999['assists_sh']/df_player_1999['games_played']

df_player_2000['goals_ev']=df_player_2000['goals_ev']/df_player_2000['games_played']
df_player_2000['goals_pp']=df_player_2000['goals_pp']/df_player_2000['games_played']
df_player_2000['goals_sh']=df_player_2000['goals_sh']/df_player_2000['games_played']
df_player_2000['assists_ev']=df_player_2000['assists_ev']/df_player_2000['games_played']
df_player_2000['assists_pp']=df_player_2000['assists_pp']/df_player_2000['games_played']
df_player_2000['assists_sh']=df_player_2000['assists_sh']/df_player_2000['games_played']

df_player_2001['goals_ev']=df_player_2001['goals_ev']/df_player_2001['games_played']
df_player_2001['goals_pp']=df_player_2001['goals_pp']/df_player_2001['games_played']
df_player_2001['goals_sh']=df_player_2001['goals_sh']/df_player_2001['games_played']
df_player_2001['assists_ev']=df_player_2001['assists_ev']/df_player_2001['games_played']
df_player_2001['assists_pp']=df_player_2001['assists_pp']/df_player_2001['games_played']
df_player_2001['assists_sh']=df_player_2001['assists_sh']/df_player_2001['games_played']

df_player_2002['goals_ev']=df_player_2002['goals_ev']/df_player_2002['games_played']
df_player_2002['goals_pp']=df_player_2002['goals_pp']/df_player_2002['games_played']
df_player_2002['goals_sh']=df_player_2002['goals_sh']/df_player_2002['games_played']
df_player_2002['assists_ev']=df_player_2002['assists_ev']/df_player_2002['games_played']
df_player_2002['assists_pp']=df_player_2002['assists_pp']/df_player_2002['games_played']
df_player_2002['assists_sh']=df_player_2002['assists_sh']/df_player_2002['games_played']

df_player_2003['goals_ev']=df_player_2003['goals_ev']/df_player_2003['games_played']
df_player_2003['goals_pp']=df_player_2003['goals_pp']/df_player_2003['games_played']
df_player_2003['goals_sh']=df_player_2003['goals_sh']/df_player_2003['games_played']
df_player_2003['assists_ev']=df_player_2003['assists_ev']/df_player_2003['games_played']
df_player_2003['assists_pp']=df_player_2003['assists_pp']/df_player_2003['games_played']
df_player_2003['assists_sh']=df_player_2003['assists_sh']/df_player_2003['games_played']

df_player_2004['goals_ev']=df_player_2004['goals_ev']/df_player_2004['games_played']
df_player_2004['goals_pp']=df_player_2004['goals_pp']/df_player_2004['games_played']
df_player_2004['goals_sh']=df_player_2004['goals_sh']/df_player_2004['games_played']
df_player_2004['assists_ev']=df_player_2004['assists_ev']/df_player_2004['games_played']
df_player_2004['assists_pp']=df_player_2004['assists_pp']/df_player_2004['games_played']
df_player_2004['assists_sh']=df_player_2004['assists_sh']/df_player_2004['games_played']

df_player_2005['goals_ev']=df_player_2005['goals_ev']/df_player_2005['games_played']
df_player_2005['goals_pp']=df_player_2005['goals_pp']/df_player_2005['games_played']
df_player_2005['goals_sh']=df_player_2005['goals_sh']/df_player_2005['games_played']
df_player_2005['assists_ev']=df_player_2005['assists_ev']/df_player_2005['games_played']
df_player_2005['assists_pp']=df_player_2005['assists_pp']/df_player_2005['games_played']
df_player_2005['assists_sh']=df_player_2005['assists_sh']/df_player_2005['games_played']

df_player_2006['goals_ev']=df_player_2006['goals_ev']/df_player_2006['games_played']
df_player_2006['goals_pp']=df_player_2006['goals_pp']/df_player_2006['games_played']
df_player_2006['goals_sh']=df_player_2006['goals_sh']/df_player_2006['games_played']
df_player_2006['assists_ev']=df_player_2006['assists_ev']/df_player_2006['games_played']
df_player_2006['assists_pp']=df_player_2006['assists_pp']/df_player_2006['games_played']
df_player_2006['assists_sh']=df_player_2006['assists_sh']/df_player_2006['games_played']

df_player_2007['goals_ev']=df_player_2007['goals_ev']/df_player_2007['games_played']
df_player_2007['goals_pp']=df_player_2007['goals_pp']/df_player_2007['games_played']
df_player_2007['goals_sh']=df_player_2007['goals_sh']/df_player_2007['games_played']
df_player_2007['assists_ev']=df_player_2007['assists_ev']/df_player_2007['games_played']
df_player_2007['assists_pp']=df_player_2007['assists_pp']/df_player_2007['games_played']
df_player_2007['assists_sh']=df_player_2007['assists_sh']/df_player_2007['games_played']

df_player_2008['goals_ev']=df_player_2008['goals_ev']/df_player_2008['games_played']
df_player_2008['goals_pp']=df_player_2008['goals_pp']/df_player_2008['games_played']
df_player_2008['goals_sh']=df_player_2008['goals_sh']/df_player_2008['games_played']
df_player_2008['assists_ev']=df_player_2008['assists_ev']/df_player_2008['games_played']
df_player_2008['assists_pp']=df_player_2008['assists_pp']/df_player_2008['games_played']
df_player_2008['assists_sh']=df_player_2008['assists_sh']/df_player_2008['games_played']

df_player_2009['goals_ev']=df_player_2009['goals_ev']/df_player_2009['games_played']
df_player_2009['goals_pp']=df_player_2009['goals_pp']/df_player_2009['games_played']
df_player_2009['goals_sh']=df_player_2009['goals_sh']/df_player_2009['games_played']
df_player_2009['assists_ev']=df_player_2009['assists_ev']/df_player_2009['games_played']
df_player_2009['assists_pp']=df_player_2009['assists_pp']/df_player_2009['games_played']
df_player_2009['assists_sh']=df_player_2009['assists_sh']/df_player_2009['games_played']

df_player_2010['goals_ev']=df_player_2010['goals_ev']/df_player_2010['games_played']
df_player_2010['goals_pp']=df_player_2010['goals_pp']/df_player_2010['games_played']
df_player_2010['goals_sh']=df_player_2010['goals_sh']/df_player_2010['games_played']
df_player_2010['assists_ev']=df_player_2010['assists_ev']/df_player_2010['games_played']
df_player_2010['assists_pp']=df_player_2010['assists_pp']/df_player_2010['games_played']
df_player_2010['assists_sh']=df_player_2010['assists_sh']/df_player_2010['games_played']

df_player_2011['goals_ev']=df_player_2011['goals_ev']/df_player_2011['games_played']
df_player_2011['goals_pp']=df_player_2011['goals_pp']/df_player_2011['games_played']
df_player_2011['goals_sh']=df_player_2011['goals_sh']/df_player_2011['games_played']
df_player_2011['assists_ev']=df_player_2011['assists_ev']/df_player_2011['games_played']
df_player_2011['assists_pp']=df_player_2011['assists_pp']/df_player_2011['games_played']
df_player_2011['assists_sh']=df_player_2011['assists_sh']/df_player_2011['games_played']

df_player_2012['goals_ev']=df_player_2012['goals_ev']/df_player_2012['games_played']
df_player_2012['goals_pp']=df_player_2012['goals_pp']/df_player_2012['games_played']
df_player_2012['goals_sh']=df_player_2012['goals_sh']/df_player_2012['games_played']
df_player_2012['assists_ev']=df_player_2012['assists_ev']/df_player_2012['games_played']
df_player_2012['assists_pp']=df_player_2012['assists_pp']/df_player_2012['games_played']
df_player_2012['assists_sh']=df_player_2012['assists_sh']/df_player_2012['games_played']

df_player_2013['goals_ev']=df_player_2013['goals_ev']/df_player_2013['games_played']
df_player_2013['goals_pp']=df_player_2013['goals_pp']/df_player_2013['games_played']
df_player_2013['goals_sh']=df_player_2013['goals_sh']/df_player_2013['games_played']
df_player_2013['assists_ev']=df_player_2013['assists_ev']/df_player_2013['games_played']
df_player_2013['assists_pp']=df_player_2013['assists_pp']/df_player_2013['games_played']
df_player_2013['assists_sh']=df_player_2013['assists_sh']/df_player_2013['games_played']

df_player_2014['goals_ev']=df_player_2014['goals_ev']/df_player_2014['games_played']
df_player_2014['goals_pp']=df_player_2014['goals_pp']/df_player_2014['games_played']
df_player_2014['goals_sh']=df_player_2014['goals_sh']/df_player_2014['games_played']
df_player_2014['assists_ev']=df_player_2014['assists_ev']/df_player_2014['games_played']
df_player_2014['assists_pp']=df_player_2014['assists_pp']/df_player_2014['games_played']
df_player_2014['assists_sh']=df_player_2014['assists_sh']/df_player_2014['games_played']

df_player_2015['goals_ev']=df_player_2015['goals_ev']/df_player_2015['games_played']
df_player_2015['goals_pp']=df_player_2015['goals_pp']/df_player_2015['games_played']
df_player_2015['goals_sh']=df_player_2015['goals_sh']/df_player_2015['games_played']
df_player_2015['assists_ev']=df_player_2015['assists_ev']/df_player_2015['games_played']
df_player_2015['assists_pp']=df_player_2015['assists_pp']/df_player_2015['games_played']
df_player_2015['assists_sh']=df_player_2015['assists_sh']/df_player_2015['games_played']

# %%
df_player_year=pd.read_csv('player_year.csv',index_col=0)

# %%
df_player_year.head()
# Out:
#         name  year
# 0  adamscr01  1996
# 1  ashamar01  1996
# 2  beginst01  1996
# 3  belaner01  1996
# 4  bouleje01  1996

# %%
dict_player_year = dict(zip(df_player_year.name, df_player_year.year))

# %%
def sorted(s, num):
    tmp = s.order(ascending=False)[:num]
    tmp.index = range(num)
    return tmp

# %%
result_lists=[]
for j in range(0,len(df_similar)):
    cur_play=df_similar.columns[j]
    newdf_similar=df_similar.sort(cur_play, ascending=True)

    names=newdf_similar[cur_play][newdf_similar[cur_play]!=0][:10].index
    all_value=(100/newdf_similar[cur_play][newdf_similar[cur_play]!=0][:10])/sum(100/newdf_similar[cur_play][newdf_similar[cur_play]!=0][:10])
    lists_of_lists=[]
    
    for i in range(0,10):
        if names[i] in dict_player_year:
            if dict_player_year[names[i]]==1996:
                result = map(lambda x: x * all_value[i], list(df_player_1996[df_player_1996['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==1997:
                result = map(lambda x: x * all_value[i], list(df_player_1997[df_player_1997['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==1998:
                result = map(lambda x: x * all_value[i], list(df_player_1998[df_player_1998['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==1999:
                result = map(lambda x: x * all_value[i], list(df_player_1999[df_player_1999['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2000:
                result = map(lambda x: x * all_value[i], list(df_player_2000[df_player_2000['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2001:
                result = map(lambda x: x * all_value[i], list(df_player_2001[df_player_2001['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2002:
                result = map(lambda x: x * all_value[i], list(df_player_2002[df_player_2002['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2003:
                result = map(lambda x: x * all_value[i], list(df_player_2003[df_player_2003['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2004:
                result = map(lambda x: x * all_value[i], list(df_player_2004[df_player_2004['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2005:
                result = map(lambda x: x * all_value[i], list(df_player_2005[df_player_2005['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2006:
                result = map(lambda x: x * all_value[i], list(df_player_2006[df_player_2006['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2007:
                result = map(lambda x: x * all_value[i], list(df_player_2007[df_player_2007['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2008:
                result = map(lambda x: x * all_value[i], list(df_player_2008[df_player_2008['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2009:
                result = map(lambda x: x * all_value[i], list(df_player_2009[df_player_2009['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2010:
                result = map(lambda x: x * all_value[i], list(df_player_2010[df_player_2010['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2011:
                result = map(lambda x: x * all_value[i], list(df_player_2011[df_player_2011['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2012:
                result = map(lambda x: x * all_value[i], list(df_player_2012[df_player_2012['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2013:
                result = map(lambda x: x * all_value[i], list(df_player_2013[df_player_2013['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2014:
                result = map(lambda x: x * all_value[i], list(df_player_2014[df_player_2014['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)

            if dict_player_year[names[i]]==2015:
                result = map(lambda x: x * all_value[i], list(df_player_2015[df_player_2015['name']==names[i]][['goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh']].mean(axis=0)))
                lists_of_lists.append(result)
        else:
            print names[i]
            
    summList=[sum(x) for x in zip(*lists_of_lists)]   
    summList.insert(0,cur_play)
    #print summList
    result_lists.append(summList)
# Out:
# yakupna01
# girgeze01
# dumbama01
# martijo01
# blandjo01
# athanan01
# kulakbr01
# hinosvi01
# lindees01
# reinhgr01
# hinosvi01
# galchal01
# hinosvi01
# digiuph01
# paquece01
# beauvan01
# dumbama01
# zachapa01
# pearsta01
# blandjo01
# athanan01
# teravte01
# rantami01
# slavija01
# carrico01
# loovvi01
# gauncbr01
# mcginbr01
# khairju01
# carrico01
# hudonch01
# leierta01
# shorede01
# parayco01
# huttobe01
# faksara01
# blandjo01
# digiuph01
# mcginbr01
# gustaer02
# lindhha01
# mcdavco01
# yakupna01
# troubja01
# yakupna01
# wilsoto01
# slavija01
# reinhgr01
# larssja01
# hinosvi01
# lindees01
# huttobe01
# griffse01
# griffse01
# mccabja01
# mcginbr01
# sundqos01
# leipsbr01
# murrary01
# teravte01
# laughsc01
# hinosvi01
# lindees01
# digiuph01
# reinhgr01
# poulide01
# gustaer02
# crousla01
# rantami01
# anderjo05
# hinosvi01
# girgeze01
# mathemi01
# stephch02
# carritr01
# mcginbr01
# griffse01
# huttobe01
# cecico01
# kulakbr01
# shorede01
# mccabja01
# mattest02
# ...

# %%
df_player_similar = pd.DataFrame(result_lists,columns=['name','goals_ev','goals_pp','goals_sh','assists_ev','assists_pp','assists_sh'])

# %%
df_player_similar.to_csv('df_player_similar_PG_4.csv')

# %%
df_player_similar
# Out:
#            name  goals_ev  goals_pp  goals_sh  assists_ev  assists_pp  \
# 0     macenma01  0.003697  0.000019  0.001475    0.006466    0.000104
# 1     staffdr01  0.002484  0.001294  0.000074    0.005133    0.001713
# 2     rangepa01  0.009219  0.000839  0.000047    0.004299    0.000652
# 3     collije01  0.003451  0.000668  0.000000    0.019822    0.000791
# 4     fransco01  0.001832  0.000480  0.000194    0.005026    0.001065
# 5     scevico01  0.001598  0.000580  0.000045    0.012861    0.001356
# 6     fabbrro01  0.002317  0.000885  0.000028    0.003866    0.001313
# 7     brodzky01  0.001591  0.000366  0.000083    0.003205    0.000864
# 8     richami02  0.001714  0.001011  0.000021    0.007630    0.005226
# 9     jurcoto01  0.001066  0.000088  0.000037    0.003033    0.000151
# 10    molleos01  0.002469  0.000603  0.000015    0.005851    0.000823
# 11    calvema01  0.000487  0.000177  0.000024    0.030312    0.003182
# ...
